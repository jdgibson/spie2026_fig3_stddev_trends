# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2019-07-01 00:00:00'
end_datetime = '2019-07-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 17:13:19
# Analysis period: 2019-07-01 00:00:00 to 2019-07-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2019-07-01 00:00:00 to 2019-07-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1561964400000, end_timestamp_ms=1564642799000
# Retrieved 2455241 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 175 records, 2019-07-12 10:45:35.826000 to 2019-07-29 20:19:40.191000
#   BINOSPEC: 829989 records, 2019-07-01 00:00:00.008000 to 2019-07-10 16:48:17.148000
#   HECTO: 1625077 records, 2019-07-10 16:48:18.891000 to 2019-07-31 23:59:58.874000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2019-07-01 00:00:00.008000
#     Last observed:  2019-07-10 16:48:17.148000
#     Duration:       9 days, 16:48:17.140000
#
#   HECTO:
#     First observed: 2019-07-10 16:48:18.891000
#     Last observed:  2019-07-31 23:59:58.874000
#     Duration:       21 days, 7:11:39.983000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-07-01 00:00:00 to 2019-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1561964400000, end_timestamp_ms=1564642799000, instrument=NA
# Retrieved 175 records from hexapod_mini_instrument table
# Processed 175 instrument records
#
# Identified 4 observing runs:
#   Run 1: 2019-07-12 17:45:35.826000 to 2019-07-12 17:45:54.581000 (duration: 0 days 00:00:18.755000)
#   Run 2: 2019-07-16 22:44:09.635000 to 2019-07-16 23:43:03.333000 (duration: 0 days 00:58:53.698000)
#   Run 3: 2019-07-17 13:39:04.880000 to 2019-07-17 13:39:24.868000 (duration: 0 days 00:00:19.988000)
#   Run 4: 2019-07-30 03:03:05.510000 to 2019-07-30 03:19:40.191000 (duration: 0 days 00:16:34.681000)
#   ✓ NA: 4 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-07-01 00:00:00 to 2019-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1561964400000, end_timestamp_ms=1564642799000, instrument=binospec
# Retrieved 829989 records from hexapod_mini_instrument table
# Processed 829989 instrument records
# Identified 1 observing runs:
#   Run 1: 2019-07-01 07:00:00.008000 to 2019-07-10 23:48:17.148000 (duration: 9 days 16:48:17.140000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-07-01 00:00:00 to 2019-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1561964400000, end_timestamp_ms=1564642799000, instrument=hecto
# Retrieved 1625077 records from hexapod_mini_instrument table
# Processed 1625077 instrument records
# Identified 5 observing runs:
#   Run 1: 2019-07-10 23:48:18.891000 to 2019-07-12 15:04:01.405000 (duration: 1 days 15:15:42.514000)
#   Run 2: 2019-07-12 17:45:54.626000 to 2019-07-16 21:35:30.175000 (duration: 4 days 03:49:35.549000)
#   Run 3: 2019-07-16 22:48:04.524000 to 2019-07-18 15:17:20.126000 (duration: 1 days 16:29:15.602000)
#   Run 4: 2019-07-19 19:21:04.687000 to 2019-07-19 20:43:08.274000 (duration: 0 days 01:22:03.587000)
#   Run 5: 2019-07-19 21:53:31.967000 to 2019-08-01 06:59:58.874000 (duration: 12 days 09:06:26.907000)
#   ✓ HECTO: 5 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 4 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:18.755000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:58:53.698000 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:00:19.988000 is less than 1.0 hours)
#   Run 4: Skipped (duration 0 days 00:16:34.681000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2019-07-01 07:00:00.008000 to 2019-07-10 23:48:17.148000
#     Duration: 9 days 16:48:17.140000
#     Filtered 53866 points in 10s intervals with variance >= 2.0" arcsec (retained 98.6%)
#     Retrieved 3769492 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0742" Std=0.0758" Min=0.0000" Max=1.1874"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4104" Std=0.8834" Min=-2.6472" Max=1.9957"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1004565 points:
#       Mean=0.0845" Std=0.0779" Min=0.0000" Max=1.2105"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1004565 points:
#       Mean=0.8725" Std=0.3703" Min=-2.0692" Max=1.9957"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2448118 points:
#       Mean=0.0747" Std=0.0800" Min=0.0000" Max=1.1327"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2448118 points:
#       Mean=-0.9744" Std=0.3308" Min=-2.6472" Max=1.7239"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 5 observing run(s) for hecto:
#   Run 1: 2019-07-10 23:48:18.891000 to 2019-07-12 15:04:01.405000
#     Duration: 1 days 15:15:42.514000
#     Filtered 6000 points in 10s intervals with variance >= 2.0" arcsec (retained 95.8%)
#     Retrieved 144000 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0372" Std=0.0251" Min=0.0000" Max=0.2609"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.4282" Std=0.3130" Min=-0.2268" Max=1.1671"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 95949 points:
#       Mean=0.0458" Std=0.0247" Min=0.0092" Max=0.2625"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 95949 points:
#       Mean=0.5854" Std=0.2209" Min=-0.1887" Max=1.1671"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2912 points:
#       Mean=0.0338" Std=0.0107" Min=0.0102" Max=0.0777"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2912 points:
#       Mean=-0.0688" Std=0.0446" Min=-0.1965" Max=0.1122"
#   Run 2: 2019-07-12 17:45:54.626000 to 2019-07-16 21:35:30.175000
#     Duration: 4 days 03:49:35.549000
#     Filtered 30605 points in 10s intervals with variance >= 2.0" arcsec (retained 94.4%)
#     Retrieved 551308 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0445" Std=0.0566" Min=0.0000" Max=1.0604"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.4989" Std=0.7528" Min=-1.8767" Max=2.4691"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 408471 points:
#       Mean=0.0318" Std=0.0365" Min=0.0000" Max=1.2479"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 408471 points:
#       Mean=0.8185" Std=0.4196" Min=-1.8767" Max=2.4691"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 86387 points:
#       Mean=0.0971" Std=0.0646" Min=0.0181" Max=0.6682"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 86387 points:
#       Mean=-0.9274" Std=0.1488" Min=-1.5875" Max=1.2627"
#   Run 3: 2019-07-16 22:48:04.524000 to 2019-07-18 15:17:20.126000
#     Duration: 1 days 16:29:15.602000
#     No valid RMS records after filtering
#   Run 4: 2019-07-19 19:21:04.687000 to 2019-07-19 20:43:08.274000
#     Duration: 0 days 01:22:03.587000
#     No valid RMS records after filtering
#   Run 5: 2019-07-19 21:53:31.967000 to 2019-08-01 06:59:58.874000
#     Duration: 12 days 09:06:26.907000
#     No valid RMS records after filtering
#
# Successfully analyzed 2 run(s) for hecto
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20190701_070000_to_20190710_234817.json
# ✓ hecto Run 1: hecto_20190710_234818_to_20190712_150401.json
# ✓ hecto Run 2: hecto_20190712_174554_to_20190716_213530.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30048
#   Timestamps: 30048
#   Rolling StdDev: 30048
#   Altitudes: 30048
#   Alt Velocities: 30048
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30138
#   Timestamps: 30138
#   Rolling StdDev: 30138
#   Altitudes: 30138
#   Alt Velocities: 30138
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30102
#   Timestamps: 30102
#   Rolling StdDev: 30102
#   Altitudes: 30102
#   Alt Velocities: 30102
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30402
#   Timestamps: 30402
#   Rolling StdDev: 30402
#   Altitudes: 30402
#   Alt Velocities: 30402
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30267
#   Timestamps: 30267
#   Rolling StdDev: 30267
#   Altitudes: 30267
#   Alt Velocities: 30267
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 33489
#   Timestamps: 33489
#   Rolling StdDev: 33489
#   Altitudes: 33489
#   Alt Velocities: 33489
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 17:13:19
# End DateTime:   2026-02-12 17:20:20
# Elapsed Time:   0h 7m 0s
# ================================================================================
