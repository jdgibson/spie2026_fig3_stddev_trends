# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2025-08-01 00:00:00'
end_datetime = '2025-08-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 22:33:56
# Analysis period: 2025-08-01 00:00:00 to 2025-08-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2025-08-01 00:00:00 to 2025-08-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1754031600000, end_timestamp_ms=1756709999000
# Retrieved 810633 total records from hexapod_mini_instrument
# Found 2 unique instrument(s)
#   NA: 252618 records, 2025-08-01 00:00:01.356000 to 2025-08-15 15:04:33.414000
#   BINOSPEC: 558015 records, 2025-08-15 15:04:33.501000 to 2025-08-31 23:59:58.818000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2025-08-15 15:04:33.501000
#     Last observed:  2025-08-31 23:59:58.818000
#     Duration:       16 days, 8:55:25.317000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-08-01 00:00:00 to 2025-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1754031600000, end_timestamp_ms=1756709999000, instrument=NA
# Retrieved 252618 records from hexapod_mini_instrument table
# Processed 252618 instrument records
# Identified 1 observing runs:
#   Run 1: 2025-08-01 07:00:01.356000 to 2025-08-15 22:04:33.414000 (duration: 14 days 15:04:32.058000)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-08-01 00:00:00 to 2025-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1754031600000, end_timestamp_ms=1756709999000, instrument=binospec
# Retrieved 558015 records from hexapod_mini_instrument table
# Processed 558015 instrument records
# Identified 1 observing runs:
#   Run 1: 2025-08-15 22:04:33.501000 to 2025-09-01 06:59:58.818000 (duration: 16 days 08:55:25.317000)
#   ✓ BINOSPEC: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: 2025-08-01 07:00:01.356000 to 2025-08-15 22:04:33.414000
#     Duration: 14 days 15:04:32.058000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2025-08-15 22:04:33.501000 to 2025-09-01 06:59:58.818000
#     Duration: 16 days 08:55:25.317000
#     Filtered 121990 points in 10s intervals with variance >= 2.0" arcsec (retained 97.1%)
#     Retrieved 4232397 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0735" Std=0.0757" Min=0.0000" Max=1.3123"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1579" Std=0.9223" Min=-2.3651" Max=2.8409"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1595594 points:
#       Mean=0.0748" Std=0.0656" Min=0.0000" Max=1.3120"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1595594 points:
#       Mean=0.5407" Std=0.6898" Min=-2.3651" Max=2.8409"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2007320 points:
#       Mean=0.0698" Std=0.0633" Min=0.0000" Max=1.3150"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2007320 points:
#       Mean=-0.7370" Std=0.6757" Min=-2.3633" Max=2.3244"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 1
#   BINOSPEC: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20250815_220433_to_20250901_065958.json
#
# ✓ Saved statistics for 1 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30003
#   Timestamps: 30003
#   Rolling StdDev: 30003
#   Altitudes: 30003
#   Alt Velocities: 30003
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30108
#   Timestamps: 30108
#   Rolling StdDev: 30108
#   Altitudes: 30108
#   Alt Velocities: 30108
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30111
#   Timestamps: 30111
#   Rolling StdDev: 30111
#   Altitudes: 30111
#   Alt Velocities: 30111
# ================================================================================
# Generated 3 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 22:33:56
# End DateTime:   2026-02-12 22:41:13
# Elapsed Time:   0h 7m 17s
# ================================================================================
