# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2020-07-01 00:00:00'
end_datetime = '2020-07-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 17:54:27
# Analysis period: 2020-07-01 00:00:00 to 2020-07-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2020-07-01 00:00:00 to 2020-07-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1593586800000, end_timestamp_ms=1596265199000
# Retrieved 2497785 total records from hexapod_mini_instrument
# Found 4 unique instrument(s)
#   1: 3 records, 2020-07-31 12:16:56.026000 to 2020-07-31 12:19:17.245000
#   NA: 6 records, 2020-07-13 02:01:05.236000 to 2020-07-28 12:28:19.554000
#   BINOSPEC: 1830589 records, 2020-07-07 14:44:23.117000 to 2020-07-31 23:59:54.950000
#   HECTO: 667187 records, 2020-07-01 00:00:00.206000 to 2020-07-07 14:44:22.079000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   1:
#     First observed: 2020-07-31 12:16:56.026000
#     Last observed:  2020-07-31 12:19:17.245000
#     Duration:       0:02:21.219000
#
#   BINOSPEC:
#     First observed: 2020-07-07 14:44:23.117000
#     Last observed:  2020-07-31 23:59:54.950000
#     Duration:       24 days, 9:15:31.833000
#
#   HECTO:
#     First observed: 2020-07-01 00:00:00.206000
#     Last observed:  2020-07-07 14:44:22.079000
#     Duration:       6 days, 14:44:21.873000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-07-01 00:00:00 to 2020-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1593586800000, end_timestamp_ms=1596265199000, instrument=1
# Retrieved 3 records from hexapod_mini_instrument table
# Processed 3 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2020-07-31 19:16:56.026000 to 2020-07-31 19:19:17.245000 (duration: 0 days 00:02:21.219000)
#   ✓ 1: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-07-01 00:00:00 to 2020-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1593586800000, end_timestamp_ms=1596265199000, instrument=NA
# Retrieved 6 records from hexapod_mini_instrument table
# Processed 6 instrument records
#
# Identified 3 observing runs:
#   Run 1: 2020-07-13 09:01:05.236000 to 2020-07-13 09:01:05.236000 (duration: 0 days 00:00:00)
#   Run 2: 2020-07-28 13:47:39.100000 to 2020-07-28 13:47:44.203000 (duration: 0 days 00:00:05.103000)
#   Run 3: 2020-07-28 19:26:07.919000 to 2020-07-28 19:28:19.554000 (duration: 0 days 00:02:11.635000)
#   ✓ NA: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-07-01 00:00:00 to 2020-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1593586800000, end_timestamp_ms=1596265199000, instrument=binospec
# Retrieved 1830589 records from hexapod_mini_instrument table
# Processed 1830589 instrument records
# Identified 1 observing runs:
#   Run 1: 2020-07-07 21:44:23.117000 to 2020-08-01 06:59:54.950000 (duration: 24 days 09:15:31.833000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-07-01 00:00:00 to 2020-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1593586800000, end_timestamp_ms=1596265199000, instrument=hecto
# Retrieved 667187 records from hexapod_mini_instrument table
# Processed 667187 instrument records
# Identified 1 observing runs:
#   Run 1: 2020-07-01 07:00:00.206000 to 2020-07-07 21:44:22.079000 (duration: 6 days 14:44:21.873000)
#   ✓ HECTO: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: 1
# ======================================================================
# Analyzing 1 observing run(s) for 1:
#   Run 1: Skipped (duration 0 days 00:02:21.219000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 3 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:05.103000 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:02:11.635000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2020-07-07 21:44:23.117000 to 2020-08-01 06:59:54.950000
#     Duration: 24 days 09:15:31.833000
#     Filtered 34838 points in 10s intervals with variance >= 2.0" arcsec (retained 98.2%)
#     Retrieved 1933953 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0648" Std=0.0544" Min=0.0000" Max=1.2646"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2961" Std=0.8799" Min=-2.5404" Max=2.7753"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 519445 points:
#       Mean=0.0633" Std=0.0498" Min=0.0000" Max=0.8159"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 519445 points:
#       Mean=0.9941" Std=0.3649" Min=-1.3543" Max=2.7753"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1237882 points:
#       Mean=0.0680" Std=0.0537" Min=0.0000" Max=1.1004"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1237882 points:
#       Mean=-0.8585" Std=0.3182" Min=-2.5404" Max=1.5154"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2020-07-01 07:00:00.206000 to 2020-07-07 21:44:22.079000
#     Duration: 6 days 14:44:21.873000
#     Filtered 42470 points in 10s intervals with variance >= 2.0" arcsec (retained 97.9%)
#     Retrieved 2071188 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0727" Std=0.0594" Min=0.0000" Max=1.1323"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.5387" Std=0.7953" Min=-2.4800" Max=1.8370"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 517358 points:
#       Mean=0.0719" Std=0.0541" Min=0.0000" Max=0.7195"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 517358 points:
#       Mean=0.6529" Std=0.2772" Min=-1.6498" Max=1.8370"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1375603 points:
#       Mean=0.0771" Std=0.0628" Min=0.0000" Max=0.8656"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1375603 points:
#       Mean=-1.0387" Std=0.2780" Min=-2.4800" Max=1.2573"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20200707_214423_to_20200801_065954.json
# ✓ hecto Run 1: hecto_20200701_070000_to_20200707_214422.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30147
#   Timestamps: 30147
#   Rolling StdDev: 30147
#   Altitudes: 30147
#   Alt Velocities: 30147
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30558
#   Timestamps: 30558
#   Rolling StdDev: 30558
#   Altitudes: 30558
#   Alt Velocities: 30558
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30195
#   Timestamps: 30195
#   Rolling StdDev: 30195
#   Altitudes: 30195
#   Alt Velocities: 30195
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30132
#   Timestamps: 30132
#   Rolling StdDev: 30132
#   Altitudes: 30132
#   Alt Velocities: 30132
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30435
#   Timestamps: 30435
#   Rolling StdDev: 30435
#   Altitudes: 30435
#   Alt Velocities: 30435
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30123
#   Timestamps: 30123
#   Rolling StdDev: 30123
#   Altitudes: 30123
#   Alt Velocities: 30123
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 17:54:27
# End DateTime:   2026-02-12 18:01:47
# Elapsed Time:   0h 7m 20s
# ================================================================================
