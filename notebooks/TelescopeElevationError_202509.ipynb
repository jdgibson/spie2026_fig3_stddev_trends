# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2025-09-01 00:00:00'
end_datetime = '2025-09-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 22:35:06
# Analysis period: 2025-09-01 00:00:00 to 2025-09-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2025-09-01 00:00:00 to 2025-09-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1756710000000, end_timestamp_ms=1759301999000
# Retrieved 1022318 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   BINOSPEC: 598349 records, 2025-09-01 00:00:03.868000 to 2025-09-25 13:26:34.354000
#   HECTO: 185491 records, 2025-09-25 13:26:38.885000 to 2025-09-30 23:59:58.553000
#   MMIRS: 238478 records, 2025-09-08 16:04:47.042000 to 2025-09-15 16:00:41.622000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2025-09-01 00:00:03.868000
#     Last observed:  2025-09-25 13:26:34.354000
#     Duration:       24 days, 13:26:30.486000
#
#   HECTO:
#     First observed: 2025-09-25 13:26:38.885000
#     Last observed:  2025-09-30 23:59:58.553000
#     Duration:       5 days, 10:33:19.668000
#
#   MMIRS:
#     First observed: 2025-09-08 16:04:47.042000
#     Last observed:  2025-09-15 16:00:41.622000
#     Duration:       6 days, 23:55:54.580000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-09-01 00:00:00 to 2025-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1756710000000, end_timestamp_ms=1759301999000, instrument=binospec
# Retrieved 598349 records from hexapod_mini_instrument table
# Processed 598349 instrument records
# Identified 2 observing runs:
#   Run 1: 2025-09-01 07:00:03.868000 to 2025-09-08 23:04:44.838000 (duration: 7 days 16:04:40.970000)
#   Run 2: 2025-09-15 23:00:46.616000 to 2025-09-25 20:26:34.354000 (duration: 9 days 21:25:47.738000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-09-01 00:00:00 to 2025-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1756710000000, end_timestamp_ms=1759301999000, instrument=hecto
# Retrieved 185491 records from hexapod_mini_instrument table
# Processed 185491 instrument records
# Identified 1 observing runs:
#   Run 1: 2025-09-25 20:26:38.885000 to 2025-10-01 06:59:58.553000 (duration: 5 days 10:33:19.668000)
#   ✓ HECTO: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-09-01 00:00:00 to 2025-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1756710000000, end_timestamp_ms=1759301999000, instrument=mmirs
# Retrieved 238478 records from hexapod_mini_instrument table
# Processed 238478 instrument records
# Identified 1 observing runs:
#   Run 1: 2025-09-08 23:04:47.042000 to 2025-09-15 23:00:41.622000 (duration: 6 days 23:55:54.580000)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2025-09-01 07:00:03.868000 to 2025-09-08 23:04:44.838000
#     Duration: 7 days 16:04:40.970000
#     No valid RMS records after filtering
#   Run 2: 2025-09-15 23:00:46.616000 to 2025-09-25 20:26:34.354000
#     Duration: 9 days 21:25:47.738000
#     Filtered 70921 points in 10s intervals with variance >= 2.0" arcsec (retained 97.9%)
#     Retrieved 3373675 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0672" Std=0.0609" Min=0.0000" Max=1.2398"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1730" Std=0.9854" Min=-2.4201" Max=2.4476"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1292802 points:
#       Mean=0.0636" Std=0.0502" Min=0.0000" Max=1.2715"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1292802 points:
#       Mean=0.6752" Std=0.6247" Min=-2.1651" Max=2.4476"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1605237 points:
#       Mean=0.0712" Std=0.0553" Min=0.0000" Max=1.3106"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1605237 points:
#       Mean=-0.8779" Std=0.5984" Min=-2.3658" Max=2.1652"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2025-09-25 20:26:38.885000 to 2025-10-01 06:59:58.553000
#     Duration: 5 days 10:33:19.668000
#     Filtered 13197 points in 10s intervals with variance >= 2.0" arcsec (retained 99.2%)
#     Retrieved 1690264 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0585" Std=0.0455" Min=0.0000" Max=1.2683"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0897" Std=0.9613" Min=-2.5667" Max=1.9283"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 829312 points:
#       Mean=0.0551" Std=0.0390" Min=0.0000" Max=1.2132"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 829312 points:
#       Mean=0.8410" Std=0.3832" Min=-1.7072" Max=1.9283"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 649769 points:
#       Mean=0.0706" Std=0.0464" Min=0.0000" Max=0.8919"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 649769 points:
#       Mean=-0.9104" Std=0.5772" Min=-2.5667" Max=1.5812"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2025-09-08 23:04:47.042000 to 2025-09-15 23:00:41.622000
#     Duration: 6 days 23:55:54.580000
#     Filtered 181181 points in 10s intervals with variance >= 2.0" arcsec (retained 93.1%)
#     Retrieved 2618469 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0526" Std=0.0507" Min=0.0000" Max=1.1883"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4282" Std=0.7263" Min=-2.6838" Max=2.4940"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 660426 points:
#       Mean=0.0579" Std=0.0439" Min=0.0000" Max=1.1864"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 660426 points:
#       Mean=0.2374" Std=0.7019" Min=-2.1401" Max=2.4576"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1427645 points:
#       Mean=0.0527" Std=0.0480" Min=0.0000" Max=1.2367"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1427645 points:
#       Mean=-0.7476" Std=0.4919" Min=-2.6838" Max=2.4416"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 3
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 2: binospec_20250915_230046_to_20250925_202634.json
# ✓ hecto Run 1: hecto_20250925_202638_to_20251001_065958.json
# ✓ mmirs Run 1: mmirs_20250908_230447_to_20250915_230041.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30027
#   Timestamps: 30027
#   Rolling StdDev: 30027
#   Altitudes: 30027
#   Alt Velocities: 30027
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30066
#   Timestamps: 30066
#   Rolling StdDev: 30066
#   Altitudes: 30066
#   Alt Velocities: 30066
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30099
#   Timestamps: 30099
#   Rolling StdDev: 30099
#   Altitudes: 30099
#   Alt Velocities: 30099
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30129
#   Timestamps: 30129
#   Rolling StdDev: 30129
#   Altitudes: 30129
#   Alt Velocities: 30129
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30342
#   Timestamps: 30342
#   Rolling StdDev: 30342
#   Altitudes: 30342
#   Alt Velocities: 30342
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30459
#   Timestamps: 30459
#   Rolling StdDev: 30459
#   Altitudes: 30459
#   Alt Velocities: 30459
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30090
#   Timestamps: 30090
#   Rolling StdDev: 30090
#   Altitudes: 30090
#   Alt Velocities: 30090
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30021
#   Timestamps: 30021
#   Rolling StdDev: 30021
#   Altitudes: 30021
#   Alt Velocities: 30021
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30162
#   Timestamps: 30162
#   Rolling StdDev: 30162
#   Altitudes: 30162
#   Alt Velocities: 30162
# ================================================================================
# Generated 9 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 22:35:06
# End DateTime:   2026-02-12 22:43:33
# Elapsed Time:   0h 8m 27s
# ================================================================================
