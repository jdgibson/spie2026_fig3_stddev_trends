# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2023-05-01 00:00:00'
end_datetime = '2023-05-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 20:37:03
# Analysis period: 2023-05-01 00:00:00 to 2023-05-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2023-05-01 00:00:00 to 2023-05-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1682924400000, end_timestamp_ms=1685602799000
# Retrieved 943642 total records from hexapod_mini_instrument
# Found 6 unique instrument(s)
#   NA: 43 records, 2023-05-25 04:25:10.726000 to 2023-05-25 04:28:41.109000
#   F15: 109 records, 2023-05-31 16:20:08.110000 to 2023-05-31 16:29:18.441000
#   F5: 8142 records, 2023-05-31 05:01:17.155000 to 2023-05-31 16:20:03.054000
#   HECTO: 699266 records, 2023-05-01 00:00:00.674000 to 2023-05-31 05:01:12.106000
#   MMIRS: 230675 records, 2023-05-05 15:38:02.236000 to 2023-05-12 09:15:27.280000
#   PISCES-LGS: 5407 records, 2023-05-31 16:26:58.629000 to 2023-05-31 23:59:55.932000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   F15:
#     First observed: 2023-05-31 16:20:08.110000
#     Last observed:  2023-05-31 16:29:18.441000
#     Duration:       0:09:10.331000
#
#   F5:
#     First observed: 2023-05-31 05:01:17.155000
#     Last observed:  2023-05-31 16:20:03.054000
#     Duration:       11:18:45.899000
#
#   HECTO:
#     First observed: 2023-05-01 00:00:00.674000
#     Last observed:  2023-05-31 05:01:12.106000
#     Duration:       30 days, 5:01:11.432000
#
#   MMIRS:
#     First observed: 2023-05-05 15:38:02.236000
#     Last observed:  2023-05-12 09:15:27.280000
#     Duration:       6 days, 17:37:25.044000
#
#   PISCES-LGS:
#     First observed: 2023-05-31 16:26:58.629000
#     Last observed:  2023-05-31 23:59:55.932000
#     Duration:       7:32:57.303000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-05-01 00:00:00 to 2023-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1682924400000, end_timestamp_ms=1685602799000, instrument=NA
# Retrieved 43 records from hexapod_mini_instrument table
# Processed 43 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-05-25 11:25:10.726000 to 2023-05-25 11:28:41.109000 (duration: 0 days 00:03:30.383000)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-05-01 00:00:00 to 2023-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1682924400000, end_timestamp_ms=1685602799000, instrument=f15
# Retrieved 109 records from hexapod_mini_instrument table
# Processed 109 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-05-31 23:20:08.110000 to 2023-05-31 23:29:18.441000 (duration: 0 days 00:09:10.331000)
#   ✓ F15: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-05-01 00:00:00 to 2023-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1682924400000, end_timestamp_ms=1685602799000, instrument=f5
# Retrieved 8142 records from hexapod_mini_instrument table
# Processed 8142 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-05-31 12:01:17.155000 to 2023-05-31 23:20:03.054000 (duration: 0 days 11:18:45.899000)
#   ✓ F5: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-05-01 00:00:00 to 2023-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1682924400000, end_timestamp_ms=1685602799000, instrument=hecto
# Retrieved 699266 records from hexapod_mini_instrument table
# Processed 699266 instrument records
# Identified 2 observing runs:
#   Run 1: 2023-05-01 07:00:00.674000 to 2023-05-05 22:37:58.514000 (duration: 4 days 15:37:57.840000)
#   Run 2: 2023-05-12 16:15:31.044000 to 2023-05-31 12:01:12.106000 (duration: 18 days 19:45:41.062000)
#   ✓ HECTO: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-05-01 00:00:00 to 2023-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1682924400000, end_timestamp_ms=1685602799000, instrument=mmirs
# Retrieved 230675 records from hexapod_mini_instrument table
# Processed 230675 instrument records
# Identified 1 observing runs:
#   Run 1: 2023-05-05 22:38:02.236000 to 2023-05-12 16:15:27.280000 (duration: 6 days 17:37:25.044000)
#   ✓ MMIRS: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-05-01 00:00:00 to 2023-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1682924400000, end_timestamp_ms=1685602799000, instrument=pisces-lgs
# Retrieved 5407 records from hexapod_mini_instrument table
# Processed 5407 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-05-31 23:26:58.629000 to 2023-06-01 06:59:55.932000 (duration: 0 days 07:32:57.303000)
#   ✓ PISCES-LGS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:03:30.383000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: F15
# ======================================================================
# Analyzing 1 observing run(s) for f15:
#   Run 1: Skipped (duration 0 days 00:09:10.331000 is less than 1.0 hours)
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 1 observing run(s) for f5:
#   Run 1: 2023-05-31 12:01:17.155000 to 2023-05-31 23:20:03.054000
#     Duration: 0 days 11:18:45.899000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 2 observing run(s) for hecto:
#   Run 1: 2023-05-01 07:00:00.674000 to 2023-05-05 22:37:58.514000
#     Duration: 4 days 15:37:57.840000
#     Filtered 97573 points in 10s intervals with variance >= 2.0" arcsec (retained 94.3%)
#     Retrieved 1703737 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0917" Std=0.0770" Min=0.0000" Max=1.0417"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.7348" Std=0.6046" Min=-2.6877" Max=1.7392"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 153111 points:
#       Mean=0.0893" Std=0.0761" Min=0.0000" Max=0.8514"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 153111 points:
#       Mean=0.7133" Std=0.3559" Min=-1.8337" Max=1.7392"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1350719 points:
#       Mean=0.0984" Std=0.0782" Min=0.0000" Max=0.7703"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1350719 points:
#       Mean=-0.9394" Std=0.3281" Min=-2.6877" Max=1.3322"
#   Run 2: 2023-05-12 16:15:31.044000 to 2023-05-31 12:01:12.106000
#     Duration: 18 days 19:45:41.062000
#     Filtered 299913 points in 10s intervals with variance >= 2.0" arcsec (retained 95.6%)
#     Retrieved 6848566 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0974" Std=0.0901" Min=0.0000" Max=1.2564"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0175" Std=0.8703" Min=-2.5449" Max=2.4040"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 3260865 points:
#       Mean=0.1101" Std=0.0926" Min=0.0000" Max=1.0407"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 3260865 points:
#       Mean=0.7499" Std=0.3577" Min=-1.6412" Max=2.4040"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2565294 points:
#       Mean=0.0913" Std=0.0830" Min=0.0000" Max=1.0186"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2565294 points:
#       Mean=-0.9470" Std=0.3375" Min=-2.5449" Max=2.1939"
#
# Successfully analyzed 2 run(s) for hecto
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2023-05-05 22:38:02.236000 to 2023-05-12 16:15:27.280000
#     Duration: 6 days 17:37:25.044000
#     Filtered 468247 points in 10s intervals with variance >= 2.0" arcsec (retained 89.5%)
#     Retrieved 4438766 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.1019" Std=0.0853" Min=0.0000" Max=1.5311"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0185" Std=0.9780" Min=-2.6029" Max=2.7225"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1914868 points:
#       Mean=0.0922" Std=0.0742" Min=0.0000" Max=1.4305"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1914868 points:
#       Mean=0.8850" Std=0.3519" Min=-2.0247" Max=2.7225"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1760997 points:
#       Mean=0.1155" Std=0.0891" Min=0.0000" Max=1.1954"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1760997 points:
#       Mean=-1.0022" Std=0.3724" Min=-2.6029" Max=1.7486"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# PROCESSING: PISCES-LGS
# ======================================================================
# Analyzing 1 observing run(s) for pisces-lgs:
#   Run 1: 2023-05-31 23:26:58.629000 to 2023-06-01 06:59:55.932000
#     Duration: 0 days 07:32:57.303000
#     No valid RMS records after filtering
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   HECTO: 2 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ hecto Run 1: hecto_20230501_070000_to_20230505_223758.json
# ✓ hecto Run 2: hecto_20230512_161531_to_20230531_120112.json
# ✓ mmirs Run 1: mmirs_20230505_223802_to_20230512_161527.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30018
#   Timestamps: 30018
#   Rolling StdDev: 30018
#   Altitudes: 30018
#   Alt Velocities: 30018
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30036
#   Timestamps: 30036
#   Rolling StdDev: 30036
#   Altitudes: 30036
#   Alt Velocities: 30036
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30048
#   Timestamps: 30048
#   Rolling StdDev: 30048
#   Altitudes: 30048
#   Alt Velocities: 30048
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30006
#   Timestamps: 30006
#   Rolling StdDev: 30006
#   Altitudes: 30006
#   Alt Velocities: 30006
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30078
#   Timestamps: 30078
#   Rolling StdDev: 30078
#   Altitudes: 30078
#   Alt Velocities: 30078
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30018
#   Timestamps: 30018
#   Rolling StdDev: 30018
#   Altitudes: 30018
#   Alt Velocities: 30018
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 20:37:03
# End DateTime:   2026-02-12 21:04:38
# Elapsed Time:   0h 27m 34s
# ================================================================================
