# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2025-12-01 00:00:00'
end_datetime = '2025-12-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 22:43:37
# Analysis period: 2025-12-01 00:00:00 to 2025-12-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1764572400000, end_timestamp_ms=1767250799000
# Retrieved 1053662 total records from hexapod_mini_instrument
# Found 5 unique instrument(s)
#   NA: 1 records, 2025-12-22 09:10:18.757000 to 2025-12-22 09:10:18.757000
#   BINOSPEC: 468121 records, 2025-12-01 00:00:00.661000 to 2025-12-29 17:04:29.316000
#   HECTO: 307926 records, 2025-12-08 12:48:00.218000 to 2025-12-17 13:42:03.269000
#   MIRAC: 199518 records, 2025-12-02 16:21:04.377000 to 2025-12-08 12:47:57.944000
#   MMIRS: 78096 records, 2025-12-29 17:04:33.878000 to 2025-12-31 23:59:58.909000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2025-12-01 00:00:00.661000
#     Last observed:  2025-12-29 17:04:29.316000
#     Duration:       28 days, 17:04:28.655000
#
#   HECTO:
#     First observed: 2025-12-08 12:48:00.218000
#     Last observed:  2025-12-17 13:42:03.269000
#     Duration:       9 days, 0:54:03.051000
#
#   MIRAC:
#     First observed: 2025-12-02 16:21:04.377000
#     Last observed:  2025-12-08 12:47:57.944000
#     Duration:       5 days, 20:26:53.567000
#
#   MMIRS:
#     First observed: 2025-12-29 17:04:33.878000
#     Last observed:  2025-12-31 23:59:58.909000
#     Duration:       2 days, 6:55:25.031000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1764572400000, end_timestamp_ms=1767250799000, instrument=NA
# Retrieved 1 records from hexapod_mini_instrument table
# Processed 1 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2025-12-22 16:10:18.757000 to 2025-12-22 16:10:18.757000 (duration: 0 days 00:00:00)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1764572400000, end_timestamp_ms=1767250799000, instrument=binospec
# Retrieved 468121 records from hexapod_mini_instrument table
# Processed 468121 instrument records
# Identified 3 observing runs:
#   Run 1: 2025-12-01 07:00:00.661000 to 2025-12-02 23:21:00.513000 (duration: 1 days 16:20:59.852000)
#   Run 2: 2025-12-17 20:42:04.517000 to 2025-12-19 20:21:00.762000 (duration: 1 days 23:38:56.245000)
#   Run 3: 2025-12-19 22:38:22.438000 to 2025-12-30 00:04:29.316000 (duration: 10 days 01:26:06.878000)
#   ✓ BINOSPEC: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1764572400000, end_timestamp_ms=1767250799000, instrument=hecto
# Retrieved 307926 records from hexapod_mini_instrument table
# Processed 307926 instrument records
# Identified 1 observing runs:
#   Run 1: 2025-12-08 19:48:00.218000 to 2025-12-17 20:42:03.269000 (duration: 9 days 00:54:03.051000)
#   ✓ HECTO: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1764572400000, end_timestamp_ms=1767250799000, instrument=mirac
# Retrieved 199518 records from hexapod_mini_instrument table
# Processed 199518 instrument records
# Identified 1 observing runs:
#   Run 1: 2025-12-02 23:21:04.377000 to 2025-12-08 19:47:57.944000 (duration: 5 days 20:26:53.567000)
#   ✓ MIRAC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-12-01 00:00:00 to 2025-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1764572400000, end_timestamp_ms=1767250799000, instrument=mmirs
# Retrieved 78096 records from hexapod_mini_instrument table
# Processed 78096 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2025-12-30 00:04:33.878000 to 2026-01-01 06:59:58.909000 (duration: 2 days 06:55:25.031000)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 3 observing run(s) for binospec:
#   Run 1: 2025-12-01 07:00:00.661000 to 2025-12-02 23:21:00.513000
#     Duration: 1 days 16:20:59.852000
#     Filtered 6983 points in 10s intervals with variance >= 2.0" arcsec (retained 98.8%)
#     Retrieved 575574 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0401" Std=0.0412" Min=0.0000" Max=0.8418"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.4176" Std=0.5807" Min=-1.2466" Max=1.8101"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 262309 points:
#       Mean=0.0535" Std=0.0386" Min=0.0000" Max=0.5927"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 262309 points:
#       Mean=0.9357" Std=0.4359" Min=-1.1712" Max=1.8101"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 46337 points:
#       Mean=0.0853" Std=0.0567" Min=0.0147" Max=0.4263"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 46337 points:
#       Mean=-0.2776" Std=0.2895" Min=-1.2461" Max=0.9761"
#   Run 2: 2025-12-17 20:42:04.517000 to 2025-12-19 20:21:00.762000
#     Duration: 1 days 23:38:56.245000
#     Filtered 57609 points in 10s intervals with variance >= 2.0" arcsec (retained 96.8%)
#     Retrieved 1815753 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0582" Std=0.0528" Min=0.0000" Max=1.3732"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0654" Std=1.0317" Min=-2.5280" Max=2.5900"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 781684 points:
#       Mean=0.0590" Std=0.0536" Min=0.0000" Max=1.3121"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 781684 points:
#       Mean=0.9597" Std=0.4314" Min=-1.8101" Max=2.5900"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 822963 points:
#       Mean=0.0622" Std=0.0528" Min=0.0000" Max=1.2786"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 822963 points:
#       Mean=-1.0486" Std=0.3243" Min=-2.5280" Max=1.9312"
#   Run 3: 2025-12-19 22:38:22.438000 to 2025-12-30 00:04:29.316000
#     Duration: 10 days 01:26:06.878000
#     Filtered 91015 points in 10s intervals with variance >= 2.0" arcsec (retained 97.9%)
#     Retrieved 4381275 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0590" Std=0.0663" Min=0.0000" Max=1.3144"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.3344" Std=0.8794" Min=-2.4415" Max=2.1530"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2542658 points:
#       Mean=0.0659" Std=0.0859" Min=0.0000" Max=0.8008"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2542658 points:
#       Mean=0.9743" Std=0.3293" Min=-1.6350" Max=2.1530"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1235470 points:
#       Mean=0.0736" Std=0.0538" Min=0.0000" Max=1.3279"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1235470 points:
#       Mean=-0.8502" Std=0.3902" Min=-2.4415" Max=1.6949"
#
# Successfully analyzed 3 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2025-12-08 19:48:00.218000 to 2025-12-17 20:42:03.269000
#     Duration: 9 days 00:54:03.051000
#     Filtered 37860 points in 10s intervals with variance >= 2.0" arcsec (retained 99.4%)
#     Retrieved 6334670 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0761" Std=0.0971" Min=0.0000" Max=1.2833"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.1490" Std=0.9978" Min=-2.2223" Max=2.2698"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 3438081 points:
#       Mean=0.0795" Std=0.1007" Min=0.0000" Max=0.7727"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 3438081 points:
#       Mean=0.9974" Std=0.2747" Min=-1.3508" Max=2.2698"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2529274 points:
#       Mean=0.0663" Std=0.0789" Min=0.0000" Max=0.8560"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2529274 points:
#       Mean=-0.9812" Std=0.3278" Min=-2.2223" Max=1.3524"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# PROCESSING: MIRAC
# ======================================================================
# Analyzing 1 observing run(s) for mirac:
#   Run 1: 2025-12-02 23:21:04.377000 to 2025-12-08 19:47:57.944000
#     Duration: 5 days 20:26:53.567000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2025-12-30 00:04:33.878000 to 2026-01-01 06:59:58.909000
#     Duration: 2 days 06:55:25.031000
#     Filtered 57207 points in 10s intervals with variance >= 2.0" arcsec (retained 93.6%)
#     Retrieved 898259 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0481" Std=0.0455" Min=0.0000" Max=1.0599"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.8241" Std=0.5939" Min=-1.9752" Max=1.6137"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 64378 points:
#       Mean=0.0621" Std=0.0572" Min=0.0121" Max=1.0281"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 64378 points:
#       Mean=0.9466" Std=0.6921" Min=-1.2753" Max=1.6137"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 767828 points:
#       Mean=0.0465" Std=0.0403" Min=0.0000" Max=0.7327"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 767828 points:
#       Mean=-0.9764" Std=0.2419" Min=-1.9752" Max=0.9496"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 3
#   BINOSPEC: 3 run(s)
#   HECTO: 1 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20251201_070000_to_20251202_232100.json
# ✓ binospec Run 2: binospec_20251217_204204_to_20251219_202100.json
# ✓ binospec Run 3: binospec_20251219_223822_to_20251230_000429.json
# ✓ hecto Run 1: hecto_20251208_194800_to_20251217_204203.json
# ✓ mmirs Run 1: mmirs_20251230_000433_to_20260101_065958.json
#
# ✓ Saved statistics for 5 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30033
#   Timestamps: 30033
#   Rolling StdDev: 30033
#   Altitudes: 30033
#   Alt Velocities: 30033
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30057
#   Timestamps: 30057
#   Rolling StdDev: 30057
#   Altitudes: 30057
#   Alt Velocities: 30057
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30069
#   Timestamps: 30069
#   Rolling StdDev: 30069
#   Altitudes: 30069
#   Alt Velocities: 30069
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30033
#   Timestamps: 30033
#   Rolling StdDev: 30033
#   Altitudes: 30033
#   Alt Velocities: 30033
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30072
#   Timestamps: 30072
#   Rolling StdDev: 30072
#   Altitudes: 30072
#   Alt Velocities: 30072
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30111
#   Timestamps: 30111
#   Rolling StdDev: 30111
#   Altitudes: 30111
#   Alt Velocities: 30111
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30039
#   Timestamps: 30039
#   Rolling StdDev: 30039
#   Altitudes: 30039
#   Alt Velocities: 30039
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 32190
#   Timestamps: 32190
#   Rolling StdDev: 32190
#   Altitudes: 32190
#   Alt Velocities: 32190
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30309
#   Timestamps: 30309
#   Rolling StdDev: 30309
#   Altitudes: 30309
#   Alt Velocities: 30309
# ================================================================================
# Generated 9 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 22:43:37
# End DateTime:   2026-02-12 23:01:12
# Elapsed Time:   0h 17m 35s
# ================================================================================
