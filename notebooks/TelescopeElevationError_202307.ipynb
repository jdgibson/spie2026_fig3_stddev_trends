# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2023-07-01 00:00:00'
end_datetime = '2023-07-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 20:46:19
# Analysis period: 2023-07-01 00:00:00 to 2023-07-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2023-07-01 00:00:00 to 2023-07-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1688194800000, end_timestamp_ms=1690873199000
# Retrieved 535448 total records from hexapod_mini_instrument
# Found 2 unique instrument(s)
#   BINOSPEC: 491180 records, 2023-07-03 13:29:55.465000 to 2023-07-31 23:59:57.301000
#   HECTO: 44268 records, 2023-07-01 00:00:03.239000 to 2023-07-03 13:29:50.416000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2023-07-03 13:29:55.465000
#     Last observed:  2023-07-31 23:59:57.301000
#     Duration:       28 days, 10:30:01.836000
#
#   HECTO:
#     First observed: 2023-07-01 00:00:03.239000
#     Last observed:  2023-07-03 13:29:50.416000
#     Duration:       2 days, 13:29:47.177000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-07-01 00:00:00 to 2023-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1688194800000, end_timestamp_ms=1690873199000, instrument=binospec
# Retrieved 491180 records from hexapod_mini_instrument table
# Processed 491180 instrument records
# Identified 1 observing runs:
#   Run 1: 2023-07-03 20:29:55.465000 to 2023-08-01 06:59:57.301000 (duration: 28 days 10:30:01.836000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-07-01 00:00:00 to 2023-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1688194800000, end_timestamp_ms=1690873199000, instrument=hecto
# Retrieved 44268 records from hexapod_mini_instrument table
# Processed 44268 instrument records
# Identified 1 observing runs:
#   Run 1: 2023-07-01 07:00:03.239000 to 2023-07-03 20:29:50.416000 (duration: 2 days 13:29:47.177000)
#   ✓ HECTO: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2023-07-03 20:29:55.465000 to 2023-08-01 06:59:57.301000
#     Duration: 28 days 10:30:01.836000
#     Filtered 91305 points in 10s intervals with variance >= 2.0" arcsec (retained 96.7%)
#     Retrieved 2795962 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0797" Std=0.0772" Min=0.0000" Max=1.4653"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.3099" Std=0.8691" Min=-2.5028" Max=2.6292"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 783941 points:
#       Mean=0.0785" Std=0.0708" Min=0.0000" Max=1.1139"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 783941 points:
#       Mean=0.8724" Std=0.3753" Min=-1.5634" Max=2.6292"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1655890 points:
#       Mean=0.0835" Std=0.0763" Min=0.0000" Max=0.9065"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1655890 points:
#       Mean=-0.9036" Std=0.3597" Min=-2.5028" Max=1.9057"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2023-07-01 07:00:03.239000 to 2023-07-03 20:29:50.416000
#     Duration: 2 days 13:29:47.177000
#     Filtered 23126 points in 10s intervals with variance >= 2.0" arcsec (retained 95.3%)
#     Retrieved 490200 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0433" Std=0.0260" Min=0.0000" Max=0.7430"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.6697" Std=0.6088" Min=-1.6749" Max=0.9311"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 62708 points:
#       Mean=0.0396" Std=0.0192" Min=0.0098" Max=0.3167"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 62708 points:
#       Mean=0.5085" Std=0.1925" Min=-1.3270" Max=0.9311"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 362046 points:
#       Mean=0.0456" Std=0.0270" Min=0.0000" Max=0.4233"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 362046 points:
#       Mean=-0.9448" Std=0.3211" Min=-1.6749" Max=0.1691"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20230703_202955_to_20230801_065957.json
# ✓ hecto Run 1: hecto_20230701_070003_to_20230703_202950.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30054
#   Timestamps: 30054
#   Rolling StdDev: 30054
#   Altitudes: 30054
#   Alt Velocities: 30054
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30153
#   Timestamps: 30153
#   Rolling StdDev: 30153
#   Altitudes: 30153
#   Alt Velocities: 30153
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30108
#   Timestamps: 30108
#   Rolling StdDev: 30108
#   Altitudes: 30108
#   Alt Velocities: 30108
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30462
#   Timestamps: 30462
#   Rolling StdDev: 30462
#   Altitudes: 30462
#   Alt Velocities: 30462
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 31356
#   Timestamps: 31356
#   Rolling StdDev: 31356
#   Altitudes: 31356
#   Alt Velocities: 31356
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30171
#   Timestamps: 30171
#   Rolling StdDev: 30171
#   Altitudes: 30171
#   Alt Velocities: 30171
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 20:46:19
# End DateTime:   2026-02-12 20:49:13
# Elapsed Time:   0h 2m 54s
# ================================================================================
