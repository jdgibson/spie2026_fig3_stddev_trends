# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2023-08-01 00:00:00'
end_datetime = '2023-08-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 20:49:17
# Analysis period: 2023-08-01 00:00:00 to 2023-08-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2023-08-01 00:00:00 to 2023-08-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1690873200000, end_timestamp_ms=1693551599000
# Retrieved 1002222 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 2 records, 2023-08-14 12:43:58.704000 to 2023-08-22 16:17:00.816000
#   BINOSPEC: 931070 records, 2023-08-01 00:00:02.360000 to 2023-08-29 22:10:10.323000
#   MMIRS: 71150 records, 2023-08-29 22:10:14.218000 to 2023-08-31 23:59:56.814000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2023-08-01 00:00:02.360000
#     Last observed:  2023-08-29 22:10:10.323000
#     Duration:       28 days, 22:10:07.963000
#
#   MMIRS:
#     First observed: 2023-08-29 22:10:14.218000
#     Last observed:  2023-08-31 23:59:56.814000
#     Duration:       2 days, 1:49:42.596000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-08-01 00:00:00 to 2023-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1690873200000, end_timestamp_ms=1693551599000, instrument=NA
# Retrieved 2 records from hexapod_mini_instrument table
# Processed 2 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2023-08-14 19:43:58.704000 to 2023-08-14 19:43:58.704000 (duration: 0 days 00:00:00)
#   Run 2: 2023-08-22 23:17:00.816000 to 2023-08-22 23:17:00.816000 (duration: 0 days 00:00:00)
#   ✓ NA: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-08-01 00:00:00 to 2023-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1690873200000, end_timestamp_ms=1693551599000, instrument=binospec
# Retrieved 931070 records from hexapod_mini_instrument table
# Processed 931070 instrument records
# Identified 1 observing runs:
#   Run 1: 2023-08-01 07:00:02.360000 to 2023-08-30 05:10:10.323000 (duration: 28 days 22:10:07.963000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-08-01 00:00:00 to 2023-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1690873200000, end_timestamp_ms=1693551599000, instrument=mmirs
# Retrieved 71150 records from hexapod_mini_instrument table
# Processed 71150 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-08-30 05:10:14.218000 to 2023-09-01 06:59:56.814000 (duration: 2 days 01:49:42.596000)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 2 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2023-08-01 07:00:02.360000 to 2023-08-30 05:10:10.323000
#     Duration: 28 days 22:10:07.963000
#     Filtered 95722 points in 10s intervals with variance >= 2.0" arcsec (retained 94.8%)
#     Retrieved 1836336 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0991" Std=0.0719" Min=0.0000" Max=1.1865"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1779" Std=0.8728" Min=-2.9976" Max=2.3367"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 622801 points:
#       Mean=0.1207" Std=0.0761" Min=0.0000" Max=1.1203"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 622801 points:
#       Mean=0.7829" Std=0.4057" Min=-1.6383" Max=2.3367"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 868717 points:
#       Mean=0.0934" Std=0.0660" Min=0.0000" Max=0.8708"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 868717 points:
#       Mean=-0.9069" Std=0.4169" Min=-2.9976" Max=1.5305"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2023-08-30 05:10:14.218000 to 2023-09-01 06:59:56.814000
#     Duration: 2 days 01:49:42.596000
#     No valid RMS records after filtering
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 1
#   BINOSPEC: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20230801_070002_to_20230830_051010.json
#
# ✓ Saved statistics for 1 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30012
#   Timestamps: 30012
#   Rolling StdDev: 30012
#   Altitudes: 30012
#   Alt Velocities: 30012
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30138
#   Timestamps: 30138
#   Rolling StdDev: 30138
#   Altitudes: 30138
#   Alt Velocities: 30138
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30306
#   Timestamps: 30306
#   Rolling StdDev: 30306
#   Altitudes: 30306
#   Alt Velocities: 30306
# ================================================================================
# Generated 3 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 20:49:17
# End DateTime:   2026-02-12 20:51:24
# Elapsed Time:   0h 2m 7s
# ================================================================================
