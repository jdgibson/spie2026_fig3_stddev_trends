# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2020-12-01 00:00:00'
end_datetime = '2020-12-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 18:07:14
# Analysis period: 2020-12-01 00:00:00 to 2020-12-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2020-12-01 00:00:00 to 2020-12-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1606806000000, end_timestamp_ms=1609484399000
# Retrieved 535447 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   BLUE: 245034 records, 2020-12-04 13:26:17.499000 to 2020-12-18 17:55:13.727000
#   F5: 37136 records, 2020-12-02 09:50:22.419000 to 2020-12-04 13:26:12.496000
#   MMIRS: 253277 records, 2020-12-01 00:00:04.278000 to 2020-12-31 23:59:58.958000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BLUE:
#     First observed: 2020-12-04 13:26:17.499000
#     Last observed:  2020-12-18 17:55:13.727000
#     Duration:       14 days, 4:28:56.228000
#
#   F5:
#     First observed: 2020-12-02 09:50:22.419000
#     Last observed:  2020-12-04 13:26:12.496000
#     Duration:       2 days, 3:35:50.077000
#
#   MMIRS:
#     First observed: 2020-12-01 00:00:04.278000
#     Last observed:  2020-12-31 23:59:58.958000
#     Duration:       30 days, 23:59:54.680000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-12-01 00:00:00 to 2020-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1606806000000, end_timestamp_ms=1609484399000, instrument=blue
# Retrieved 245034 records from hexapod_mini_instrument table
# Processed 245034 instrument records
# Identified 1 observing runs:
#   Run 1: 2020-12-04 20:26:17.499000 to 2020-12-19 00:55:13.727000 (duration: 14 days 04:28:56.228000)
#   ✓ BLUE: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-12-01 00:00:00 to 2020-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1606806000000, end_timestamp_ms=1609484399000, instrument=f5
# Retrieved 37136 records from hexapod_mini_instrument table
# Processed 37136 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2020-12-02 16:50:22.419000 to 2020-12-04 20:26:12.496000 (duration: 2 days 03:35:50.077000)
#   ✓ F5: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-12-01 00:00:00 to 2020-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1606806000000, end_timestamp_ms=1609484399000, instrument=mmirs
# Retrieved 253277 records from hexapod_mini_instrument table
# Processed 253277 instrument records
# Identified 2 observing runs:
#   Run 1: 2020-12-01 07:00:04.278000 to 2020-12-02 16:50:17.351000 (duration: 1 days 09:50:13.073000)
#   Run 2: 2020-12-19 00:55:18.728000 to 2021-01-01 06:59:58.958000 (duration: 13 days 06:04:40.230000)
#   ✓ MMIRS: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BLUE
# ======================================================================
# Analyzing 1 observing run(s) for blue:
#   Run 1: 2020-12-04 20:26:17.499000 to 2020-12-19 00:55:13.727000
#     Duration: 14 days 04:28:56.228000
#     Filtered 187153 points in 10s intervals with variance >= 2.0" arcsec (retained 97.9%)
#     Retrieved 8768258 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.1042" Std=0.1597" Min=0.0000" Max=1.2206"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.5520" Std=0.7799" Min=-2.8958" Max=2.2367"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1583747 points:
#       Mean=0.0596" Std=0.0683" Min=0.0000" Max=0.9474"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1583747 points:
#       Mean=0.7970" Std=0.4316" Min=-2.2446" Max=2.2367"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 6047584 points:
#       Mean=0.1184" Std=0.1646" Min=0.0000" Max=0.9262"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 6047584 points:
#       Mean=-0.9816" Std=0.3096" Min=-2.8958" Max=1.7073"
#
# Successfully analyzed 1 run(s) for blue
#
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 1 observing run(s) for f5:
#   Run 1: 2020-12-02 16:50:22.419000 to 2020-12-04 20:26:12.496000
#     Duration: 2 days 03:35:50.077000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 2 observing run(s) for mmirs:
#   Run 1: 2020-12-01 07:00:04.278000 to 2020-12-02 16:50:17.351000
#     Duration: 1 days 09:50:13.073000
#     Filtered 128279 points in 10s intervals with variance >= 2.0" arcsec (retained 91.1%)
#     Retrieved 1443768 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0494" Std=0.0466" Min=0.0000" Max=0.9979"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.1049" Std=0.9029" Min=-2.9317" Max=2.4892"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 680971 points:
#       Mean=0.0432" Std=0.0365" Min=0.0000" Max=1.0522"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 680971 points:
#       Mean=0.8718" Std=0.3718" Min=-1.5893" Max=2.4892"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 523318 points:
#       Mean=0.0609" Std=0.0531" Min=0.0000" Max=1.0234"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 523318 points:
#       Mean=-0.8759" Std=0.3369" Min=-2.9317" Max=1.3636"
#   Run 2: 2020-12-19 00:55:18.728000 to 2021-01-01 06:59:58.958000
#     Duration: 13 days 06:04:40.230000
#     Filtered 446584 points in 10s intervals with variance >= 2.0" arcsec (retained 93.4%)
#     Retrieved 6738802 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0545" Std=0.0690" Min=0.0000" Max=1.3140"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2730" Std=0.7214" Min=-2.4483" Max=2.6005"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1529629 points:
#       Mean=0.0505" Std=0.0480" Min=0.0000" Max=1.0401"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1529629 points:
#       Mean=0.7746" Std=0.3464" Min=-1.8140" Max=2.6005"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 3788427 points:
#       Mean=0.0709" Std=0.0874" Min=0.0000" Max=1.2713"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 3788427 points:
#       Mean=-0.7374" Std=0.3639" Min=-2.4483" Max=1.7317"
#
# Successfully analyzed 2 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BLUE: 1 run(s)
#   MMIRS: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ blue Run 1: blue_20201204_202617_to_20201219_005513.json
# ✓ mmirs Run 1: mmirs_20201201_070004_to_20201202_165017.json
# ✓ mmirs Run 2: mmirs_20201219_005518_to_20210101_065958.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BLUE (BOTH (Total)):
#   RMS Errors: 30006
#   Timestamps: 30006
#   Rolling StdDev: 30006
#   Altitudes: 30006
#   Alt Velocities: 30006
# Plot data array lengths for BLUE (UP (Elevation Increasing)):
#   RMS Errors: 30072
#   Timestamps: 30072
#   Rolling StdDev: 30072
#   Altitudes: 30072
#   Alt Velocities: 30072
# Plot data array lengths for BLUE (DOWN (Elevation Decreasing)):
#   RMS Errors: 30039
#   Timestamps: 30039
#   Rolling StdDev: 30039
#   Altitudes: 30039
#   Alt Velocities: 30039
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30033
#   Timestamps: 30033
#   Rolling StdDev: 30033
#   Altitudes: 30033
#   Alt Velocities: 30033
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30009
#   Timestamps: 30009
#   Rolling StdDev: 30009
#   Altitudes: 30009
#   Alt Velocities: 30009
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 18:07:14
# End DateTime:   2026-02-12 18:43:37
# Elapsed Time:   0h 36m 23s
# ================================================================================
