# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2021-06-01 00:00:00'
end_datetime = '2021-06-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 18:46:06
# Analysis period: 2021-06-01 00:00:00 to 2021-06-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2021-06-01 00:00:00 to 2021-06-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1622530800000, end_timestamp_ms=1625122799000
# Retrieved 892683 total records from hexapod_mini_instrument
# Found 8 unique instrument(s)
#   : 2 records, 2021-06-17 14:10:56.045000 to 2021-06-17 14:11:01.102000
#   NA: 6 records, 2021-06-08 10:49:17.642000 to 2021-06-17 14:10:58.999000
#   BINOSPEC: 120948 records, 2021-06-04 15:02:00.825000 to 2021-06-10 04:00:03.833000
#   BLUE: 255581 records, 2021-06-10 15:41:29.700000 to 2021-06-18 04:26:04.174000
#   F5: 16590 records, 2021-06-10 04:00:08.490000 to 2021-06-10 15:41:25.346000
#   F9: 9941 records, 2021-06-10 15:44:14.937000 to 2021-06-18 11:25:20.023000
#   HECTO: 87026 records, 2021-06-28 10:42:56.830000 to 2021-06-30 23:59:55.617000
#   MMIRS: 402589 records, 2021-06-01 00:00:01.585000 to 2021-06-28 10:42:54.054000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   :
#     First observed: 2021-06-17 14:10:56.045000
#     Last observed:  2021-06-17 14:11:01.102000
#     Duration:       0:00:05.057000
#
#   BINOSPEC:
#     First observed: 2021-06-04 15:02:00.825000
#     Last observed:  2021-06-10 04:00:03.833000
#     Duration:       5 days, 12:58:03.008000
#
#   BLUE:
#     First observed: 2021-06-10 15:41:29.700000
#     Last observed:  2021-06-18 04:26:04.174000
#     Duration:       7 days, 12:44:34.474000
#
#   F5:
#     First observed: 2021-06-10 04:00:08.490000
#     Last observed:  2021-06-10 15:41:25.346000
#     Duration:       11:41:16.856000
#
#   F9:
#     First observed: 2021-06-10 15:44:14.937000
#     Last observed:  2021-06-18 11:25:20.023000
#     Duration:       7 days, 19:41:05.086000
#
#   HECTO:
#     First observed: 2021-06-28 10:42:56.830000
#     Last observed:  2021-06-30 23:59:55.617000
#     Duration:       2 days, 13:16:58.787000
#
#   MMIRS:
#     First observed: 2021-06-01 00:00:01.585000
#     Last observed:  2021-06-28 10:42:54.054000
#     Duration:       27 days, 10:42:52.469000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-06-01 00:00:00 to 2021-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1622530800000, end_timestamp_ms=1625122799000, instrument=
# Retrieved 2 records from hexapod_mini_instrument table
# Processed 2 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-06-17 21:10:56.045000 to 2021-06-17 21:11:01.102000 (duration: 0 days 00:00:05.057000)
#   ✓ : 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-06-01 00:00:00 to 2021-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1622530800000, end_timestamp_ms=1625122799000, instrument=NA
# Retrieved 6 records from hexapod_mini_instrument table
# Processed 6 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2021-06-08 17:49:17.642000 to 2021-06-08 17:49:22.727000 (duration: 0 days 00:00:05.085000)
#   Run 2: 2021-06-17 21:10:53.881000 to 2021-06-17 21:10:58.999000 (duration: 0 days 00:00:05.118000)
#   ✓ NA: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-06-01 00:00:00 to 2021-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1622530800000, end_timestamp_ms=1625122799000, instrument=binospec
# Retrieved 120948 records from hexapod_mini_instrument table
# Processed 120948 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-06-04 22:02:00.825000 to 2021-06-10 11:00:03.833000 (duration: 5 days 12:58:03.008000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-06-01 00:00:00 to 2021-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1622530800000, end_timestamp_ms=1625122799000, instrument=blue
# Retrieved 255581 records from hexapod_mini_instrument table
# Processed 255581 instrument records
# Identified 1 observing runs:
#   Run 1: 2021-06-10 22:41:29.700000 to 2021-06-18 11:26:04.174000 (duration: 7 days 12:44:34.474000)
#   ✓ BLUE: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-06-01 00:00:00 to 2021-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1622530800000, end_timestamp_ms=1625122799000, instrument=f5
# Retrieved 16590 records from hexapod_mini_instrument table
# Processed 16590 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-06-10 11:00:08.490000 to 2021-06-10 22:41:25.346000 (duration: 0 days 11:41:16.856000)
#   ✓ F5: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-06-01 00:00:00 to 2021-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1622530800000, end_timestamp_ms=1625122799000, instrument=f9
# Retrieved 9941 records from hexapod_mini_instrument table
# Processed 9941 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2021-06-10 22:44:14.937000 to 2021-06-10 22:44:45.752000 (duration: 0 days 00:00:30.815000)
#   Run 2: 2021-06-18 11:26:07.744000 to 2021-06-18 18:25:20.023000 (duration: 0 days 06:59:12.279000)
#   ✓ F9: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-06-01 00:00:00 to 2021-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1622530800000, end_timestamp_ms=1625122799000, instrument=hecto
# Retrieved 87026 records from hexapod_mini_instrument table
# Processed 87026 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-06-28 17:42:56.830000 to 2021-07-01 06:59:55.617000 (duration: 2 days 13:16:58.787000)
#   ✓ HECTO: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-06-01 00:00:00 to 2021-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1622530800000, end_timestamp_ms=1625122799000, instrument=mmirs
# Retrieved 402589 records from hexapod_mini_instrument table
# Processed 402589 instrument records
# Identified 2 observing runs:
#   Run 1: 2021-06-01 07:00:01.585000 to 2021-06-04 22:01:55.747000 (duration: 3 days 15:01:54.162000)
#   Run 2: 2021-06-18 18:25:22.801000 to 2021-06-28 17:42:54.054000 (duration: 9 days 23:17:31.253000)
#   ✓ MMIRS: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING:
# ======================================================================
# Analyzing 1 observing run(s) for :
#   Run 1: Skipped (duration 0 days 00:00:05.057000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 2 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:05.085000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:05.118000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2021-06-04 22:02:00.825000 to 2021-06-10 11:00:03.833000
#     Duration: 5 days 12:58:03.008000
#     Filtered 67485 points in 10s intervals with variance >= 2.0" arcsec (retained 97.6%)
#     Retrieved 2861022 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0756" Std=0.0704" Min=0.0000" Max=1.2411"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.6308" Std=0.7076" Min=-2.4401" Max=2.8377"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 386526 points:
#       Mean=0.0584" Std=0.0721" Min=0.0000" Max=1.2580"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 386526 points:
#       Mean=0.8249" Std=0.3996" Min=-1.9205" Max=2.8377"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2204479 points:
#       Mean=0.0805" Std=0.0673" Min=0.0000" Max=0.9727"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2204479 points:
#       Mean=-0.9326" Std=0.3325" Min=-2.4401" Max=1.3888"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: BLUE
# ======================================================================
# Analyzing 1 observing run(s) for blue:
#   Run 1: 2021-06-10 22:41:29.700000 to 2021-06-18 11:26:04.174000
#     Duration: 7 days 12:44:34.474000
#     Filtered 75639 points in 10s intervals with variance >= 2.0" arcsec (retained 98.5%)
#     Retrieved 5098913 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0676" Std=0.0780" Min=0.0000" Max=1.3068"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1579" Std=0.8641" Min=-2.1685" Max=2.6449"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1783491 points:
#       Mean=0.0796" Std=0.0717" Min=0.0000" Max=1.0470"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1783491 points:
#       Mean=0.8316" Std=0.3936" Min=-1.7377" Max=2.6449"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2596563 points:
#       Mean=0.0627" Std=0.0690" Min=0.0000" Max=1.2268"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2596563 points:
#       Mean=-0.8753" Std=0.3449" Min=-2.1491" Max=1.9865"
#
# Successfully analyzed 1 run(s) for blue
#
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 1 observing run(s) for f5:
#   Run 1: 2021-06-10 11:00:08.490000 to 2021-06-10 22:41:25.346000
#     Duration: 0 days 11:41:16.856000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: F9
# ======================================================================
# Analyzing 2 observing run(s) for f9:
#   Run 1: Skipped (duration 0 days 00:00:30.815000 is less than 1.0 hours)
#   Run 2: 2021-06-18 11:26:07.744000 to 2021-06-18 18:25:20.023000
#     Duration: 0 days 06:59:12.279000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2021-06-28 17:42:56.830000 to 2021-07-01 06:59:55.617000
#     Duration: 2 days 13:16:58.787000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 2 observing run(s) for mmirs:
#   Run 1: 2021-06-01 07:00:01.585000 to 2021-06-04 22:01:55.747000
#     Duration: 3 days 15:01:54.162000
#     Filtered 110931 points in 10s intervals with variance >= 2.0" arcsec (retained 90.2%)
#     Retrieved 1134844 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0577" Std=0.0549" Min=0.0000" Max=1.2364"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.5954" Std=0.7400" Min=-2.7650" Max=2.7301"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 128832 points:
#       Mean=0.0729" Std=0.0661" Min=0.0000" Max=1.0242"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 128832 points:
#       Mean=1.0670" Std=0.3465" Min=-1.5524" Max=2.7301"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 817517 points:
#       Mean=0.0587" Std=0.0537" Min=0.0000" Max=1.3442"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 817517 points:
#       Mean=-0.8994" Std=0.3348" Min=-2.7650" Max=1.7048"
#   Run 2: 2021-06-18 18:25:22.801000 to 2021-06-28 17:42:54.054000
#     Duration: 9 days 23:17:31.253000
#     Filtered 240958 points in 10s intervals with variance >= 2.0" arcsec (retained 94.2%)
#     Retrieved 4150540 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0697" Std=0.0653" Min=0.0000" Max=1.3022"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4564" Std=0.8334" Min=-2.4083" Max=2.4933"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 950246 points:
#       Mean=0.0671" Std=0.0524" Min=0.0000" Max=1.2144"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 950246 points:
#       Mean=0.7915" Std=0.4407" Min=-1.7880" Max=2.4933"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2594179 points:
#       Mean=0.0841" Std=0.0827" Min=0.0000" Max=1.3430"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2594179 points:
#       Mean=-0.9728" Std=0.3031" Min=-2.4083" Max=1.9502"
#
# Successfully analyzed 2 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 3
#   BINOSPEC: 1 run(s)
#   BLUE: 1 run(s)
#   MMIRS: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20210604_220200_to_20210610_110003.json
# ✓ blue Run 1: blue_20210610_224129_to_20210618_112604.json
# ✓ mmirs Run 1: mmirs_20210601_070001_to_20210604_220155.json
# ✓ mmirs Run 2: mmirs_20210618_182522_to_20210628_174254.json
#
# ✓ Saved statistics for 4 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30039
#   Timestamps: 30039
#   Rolling StdDev: 30039
#   Altitudes: 30039
#   Alt Velocities: 30039
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30516
#   Timestamps: 30516
#   Rolling StdDev: 30516
#   Altitudes: 30516
#   Alt Velocities: 30516
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30063
#   Timestamps: 30063
#   Rolling StdDev: 30063
#   Altitudes: 30063
#   Alt Velocities: 30063
# Plot data array lengths for BLUE (BOTH (Total)):
#   RMS Errors: 30021
#   Timestamps: 30021
#   Rolling StdDev: 30021
#   Altitudes: 30021
#   Alt Velocities: 30021
# Plot data array lengths for BLUE (UP (Elevation Increasing)):
#   RMS Errors: 30060
#   Timestamps: 30060
#   Rolling StdDev: 30060
#   Altitudes: 30060
#   Alt Velocities: 30060
# Plot data array lengths for BLUE (DOWN (Elevation Decreasing)):
#   RMS Errors: 30078
#   Timestamps: 30078
#   Rolling StdDev: 30078
#   Altitudes: 30078
#   Alt Velocities: 30078
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30024
#   Timestamps: 30024
#   Rolling StdDev: 30024
#   Altitudes: 30024
#   Alt Velocities: 30024
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30255
#   Timestamps: 30255
#   Rolling StdDev: 30255
#   Altitudes: 30255
#   Alt Velocities: 30255
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# ================================================================================
# Generated 9 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 18:46:06
# End DateTime:   2026-02-12 19:04:11
# Elapsed Time:   0h 18m 4s
# ================================================================================
