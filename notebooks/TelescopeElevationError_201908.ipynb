# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2019-08-01 00:00:00'
end_datetime = '2019-08-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 17:20:24
# Analysis period: 2019-08-01 00:00:00 to 2019-08-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2019-08-01 00:00:00 to 2019-08-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1564642800000, end_timestamp_ms=1567321199000
# Retrieved 2499353 total records from hexapod_mini_instrument
# Found 2 unique instrument(s)
#   NA: 67 records, 2019-08-01 04:50:58.932000 to 2019-08-27 18:37:37.083000
#   HECTO: 2499286 records, 2019-08-01 00:00:00.954000 to 2019-08-31 23:59:58.312000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   HECTO:
#     First observed: 2019-08-01 00:00:00.954000
#     Last observed:  2019-08-31 23:59:58.312000
#     Duration:       30 days, 23:59:57.358000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-08-01 00:00:00 to 2019-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1564642800000, end_timestamp_ms=1567321199000, instrument=NA
# Retrieved 67 records from hexapod_mini_instrument table
# Processed 67 instrument records
#
# Identified 5 observing runs:
#   Run 1: 2019-08-01 11:50:58.932000 to 2019-08-01 11:51:11.025000 (duration: 0 days 00:00:12.093000)
#   Run 2: 2019-08-20 14:49:34.146000 to 2019-08-20 14:49:45.363000 (duration: 0 days 00:00:11.217000)
#   Run 3: 2019-08-20 22:13:40.664000 to 2019-08-20 22:14:01.197000 (duration: 0 days 00:00:20.533000)
#   Run 4: 2019-08-22 18:05:32.018000 to 2019-08-22 18:05:52.687000 (duration: 0 days 00:00:20.669000)
#   Run 5: 2019-08-28 01:37:36.893000 to 2019-08-28 01:37:37.083000 (duration: 0 days 00:00:00.190000)
#   ✓ NA: 5 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-08-01 00:00:00 to 2019-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1564642800000, end_timestamp_ms=1567321199000, instrument=hecto
# Retrieved 2499286 records from hexapod_mini_instrument table
# Processed 2499286 instrument records
# Identified 3 observing runs:
#   Run 1: 2019-08-01 07:00:00.954000 to 2019-08-20 14:59:00.310000 (duration: 19 days 07:58:59.356000)
#   Run 2: 2019-08-20 22:14:01.241000 to 2019-08-22 14:42:51.836000 (duration: 1 days 16:28:50.595000)
#   Run 3: 2019-08-22 18:05:52.762000 to 2019-09-01 06:59:58.312000 (duration: 9 days 12:54:05.550000)
#   ✓ HECTO: 3 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 5 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:12.093000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:11.217000 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:00:20.533000 is less than 1.0 hours)
#   Run 4: Skipped (duration 0 days 00:00:20.669000 is less than 1.0 hours)
#   Run 5: Skipped (duration 0 days 00:00:00.190000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 3 observing run(s) for hecto:
#   Run 1: 2019-08-01 07:00:00.954000 to 2019-08-20 14:59:00.310000
#     Duration: 19 days 07:58:59.356000
#     No valid RMS records after filtering
#   Run 2: 2019-08-20 22:14:01.241000 to 2019-08-22 14:42:51.836000
#     Duration: 1 days 16:28:50.595000
#     No valid RMS records after filtering
#   Run 3: 2019-08-22 18:05:52.762000 to 2019-09-01 06:59:58.312000
#     Duration: 9 days 12:54:05.550000
#     Filtered 7493 points in 10s intervals with variance >= 2.0" arcsec (retained 97.8%)
#     Retrieved 347466 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.1216" Std=0.1260" Min=0.0000" Max=0.6344"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.6194" Std=0.5948" Min=-1.4347" Max=2.0211"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 197269 points:
#       Mean=0.0971" Std=0.0886" Min=0.0000" Max=0.4691"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 197269 points:
#       Mean=0.8362" Std=0.5200" Min=-1.4347" Max=2.0211"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 64297 points:
#       Mean=0.1668" Std=0.1004" Min=0.0143" Max=0.5222"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 64297 points:
#       Mean=0.6045" Std=0.6577" Min=-1.2142" Max=1.7519"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 1
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ hecto Run 3: hecto_20190822_180552_to_20190901_065958.json
#
# ✓ Saved statistics for 1 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30909
#   Timestamps: 30909
#   Rolling StdDev: 30909
#   Altitudes: 30909
#   Alt Velocities: 30909
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 31149
#   Timestamps: 31149
#   Rolling StdDev: 31149
#   Altitudes: 31149
#   Alt Velocities: 31149
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 32150
#   Timestamps: 32150
#   Rolling StdDev: 32150
#   Altitudes: 32150
#   Alt Velocities: 32150
# ================================================================================
# Generated 3 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 17:20:24
# End DateTime:   2026-02-12 17:21:06
# Elapsed Time:   0h 0m 42s
# ================================================================================
