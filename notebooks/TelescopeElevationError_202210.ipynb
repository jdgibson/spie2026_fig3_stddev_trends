# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2022-10-01 00:00:00'
end_datetime = '2022-10-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 20:02:58
# Analysis period: 2022-10-01 00:00:00 to 2022-10-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2022-10-01 00:00:00 to 2022-10-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1664607600000, end_timestamp_ms=1667285999000
# Retrieved 1057878 total records from hexapod_mini_instrument
# Found 7 unique instrument(s)
#   ARIES: 8177 records, 2022-10-31 18:16:11.503000 to 2022-10-31 23:59:57.581000
#   BINOSPEC: 427053 records, 2022-10-01 00:00:01.765000 to 2022-10-31 05:40:25.781000
#   BLUE: 109 records, 2022-10-26 10:41:19.393000 to 2022-10-26 10:45:51.092000
#   F15: 494 records, 2022-10-31 17:55:26.067000 to 2022-10-31 18:16:08.172000
#   F5: 17449 records, 2022-10-31 05:40:30.091000 to 2022-10-31 17:55:22.193000
#   F9: 1572 records, 2022-10-26 10:01:53.773000 to 2022-10-26 11:12:31.961000
#   HECTO: 603024 records, 2022-10-06 21:11:58.871000 to 2022-10-24 13:26:50.564000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   ARIES:
#     First observed: 2022-10-31 18:16:11.503000
#     Last observed:  2022-10-31 23:59:57.581000
#     Duration:       5:43:46.078000
#
#   BINOSPEC:
#     First observed: 2022-10-01 00:00:01.765000
#     Last observed:  2022-10-31 05:40:25.781000
#     Duration:       30 days, 5:40:24.016000
#
#   BLUE:
#     First observed: 2022-10-26 10:41:19.393000
#     Last observed:  2022-10-26 10:45:51.092000
#     Duration:       0:04:31.699000
#
#   F15:
#     First observed: 2022-10-31 17:55:26.067000
#     Last observed:  2022-10-31 18:16:08.172000
#     Duration:       0:20:42.105000
#
#   F5:
#     First observed: 2022-10-31 05:40:30.091000
#     Last observed:  2022-10-31 17:55:22.193000
#     Duration:       12:14:52.102000
#
#   F9:
#     First observed: 2022-10-26 10:01:53.773000
#     Last observed:  2022-10-26 11:12:31.961000
#     Duration:       1:10:38.188000
#
#   HECTO:
#     First observed: 2022-10-06 21:11:58.871000
#     Last observed:  2022-10-24 13:26:50.564000
#     Duration:       17 days, 16:14:51.693000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-10-01 00:00:00 to 2022-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1664607600000, end_timestamp_ms=1667285999000, instrument=aries
# Retrieved 8177 records from hexapod_mini_instrument table
# Processed 8177 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2022-11-01 01:16:11.503000 to 2022-11-01 06:59:57.581000 (duration: 0 days 05:43:46.078000)
#   ✓ ARIES: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-10-01 00:00:00 to 2022-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1664607600000, end_timestamp_ms=1667285999000, instrument=binospec
# Retrieved 427053 records from hexapod_mini_instrument table
# Processed 427053 instrument records
# Identified 3 observing runs:
#   Run 1: 2022-10-01 07:00:01.765000 to 2022-10-07 04:11:57.646000 (duration: 5 days 21:11:55.881000)
#   Run 2: 2022-10-24 20:26:54.790000 to 2022-10-26 17:01:51.203000 (duration: 1 days 20:34:56.413000)
#   Run 3: 2022-10-26 18:12:36.022000 to 2022-10-31 12:40:25.781000 (duration: 4 days 18:27:49.759000)
#   ✓ BINOSPEC: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-10-01 00:00:00 to 2022-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1664607600000, end_timestamp_ms=1667285999000, instrument=blue
# Retrieved 109 records from hexapod_mini_instrument table
# Processed 109 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2022-10-26 17:41:19.393000 to 2022-10-26 17:45:51.092000 (duration: 0 days 00:04:31.699000)
#   ✓ BLUE: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-10-01 00:00:00 to 2022-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1664607600000, end_timestamp_ms=1667285999000, instrument=f15
# Retrieved 494 records from hexapod_mini_instrument table
# Processed 494 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2022-11-01 00:55:26.067000 to 2022-11-01 01:16:08.172000 (duration: 0 days 00:20:42.105000)
#   ✓ F15: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-10-01 00:00:00 to 2022-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1664607600000, end_timestamp_ms=1667285999000, instrument=f5
# Retrieved 17449 records from hexapod_mini_instrument table
# Processed 17449 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2022-10-31 12:40:30.091000 to 2022-11-01 00:55:22.193000 (duration: 0 days 12:14:52.102000)
#   ✓ F5: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-10-01 00:00:00 to 2022-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1664607600000, end_timestamp_ms=1667285999000, instrument=f9
# Retrieved 1572 records from hexapod_mini_instrument table
# Processed 1572 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2022-10-26 17:01:53.773000 to 2022-10-26 18:12:31.961000 (duration: 0 days 01:10:38.188000)
#   ✓ F9: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-10-01 00:00:00 to 2022-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1664607600000, end_timestamp_ms=1667285999000, instrument=hecto
# Retrieved 603024 records from hexapod_mini_instrument table
# Processed 603024 instrument records
# Identified 1 observing runs:
#   Run 1: 2022-10-07 04:11:58.871000 to 2022-10-24 20:26:50.564000 (duration: 17 days 16:14:51.693000)
#   ✓ HECTO: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: ARIES
# ======================================================================
# Analyzing 1 observing run(s) for aries:
#   Run 1: 2022-11-01 01:16:11.503000 to 2022-11-01 06:59:57.581000
#     Duration: 0 days 05:43:46.078000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 3 observing run(s) for binospec:
#   Run 1: 2022-10-01 07:00:01.765000 to 2022-10-07 04:11:57.646000
#     Duration: 5 days 21:11:55.881000
#     Filtered 71813 points in 10s intervals with variance >= 2.0" arcsec (retained 90.7%)
#     Retrieved 774232 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0854" Std=0.0834" Min=0.0000" Max=0.9861"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4881" Std=0.8213" Min=-2.4159" Max=1.4404"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 180076 points:
#       Mean=0.0245" Std=0.0305" Min=0.0000" Max=1.2046"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 180076 points:
#       Mean=0.6845" Std=0.2509" Min=-2.1612" Max=1.4404"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 449354 points:
#       Mean=0.1168" Std=0.0854" Min=0.0000" Max=0.6690"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 449354 points:
#       Mean=-1.0065" Std=0.4178" Min=-2.4159" Max=1.2818"
#   Run 2: 2022-10-24 20:26:54.790000 to 2022-10-26 17:01:51.203000
#     Duration: 1 days 20:34:56.413000
#     Filtered 34313 points in 10s intervals with variance >= 2.0" arcsec (retained 97.9%)
#     Retrieved 1638317 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0481" Std=0.0396" Min=0.0000" Max=1.2605"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4074" Std=0.8677" Min=-2.0169" Max=2.3290"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 329779 points:
#       Mean=0.0514" Std=0.0353" Min=0.0000" Max=0.7943"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 329779 points:
#       Mean=1.0665" Std=0.3943" Min=-1.4232" Max=2.3290"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1075575 points:
#       Mean=0.0518" Std=0.0389" Min=0.0000" Max=0.6820"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1075575 points:
#       Mean=-0.9128" Std=0.3558" Min=-2.0169" Max=1.4945"
#   Run 3: 2022-10-26 18:12:36.022000 to 2022-10-31 12:40:25.781000
#     Duration: 4 days 18:27:49.759000
#     Filtered 66284 points in 10s intervals with variance >= 2.0" arcsec (retained 98.3%)
#     Retrieved 3861642 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0679" Std=0.0851" Min=0.0000" Max=1.1267"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.6283" Std=0.6333" Min=-2.3864" Max=2.2884"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 454721 points:
#       Mean=0.0409" Std=0.0347" Min=0.0000" Max=1.0637"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 454721 points:
#       Mean=0.5626" Std=0.3506" Min=-1.9711" Max=2.2884"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2784146 points:
#       Mean=0.0866" Std=0.0962" Min=0.0000" Max=0.7464"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2784146 points:
#       Mean=-0.9374" Std=0.3489" Min=-2.3864" Max=1.1105"
#
# Successfully analyzed 3 run(s) for binospec
#
# ======================================================================
# PROCESSING: BLUE
# ======================================================================
# Analyzing 1 observing run(s) for blue:
#   Run 1: Skipped (duration 0 days 00:04:31.699000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: F15
# ======================================================================
# Analyzing 1 observing run(s) for f15:
#   Run 1: Skipped (duration 0 days 00:20:42.105000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 1 observing run(s) for f5:
#   Run 1: 2022-10-31 12:40:30.091000 to 2022-11-01 00:55:22.193000
#     Duration: 0 days 12:14:52.102000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: F9
# ======================================================================
# Analyzing 1 observing run(s) for f9:
#   Run 1: 2022-10-26 17:01:53.773000 to 2022-10-26 18:12:31.961000
#     Duration: 0 days 01:10:38.188000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2022-10-07 04:11:58.871000 to 2022-10-24 20:26:50.564000
#     Duration: 17 days 16:14:51.693000
#     Filtered 96400 points in 10s intervals with variance >= 2.0" arcsec (retained 98.0%)
#     Retrieved 4726025 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0658" Std=0.0739" Min=0.0000" Max=1.2695"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0761" Std=1.0122" Min=-2.2894" Max=2.3561"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2381954 points:
#       Mean=0.0767" Std=0.0848" Min=0.0000" Max=1.2513"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2381954 points:
#       Mean=0.9630" Std=0.3499" Min=-1.4703" Max=2.3561"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1880321 points:
#       Mean=0.0632" Std=0.0643" Min=0.0000" Max=1.0012"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1880321 points:
#       Mean=-1.0396" Std=0.3283" Min=-2.2894" Max=1.6037"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 3 run(s)
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20221001_070001_to_20221007_041157.json
# ✓ binospec Run 2: binospec_20221024_202654_to_20221026_170151.json
# ✓ binospec Run 3: binospec_20221026_181236_to_20221031_124025.json
# ✓ hecto Run 1: hecto_20221007_041158_to_20221024_202650.json
#
# ✓ Saved statistics for 4 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30009
#   Timestamps: 30009
#   Rolling StdDev: 30009
#   Altitudes: 30009
#   Alt Velocities: 30009
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30144
#   Timestamps: 30144
#   Rolling StdDev: 30144
#   Altitudes: 30144
#   Alt Velocities: 30144
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30066
#   Timestamps: 30066
#   Rolling StdDev: 30066
#   Altitudes: 30066
#   Alt Velocities: 30066
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30063
#   Timestamps: 30063
#   Rolling StdDev: 30063
#   Altitudes: 30063
#   Alt Velocities: 30063
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30027
#   Timestamps: 30027
#   Rolling StdDev: 30027
#   Altitudes: 30027
#   Alt Velocities: 30027
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30006
#   Timestamps: 30006
#   Rolling StdDev: 30006
#   Altitudes: 30006
#   Alt Velocities: 30006
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 20:02:58
# End DateTime:   2026-02-12 20:20:35
# Elapsed Time:   0h 17m 36s
# ================================================================================
