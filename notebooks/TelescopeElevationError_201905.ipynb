# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2019-05-01 00:00:00'
end_datetime = '2019-05-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 17:07:37
# Analysis period: 2019-05-01 00:00:00 to 2019-05-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2019-05-01 00:00:00 to 2019-05-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1556694000000, end_timestamp_ms=1559372399000
# Retrieved 648400 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   BINOSPEC: 576976 records, 2019-05-24 16:17:02 to 2019-05-31 23:59:58.142000
#   HECTO: 23984 records, 2019-05-01 00:00:31 to 2019-05-17 16:30:30
#   MMIRS: 47440 records, 2019-05-17 16:31:30 to 2019-05-24 16:16:02
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2019-05-24 16:17:02
#     Last observed:  2019-05-31 23:59:58.142000
#     Duration:       7 days, 7:42:56.142000
#
#   HECTO:
#     First observed: 2019-05-01 00:00:31
#     Last observed:  2019-05-17 16:30:30
#     Duration:       16 days, 16:29:59
#
#   MMIRS:
#     First observed: 2019-05-17 16:31:30
#     Last observed:  2019-05-24 16:16:02
#     Duration:       6 days, 23:44:32
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-05-01 00:00:00 to 2019-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1556694000000, end_timestamp_ms=1559372399000, instrument=binospec
# Retrieved 576976 records from hexapod_mini_instrument table
# Processed 576976 instrument records
# Identified 1 observing runs:
#   Run 1: 2019-05-24 23:17:02 to 2019-06-01 06:59:58.142000 (duration: 7 days 07:42:56.142000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-05-01 00:00:00 to 2019-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1556694000000, end_timestamp_ms=1559372399000, instrument=hecto
# Retrieved 23984 records from hexapod_mini_instrument table
# Processed 23984 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2019-05-01 07:00:31 to 2019-05-17 23:30:30 (duration: 16 days 16:29:59)
#   ✓ HECTO: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-05-01 00:00:00 to 2019-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1556694000000, end_timestamp_ms=1559372399000, instrument=mmirs
# Retrieved 47440 records from hexapod_mini_instrument table
# Processed 47440 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2019-05-17 23:31:30 to 2019-05-24 23:16:02 (duration: 6 days 23:44:32)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2019-05-24 23:17:02 to 2019-06-01 06:59:58.142000
#     Duration: 7 days 07:42:56.142000
#     Filtered 81084 points in 10s intervals with variance >= 2.0" arcsec (retained 98.0%)
#     Retrieved 4013111 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0568" Std=0.0728" Min=0.0000" Max=1.2772"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.5699" Std=0.6762" Min=-2.5531" Max=1.8170"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 594791 points:
#       Mean=0.0567" Std=0.0664" Min=0.0000" Max=0.8029"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 594791 points:
#       Mean=0.6922" Std=0.3539" Min=-1.7346" Max=1.8170"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2972918 points:
#       Mean=0.0661" Std=0.0869" Min=0.0000" Max=0.9383"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2972918 points:
#       Mean=-0.8840" Std=0.3429" Min=-2.5531" Max=1.6906"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2019-05-01 07:00:31 to 2019-05-17 23:30:30
#     Duration: 16 days 16:29:59
#     Filtered 100011 points in 10s intervals with variance >= 2.0" arcsec (retained 98.6%)
#     Retrieved 7048582 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0772" Std=0.1080" Min=0.0000" Max=1.3724"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0434" Std=1.0605" Min=-2.6766" Max=2.2632"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 3320741 points:
#       Mean=0.0728" Std=0.1067" Min=0.0000" Max=1.2841"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 3320741 points:
#       Mean=0.9893" Std=0.3542" Min=-2.2883" Max=2.2632"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 3313194 points:
#       Mean=0.0850" Std=0.1085" Min=0.0000" Max=0.8620"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 3313194 points:
#       Mean=-1.0768" Std=0.2903" Min=-2.6766" Max=1.4419"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2019-05-17 23:31:30 to 2019-05-24 23:16:02
#     Duration: 6 days 23:44:32
#     Filtered 176312 points in 10s intervals with variance >= 2.0" arcsec (retained 92.5%)
#     Retrieved 2344369 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0414" Std=0.0423" Min=0.0000" Max=1.1611"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1259" Std=0.7715" Min=-2.5572" Max=2.7333"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 746793 points:
#       Mean=0.0430" Std=0.0413" Min=0.0000" Max=1.0691"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 746793 points:
#       Mean=0.7562" Std=0.3495" Min=-1.4473" Max=2.7333"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1075337 points:
#       Mean=0.0443" Std=0.0388" Min=0.0000" Max=1.2214"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1075337 points:
#       Mean=-0.7671" Std=0.3720" Min=-2.5572" Max=1.5348"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 3
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20190524_231702_to_20190601_065958.json
# ✓ hecto Run 1: hecto_20190501_070031_to_20190517_233030.json
# ✓ mmirs Run 1: mmirs_20190517_233130_to_20190524_231602.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30018
#   Timestamps: 30018
#   Rolling StdDev: 30018
#   Altitudes: 30018
#   Alt Velocities: 30018
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30246
#   Timestamps: 30246
#   Rolling StdDev: 30246
#   Altitudes: 30246
#   Alt Velocities: 30246
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30030
#   Timestamps: 30030
#   Rolling StdDev: 30030
#   Altitudes: 30030
#   Alt Velocities: 30030
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30039
#   Timestamps: 30039
#   Rolling StdDev: 30039
#   Altitudes: 30039
#   Alt Velocities: 30039
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30009
#   Timestamps: 30009
#   Rolling StdDev: 30009
#   Altitudes: 30009
#   Alt Velocities: 30009
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30030
#   Timestamps: 30030
#   Rolling StdDev: 30030
#   Altitudes: 30030
#   Alt Velocities: 30030
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30114
#   Timestamps: 30114
#   Rolling StdDev: 30114
#   Altitudes: 30114
#   Alt Velocities: 30114
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30276
#   Timestamps: 30276
#   Rolling StdDev: 30276
#   Altitudes: 30276
#   Alt Velocities: 30276
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30150
#   Timestamps: 30150
#   Rolling StdDev: 30150
#   Altitudes: 30150
#   Alt Velocities: 30150
# ================================================================================
# Generated 9 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 17:07:37
# End DateTime:   2026-02-12 17:32:42
# Elapsed Time:   0h 25m 4s
# ================================================================================
