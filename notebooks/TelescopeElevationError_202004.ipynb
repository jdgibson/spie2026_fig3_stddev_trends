# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2020-04-01 00:00:00'
end_datetime = '2020-04-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ...
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ...
# Start DateTime: 2026-02-12 17:52:17
# Analysis period: 2020-04-01 00:00:00 to 2020-04-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2020-04-01 00:00:00 to 2020-04-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1585724400000, end_timestamp_ms=1588316399000
# Retrieved 2476963 total records from hexapod_mini_instrument
# Found 1 unique instrument(s)
#   BINOSPEC: 2476963 records, 2020-04-01 00:00:00.259000 to 2020-04-30 23:59:58.587000
#
# ...
# INSTRUMENTS ON TELESCOPE
# ...
#
#   BINOSPEC:
#     First observed: 2020-04-01 00:00:00.259000
#     Last observed:  2020-04-30 23:59:58.587000
#     Duration:       29 days, 23:59:58.328000
#
# ...
#
# Preparing observing runs data...
# ...
