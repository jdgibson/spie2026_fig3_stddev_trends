# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2022-07-01 00:00:00'
end_datetime = '2022-07-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 20:01:30
# Analysis period: 2022-07-01 00:00:00 to 2022-07-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2022-07-01 00:00:00 to 2022-07-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1656658800000, end_timestamp_ms=1659337199000
# Retrieved 1059243 total records from hexapod_mini_instrument
# Found 2 unique instrument(s)
#   NA: 12 records, 2022-07-26 10:58:03.502000 to 2022-07-30 11:24:59.897000
#   BINOSPEC: 1059231 records, 2022-07-01 00:00:04.600000 to 2022-07-31 23:59:56.808000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2022-07-01 00:00:04.600000
#     Last observed:  2022-07-31 23:59:56.808000
#     Duration:       30 days, 23:59:52.208000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-07-01 00:00:00 to 2022-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1656658800000, end_timestamp_ms=1659337199000, instrument=NA
# Retrieved 12 records from hexapod_mini_instrument table
# Processed 12 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2022-07-26 17:58:03.502000 to 2022-07-26 17:58:53.004000 (duration: 0 days 00:00:49.502000)
#   Run 2: 2022-07-30 18:24:59.897000 to 2022-07-30 18:24:59.897000 (duration: 0 days 00:00:00)
#   ✓ NA: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-07-01 00:00:00 to 2022-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1656658800000, end_timestamp_ms=1659337199000, instrument=binospec
# Retrieved 1059231 records from hexapod_mini_instrument table
# Processed 1059231 instrument records
# Identified 2 observing runs:
#   Run 1: 2022-07-01 07:00:04.600000 to 2022-07-26 16:41:02.597000 (duration: 25 days 09:40:57.997000)
#   Run 2: 2022-07-26 17:58:53.037000 to 2022-08-01 06:59:56.808000 (duration: 5 days 13:01:03.771000)
#   ✓ BINOSPEC: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 2 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:49.502000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2022-07-01 07:00:04.600000 to 2022-07-26 16:41:02.597000
#     Duration: 25 days 09:40:57.997000
#     Filtered 42684 points in 10s intervals with variance >= 2.0" arcsec (retained 98.0%)
#     Retrieved 2124177 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0746" Std=0.0635" Min=0.0000" Max=1.2088"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2509" Std=0.8570" Min=-2.0527" Max=2.4103"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 671855 points:
#       Mean=0.0949" Std=0.0742" Min=0.0000" Max=0.8454"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 671855 points:
#       Mean=0.7547" Std=0.4146" Min=-1.6672" Max=2.4103"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1100125 points:
#       Mean=0.0697" Std=0.0570" Min=0.0000" Max=0.8832"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1100125 points:
#       Mean=-0.9428" Std=0.3587" Min=-2.0527" Max=1.4584"
#   Run 2: 2022-07-26 17:58:53.037000 to 2022-08-01 06:59:56.808000
#     Duration: 5 days 13:01:03.771000
#     No valid RMS records after filtering
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 1
#   BINOSPEC: 1 run(s)
# ======================================================================
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20220701_070004_to_20220726_164102.json
#
# ✓ Saved statistics for 1 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30024
#   Timestamps: 30024
#   Rolling StdDev: 30024
#   Altitudes: 30024
#   Alt Velocities: 30024
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30084
#   Timestamps: 30084
#   Rolling StdDev: 30084
#   Altitudes: 30084
#   Alt Velocities: 30084
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30006
#   Timestamps: 30006
#   Rolling StdDev: 30006
#   Altitudes: 30006
#   Alt Velocities: 30006
# ================================================================================
# Generated 3 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 20:01:30
# End DateTime:   2026-02-12 20:03:20
# Elapsed Time:   0h 1m 50s
# ================================================================================
