# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2019-11-01 00:00:00'
end_datetime = '2019-11-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 17:22:49
# Analysis period: 2019-11-01 00:00:00 to 2019-11-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2019-11-01 00:00:00 to 2019-11-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1572591600000, end_timestamp_ms=1575183599000
# Retrieved 2431912 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 54 records, 2019-11-05 05:48:50.313000 to 2019-11-26 05:42:28.173000
#   BINOSPEC: 1481123 records, 2019-11-01 00:00:00.933000 to 2019-11-30 23:59:58.120000
#   HECTO: 950735 records, 2019-11-06 16:34:35.718000 to 2019-11-18 15:54:34.642000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2019-11-01 00:00:00.933000
#     Last observed:  2019-11-30 23:59:58.120000
#     Duration:       29 days, 23:59:57.187000
#
#   HECTO:
#     First observed: 2019-11-06 16:34:35.718000
#     Last observed:  2019-11-18 15:54:34.642000
#     Duration:       11 days, 23:19:58.924000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-11-01 00:00:00 to 2019-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1572591600000, end_timestamp_ms=1575183599000, instrument=NA
# Retrieved 54 records from hexapod_mini_instrument table
# Processed 54 instrument records
#
# Identified 4 observing runs:
#   Run 1: 2019-11-05 12:48:50.313000 to 2019-11-05 12:48:50.313000 (duration: 0 days 00:00:00)
#   Run 2: 2019-11-13 23:46:39.237000 to 2019-11-13 23:47:05.218000 (duration: 0 days 00:00:25.981000)
#   Run 3: 2019-11-25 22:24:06.161000 to 2019-11-25 22:55:43.940000 (duration: 0 days 00:31:37.779000)
#   Run 4: 2019-11-26 12:42:07.331000 to 2019-11-26 12:42:28.173000 (duration: 0 days 00:00:20.842000)
#   ✓ NA: 4 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-11-01 00:00:00 to 2019-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1572591600000, end_timestamp_ms=1575183599000, instrument=binospec
# Retrieved 1481123 records from hexapod_mini_instrument table
# Processed 1481123 instrument records
# Identified 2 observing runs:
#   Run 1: 2019-11-01 07:00:00.933000 to 2019-11-06 23:34:34.637000 (duration: 5 days 16:34:33.704000)
#   Run 2: 2019-11-18 22:54:35.726000 to 2019-12-01 06:59:58.120000 (duration: 12 days 08:05:22.394000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-11-01 00:00:00 to 2019-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1572591600000, end_timestamp_ms=1575183599000, instrument=hecto
# Retrieved 950735 records from hexapod_mini_instrument table
# Processed 950735 instrument records
# Identified 2 observing runs:
#   Run 1: 2019-11-06 23:34:35.718000 to 2019-11-13 15:07:32.653000 (duration: 6 days 15:32:56.935000)
#   Run 2: 2019-11-13 23:47:05.285000 to 2019-11-18 22:54:34.642000 (duration: 4 days 23:07:29.357000)
#   ✓ HECTO: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 4 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:25.981000 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:31:37.779000 is less than 1.0 hours)
#   Run 4: Skipped (duration 0 days 00:00:20.842000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2019-11-01 07:00:00.933000 to 2019-11-06 23:34:34.637000
#     Duration: 5 days 16:34:33.704000
#     Filtered 24757 points in 10s intervals with variance >= 2.0" arcsec (retained 99.1%)
#     Retrieved 2895180 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0597" Std=0.0574" Min=0.0000" Max=1.2114"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2469" Std=0.8942" Min=-2.5256" Max=1.9708"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 922159 points:
#       Mean=0.0526" Std=0.0475" Min=0.0000" Max=0.9602"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 922159 points:
#       Mean=0.9133" Std=0.3310" Min=-1.5712" Max=1.9708"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1661334 points:
#       Mean=0.0712" Std=0.0609" Min=0.0000" Max=1.2708"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1661334 points:
#       Mean=-0.9230" Std=0.3124" Min=-2.5256" Max=1.7284"
#   Run 2: 2019-11-18 22:54:35.726000 to 2019-12-01 06:59:58.120000
#     Duration: 12 days 08:05:22.394000
#     Filtered 15780 points in 10s intervals with variance >= 2.0" arcsec (retained 99.1%)
#     Retrieved 1718767 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0404" Std=0.0443" Min=0.0000" Max=1.2096"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0514" Std=0.9715" Min=-2.3301" Max=2.4099"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 893284 points:
#       Mean=0.0356" Std=0.0369" Min=0.0000" Max=1.3087"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 893284 points:
#       Mean=0.8577" Std=0.3435" Min=-1.6338" Max=2.4099"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 612159 points:
#       Mean=0.0441" Std=0.0371" Min=0.0000" Max=0.7898"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 612159 points:
#       Mean=-1.0979" Std=0.3670" Min=-2.3301" Max=2.0341"
#
# Successfully analyzed 2 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 2 observing run(s) for hecto:
#   Run 1: 2019-11-06 23:34:35.718000 to 2019-11-13 15:07:32.653000
#     Duration: 6 days 15:32:56.935000
#     Filtered 17958 points in 10s intervals with variance >= 2.0" arcsec (retained 98.9%)
#     Retrieved 1679880 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0416" Std=0.0423" Min=0.0000" Max=0.9694"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0213" Std=0.7231" Min=-1.4038" Max=1.9955"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 608802 points:
#       Mean=0.0513" Std=0.0540" Min=0.0000" Max=0.8885"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 608802 points:
#       Mean=0.8006" Std=0.3495" Min=-0.8046" Max=1.9955"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 787831 points:
#       Mean=0.0398" Std=0.0284" Min=0.0000" Max=0.5418"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 787831 points:
#       Mean=-0.6536" Std=0.2581" Min=-1.4038" Max=1.5495"
#   Run 2: 2019-11-13 23:47:05.285000 to 2019-11-18 22:54:34.642000
#     Duration: 4 days 23:07:29.357000
#     Filtered 34553 points in 10s intervals with variance >= 2.0" arcsec (retained 98.9%)
#     Retrieved 3069231 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0387" Std=0.0471" Min=0.0000" Max=1.0588"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.2128" Std=0.7006" Min=-1.9058" Max=1.7005"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1438195 points:
#       Mean=0.0437" Std=0.0512" Min=0.0000" Max=0.7573"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1438195 points:
#       Mean=0.8425" Std=0.3865" Min=-1.0822" Max=1.7005"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1015629 points:
#       Mean=0.0405" Std=0.0262" Min=0.0000" Max=0.5627"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1015629 points:
#       Mean=-0.5459" Std=0.2379" Min=-1.9058" Max=1.6138"
#
# Successfully analyzed 2 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 2 run(s)
#   HECTO: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20191101_070000_to_20191106_233434.json
# ✓ binospec Run 2: binospec_20191118_225435_to_20191201_065958.json
# ✓ hecto Run 1: hecto_20191106_233435_to_20191113_150732.json
# ✓ hecto Run 2: hecto_20191113_234705_to_20191118_225434.json
#
# ✓ Saved statistics for 4 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30024
#   Timestamps: 30024
#   Rolling StdDev: 30024
#   Altitudes: 30024
#   Alt Velocities: 30024
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30093
#   Timestamps: 30093
#   Rolling StdDev: 30093
#   Altitudes: 30093
#   Alt Velocities: 30093
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30048
#   Timestamps: 30048
#   Rolling StdDev: 30048
#   Altitudes: 30048
#   Alt Velocities: 30048
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30045
#   Timestamps: 30045
#   Rolling StdDev: 30045
#   Altitudes: 30045
#   Alt Velocities: 30045
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30105
#   Timestamps: 30105
#   Rolling StdDev: 30105
#   Altitudes: 30105
#   Alt Velocities: 30105
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30060
#   Timestamps: 30060
#   Rolling StdDev: 30060
#   Altitudes: 30060
#   Alt Velocities: 30060
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 17:22:49
# End DateTime:   2026-02-12 17:31:05
# Elapsed Time:   0h 8m 16s
# ================================================================================
