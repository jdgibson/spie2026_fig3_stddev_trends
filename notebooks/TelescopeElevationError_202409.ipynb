# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2024-09-01 00:00:00'
end_datetime = '2024-09-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 21:43:24
# Analysis period: 2024-09-01 00:00:00 to 2024-09-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2024-09-01 00:00:00 to 2024-09-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1725174000000, end_timestamp_ms=1727765999000
# Retrieved 1027693 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   BINOSPEC: 506918 records, 2024-09-01 00:00:02.921000 to 2024-09-30 23:59:57.670000
#   HECTO: 248062 records, 2024-09-20 14:44:15.659000 to 2024-09-27 20:32:10.118000
#   MMIRS: 272713 records, 2024-09-12 15:42:59.157000 to 2024-09-20 14:44:12.188000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2024-09-01 00:00:02.921000
#     Last observed:  2024-09-30 23:59:57.670000
#     Duration:       29 days, 23:59:54.749000
#
#   HECTO:
#     First observed: 2024-09-20 14:44:15.659000
#     Last observed:  2024-09-27 20:32:10.118000
#     Duration:       7 days, 5:47:54.459000
#
#   MMIRS:
#     First observed: 2024-09-12 15:42:59.157000
#     Last observed:  2024-09-20 14:44:12.188000
#     Duration:       7 days, 23:01:13.031000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-09-01 00:00:00 to 2024-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1725174000000, end_timestamp_ms=1727765999000, instrument=binospec
# Retrieved 506918 records from hexapod_mini_instrument table
# Processed 506918 instrument records
# Identified 2 observing runs:
#   Run 1: 2024-09-01 07:00:02.921000 to 2024-09-12 22:42:57.170000 (duration: 11 days 15:42:54.249000)
#   Run 2: 2024-09-28 03:32:13.598000 to 2024-10-01 06:59:57.670000 (duration: 3 days 03:27:44.072000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-09-01 00:00:00 to 2024-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1725174000000, end_timestamp_ms=1727765999000, instrument=hecto
# Retrieved 248062 records from hexapod_mini_instrument table
# Processed 248062 instrument records
# Identified 1 observing runs:
#   Run 1: 2024-09-20 21:44:15.659000 to 2024-09-28 03:32:10.118000 (duration: 7 days 05:47:54.459000)
#   ✓ HECTO: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-09-01 00:00:00 to 2024-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1725174000000, end_timestamp_ms=1727765999000, instrument=mmirs
# Retrieved 272713 records from hexapod_mini_instrument table
# Processed 272713 instrument records
# Identified 1 observing runs:
#   Run 1: 2024-09-12 22:42:59.157000 to 2024-09-20 21:44:12.188000 (duration: 7 days 23:01:13.031000)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2024-09-01 07:00:02.921000 to 2024-09-12 22:42:57.170000
#     Duration: 11 days 15:42:54.249000
#     Filtered 470036 points in 10s intervals with variance >= 2.0" arcsec (retained 94.1%)
#     Retrieved 7973464 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0993" Std=0.1009" Min=0.0000" Max=1.3134"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1483" Std=0.8756" Min=-2.5180" Max=2.6078"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2854259 points:
#       Mean=0.1122" Std=0.0926" Min=0.0000" Max=1.3107"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2854259 points:
#       Mean=0.6827" Std=0.6645" Min=-2.5170" Max=2.6078"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 3451703 points:
#       Mean=0.0888" Std=0.0849" Min=0.0000" Max=1.2576"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 3451703 points:
#       Mean=-0.8402" Std=0.3917" Min=-2.5180" Max=2.2660"
#   Run 2: 2024-09-28 03:32:13.598000 to 2024-10-01 06:59:57.670000
#     Duration: 3 days 03:27:44.072000
#     Filtered 49953 points in 10s intervals with variance >= 2.0" arcsec (retained 97.4%)
#     Retrieved 1887624 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0863" Std=0.0653" Min=0.0000" Max=0.9023"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4663" Std=0.6192" Min=-2.1048" Max=1.7943"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 336557 points:
#       Mean=0.1223" Std=0.0729" Min=0.0000" Max=0.8581"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 336557 points:
#       Mean=0.3270" Std=0.5174" Min=-2.1048" Max=1.7943"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1079684 points:
#       Mean=0.0924" Std=0.0611" Min=0.0000" Max=0.8378"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1079684 points:
#       Mean=-0.8053" Std=0.3759" Min=-2.0966" Max=1.6401"
#
# Successfully analyzed 2 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2024-09-20 21:44:15.659000 to 2024-09-28 03:32:10.118000
#     Duration: 7 days 05:47:54.459000
#     Filtered 53386 points in 10s intervals with variance >= 2.0" arcsec (retained 98.7%)
#     Retrieved 4134867 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0662" Std=0.0760" Min=0.0000" Max=1.2847"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.3799" Std=1.0528" Min=-2.3479" Max=2.2165"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1220401 points:
#       Mean=0.0704" Std=0.0699" Min=0.0000" Max=1.3303"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1220401 points:
#       Mean=1.1147" Std=0.4428" Min=-1.9202" Max=2.2165"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2708997 points:
#       Mean=0.0822" Std=0.0985" Min=0.0000" Max=1.3449"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2708997 points:
#       Mean=-1.0541" Std=0.3226" Min=-2.3479" Max=1.7336"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2024-09-12 22:42:59.157000 to 2024-09-20 21:44:12.188000
#     Duration: 7 days 23:01:13.031000
#     Filtered 257565 points in 10s intervals with variance >= 2.0" arcsec (retained 90.6%)
#     Retrieved 2727834 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0923" Std=0.0678" Min=0.0000" Max=1.2168"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1633" Std=1.0259" Min=-2.7566" Max=2.7409"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1016450 points:
#       Mean=0.1002" Std=0.0599" Min=0.0000" Max=1.1290"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1016450 points:
#       Mean=0.9574" Std=0.3834" Min=-1.5394" Max=2.7409"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1315660 points:
#       Mean=0.0920" Std=0.0710" Min=0.0000" Max=0.7323"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1315660 points:
#       Mean=-1.0423" Std=0.3200" Min=-2.7566" Max=1.8011"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 3
#   BINOSPEC: 2 run(s)
#   HECTO: 1 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20240901_070002_to_20240912_224257.json
# ✓ binospec Run 2: binospec_20240928_033213_to_20241001_065957.json
# ✓ hecto Run 1: hecto_20240920_214415_to_20240928_033210.json
# ✓ mmirs Run 1: mmirs_20240912_224259_to_20240920_214412.json
#
# ✓ Saved statistics for 4 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30006
#   Timestamps: 30006
#   Rolling StdDev: 30006
#   Altitudes: 30006
#   Alt Velocities: 30006
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30009
#   Timestamps: 30009
#   Rolling StdDev: 30009
#   Altitudes: 30009
#   Alt Velocities: 30009
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30012
#   Timestamps: 30012
#   Rolling StdDev: 30012
#   Altitudes: 30012
#   Alt Velocities: 30012
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30012
#   Timestamps: 30012
#   Rolling StdDev: 30012
#   Altitudes: 30012
#   Alt Velocities: 30012
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30012
#   Timestamps: 30012
#   Rolling StdDev: 30012
#   Altitudes: 30012
#   Alt Velocities: 30012
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30102
#   Timestamps: 30102
#   Rolling StdDev: 30102
#   Altitudes: 30102
#   Alt Velocities: 30102
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30006
#   Timestamps: 30006
#   Rolling StdDev: 30006
#   Altitudes: 30006
#   Alt Velocities: 30006
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30192
#   Timestamps: 30192
#   Rolling StdDev: 30192
#   Altitudes: 30192
#   Alt Velocities: 30192
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30132
#   Timestamps: 30132
#   Rolling StdDev: 30132
#   Altitudes: 30132
#   Alt Velocities: 30132
# ================================================================================
# Generated 9 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 21:43:24
# End DateTime:   2026-02-12 22:07:39
# Elapsed Time:   0h 24m 15s
# ================================================================================
