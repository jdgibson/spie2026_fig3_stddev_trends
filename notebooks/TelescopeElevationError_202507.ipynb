# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2025-07-01 00:00:00'
end_datetime = '2025-07-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 22:32:57
# Analysis period: 2025-07-01 00:00:00 to 2025-07-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2025-07-01 00:00:00 to 2025-07-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1751353200000, end_timestamp_ms=1754031599000
# Retrieved 991998 total records from hexapod_mini_instrument
# Found 5 unique instrument(s)
#   NA: 63316 records, 2025-07-28 08:00:24.846000 to 2025-07-31 23:59:56.276000
#   BINOSPEC: 465015 records, 2025-07-01 00:00:00.189000 to 2025-07-28 06:25:35.345000
#   BLUE: 8365 records, 2025-07-03 10:30:45.348000 to 2025-07-03 16:23:41.280000
#   HECTO: 239263 records, 2025-07-03 16:23:28.411000 to 2025-07-10 16:32:43.758000
#   MMIRS: 216039 records, 2025-07-10 16:32:47.953000 to 2025-07-17 02:05:58.860000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2025-07-01 00:00:00.189000
#     Last observed:  2025-07-28 06:25:35.345000
#     Duration:       27 days, 6:25:35.156000
#
#   BLUE:
#     First observed: 2025-07-03 10:30:45.348000
#     Last observed:  2025-07-03 16:23:41.280000
#     Duration:       5:52:55.932000
#
#   HECTO:
#     First observed: 2025-07-03 16:23:28.411000
#     Last observed:  2025-07-10 16:32:43.758000
#     Duration:       7 days, 0:09:15.347000
#
#   MMIRS:
#     First observed: 2025-07-10 16:32:47.953000
#     Last observed:  2025-07-17 02:05:58.860000
#     Duration:       6 days, 9:33:10.907000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-07-01 00:00:00 to 2025-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1751353200000, end_timestamp_ms=1754031599000, instrument=NA
# Retrieved 63316 records from hexapod_mini_instrument table
# Processed 63316 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2025-07-28 15:00:24.846000 to 2025-08-01 06:59:56.276000 (duration: 3 days 15:59:31.430000)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-07-01 00:00:00 to 2025-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1751353200000, end_timestamp_ms=1754031599000, instrument=binospec
# Retrieved 465015 records from hexapod_mini_instrument table
# Processed 465015 instrument records
# Identified 2 observing runs:
#   Run 1: 2025-07-01 07:00:00.189000 to 2025-07-03 17:30:40.747000 (duration: 2 days 10:30:40.558000)
#   Run 2: 2025-07-17 09:06:03.314000 to 2025-07-28 13:25:35.345000 (duration: 11 days 04:19:32.031000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-07-01 00:00:00 to 2025-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1751353200000, end_timestamp_ms=1754031599000, instrument=blue
# Retrieved 8365 records from hexapod_mini_instrument table
# Processed 8365 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2025-07-03 17:30:45.348000 to 2025-07-03 23:23:41.280000 (duration: 0 days 05:52:55.932000)
#   ✓ BLUE: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-07-01 00:00:00 to 2025-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1751353200000, end_timestamp_ms=1754031599000, instrument=hecto
# Retrieved 239263 records from hexapod_mini_instrument table
# Processed 239263 instrument records
# Identified 1 observing runs:
#   Run 1: 2025-07-03 23:23:28.411000 to 2025-07-10 23:32:43.758000 (duration: 7 days 00:09:15.347000)
#   ✓ HECTO: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-07-01 00:00:00 to 2025-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1751353200000, end_timestamp_ms=1754031599000, instrument=mmirs
# Retrieved 216039 records from hexapod_mini_instrument table
# Processed 216039 instrument records
# Identified 1 observing runs:
#   Run 1: 2025-07-10 23:32:47.953000 to 2025-07-17 09:05:58.860000 (duration: 6 days 09:33:10.907000)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: 2025-07-28 15:00:24.846000 to 2025-08-01 06:59:56.276000
#     Duration: 3 days 15:59:31.430000
#     No valid RMS records after filtering
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2025-07-01 07:00:00.189000 to 2025-07-03 17:30:40.747000
#     Duration: 2 days 10:30:40.558000
#     Filtered 2000 points in 10s intervals with variance >= 2.0" arcsec (retained 99.2%)
#     Retrieved 252000 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0687" Std=0.0408" Min=0.0148" Max=0.5986"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2751" Std=0.1753" Min=-1.3347" Max=0.7513"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 75601 points:
#       Mean=0.0751" Std=0.0525" Min=0.0094" Max=0.4705"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 75601 points:
#       Mean=-0.2786" Std=0.1707" Min=-1.3347" Max=0.6625"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 135882 points:
#       Mean=0.0756" Std=0.0511" Min=0.0057" Max=0.5212"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 135882 points:
#       Mean=-0.2633" Std=0.1755" Min=-1.2779" Max=0.7513"
#   Run 2: 2025-07-17 09:06:03.314000 to 2025-07-28 13:25:35.345000
#     Duration: 11 days 04:19:32.031000
#     Filtered 31665 points in 10s intervals with variance >= 2.0" arcsec (retained 97.0%)
#     Retrieved 1073325 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0853" Std=0.0482" Min=0.0000" Max=1.3047"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1766" Std=0.9428" Min=-2.2407" Max=2.3215"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 387985 points:
#       Mean=0.0877" Std=0.0559" Min=0.0000" Max=1.3244"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 387985 points:
#       Mean=0.6866" Std=0.6147" Min=-2.2407" Max=2.2605"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 515980 points:
#       Mean=0.0927" Std=0.0482" Min=0.0000" Max=1.3147"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 515980 points:
#       Mean=-0.8302" Std=0.5620" Min=-2.1986" Max=2.0192"
#
# Successfully analyzed 2 run(s) for binospec
#
# ======================================================================
# PROCESSING: BLUE
# ======================================================================
# Analyzing 1 observing run(s) for blue:
#   Run 1: 2025-07-03 17:30:45.348000 to 2025-07-03 23:23:41.280000
#     Duration: 0 days 05:52:55.932000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2025-07-03 23:23:28.411000 to 2025-07-10 23:32:43.758000
#     Duration: 7 days 00:09:15.347000
#     Filtered 18070 points in 10s intervals with variance >= 2.0" arcsec (retained 98.3%)
#     Retrieved 1091945 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0873" Std=0.0544" Min=0.0000" Max=1.1770"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.9651" Std=0.4916" Min=-2.4293" Max=1.7398"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 92313 points:
#       Mean=0.1125" Std=0.0572" Min=0.0256" Max=1.1571"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 92313 points:
#       Mean=-0.0520" Std=0.6851" Min=-2.2044" Max=1.7233"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 886683 points:
#       Mean=0.0855" Std=0.0539" Min=0.0000" Max=0.9269"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 886683 points:
#       Mean=-1.0807" Std=0.3126" Min=-2.3690" Max=1.6300"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2025-07-10 23:32:47.953000 to 2025-07-17 09:05:58.860000
#     Duration: 6 days 09:33:10.907000
#     Filtered 112815 points in 10s intervals with variance >= 2.0" arcsec (retained 89.8%)
#     Retrieved 1107920 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0784" Std=0.0640" Min=0.0000" Max=1.0656"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4992" Std=0.6792" Min=-2.6030" Max=1.9379"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 256703 points:
#       Mean=0.0779" Std=0.0606" Min=0.0000" Max=1.1487"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 256703 points:
#       Mean=0.0730" Std=0.5776" Min=-2.2765" Max=1.9379"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 609130 points:
#       Mean=0.0890" Std=0.0607" Min=0.0000" Max=1.1490"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 609130 points:
#       Mean=-0.7704" Std=0.5467" Min=-2.6030" Max=1.7808"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 3
#   BINOSPEC: 2 run(s)
#   HECTO: 1 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20250701_070000_to_20250703_173040.json
# ✓ binospec Run 2: binospec_20250717_090603_to_20250728_132535.json
# ✓ hecto Run 1: hecto_20250703_232328_to_20250710_233243.json
# ✓ mmirs Run 1: mmirs_20250710_233247_to_20250717_090558.json
#
# ✓ Saved statistics for 4 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30039
#   Timestamps: 30039
#   Rolling StdDev: 30039
#   Altitudes: 30039
#   Alt Velocities: 30039
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30234
#   Timestamps: 30234
#   Rolling StdDev: 30234
#   Altitudes: 30234
#   Alt Velocities: 30234
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30087
#   Timestamps: 30087
#   Rolling StdDev: 30087
#   Altitudes: 30087
#   Alt Velocities: 30087
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30111
#   Timestamps: 30111
#   Rolling StdDev: 30111
#   Altitudes: 30111
#   Alt Velocities: 30111
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30771
#   Timestamps: 30771
#   Rolling StdDev: 30771
#   Altitudes: 30771
#   Alt Velocities: 30771
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30228
#   Timestamps: 30228
#   Rolling StdDev: 30228
#   Altitudes: 30228
#   Alt Velocities: 30228
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30156
#   Timestamps: 30156
#   Rolling StdDev: 30156
#   Altitudes: 30156
#   Alt Velocities: 30156
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30807
#   Timestamps: 30807
#   Rolling StdDev: 30807
#   Altitudes: 30807
#   Alt Velocities: 30807
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30459
#   Timestamps: 30459
#   Rolling StdDev: 30459
#   Altitudes: 30459
#   Alt Velocities: 30459
# ================================================================================
# Generated 9 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 22:32:57
# End DateTime:   2026-02-12 22:35:03
# Elapsed Time:   0h 2m 5s
# ================================================================================
