# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2023-11-01 00:00:00'
end_datetime = '2023-11-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 21:04:42
# Analysis period: 2023-11-01 00:00:00 to 2023-11-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2023-11-01 00:00:00 to 2023-11-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1698822000000, end_timestamp_ms=1701413999000
# Retrieved 1028310 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   BINOSPEC: 241916 records, 2023-11-14 15:44:12.717000 to 2023-11-21 17:08:35.652000
#   HECTO: 776433 records, 2023-11-01 00:00:01.289000 to 2023-11-30 17:01:31.798000
#   MMIRS: 9961 records, 2023-11-30 17:01:36.174000 to 2023-11-30 23:59:57.955000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2023-11-14 15:44:12.717000
#     Last observed:  2023-11-21 17:08:35.652000
#     Duration:       7 days, 1:24:22.935000
#
#   HECTO:
#     First observed: 2023-11-01 00:00:01.289000
#     Last observed:  2023-11-30 17:01:31.798000
#     Duration:       29 days, 17:01:30.509000
#
#   MMIRS:
#     First observed: 2023-11-30 17:01:36.174000
#     Last observed:  2023-11-30 23:59:57.955000
#     Duration:       6:58:21.781000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-11-01 00:00:00 to 2023-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1698822000000, end_timestamp_ms=1701413999000, instrument=binospec
# Retrieved 241916 records from hexapod_mini_instrument table
# Processed 241916 instrument records
# Identified 1 observing runs:
#   Run 1: 2023-11-14 22:44:12.717000 to 2023-11-22 00:08:35.652000 (duration: 7 days 01:24:22.935000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-11-01 00:00:00 to 2023-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1698822000000, end_timestamp_ms=1701413999000, instrument=hecto
# Retrieved 776433 records from hexapod_mini_instrument table
# Processed 776433 instrument records
# Identified 2 observing runs:
#   Run 1: 2023-11-01 07:00:01.289000 to 2023-11-14 22:44:10.206000 (duration: 13 days 15:44:08.917000)
#   Run 2: 2023-11-22 00:08:37.705000 to 2023-12-01 00:01:31.798000 (duration: 8 days 23:52:54.093000)
#   ✓ HECTO: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-11-01 00:00:00 to 2023-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1698822000000, end_timestamp_ms=1701413999000, instrument=mmirs
# Retrieved 9961 records from hexapod_mini_instrument table
# Processed 9961 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-12-01 00:01:36.174000 to 2023-12-01 06:59:57.955000 (duration: 0 days 06:58:21.781000)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2023-11-14 22:44:12.717000 to 2023-11-22 00:08:35.652000
#     Duration: 7 days 01:24:22.935000
#     Filtered 14712 points in 10s intervals with variance >= 2.0" arcsec (retained 98.7%)
#     Retrieved 1169678 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0413" Std=0.0404" Min=0.0000" Max=1.2555"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2482" Std=0.9688" Min=-1.9062" Max=2.4042"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 492386 points:
#       Mean=0.0371" Std=0.0384" Min=0.0000" Max=0.9642"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 492386 points:
#       Mean=0.7852" Std=0.3399" Min=-1.4496" Max=2.4042"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 580623 points:
#       Mean=0.0444" Std=0.0381" Min=0.0000" Max=0.8527"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 580623 points:
#       Mean=-1.1360" Std=0.2028" Min=-1.9062" Max=1.9168"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 2 observing run(s) for hecto:
#   Run 1: 2023-11-01 07:00:01.289000 to 2023-11-14 22:44:10.206000
#     Duration: 13 days 15:44:08.917000
#     Filtered 208279 points in 10s intervals with variance >= 2.0" arcsec (retained 97.8%)
#     Retrieved 9353289 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0784" Std=0.0972" Min=0.0000" Max=1.3269"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.2634" Std=0.8514" Min=-2.3894" Max=2.3411"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 5663678 points:
#       Mean=0.0890" Std=0.1085" Min=0.0000" Max=1.0376"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 5663678 points:
#       Mean=0.8138" Std=0.3811" Min=-1.7874" Max=2.3411"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2430053 points:
#       Mean=0.0797" Std=0.0833" Min=0.0000" Max=1.1478"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2430053 points:
#       Mean=-0.9536" Std=0.3861" Min=-2.3894" Max=1.5863"
#   Run 2: 2023-11-22 00:08:37.705000 to 2023-12-01 00:01:31.798000
#     Duration: 8 days 23:52:54.093000
#     Filtered 34572 points in 10s intervals with variance >= 2.0" arcsec (retained 98.3%)
#     Retrieved 1979596 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0436" Std=0.0479" Min=0.0000" Max=1.2750"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.2207" Std=0.9498" Min=-1.8783" Max=2.6378"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1176081 points:
#       Mean=0.0435" Std=0.0476" Min=0.0000" Max=0.7401"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1176081 points:
#       Mean=0.9148" Std=0.3405" Min=-1.1756" Max=2.6378"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 657835 points:
#       Mean=0.0392" Std=0.0372" Min=0.0000" Max=0.7417"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 657835 points:
#       Mean=-1.0095" Std=0.2716" Min=-1.8783" Max=1.2969"
#
# Successfully analyzed 2 run(s) for hecto
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2023-12-01 00:01:36.174000 to 2023-12-01 06:59:57.955000
#     Duration: 0 days 06:58:21.781000
#     No valid RMS records after filtering
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20231114_224412_to_20231122_000835.json
# ✓ hecto Run 1: hecto_20231101_070001_to_20231114_224410.json
# ✓ hecto Run 2: hecto_20231122_000837_to_20231201_000131.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30132
#   Timestamps: 30132
#   Rolling StdDev: 30132
#   Altitudes: 30132
#   Alt Velocities: 30132
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30147
#   Timestamps: 30147
#   Rolling StdDev: 30147
#   Altitudes: 30147
#   Alt Velocities: 30147
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30033
#   Timestamps: 30033
#   Rolling StdDev: 30033
#   Altitudes: 30033
#   Alt Velocities: 30033
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30003
#   Timestamps: 30003
#   Rolling StdDev: 30003
#   Altitudes: 30003
#   Alt Velocities: 30003
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30045
#   Timestamps: 30045
#   Rolling StdDev: 30045
#   Altitudes: 30045
#   Alt Velocities: 30045
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30078
#   Timestamps: 30078
#   Rolling StdDev: 30078
#   Altitudes: 30078
#   Alt Velocities: 30078
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 21:04:42
# End DateTime:   2026-02-12 21:28:14
# Elapsed Time:   0h 23m 31s
# ================================================================================
