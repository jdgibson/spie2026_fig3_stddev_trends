# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2019-02-01 00:00:00'
end_datetime = '2019-02-28 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 16:52:39
# Analysis period: 2019-02-01 00:00:00 to 2019-02-28 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2019-02-01 00:00:00 to 2019-02-28 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1549004400000, end_timestamp_ms=1551423599000
# Retrieved 39560 total records from hexapod_mini_instrument
# Found 4 unique instrument(s)
#   NA: 8 records, 2019-02-26 17:21:27 to 2019-02-26 17:28:27
#   BINOSPEC: 21052 records, 2019-02-01 00:00:18 to 2019-02-15 18:18:18
#   HECTO: 18497 records, 2019-02-15 18:18:25.785000 to 2019-02-28 23:59:51
#   NAN: 3 records, 2019-02-26 06:49:46.260000 to 2019-02-26 17:20:29.235000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2019-02-01 00:00:18
#     Last observed:  2019-02-15 18:18:18
#     Duration:       14 days, 18:18:00
#
#   HECTO:
#     First observed: 2019-02-15 18:18:25.785000
#     Last observed:  2019-02-28 23:59:51
#     Duration:       13 days, 5:41:25.215000
#
#   NAN:
#     First observed: 2019-02-26 06:49:46.260000
#     Last observed:  2019-02-26 17:20:29.235000
#     Duration:       10:30:42.975000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-02-01 00:00:00 to 2019-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1549004400000, end_timestamp_ms=1551423599000, instrument=NA
# Retrieved 8 records from hexapod_mini_instrument table
# Processed 8 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2019-02-27 00:21:27 to 2019-02-27 00:28:27 (duration: 0 days 00:07:00)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-02-01 00:00:00 to 2019-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1549004400000, end_timestamp_ms=1551423599000, instrument=binospec
# Retrieved 21052 records from hexapod_mini_instrument table
# Processed 21052 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2019-02-01 07:00:18 to 2019-02-03 13:55:18 (duration: 2 days 06:55:00)
#   Run 2: 2019-02-03 16:42:08.215000 to 2019-02-16 01:18:18 (duration: 12 days 08:36:09.785000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-02-01 00:00:00 to 2019-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1549004400000, end_timestamp_ms=1551423599000, instrument=hecto
# Retrieved 18497 records from hexapod_mini_instrument table
# Processed 18497 instrument records
# Identified 2 observing runs:
#   Run 1: 2019-02-16 01:18:25.785000 to 2019-02-26 15:13:45 (duration: 10 days 13:55:19.215000)
#   Run 2: 2019-02-27 00:02:28.476000 to 2019-03-01 06:59:51 (duration: 2 days 06:57:22.524000)
#   ✓ HECTO: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-02-01 00:00:00 to 2019-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1549004400000, end_timestamp_ms=1551423599000, instrument=nan
# Retrieved 3 records from hexapod_mini_instrument table
# Processed 3 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2019-02-26 13:49:46.260000 to 2019-02-26 13:49:46.260000 (duration: 0 days 00:00:00)
#   Run 2: 2019-02-27 00:02:16.038000 to 2019-02-27 00:20:29.235000 (duration: 0 days 00:18:13.197000)
#   ✓ NAN: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:07:00 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2019-02-01 07:00:18 to 2019-02-03 13:55:18
#     Duration: 2 days 06:55:00
#     Filtered 1951 points in 10s intervals with variance >= 2.0" arcsec (retained 97.3%)
#     Retrieved 71951 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0598" Std=0.0249" Min=0.0108" Max=0.2533"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1532" Std=0.1356" Min=-0.7157" Max=0.3006"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1367 points:
#       Mean=0.0783" Std=0.0287" Min=0.0305" Max=0.2130"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1367 points:
#       Mean=-0.0921" Std=0.0995" Min=-0.6196" Max=0.2410"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 26748 points:
#       Mean=0.0775" Std=0.0283" Min=0.0171" Max=0.3220"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 26748 points:
#       Mean=-0.1837" Std=0.1362" Min=-0.6875" Max=0.3006"
#   Run 2: 2019-02-03 16:42:08.215000 to 2019-02-16 01:18:18
#     Duration: 12 days 08:36:09.785000
#     Filtered 45698 points in 10s intervals with variance >= 2.0" arcsec (retained 98.4%)
#     Retrieved 2908868 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0450" Std=0.0500" Min=0.0000" Max=1.2228"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.1626" Std=0.9244" Min=-2.0971" Max=2.7919"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1480705 points:
#       Mean=0.0480" Std=0.0575" Min=0.0000" Max=1.0871"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1480705 points:
#       Mean=0.9770" Std=0.2812" Min=-2.0935" Max=2.7919"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1086040 points:
#       Mean=0.0460" Std=0.0419" Min=0.0000" Max=0.7099"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1086040 points:
#       Mean=-0.8753" Std=0.3527" Min=-2.0971" Max=1.4348"
#
# Successfully analyzed 2 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 2 observing run(s) for hecto:
#   Run 1: 2019-02-16 01:18:25.785000 to 2019-02-26 15:13:45
#     Duration: 10 days 13:55:19.215000
#     Filtered 55553 points in 10s intervals with variance >= 2.0" arcsec (retained 96.3%)
#     Retrieved 1509976 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0757" Std=0.0703" Min=0.0000" Max=1.1791"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.3973" Std=0.8748" Min=-2.4774" Max=2.3499"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 936618 points:
#       Mean=0.0793" Std=0.0727" Min=0.0000" Max=0.8234"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 936618 points:
#       Mean=0.9546" Std=0.3482" Min=-1.2591" Max=2.3499"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 365228 points:
#       Mean=0.0824" Std=0.0618" Min=0.0000" Max=1.1230"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 365228 points:
#       Mean=-0.8816" Std=0.4354" Min=-2.4774" Max=1.4671"
#   Run 2: 2019-02-27 00:02:28.476000 to 2019-03-01 06:59:51
#     Duration: 2 days 06:57:22.524000
#     Filtered 14925 points in 10s intervals with variance >= 2.0" arcsec (retained 98.6%)
#     Retrieved 1043202 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0296" Std=0.0305" Min=0.0000" Max=1.0720"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.5966" Std=0.6081" Min=-1.0609" Max=2.0453"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 742525 points:
#       Mean=0.0315" Std=0.0319" Min=0.0000" Max=0.7639"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 742525 points:
#       Mean=0.9191" Std=0.3072" Min=-0.6233" Max=2.0453"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 142225 points:
#       Mean=0.0378" Std=0.0201" Min=0.0000" Max=0.6087"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 142225 points:
#       Mean=-0.4903" Std=0.2273" Min=-1.0609" Max=1.4652"
#
# Successfully analyzed 2 run(s) for hecto
#
# ======================================================================
# PROCESSING: NAN
# ======================================================================
# Analyzing 2 observing run(s) for nan:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:18:13.197000 is less than 1.0 hours)
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 2 run(s)
#   HECTO: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20190201_070018_to_20190203_135518.json
# ✓ binospec Run 2: binospec_20190203_164208_to_20190216_011818.json
# ✓ hecto Run 1: hecto_20190216_011825_to_20190226_151345.json
# ✓ hecto Run 2: hecto_20190227_000228_to_20190301_065951.json
#
# ✓ Saved statistics for 4 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30033
#   Timestamps: 30033
#   Rolling StdDev: 30033
#   Altitudes: 30033
#   Alt Velocities: 30033
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30042
#   Timestamps: 30042
#   Rolling StdDev: 30042
#   Altitudes: 30042
#   Alt Velocities: 30042
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30078
#   Timestamps: 30078
#   Rolling StdDev: 30078
#   Altitudes: 30078
#   Alt Velocities: 30078
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30033
#   Timestamps: 30033
#   Rolling StdDev: 30033
#   Altitudes: 30033
#   Alt Velocities: 30033
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30165
#   Timestamps: 30165
#   Rolling StdDev: 30165
#   Altitudes: 30165
#   Alt Velocities: 30165
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30450
#   Timestamps: 30450
#   Rolling StdDev: 30450
#   Altitudes: 30450
#   Alt Velocities: 30450
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 16:52:39
# End DateTime:   2026-02-12 16:59:07
# Elapsed Time:   0h 6m 28s
# ================================================================================
