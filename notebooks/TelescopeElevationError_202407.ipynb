# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2024-07-01 00:00:00'
end_datetime = '2024-07-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 21:40:04
# Analysis period: 2024-07-01 00:00:00 to 2024-07-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2024-07-01 00:00:00 to 2024-07-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1719817200000, end_timestamp_ms=1722495599000
# Retrieved 913685 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 1014 records, 2024-07-27 13:00:52.484000 to 2024-07-27 15:10:09.278000
#   BINOSPEC: 822828 records, 2024-07-03 14:53:37.447000 to 2024-07-31 23:59:58.899000
#   HECTO: 89843 records, 2024-07-01 00:00:00.323000 to 2024-07-03 14:53:33.308000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2024-07-03 14:53:37.447000
#     Last observed:  2024-07-31 23:59:58.899000
#     Duration:       28 days, 9:06:21.452000
#
#   HECTO:
#     First observed: 2024-07-01 00:00:00.323000
#     Last observed:  2024-07-03 14:53:33.308000
#     Duration:       2 days, 14:53:32.985000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-07-01 00:00:00 to 2024-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1719817200000, end_timestamp_ms=1722495599000, instrument=NA
# Retrieved 1014 records from hexapod_mini_instrument table
# Processed 1014 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2024-07-27 20:00:52.484000 to 2024-07-27 22:10:09.278000 (duration: 0 days 02:09:16.794000)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-07-01 00:00:00 to 2024-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1719817200000, end_timestamp_ms=1722495599000, instrument=binospec
# Retrieved 822828 records from hexapod_mini_instrument table
# Processed 822828 instrument records
# Identified 3 observing runs:
#   Run 1: 2024-07-03 21:53:37.447000 to 2024-07-23 12:36:22.901000 (duration: 19 days 14:42:45.454000)
#   Run 2: 2024-07-27 20:00:52.536000 to 2024-07-27 20:24:21.345000 (duration: 0 days 00:23:28.809000)
#   Run 3: 2024-07-27 21:53:26.227000 to 2024-08-01 06:59:58.899000 (duration: 4 days 09:06:32.672000)
#   ✓ BINOSPEC: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-07-01 00:00:00 to 2024-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1719817200000, end_timestamp_ms=1722495599000, instrument=hecto
# Retrieved 89843 records from hexapod_mini_instrument table
# Processed 89843 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2024-07-01 07:00:00.323000 to 2024-07-03 21:53:33.308000 (duration: 2 days 14:53:32.985000)
#   ✓ HECTO: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: 2024-07-27 20:00:52.484000 to 2024-07-27 22:10:09.278000
#     Duration: 0 days 02:09:16.794000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 3 observing run(s) for binospec:
#   Run 1: 2024-07-03 21:53:37.447000 to 2024-07-23 12:36:22.901000
#     Duration: 19 days 14:42:45.454000
#     Filtered 70353 points in 10s intervals with variance >= 2.0" arcsec (retained 96.8%)
#     Retrieved 2194881 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0991" Std=0.0767" Min=0.0000" Max=1.2431"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2045" Std=0.9759" Min=-2.7167" Max=2.6731"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 788046 points:
#       Mean=0.1110" Std=0.0859" Min=0.0000" Max=0.9583"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 788046 points:
#       Mean=0.8651" Std=0.4759" Min=-2.0017" Max=2.6731"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1086425 points:
#       Mean=0.1004" Std=0.0673" Min=0.0000" Max=1.1525"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1086425 points:
#       Mean=-1.0280" Std=0.3901" Min=-2.7167" Max=1.8550"
#   Run 2: Skipped (duration 0 days 00:23:28.809000 is less than 1.0 hours)
#   Run 3: 2024-07-27 21:53:26.227000 to 2024-08-01 06:59:58.899000
#     Duration: 4 days 09:06:32.672000
#     No valid RMS records after filtering
#
# Successfully analyzed 1 run(s) for binospec
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2024-07-01 07:00:00.323000 to 2024-07-03 21:53:33.308000
#     Duration: 2 days 14:53:32.985000
#     No valid RMS records after filtering
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 1
#   BINOSPEC: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20240703_215337_to_20240723_123622.json
#
# ✓ Saved statistics for 1 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30066
#   Timestamps: 30066
#   Rolling StdDev: 30066
#   Altitudes: 30066
#   Alt Velocities: 30066
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30312
#   Timestamps: 30312
#   Rolling StdDev: 30312
#   Altitudes: 30312
#   Alt Velocities: 30312
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30180
#   Timestamps: 30180
#   Rolling StdDev: 30180
#   Altitudes: 30180
#   Alt Velocities: 30180
# ================================================================================
# Generated 3 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 21:40:04
# End DateTime:   2026-02-12 21:42:03
# Elapsed Time:   0h 1m 58s
# ================================================================================
