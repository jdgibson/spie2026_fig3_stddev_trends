# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2022-08-01 00:00:00'
end_datetime = '2022-08-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 20:01:36
# Analysis period: 2022-08-01 00:00:00 to 2022-08-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2022-08-01 00:00:00 to 2022-08-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1659337200000, end_timestamp_ms=1662015599000
# Retrieved 1059863 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 567 records, 2022-08-04 22:38:25.547000 to 2022-08-11 02:45:40.660000
#   BINOSPEC: 392803 records, 2022-08-01 00:00:01.309000 to 2022-08-31 14:09:42.842000
#   HECTO: 666493 records, 2022-08-10 14:57:36.066000 to 2022-08-31 23:59:54.838000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2022-08-01 00:00:01.309000
#     Last observed:  2022-08-31 14:09:42.842000
#     Duration:       30 days, 14:09:41.533000
#
#   HECTO:
#     First observed: 2022-08-10 14:57:36.066000
#     Last observed:  2022-08-31 23:59:54.838000
#     Duration:       21 days, 9:02:18.772000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-08-01 00:00:00 to 2022-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1659337200000, end_timestamp_ms=1662015599000, instrument=NA
# Retrieved 567 records from hexapod_mini_instrument table
# Processed 567 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2022-08-05 05:38:25.547000 to 2022-08-05 05:38:25.547000 (duration: 0 days 00:00:00)
#   Run 2: 2022-08-11 08:08:30.181000 to 2022-08-11 09:45:40.660000 (duration: 0 days 01:37:10.479000)
#   ✓ NA: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-08-01 00:00:00 to 2022-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1659337200000, end_timestamp_ms=1662015599000, instrument=binospec
# Retrieved 392803 records from hexapod_mini_instrument table
# Processed 392803 instrument records
# Identified 2 observing runs:
#   Run 1: 2022-08-01 07:00:01.309000 to 2022-08-10 21:57:35.010000 (duration: 9 days 14:57:33.701000)
#   Run 2: 2022-08-30 00:50:34.947000 to 2022-08-31 21:09:42.842000 (duration: 1 days 20:19:07.895000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-08-01 00:00:00 to 2022-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1659337200000, end_timestamp_ms=1662015599000, instrument=hecto
# Retrieved 666493 records from hexapod_mini_instrument table
# Processed 666493 instrument records
# Identified 2 observing runs:
#   Run 1: 2022-08-10 21:57:36.066000 to 2022-08-30 00:14:10.517000 (duration: 19 days 02:16:34.451000)
#   Run 2: 2022-08-31 21:09:47.150000 to 2022-09-01 06:59:54.838000 (duration: 0 days 09:50:07.688000)
#   ✓ HECTO: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 2 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 2: 2022-08-11 08:08:30.181000 to 2022-08-11 09:45:40.660000
#     Duration: 0 days 01:37:10.479000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2022-08-01 07:00:01.309000 to 2022-08-10 21:57:35.010000
#     Duration: 9 days 14:57:33.701000
#     No valid RMS records after filtering
#   Run 2: 2022-08-30 00:50:34.947000 to 2022-08-31 21:09:42.842000
#     Duration: 1 days 20:19:07.895000
#     Filtered 162172 points in 10s intervals with variance >= 2.0" arcsec (retained 85.2%)
#     Retrieved 1096484 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.1231" Std=0.0762" Min=0.0000" Max=1.4405"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2974" Std=0.8987" Min=-2.6307" Max=2.3541"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 242648 points:
#       Mean=0.1420" Std=0.0799" Min=0.0000" Max=0.9649"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 242648 points:
#       Mean=0.9998" Std=0.4404" Min=-2.0963" Max=2.3541"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 571402 points:
#       Mean=0.1261" Std=0.0713" Min=0.0000" Max=1.4174"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 571402 points:
#       Mean=-0.8707" Std=0.3949" Min=-2.6307" Max=1.6928"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 2 observing run(s) for hecto:
#   Run 1: 2022-08-10 21:57:36.066000 to 2022-08-30 00:14:10.517000
#     Duration: 19 days 02:16:34.451000
#     Retrieved 84000 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0979" Std=0.0551" Min=0.0180" Max=0.7201"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=1.1557" Std=0.1565" Min=0.2955" Max=2.3060"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 83947 points:
#       Mean=0.0978" Std=0.0551" Min=0.0180" Max=0.7159"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 83947 points:
#       Mean=1.1557" Std=0.1563" Min=0.2955" Max=2.3060"
#   Run 2: 2022-08-31 21:09:47.150000 to 2022-09-01 06:59:54.838000
#     Duration: 0 days 09:50:07.688000
#     Filtered 13690 points in 10s intervals with variance >= 2.0" arcsec (retained 95.8%)
#     Retrieved 324000 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.1231" Std=0.0766" Min=0.0000" Max=0.8872"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1492" Std=0.6491" Min=-1.4608" Max=2.2351"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 49970 points:
#       Mean=0.1216" Std=0.0777" Min=0.0189" Max=1.0009"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 49970 points:
#       Mean=1.1591" Std=0.4492" Min=-1.3759" Max=2.2351"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 180657 points:
#       Mean=0.1460" Std=0.0821" Min=0.0115" Max=0.6869"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 180657 points:
#       Mean=-0.4323" Std=0.2641" Min=-1.4458" Max=0.8337"
#
# Successfully analyzed 2 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 2: binospec_20220830_005034_to_20220831_210942.json
# ✗ hecto Run 1: Error saving JSON - 'NoneType' object has no attribute 'get'
# ✓ hecto Run 2: hecto_20220831_210947_to_20220901_065954.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30141
#   Timestamps: 30141
#   Rolling StdDev: 30141
#   Altitudes: 30141
#   Alt Velocities: 30141
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30333
#   Timestamps: 30333
#   Rolling StdDev: 30333
#   Altitudes: 30333
#   Alt Velocities: 30333
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30075
#   Timestamps: 30075
#   Rolling StdDev: 30075
#   Altitudes: 30075
#   Alt Velocities: 30075
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30333
#   Timestamps: 30333
#   Rolling StdDev: 30333
#   Altitudes: 30333
#   Alt Velocities: 30333
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30906
#   Timestamps: 30906
#   Rolling StdDev: 30906
#   Altitudes: 30906
#   Alt Velocities: 30906
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30111
#   Timestamps: 30111
#   Rolling StdDev: 30111
#   Altitudes: 30111
#   Alt Velocities: 30111
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 20:01:36
# End DateTime:   2026-02-12 20:02:23
# Elapsed Time:   0h 0m 46s
# ================================================================================
