# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2024-01-01 00:00:00'
end_datetime = '2024-01-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 21:13:27
# Analysis period: 2024-01-01 00:00:00 to 2024-01-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2024-01-01 00:00:00 to 2024-01-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1704092400000, end_timestamp_ms=1706770799000
# Retrieved 896175 total records from hexapod_mini_instrument
# Found 5 unique instrument(s)
#   BINOSPEC: 535635 records, 2024-01-03 15:28:06.037000 to 2024-01-19 06:30:26.014000
#   F5: 12867 records, 2024-01-19 06:30:30.717000 to 2024-01-19 15:31:04.523000
#   HECTO: 90645 records, 2024-01-01 00:00:00.331000 to 2024-01-03 15:28:01.194000
#   MIRAC: 232378 records, 2024-01-19 15:31:07.372000 to 2024-01-26 11:16:52.713000
#   MMIRS: 24650 records, 2024-01-26 11:17:01.994000 to 2024-01-27 06:07:27.419000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2024-01-03 15:28:06.037000
#     Last observed:  2024-01-19 06:30:26.014000
#     Duration:       15 days, 15:02:19.977000
#
#   F5:
#     First observed: 2024-01-19 06:30:30.717000
#     Last observed:  2024-01-19 15:31:04.523000
#     Duration:       9:00:33.806000
#
#   HECTO:
#     First observed: 2024-01-01 00:00:00.331000
#     Last observed:  2024-01-03 15:28:01.194000
#     Duration:       2 days, 15:28:00.863000
#
#   MIRAC:
#     First observed: 2024-01-19 15:31:07.372000
#     Last observed:  2024-01-26 11:16:52.713000
#     Duration:       6 days, 19:45:45.341000
#
#   MMIRS:
#     First observed: 2024-01-26 11:17:01.994000
#     Last observed:  2024-01-27 06:07:27.419000
#     Duration:       18:50:25.425000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-01-01 00:00:00 to 2024-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1704092400000, end_timestamp_ms=1706770799000, instrument=binospec
# Retrieved 535635 records from hexapod_mini_instrument table
# Processed 535635 instrument records
# Identified 1 observing runs:
#   Run 1: 2024-01-03 22:28:06.037000 to 2024-01-19 13:30:26.014000 (duration: 15 days 15:02:19.977000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-01-01 00:00:00 to 2024-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1704092400000, end_timestamp_ms=1706770799000, instrument=f5
# Retrieved 12867 records from hexapod_mini_instrument table
# Processed 12867 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2024-01-19 13:30:30.717000 to 2024-01-19 22:31:04.523000 (duration: 0 days 09:00:33.806000)
#   ✓ F5: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-01-01 00:00:00 to 2024-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1704092400000, end_timestamp_ms=1706770799000, instrument=hecto
# Retrieved 90645 records from hexapod_mini_instrument table
# Processed 90645 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2024-01-01 07:00:00.331000 to 2024-01-03 22:28:01.194000 (duration: 2 days 15:28:00.863000)
#   ✓ HECTO: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-01-01 00:00:00 to 2024-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1704092400000, end_timestamp_ms=1706770799000, instrument=mirac
# Retrieved 232378 records from hexapod_mini_instrument table
# Processed 232378 instrument records
# Identified 1 observing runs:
#   Run 1: 2024-01-19 22:31:07.372000 to 2024-01-26 18:16:52.713000 (duration: 6 days 19:45:45.341000)
#   ✓ MIRAC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-01-01 00:00:00 to 2024-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1704092400000, end_timestamp_ms=1706770799000, instrument=mmirs
# Retrieved 24650 records from hexapod_mini_instrument table
# Processed 24650 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2024-01-26 18:17:01.994000 to 2024-01-27 13:07:27.419000 (duration: 0 days 18:50:25.425000)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2024-01-03 22:28:06.037000 to 2024-01-19 13:30:26.014000
#     Duration: 15 days 15:02:19.977000
#     Filtered 104703 points in 10s intervals with variance >= 2.0" arcsec (retained 98.6%)
#     Retrieved 7444977 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0679" Std=0.0885" Min=0.0000" Max=1.2132"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0140" Std=0.7884" Min=-2.5335" Max=2.1608"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 3341665 points:
#       Mean=0.0631" Std=0.0756" Min=0.0000" Max=1.1120"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 3341665 points:
#       Mean=0.7449" Std=0.3397" Min=-1.8729" Max=2.1608"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 3011728 points:
#       Mean=0.0667" Std=0.0733" Min=0.0000" Max=0.8331"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 3011728 points:
#       Mean=-0.7849" Std=0.3577" Min=-2.5335" Max=1.9424"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 1 observing run(s) for f5:
#   Run 1: 2024-01-19 13:30:30.717000 to 2024-01-19 22:31:04.523000
#     Duration: 0 days 09:00:33.806000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2024-01-01 07:00:00.331000 to 2024-01-03 22:28:01.194000
#     Duration: 2 days 15:28:00.863000
#     Filtered 2000 points in 10s intervals with variance >= 2.0" arcsec (retained 99.3%)
#     Retrieved 300000 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0504" Std=0.0312" Min=0.0000" Max=0.9391"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0433" Std=0.9923" Min=-1.7877" Max=1.7779"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 153689 points:
#       Mean=0.0515" Std=0.0314" Min=0.0000" Max=0.3536"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 153689 points:
#       Mean=0.9036" Std=0.1851" Min=-0.7832" Max=1.7779"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 143983 points:
#       Mean=0.0501" Std=0.0266" Min=0.0000" Max=0.3401"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 143983 points:
#       Mean=-1.0554" Std=0.1376" Min=-1.7877" Max=0.9333"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# PROCESSING: MIRAC
# ======================================================================
# Analyzing 1 observing run(s) for mirac:
#   Run 1: 2024-01-19 22:31:07.372000 to 2024-01-26 18:16:52.713000
#     Duration: 6 days 19:45:45.341000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2024-01-26 18:17:01.994000 to 2024-01-27 13:07:27.419000
#     Duration: 0 days 18:50:25.425000
#     No valid RMS records after filtering
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20240103_222806_to_20240119_133026.json
# ✓ hecto Run 1: hecto_20240101_070000_to_20240103_222801.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30003
#   Timestamps: 30003
#   Rolling StdDev: 30003
#   Altitudes: 30003
#   Alt Velocities: 30003
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30018
#   Timestamps: 30018
#   Rolling StdDev: 30018
#   Altitudes: 30018
#   Alt Velocities: 30018
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30828
#   Timestamps: 30828
#   Rolling StdDev: 30828
#   Altitudes: 30828
#   Alt Velocities: 30828
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30738
#   Timestamps: 30738
#   Rolling StdDev: 30738
#   Altitudes: 30738
#   Alt Velocities: 30738
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30855
#   Timestamps: 30855
#   Rolling StdDev: 30855
#   Altitudes: 30855
#   Alt Velocities: 30855
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 21:13:27
# End DateTime:   2026-02-12 21:26:09
# Elapsed Time:   0h 12m 42s
# ================================================================================
