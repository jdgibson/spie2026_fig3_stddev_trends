# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2020-09-01 00:00:00'
end_datetime = '2020-09-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 18:00:01
# Analysis period: 2020-09-01 00:00:00 to 2020-09-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2020-09-01 00:00:00 to 2020-09-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1598943600000, end_timestamp_ms=1601535599000
# Retrieved 517681 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 412 records, 2020-09-03 15:30:03.471000 to 2020-09-29 05:03:42.853000
#   BINOSPEC: 188222 records, 2020-09-14 17:43:00.784000 to 2020-09-25 15:32:09.911000
#   HECTO: 329047 records, 2020-09-01 00:00:04.184000 to 2020-09-30 23:59:57.700000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2020-09-14 17:43:00.784000
#     Last observed:  2020-09-25 15:32:09.911000
#     Duration:       10 days, 21:49:09.127000
#
#   HECTO:
#     First observed: 2020-09-01 00:00:04.184000
#     Last observed:  2020-09-30 23:59:57.700000
#     Duration:       29 days, 23:59:53.516000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-09-01 00:00:00 to 2020-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1598943600000, end_timestamp_ms=1601535599000, instrument=NA
# Retrieved 412 records from hexapod_mini_instrument table
# Processed 412 instrument records
#
# Identified 4 observing runs:
#   Run 1: 2020-09-03 22:30:03.471000 to 2020-09-03 22:57:48.548000 (duration: 0 days 00:27:45.077000)
#   Run 2: 2020-09-04 01:55:53.190000 to 2020-09-04 02:01:48.150000 (duration: 0 days 00:05:54.960000)
#   Run 3: 2020-09-22 11:53:11.245000 to 2020-09-22 12:15:49.440000 (duration: 0 days 00:22:38.195000)
#   Run 4: 2020-09-29 12:03:37.695000 to 2020-09-29 12:03:42.853000 (duration: 0 days 00:00:05.158000)
#   ✓ NA: 4 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-09-01 00:00:00 to 2020-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1598943600000, end_timestamp_ms=1601535599000, instrument=binospec
# Retrieved 188222 records from hexapod_mini_instrument table
# Processed 188222 instrument records
# Identified 1 observing runs:
#   Run 1: 2020-09-15 00:43:00.784000 to 2020-09-25 22:32:09.911000 (duration: 10 days 21:49:09.127000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-09-01 00:00:00 to 2020-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1598943600000, end_timestamp_ms=1601535599000, instrument=hecto
# Retrieved 329047 records from hexapod_mini_instrument table
# Processed 329047 instrument records
# Identified 2 observing runs:
#   Run 1: 2020-09-01 07:00:04.184000 to 2020-09-15 00:42:55.705000 (duration: 13 days 17:42:51.521000)
#   Run 2: 2020-09-25 22:32:14.913000 to 2020-10-01 06:59:57.700000 (duration: 5 days 08:27:42.787000)
#   ✓ HECTO: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 4 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:27:45.077000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:05:54.960000 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:22:38.195000 is less than 1.0 hours)
#   Run 4: Skipped (duration 0 days 00:00:05.158000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2020-09-15 00:43:00.784000 to 2020-09-25 22:32:09.911000
#     Duration: 10 days 21:49:09.127000
#     Filtered 34938 points in 10s intervals with variance >= 2.0" arcsec (retained 98.6%)
#     Retrieved 2578083 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0527" Std=0.0577" Min=0.0000" Max=0.9362"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4955" Std=0.7373" Min=-2.6057" Max=2.1649"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 477128 points:
#       Mean=0.0649" Std=0.0596" Min=0.0000" Max=1.0162"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 477128 points:
#       Mean=0.7291" Std=0.3757" Min=-2.5109" Max=2.1410"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1737477 points:
#       Mean=0.0593" Std=0.0607" Min=0.0000" Max=0.8656"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1737477 points:
#       Mean=-0.9138" Std=0.3493" Min=-2.6057" Max=2.1649"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 2 observing run(s) for hecto:
#   Run 1: 2020-09-01 07:00:04.184000 to 2020-09-15 00:42:55.705000
#     Duration: 13 days 17:42:51.521000
#     Filtered 158225 points in 10s intervals with variance >= 2.0" arcsec (retained 94.7%)
#     Retrieved 2981969 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0675" Std=0.0666" Min=0.0000" Max=1.3405"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.3685" Std=0.9007" Min=-2.5859" Max=3.0950"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1748186 points:
#       Mean=0.0765" Std=0.0733" Min=0.0000" Max=1.0932"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1748186 points:
#       Mean=0.9719" Std=0.3724" Min=-1.5631" Max=3.0950"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 744864 points:
#       Mean=0.0745" Std=0.0647" Min=0.0000" Max=1.1430"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 744864 points:
#       Mean=-0.8914" Std=0.4508" Min=-2.5859" Max=1.8669"
#   Run 2: 2020-09-25 22:32:14.913000 to 2020-10-01 06:59:57.700000
#     Duration: 5 days 08:27:42.787000
#     Filtered 99265 points in 10s intervals with variance >= 2.0" arcsec (retained 94.3%)
#     Retrieved 1749042 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0525" Std=0.0558" Min=0.0000" Max=1.1113"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.3356" Std=0.8090" Min=-1.5859" Max=2.7896"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 909877 points:
#       Mean=0.0625" Std=0.0572" Min=0.0000" Max=0.7650"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 909877 points:
#       Mean=0.9518" Std=0.4044" Min=-1.2408" Max=2.7896"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 452645 points:
#       Mean=0.0538" Std=0.0357" Min=0.0000" Max=0.5431"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 452645 points:
#       Mean=-0.7067" Std=0.3350" Min=-1.5859" Max=1.4552"
#
# Successfully analyzed 2 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20200915_004300_to_20200925_223209.json
# ✓ hecto Run 1: hecto_20200901_070004_to_20200915_004255.json
# ✓ hecto Run 2: hecto_20200925_223214_to_20201001_065957.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30039
#   Timestamps: 30039
#   Rolling StdDev: 30039
#   Altitudes: 30039
#   Alt Velocities: 30039
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30456
#   Timestamps: 30456
#   Rolling StdDev: 30456
#   Altitudes: 30456
#   Alt Velocities: 30456
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30132
#   Timestamps: 30132
#   Rolling StdDev: 30132
#   Altitudes: 30132
#   Alt Velocities: 30132
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30024
#   Timestamps: 30024
#   Rolling StdDev: 30024
#   Altitudes: 30024
#   Alt Velocities: 30024
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30093
#   Timestamps: 30093
#   Rolling StdDev: 30093
#   Altitudes: 30093
#   Alt Velocities: 30093
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30192
#   Timestamps: 30192
#   Rolling StdDev: 30192
#   Altitudes: 30192
#   Alt Velocities: 30192
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 18:00:01
# End DateTime:   2026-02-12 18:07:10
# Elapsed Time:   0h 7m 8s
# ================================================================================
