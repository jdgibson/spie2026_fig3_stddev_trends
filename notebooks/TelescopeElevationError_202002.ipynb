# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2020-02-01 00:00:00'
end_datetime = '2020-02-29 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 17:32:46
# Analysis period: 2020-02-01 00:00:00 to 2020-02-29 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2020-02-01 00:00:00 to 2020-02-29 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1580540400000, end_timestamp_ms=1583045999000
# Retrieved 2413680 total records from hexapod_mini_instrument
# Found 6 unique instrument(s)
#   NA: 1 records, 2020-02-08 06:33:49.048000 to 2020-02-08 06:33:49.048000
#   BLUE: 994145 records, 2020-02-17 18:49:42.541000 to 2020-02-29 23:59:58.871000
#   F5: 34321 records, 2020-02-17 06:20:47.915000 to 2020-02-17 16:15:55.096000
#   F9: 8757 records, 2020-02-17 16:15:56.164000 to 2020-02-17 18:49:41.504000
#   HECTO: 1347240 records, 2020-02-01 00:00:00.915000 to 2020-02-17 06:22:13.718000
#   RED: 29216 records, 2020-02-26 15:57:17.067000 to 2020-02-27 00:04:22.438000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BLUE:
#     First observed: 2020-02-17 18:49:42.541000
#     Last observed:  2020-02-29 23:59:58.871000
#     Duration:       12 days, 5:10:16.330000
#
#   F5:
#     First observed: 2020-02-17 06:20:47.915000
#     Last observed:  2020-02-17 16:15:55.096000
#     Duration:       9:55:07.181000
#
#   F9:
#     First observed: 2020-02-17 16:15:56.164000
#     Last observed:  2020-02-17 18:49:41.504000
#     Duration:       2:33:45.340000
#
#   HECTO:
#     First observed: 2020-02-01 00:00:00.915000
#     Last observed:  2020-02-17 06:22:13.718000
#     Duration:       16 days, 6:22:12.803000
#
#   RED:
#     First observed: 2020-02-26 15:57:17.067000
#     Last observed:  2020-02-27 00:04:22.438000
#     Duration:       8:07:05.371000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-02-01 00:00:00 to 2020-02-29 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1580540400000, end_timestamp_ms=1583045999000, instrument=NA
# Retrieved 1 records from hexapod_mini_instrument table
# Processed 1 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2020-02-08 13:33:49.048000 to 2020-02-08 13:33:49.048000 (duration: 0 days 00:00:00)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-02-01 00:00:00 to 2020-02-29 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1580540400000, end_timestamp_ms=1583045999000, instrument=blue
# Retrieved 994145 records from hexapod_mini_instrument table
# Processed 994145 instrument records
# Identified 2 observing runs:
#   Run 1: 2020-02-18 01:49:42.541000 to 2020-02-26 22:57:16.064000 (duration: 8 days 21:07:33.523000)
#   Run 2: 2020-02-27 07:04:23.567000 to 2020-03-01 06:59:58.871000 (duration: 2 days 23:55:35.304000)
#   ✓ BLUE: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-02-01 00:00:00 to 2020-02-29 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1580540400000, end_timestamp_ms=1583045999000, instrument=f5
# Retrieved 34321 records from hexapod_mini_instrument table
# Processed 34321 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2020-02-17 13:20:47.915000 to 2020-02-17 23:15:55.096000 (duration: 0 days 09:55:07.181000)
#   ✓ F5: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-02-01 00:00:00 to 2020-02-29 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1580540400000, end_timestamp_ms=1583045999000, instrument=f9
# Retrieved 8757 records from hexapod_mini_instrument table
# Processed 8757 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2020-02-17 23:15:56.164000 to 2020-02-18 01:49:41.504000 (duration: 0 days 02:33:45.340000)
#   ✓ F9: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-02-01 00:00:00 to 2020-02-29 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1580540400000, end_timestamp_ms=1583045999000, instrument=hecto
# Retrieved 1347240 records from hexapod_mini_instrument table
# Processed 1347240 instrument records
# Identified 1 observing runs:
#   Run 1: 2020-02-01 07:00:00.915000 to 2020-02-17 13:22:13.718000 (duration: 16 days 06:22:12.803000)
#   ✓ HECTO: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-02-01 00:00:00 to 2020-02-29 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1580540400000, end_timestamp_ms=1583045999000, instrument=red
# Retrieved 29216 records from hexapod_mini_instrument table
# Processed 29216 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2020-02-26 22:57:17.067000 to 2020-02-27 07:04:22.438000 (duration: 0 days 08:07:05.371000)
#   ✓ RED: 1 observing runs
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BLUE
# ======================================================================
# Analyzing 2 observing run(s) for blue:
#   Run 1: 2020-02-18 01:49:42.541000 to 2020-02-26 22:57:16.064000
#     Duration: 8 days 21:07:33.523000
#     Filtered 18036 points in 10s intervals with variance >= 2.0" arcsec (retained 99.6%)
#     Retrieved 4207313 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0583" Std=0.0680" Min=0.0000" Max=1.2424"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0878" Std=0.8966" Min=-2.4024" Max=2.5934"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1672671 points:
#       Mean=0.0539" Std=0.0618" Min=0.0000" Max=0.7700"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1672671 points:
#       Mean=0.8588" Std=0.3533" Min=-1.3401" Max=2.5934"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1931140 points:
#       Mean=0.0599" Std=0.0585" Min=0.0000" Max=0.9488"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1931140 points:
#       Mean=-0.9297" Std=0.3591" Min=-2.4024" Max=1.6856"
#   Run 2: 2020-02-27 07:04:23.567000 to 2020-03-01 06:59:58.871000
#     Duration: 2 days 23:55:35.304000
#     Filtered 14570 points in 10s intervals with variance >= 2.0" arcsec (retained 98.6%)
#     Retrieved 1007933 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0393" Std=0.0330" Min=0.0000" Max=0.7719"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0674" Std=0.8842" Min=-2.0492" Max=2.0194"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 457761 points:
#       Mean=0.0416" Std=0.0352" Min=0.0000" Max=0.5903"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 457761 points:
#       Mean=0.8967" Std=0.3956" Min=-1.2861" Max=2.0194"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 415949 points:
#       Mean=0.0393" Std=0.0294" Min=0.0000" Max=0.6944"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 415949 points:
#       Mean=-0.8298" Std=0.3354" Min=-2.0492" Max=1.2339"
#
# Successfully analyzed 2 run(s) for blue
#
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 1 observing run(s) for f5:
#   Run 1: 2020-02-17 13:20:47.915000 to 2020-02-17 23:15:55.096000
#     Duration: 0 days 09:55:07.181000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: F9
# ======================================================================
# Analyzing 1 observing run(s) for f9:
#   Run 1: 2020-02-17 23:15:56.164000 to 2020-02-18 01:49:41.504000
#     Duration: 0 days 02:33:45.340000
#     No valid RMS records after filtering
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2020-02-01 07:00:00.915000 to 2020-02-17 13:22:13.718000
#     Duration: 16 days 06:22:12.803000
#     Filtered 220368 points in 10s intervals with variance >= 2.0" arcsec (retained 96.4%)
#     Retrieved 6189215 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0695" Std=0.0843" Min=0.0000" Max=1.1942"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.1566" Std=0.8766" Min=-2.5475" Max=2.6947"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 3164327 points:
#       Mean=0.0853" Std=0.0978" Min=0.0000" Max=1.0115"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 3164327 points:
#       Mean=0.8766" Std=0.3409" Min=-2.0347" Max=2.6947"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2177978 points:
#       Mean=0.0615" Std=0.0637" Min=0.0000" Max=1.1586"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2177978 points:
#       Mean=-0.8466" Std=0.3768" Min=-2.5475" Max=1.7204"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# PROCESSING: RED
# ======================================================================
# Analyzing 1 observing run(s) for red:
#   Run 1: 2020-02-26 22:57:17.067000 to 2020-02-27 07:04:22.438000
#     Duration: 0 days 08:07:05.371000
#     No valid RMS records after filtering
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BLUE: 2 run(s)
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ blue Run 1: blue_20200218_014942_to_20200226_225716.json
# ✓ blue Run 2: blue_20200227_070423_to_20200301_065958.json
# ✓ hecto Run 1: hecto_20200201_070000_to_20200217_132213.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BLUE (BOTH (Total)):
#   RMS Errors: 30018
#   Timestamps: 30018
#   Rolling StdDev: 30018
#   Altitudes: 30018
#   Alt Velocities: 30018
# Plot data array lengths for BLUE (UP (Elevation Increasing)):
#   RMS Errors: 30009
#   Timestamps: 30009
#   Rolling StdDev: 30009
#   Altitudes: 30009
#   Alt Velocities: 30009
# Plot data array lengths for BLUE (DOWN (Elevation Decreasing)):
#   RMS Errors: 30093
#   Timestamps: 30093
#   Rolling StdDev: 30093
#   Altitudes: 30093
#   Alt Velocities: 30093
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30045
#   Timestamps: 30045
#   Rolling StdDev: 30045
#   Altitudes: 30045
#   Alt Velocities: 30045
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30042
#   Timestamps: 30042
#   Rolling StdDev: 30042
#   Altitudes: 30042
#   Alt Velocities: 30042
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30111
#   Timestamps: 30111
#   Rolling StdDev: 30111
#   Altitudes: 30111
#   Alt Velocities: 30111
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 17:32:46
# End DateTime:   2026-02-12 17:56:45
# Elapsed Time:   0h 23m 59s
# ================================================================================
