# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2021-07-01 00:00:00'
end_datetime = '2021-07-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 19:04:14
# Analysis period: 2021-07-01 00:00:00 to 2021-07-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2021-07-01 00:00:00 to 2021-07-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1625122800000, end_timestamp_ms=1627801199000
# Retrieved 973165 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   : 3 records, 2021-07-09 13:03:29.853000 to 2021-07-24 19:51:44.929000
#   NA: 9 records, 2021-07-02 17:23:26.076000 to 2021-07-27 14:34:28.523000
#   HECTO: 973153 records, 2021-07-01 00:00:00.760000 to 2021-07-31 23:59:57.820000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   :
#     First observed: 2021-07-09 13:03:29.853000
#     Last observed:  2021-07-24 19:51:44.929000
#     Duration:       15 days, 6:48:15.076000
#
#   HECTO:
#     First observed: 2021-07-01 00:00:00.760000
#     Last observed:  2021-07-31 23:59:57.820000
#     Duration:       30 days, 23:59:57.060000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-07-01 00:00:00 to 2021-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1625122800000, end_timestamp_ms=1627801199000, instrument=
# Retrieved 3 records from hexapod_mini_instrument table
# Processed 3 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2021-07-09 20:03:29.853000 to 2021-07-09 20:03:34.914000 (duration: 0 days 00:00:05.061000)
#   Run 2: 2021-07-25 02:51:44.929000 to 2021-07-25 02:51:44.929000 (duration: 0 days 00:00:00)
#   ✓ : 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-07-01 00:00:00 to 2021-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1625122800000, end_timestamp_ms=1627801199000, instrument=NA
# Retrieved 9 records from hexapod_mini_instrument table
# Processed 9 instrument records
#
# Identified 4 observing runs:
#   Run 1: 2021-07-03 00:23:26.076000 to 2021-07-03 00:23:26.076000 (duration: 0 days 00:00:00)
#   Run 2: 2021-07-09 20:03:26.611000 to 2021-07-09 20:03:31.730000 (duration: 0 days 00:00:05.119000)
#   Run 3: 2021-07-25 02:51:44.833000 to 2021-07-25 02:51:49.149000 (duration: 0 days 00:00:04.316000)
#   Run 4: 2021-07-27 21:34:28.467000 to 2021-07-27 21:34:28.523000 (duration: 0 days 00:00:00.056000)
#   ✓ NA: 4 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-07-01 00:00:00 to 2021-07-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1625122800000, end_timestamp_ms=1627801199000, instrument=hecto
# Retrieved 973153 records from hexapod_mini_instrument table
# Processed 973153 instrument records
# Identified 3 observing runs:
#   Run 1: 2021-07-01 07:00:00.760000 to 2021-07-09 17:58:48.324000 (duration: 8 days 10:58:47.564000)
#   Run 2: 2021-07-09 20:03:36.307000 to 2021-07-25 01:02:41.796000 (duration: 15 days 04:59:05.489000)
#   Run 3: 2021-07-25 02:51:54.048000 to 2021-08-01 06:59:57.820000 (duration: 7 days 04:08:03.772000)
#   ✓ HECTO: 3 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING:
# ======================================================================
# Analyzing 2 observing run(s) for :
#   Run 1: Skipped (duration 0 days 00:00:05.061000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 4 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:05.119000 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:00:04.316000 is less than 1.0 hours)
#   Run 4: Skipped (duration 0 days 00:00:00.056000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 3 observing run(s) for hecto:
#   Run 1: 2021-07-01 07:00:00.760000 to 2021-07-09 17:58:48.324000
#     Duration: 8 days 10:58:47.564000
#     Filtered 8888 points in 10s intervals with variance >= 2.0" arcsec (retained 98.2%)
#     Retrieved 491908 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.1137" Std=0.0614" Min=0.0000" Max=1.2399"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.3287" Std=0.9296" Min=-2.4886" Max=2.1983"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 156003 points:
#       Mean=0.1290" Std=0.0704" Min=0.0000" Max=0.9408"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 156003 points:
#       Mean=0.8236" Std=0.5034" Min=-1.2919" Max=2.1983"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 294550 points:
#       Mean=0.1102" Std=0.0582" Min=0.0000" Max=0.6953"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 294550 points:
#       Mean=-1.0039" Std=0.2700" Min=-2.4886" Max=1.1322"
#   Run 2: 2021-07-09 20:03:36.307000 to 2021-07-25 01:02:41.796000
#     Duration: 15 days 04:59:05.489000
#     No valid RMS records after filtering
#   Run 3: 2021-07-25 02:51:54.048000 to 2021-08-01 06:59:57.820000
#     Duration: 7 days 04:08:03.772000
#     No valid RMS records after filtering
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 1
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ hecto Run 1: hecto_20210701_070000_to_20210709_175848.json
#
# ✓ Saved statistics for 1 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30189
#   Timestamps: 30189
#   Rolling StdDev: 30189
#   Altitudes: 30189
#   Alt Velocities: 30189
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 31203
#   Timestamps: 31203
#   Rolling StdDev: 31203
#   Altitudes: 31203
#   Alt Velocities: 31203
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30471
#   Timestamps: 30471
#   Rolling StdDev: 30471
#   Altitudes: 30471
#   Alt Velocities: 30471
# ================================================================================
# Generated 3 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 19:04:14
# End DateTime:   2026-02-12 19:04:37
# Elapsed Time:   0h 0m 23s
# ================================================================================
