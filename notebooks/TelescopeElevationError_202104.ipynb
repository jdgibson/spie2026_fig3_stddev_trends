# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2021-04-01 00:00:00'
end_datetime = '2021-04-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 18:43:41
# Analysis period: 2021-04-01 00:00:00 to 2021-04-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2021-04-01 00:00:00 to 2021-04-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1617260400000, end_timestamp_ms=1619852399000
# Retrieved 514907 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 11 records, 2021-04-08 14:16:05.860000 to 2021-04-28 11:22:53.181000
#   BINOSPEC: 410305 records, 2021-04-01 00:00:03.753000 to 2021-04-30 23:59:58.967000
#   MMIRS: 104591 records, 2021-04-23 15:46:52.492000 to 2021-04-29 17:07:23.336000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2021-04-01 00:00:03.753000
#     Last observed:  2021-04-30 23:59:58.967000
#     Duration:       29 days, 23:59:55.214000
#
#   MMIRS:
#     First observed: 2021-04-23 15:46:52.492000
#     Last observed:  2021-04-29 17:07:23.336000
#     Duration:       6 days, 1:20:30.844000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-04-01 00:00:00 to 2021-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1617260400000, end_timestamp_ms=1619852399000, instrument=NA
# Retrieved 11 records from hexapod_mini_instrument table
# Processed 11 instrument records
#
# Identified 4 observing runs:
#   Run 1: 2021-04-08 21:16:05.860000 to 2021-04-08 21:16:10.039000 (duration: 0 days 00:00:04.179000)
#   Run 2: 2021-04-09 17:39:12.944000 to 2021-04-09 17:39:17.171000 (duration: 0 days 00:00:04.227000)
#   Run 3: 2021-04-09 18:58:25.775000 to 2021-04-09 18:58:30.934000 (duration: 0 days 00:00:05.159000)
#   Run 4: 2021-04-28 18:22:53.105000 to 2021-04-28 18:22:53.181000 (duration: 0 days 00:00:00.076000)
#   ✓ NA: 4 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-04-01 00:00:00 to 2021-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1617260400000, end_timestamp_ms=1619852399000, instrument=binospec
# Retrieved 410305 records from hexapod_mini_instrument table
# Processed 410305 instrument records
# Identified 3 observing runs:
#   Run 1: 2021-04-01 07:00:03.753000 to 2021-04-08 17:04:30.392000 (duration: 7 days 10:04:26.639000)
#   Run 2: 2021-04-08 21:16:15.248000 to 2021-04-23 22:46:47.448000 (duration: 15 days 01:30:32.200000)
#   Run 3: 2021-04-30 00:07:28.408000 to 2021-05-01 06:59:58.967000 (duration: 1 days 06:52:30.559000)
#   ✓ BINOSPEC: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-04-01 00:00:00 to 2021-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1617260400000, end_timestamp_ms=1619852399000, instrument=mmirs
# Retrieved 104591 records from hexapod_mini_instrument table
# Processed 104591 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-04-23 22:46:52.492000 to 2021-04-30 00:07:23.336000 (duration: 6 days 01:20:30.844000)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 4 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:04.179000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:04.227000 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:00:05.159000 is less than 1.0 hours)
#   Run 4: Skipped (duration 0 days 00:00:00.076000 is less than 1.0 hours)
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 3 observing run(s) for binospec:
#   Run 1: 2021-04-01 07:00:03.753000 to 2021-04-08 17:04:30.392000
#     Duration: 7 days 10:04:26.639000
#     Filtered 238072 points in 10s intervals with variance >= 2.0" arcsec (retained 94.8%)
#     Retrieved 4622317 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0791" Std=0.0799" Min=0.0000" Max=1.1679"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1097" Std=0.8732" Min=-2.6123" Max=2.4101"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1701354 points:
#       Mean=0.0781" Std=0.0702" Min=0.0000" Max=1.0575"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1701354 points:
#       Mean=0.8392" Std=0.3846" Min=-1.9692" Max=2.4101"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2180075 points:
#       Mean=0.0837" Std=0.0794" Min=0.0000" Max=1.0354"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2180075 points:
#       Mean=-0.8638" Std=0.3427" Min=-2.6123" Max=1.6582"
#   Run 2: 2021-04-08 21:16:15.248000 to 2021-04-23 22:46:47.448000
#     Duration: 15 days 01:30:32.200000
#     Filtered 132370 points in 10s intervals with variance >= 2.0" arcsec (retained 97.8%)
#     Retrieved 6060823 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0779" Std=0.0743" Min=0.0000" Max=1.5239"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1578" Std=0.7379" Min=-2.6394" Max=2.4616"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2066541 points:
#       Mean=0.0779" Std=0.0675" Min=0.0000" Max=1.3504"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2066541 points:
#       Mean=0.6626" Std=0.3379" Min=-1.8292" Max=2.4198"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2951731 points:
#       Mean=0.0920" Std=0.0739" Min=0.0000" Max=0.9182"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2951731 points:
#       Mean=-0.7652" Std=0.3718" Min=-2.6394" Max=2.4616"
#   Run 3: 2021-04-30 00:07:28.408000 to 2021-05-01 06:59:58.967000
#     Duration: 1 days 06:52:30.559000
#     Filtered 18468 points in 10s intervals with variance >= 2.0" arcsec (retained 97.7%)
#     Retrieved 798830 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0381" Std=0.0328" Min=0.0000" Max=0.5540"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.3530" Std=0.7802" Min=-2.3253" Max=2.2309"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 223780 points:
#       Mean=0.0474" Std=0.0457" Min=0.0000" Max=0.6725"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 223780 points:
#       Mean=0.7398" Std=0.2915" Min=-1.4527" Max=2.2309"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 495026 points:
#       Mean=0.0358" Std=0.0273" Min=0.0000" Max=0.4441"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 495026 points:
#       Mean=-0.8904" Std=0.2614" Min=-2.3253" Max=1.0078"
#
# Successfully analyzed 3 run(s) for binospec
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2021-04-23 22:46:52.492000 to 2021-04-30 00:07:23.336000
#     Duration: 6 days 01:20:30.844000
#     Filtered 84378 points in 10s intervals with variance >= 2.0" arcsec (retained 94.4%)
#     Retrieved 1493790 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0532" Std=0.0610" Min=0.0000" Max=1.0640"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.2788" Std=0.9283" Min=-2.5410" Max=2.4892"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 821798 points:
#       Mean=0.0480" Std=0.0555" Min=0.0000" Max=0.9573"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 821798 points:
#       Mean=0.9682" Std=0.3570" Min=-1.6869" Max=2.4892"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 445498 points:
#       Mean=0.0699" Std=0.0698" Min=0.0000" Max=1.0678"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 445498 points:
#       Mean=-0.9138" Std=0.3771" Min=-2.5410" Max=1.6757"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 3 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20210401_070003_to_20210408_170430.json
# ✓ binospec Run 2: binospec_20210408_211615_to_20210423_224647.json
# ✓ binospec Run 3: binospec_20210430_000728_to_20210501_065958.json
# ✓ mmirs Run 1: mmirs_20210423_224652_to_20210430_000723.json
#
# ✓ Saved statistics for 4 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30009
#   Timestamps: 30009
#   Rolling StdDev: 30009
#   Altitudes: 30009
#   Alt Velocities: 30009
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30039
#   Timestamps: 30039
#   Rolling StdDev: 30039
#   Altitudes: 30039
#   Alt Velocities: 30039
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30204
#   Timestamps: 30204
#   Rolling StdDev: 30204
#   Altitudes: 30204
#   Alt Velocities: 30204
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30066
#   Timestamps: 30066
#   Rolling StdDev: 30066
#   Altitudes: 30066
#   Alt Velocities: 30066
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30375
#   Timestamps: 30375
#   Rolling StdDev: 30375
#   Altitudes: 30375
#   Alt Velocities: 30375
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 18:43:41
# End DateTime:   2026-02-12 19:05:23
# Elapsed Time:   0h 21m 41s
# ================================================================================
