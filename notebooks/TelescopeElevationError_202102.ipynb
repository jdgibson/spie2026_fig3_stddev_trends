# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2021-02-01 00:00:00'
end_datetime = '2021-02-28 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 18:26:47
# Analysis period: 2021-02-01 00:00:00 to 2021-02-28 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2021-02-01 00:00:00 to 2021-02-28 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1612162800000, end_timestamp_ms=1614581999000
# Retrieved 483374 total records from hexapod_mini_instrument
# Found 4 unique instrument(s)
#   99.9: 709 records, 2021-02-13 23:35:42.325000 to 2021-02-14 00:34:42.779000
#   NA: 2 records, 2021-02-13 22:52:14.618000 to 2021-02-13 23:35:42.232000
#   BINOSPEC: 362907 records, 2021-02-01 16:05:25.154000 to 2021-02-22 17:41:39.448000
#   MMIRS: 119756 records, 2021-02-01 00:00:04.820000 to 2021-02-28 23:59:56.114000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   99.9:
#     First observed: 2021-02-13 23:35:42.325000
#     Last observed:  2021-02-14 00:34:42.779000
#     Duration:       0:59:00.454000
#
#   BINOSPEC:
#     First observed: 2021-02-01 16:05:25.154000
#     Last observed:  2021-02-22 17:41:39.448000
#     Duration:       21 days, 1:36:14.294000
#
#   MMIRS:
#     First observed: 2021-02-01 00:00:04.820000
#     Last observed:  2021-02-28 23:59:56.114000
#     Duration:       27 days, 23:59:51.294000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-02-01 00:00:00 to 2021-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1612162800000, end_timestamp_ms=1614581999000, instrument=99.9
# Retrieved 709 records from hexapod_mini_instrument table
# Processed 709 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-02-14 06:35:42.325000 to 2021-02-14 07:34:42.779000 (duration: 0 days 00:59:00.454000)
#   ✓ 99.9: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-02-01 00:00:00 to 2021-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1612162800000, end_timestamp_ms=1614581999000, instrument=NA
# Retrieved 2 records from hexapod_mini_instrument table
# Processed 2 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-02-14 05:52:14.618000 to 2021-02-14 06:35:42.232000 (duration: 0 days 00:43:27.614000)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-02-01 00:00:00 to 2021-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1612162800000, end_timestamp_ms=1614581999000, instrument=binospec
# Retrieved 362907 records from hexapod_mini_instrument table
# Processed 362907 instrument records
# Identified 1 observing runs:
#   Run 1: 2021-02-01 23:05:25.154000 to 2021-02-23 00:41:39.448000 (duration: 21 days 01:36:14.294000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-02-01 00:00:00 to 2021-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1612162800000, end_timestamp_ms=1614581999000, instrument=mmirs
# Retrieved 119756 records from hexapod_mini_instrument table
# Processed 119756 instrument records
#
# Identified 3 observing runs:
#   Run 1: 2021-02-01 07:00:04.820000 to 2021-02-01 23:05:20.103000 (duration: 0 days 16:05:15.283000)
#   Run 2: 2021-02-14 07:34:47.840000 to 2021-02-14 07:34:52.898000 (duration: 0 days 00:00:05.058000)
#   Run 3: 2021-02-23 00:41:44.439000 to 2021-03-01 06:59:56.114000 (duration: 6 days 06:18:11.675000)
#   ✓ MMIRS: 3 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: 99.9
# ======================================================================
# Analyzing 1 observing run(s) for 99.9:
#   Run 1: Skipped (duration 0 days 00:59:00.454000 is less than 1.0 hours)
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:43:27.614000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2021-02-01 23:05:25.154000 to 2021-02-23 00:41:39.448000
#     Duration: 21 days 01:36:14.294000
#     Filtered 227255 points in 10s intervals with variance >= 2.0" arcsec (retained 97.9%)
#     Retrieved 10685806 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0740" Std=0.1020" Min=0.0000" Max=1.4813"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0580" Std=0.8571" Min=-2.5097" Max=2.7464"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 4722092 points:
#       Mean=0.0839" Std=0.1104" Min=0.0000" Max=1.5358"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 4722092 points:
#       Mean=0.8783" Std=0.3566" Min=-2.0159" Max=2.7464"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 4361846 points:
#       Mean=0.0824" Std=0.0980" Min=0.0000" Max=1.2013"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 4361846 points:
#       Mean=-0.7981" Std=0.3710" Min=-2.5097" Max=2.0346"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 3 observing run(s) for mmirs:
#   Run 1: 2021-02-01 07:00:04.820000 to 2021-02-01 23:05:20.103000
#     Duration: 0 days 16:05:15.283000
#     No valid RMS records after filtering
#   Run 2: Skipped (duration 0 days 00:00:05.058000 is less than 1.0 hours)
#   Run 3: 2021-02-23 00:41:44.439000 to 2021-03-01 06:59:56.114000
#     Duration: 6 days 06:18:11.675000
#     Filtered 507885 points in 10s intervals with variance >= 2.0" arcsec (retained 90.0%)
#     Retrieved 5063591 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0767" Std=0.0728" Min=0.0000" Max=1.1934"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1351" Std=0.9089" Min=-2.6708" Max=2.6205"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1846817 points:
#       Mean=0.0737" Std=0.0678" Min=0.0000" Max=1.2038"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1846817 points:
#       Mean=0.8126" Std=0.3637" Min=-1.9618" Max=2.6205"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2185914 points:
#       Mean=0.0886" Std=0.0733" Min=0.0000" Max=1.0081"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2185914 points:
#       Mean=-0.9663" Std=0.3582" Min=-2.6708" Max=1.7045"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20210201_230525_to_20210223_004139.json
# ✓ mmirs Run 3: mmirs_20210223_004144_to_20210301_065956.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30027
#   Timestamps: 30027
#   Rolling StdDev: 30027
#   Altitudes: 30027
#   Alt Velocities: 30027
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30039
#   Timestamps: 30039
#   Rolling StdDev: 30039
#   Altitudes: 30039
#   Alt Velocities: 30039
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30114
#   Timestamps: 30114
#   Rolling StdDev: 30114
#   Altitudes: 30114
#   Alt Velocities: 30114
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30084
#   Timestamps: 30084
#   Rolling StdDev: 30084
#   Altitudes: 30084
#   Alt Velocities: 30084
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 18:26:47
# End DateTime:   2026-02-12 19:04:34
# Elapsed Time:   0h 37m 47s
# ================================================================================
