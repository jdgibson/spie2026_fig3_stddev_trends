# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2025-03-01 00:00:00'
end_datetime = '2025-03-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 22:11:13
# Analysis period: 2025-03-01 00:00:00 to 2025-03-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2025-03-01 00:00:00 to 2025-03-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1740812400000, end_timestamp_ms=1743490799000
# Retrieved 1011778 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   BINOSPEC: 458304 records, 2025-03-16 23:38:32.572000 to 2025-03-31 23:59:54.825000
#   BLUE: 2 records, 2025-03-16 23:38:27.524000 to 2025-03-16 23:38:28.880000
#   HECTO: 553472 records, 2025-03-01 00:00:00.675000 to 2025-03-18 13:58:05.625000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2025-03-16 23:38:32.572000
#     Last observed:  2025-03-31 23:59:54.825000
#     Duration:       15 days, 0:21:22.253000
#
#   BLUE:
#     First observed: 2025-03-16 23:38:27.524000
#     Last observed:  2025-03-16 23:38:28.880000
#     Duration:       0:00:01.356000
#
#   HECTO:
#     First observed: 2025-03-01 00:00:00.675000
#     Last observed:  2025-03-18 13:58:05.625000
#     Duration:       17 days, 13:58:04.950000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-03-01 00:00:00 to 2025-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1740812400000, end_timestamp_ms=1743490799000, instrument=binospec
# Retrieved 458304 records from hexapod_mini_instrument table
# Processed 458304 instrument records
# Identified 2 observing runs:
#   Run 1: 2025-03-17 06:38:32.572000 to 2025-03-17 06:38:33.962000 (duration: 0 days 00:00:01.390000)
#   Run 2: 2025-03-18 20:58:09.568000 to 2025-04-01 06:59:54.825000 (duration: 13 days 10:01:45.257000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-03-01 00:00:00 to 2025-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1740812400000, end_timestamp_ms=1743490799000, instrument=blue
# Retrieved 2 records from hexapod_mini_instrument table
# Processed 2 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2025-03-17 06:38:27.524000 to 2025-03-17 06:38:28.880000 (duration: 0 days 00:00:01.356000)
#   ✓ BLUE: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-03-01 00:00:00 to 2025-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1740812400000, end_timestamp_ms=1743490799000, instrument=hecto
# Retrieved 553472 records from hexapod_mini_instrument table
# Processed 553472 instrument records
# Identified 5 observing runs:
#   Run 1: 2025-03-01 07:00:00.675000 to 2025-03-06 18:30:21.162000 (duration: 5 days 11:30:20.487000)
#   Run 2: 2025-03-06 21:03:26.192000 to 2025-03-08 01:19:42.162000 (duration: 1 days 04:16:15.970000)
#   Run 3: 2025-03-08 03:08:46.472000 to 2025-03-10 10:41:47.103000 (duration: 2 days 07:33:00.631000)
#   Run 4: 2025-03-10 14:55:38.132000 to 2025-03-13 18:51:32.090000 (duration: 3 days 03:55:53.958000)
#   Run 5: 2025-03-14 20:02:12.792000 to 2025-03-18 20:58:05.625000 (duration: 4 days 00:55:52.833000)
#   ✓ HECTO: 5 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: Skipped (duration 0 days 00:00:01.390000 is less than 1.0 hours)
#   Run 2: 2025-03-18 20:58:09.568000 to 2025-04-01 06:59:54.825000
#     Duration: 13 days 10:01:45.257000
#     Filtered 268901 points in 10s intervals with variance >= 2.0" arcsec (retained 97.0%)
#     Retrieved 9022554 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0758" Std=0.0907" Min=0.0000" Max=1.1970"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2148" Std=0.8125" Min=-2.6810" Max=2.6035"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 3022981 points:
#       Mean=0.0637" Std=0.0654" Min=0.0000" Max=1.2785"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 3022981 points:
#       Mean=0.6576" Std=0.3928" Min=-2.0443" Max=2.6035"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 4199341 points:
#       Mean=0.0910" Std=0.0928" Min=0.0000" Max=1.1624"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 4199341 points:
#       Mean=-0.9100" Std=0.4168" Min=-2.6810" Max=1.4497"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: BLUE
# ======================================================================
# Analyzing 1 observing run(s) for blue:
#   Run 1: Skipped (duration 0 days 00:00:01.356000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 5 observing run(s) for hecto:
#   Run 1: 2025-03-01 07:00:00.675000 to 2025-03-06 18:30:21.162000
#     Duration: 5 days 11:30:20.487000
#     Filtered 2933 points in 10s intervals with variance >= 2.0" arcsec (retained 99.8%)
#     Retrieved 1175943 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0374" Std=0.0354" Min=0.0000" Max=0.7986"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.1506" Std=0.5886" Min=-1.5224" Max=1.5968"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 540029 points:
#       Mean=0.0319" Std=0.0319" Min=0.0000" Max=0.7775"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 540029 points:
#       Mean=0.6577" Std=0.3818" Min=-0.9540" Max=1.5968"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 374471 points:
#       Mean=0.0518" Std=0.0449" Min=0.0000" Max=0.8351"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 374471 points:
#       Mean=-0.4630" Std=0.2428" Min=-1.5001" Max=1.2906"
#   Run 2: 2025-03-06 21:03:26.192000 to 2025-03-08 01:19:42.162000
#     Duration: 1 days 04:16:15.970000
#     Filtered 14964 points in 10s intervals with variance >= 2.0" arcsec (retained 94.3%)
#     Retrieved 263964 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0978" Std=0.0661" Min=0.0000" Max=1.2048"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.8483" Std=0.6810" Min=-2.2630" Max=2.0728"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 22001 points:
#       Mean=0.0797" Std=0.0543" Min=0.0183" Max=0.8094"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 22001 points:
#       Mean=1.2486" Std=0.1532" Min=-1.1122" Max=2.0728"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 226675 points:
#       Mean=0.0997" Std=0.0654" Min=0.0000" Max=0.5993"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 226675 points:
#       Mean=-1.0515" Std=0.1973" Min=-2.2630" Max=0.2421"
#   Run 3: 2025-03-08 03:08:46.472000 to 2025-03-10 10:41:47.103000
#     Duration: 2 days 07:33:00.631000
#     Filtered 12280 points in 10s intervals with variance >= 2.0" arcsec (retained 97.8%)
#     Retrieved 563905 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0765" Std=0.0550" Min=0.0000" Max=1.1096"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.6364" Std=0.7586" Min=-1.7385" Max=1.9785"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 119447 points:
#       Mean=0.1123" Std=0.0796" Min=0.0000" Max=1.0920"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 119447 points:
#       Mean=0.6776" Std=0.3841" Min=-1.6163" Max=1.9785"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 412776 points:
#       Mean=0.0649" Std=0.0415" Min=0.0000" Max=1.0602"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 412776 points:
#       Mean=-1.0191" Std=0.1956" Min=-1.7314" Max=1.5426"
#   Run 4: 2025-03-10 14:55:38.132000 to 2025-03-13 18:51:32.090000
#     Duration: 3 days 03:55:53.958000
#     Filtered 9774 points in 10s intervals with variance >= 2.0" arcsec (retained 99.1%)
#     Retrieved 1043899 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0758" Std=0.0631" Min=0.0000" Max=0.8628"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.6306" Std=0.7892" Min=-2.2336" Max=2.0547"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 241557 points:
#       Mean=0.1218" Std=0.0631" Min=0.0000" Max=0.9038"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 241557 points:
#       Mean=0.6246" Std=0.5464" Min=-1.6376" Max=2.0547"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 760625 points:
#       Mean=0.0593" Std=0.0537" Min=0.0000" Max=0.8649"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 760625 points:
#       Mean=-1.0567" Std=0.1919" Min=-2.2336" Max=1.1688"
#   Run 5: 2025-03-14 20:02:12.792000 to 2025-03-18 20:58:05.625000
#     Duration: 4 days 00:55:52.833000
#     Filtered 37686 points in 10s intervals with variance >= 2.0" arcsec (retained 95.2%)
#     Retrieved 777915 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.1101" Std=0.0829" Min=0.0000" Max=1.1366"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.2513" Std=0.7175" Min=-2.4263" Max=2.1943"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 394164 points:
#       Mean=0.0978" Std=0.0675" Min=0.0000" Max=1.3758"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 394164 points:
#       Mean=0.7497" Std=0.4324" Min=-2.1331" Max=2.1943"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 218950 points:
#       Mean=0.1304" Std=0.0828" Min=0.0000" Max=0.9123"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 218950 points:
#       Mean=-0.4586" Std=0.5733" Min=-2.4263" Max=1.4103"
#
# Successfully analyzed 5 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 5 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 2: binospec_20250318_205809_to_20250401_065954.json
# ✓ hecto Run 1: hecto_20250301_070000_to_20250306_183021.json
# ✓ hecto Run 2: hecto_20250306_210326_to_20250308_011942.json
# ✓ hecto Run 3: hecto_20250308_030846_to_20250310_104147.json
# ✓ hecto Run 4: hecto_20250310_145538_to_20250313_185132.json
# ✓ hecto Run 5: hecto_20250314_200212_to_20250318_205805.json
#
# ✓ Saved statistics for 6 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30030
#   Timestamps: 30030
#   Rolling StdDev: 30030
#   Altitudes: 30030
#   Alt Velocities: 30030
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30069
#   Timestamps: 30069
#   Rolling StdDev: 30069
#   Altitudes: 30069
#   Alt Velocities: 30069
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30066
#   Timestamps: 30066
#   Rolling StdDev: 30066
#   Altitudes: 30066
#   Alt Velocities: 30066
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30165
#   Timestamps: 30165
#   Rolling StdDev: 30165
#   Altitudes: 30165
#   Alt Velocities: 30165
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30054
#   Timestamps: 30054
#   Rolling StdDev: 30054
#   Altitudes: 30054
#   Alt Velocities: 30054
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 22:11:13
# End DateTime:   2026-02-12 22:32:53
# Elapsed Time:   0h 21m 40s
# ================================================================================
