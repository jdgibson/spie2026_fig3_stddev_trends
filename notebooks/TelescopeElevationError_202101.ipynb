# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2021-01-01 00:00:00'
end_datetime = '2021-01-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 18:13:51
# Analysis period: 2021-01-01 00:00:00 to 2021-01-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2021-01-01 00:00:00 to 2021-01-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1609484400000, end_timestamp_ms=1612162799000
# Retrieved 534348 total records from hexapod_mini_instrument
# Found 5 unique instrument(s)
#   NA: 3 records, 2021-01-26 09:37:38.240000 to 2021-01-26 09:37:43.328000
#   BLUE: 205957 records, 2021-01-05 13:57:17.217000 to 2021-01-20 12:00:00.997000
#   F5: 1659 records, 2021-01-05 11:39:01.731000 to 2021-01-05 13:57:12.216000
#   MMIRS: 274989 records, 2021-01-01 00:00:03.966000 to 2021-01-31 23:59:54.825000
#   RED: 51740 records, 2021-01-06 15:17:07.826000 to 2021-01-12 17:51:55.032000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BLUE:
#     First observed: 2021-01-05 13:57:17.217000
#     Last observed:  2021-01-20 12:00:00.997000
#     Duration:       14 days, 22:02:43.780000
#
#   F5:
#     First observed: 2021-01-05 11:39:01.731000
#     Last observed:  2021-01-05 13:57:12.216000
#     Duration:       2:18:10.485000
#
#   MMIRS:
#     First observed: 2021-01-01 00:00:03.966000
#     Last observed:  2021-01-31 23:59:54.825000
#     Duration:       30 days, 23:59:50.859000
#
#   RED:
#     First observed: 2021-01-06 15:17:07.826000
#     Last observed:  2021-01-12 17:51:55.032000
#     Duration:       6 days, 2:34:47.206000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-01-01 00:00:00 to 2021-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1609484400000, end_timestamp_ms=1612162799000, instrument=NA
# Retrieved 3 records from hexapod_mini_instrument table
# Processed 3 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-01-26 16:37:38.240000 to 2021-01-26 16:37:43.328000 (duration: 0 days 00:00:05.088000)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-01-01 00:00:00 to 2021-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1609484400000, end_timestamp_ms=1612162799000, instrument=blue
# Retrieved 205957 records from hexapod_mini_instrument table
# Processed 205957 instrument records
# Identified 2 observing runs:
#   Run 1: 2021-01-05 20:57:17.217000 to 2021-01-06 22:17:02.831000 (duration: 1 days 01:19:45.614000)
#   Run 2: 2021-01-09 22:08:19.925000 to 2021-01-20 19:00:00.997000 (duration: 10 days 20:51:41.072000)
#   ✓ BLUE: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-01-01 00:00:00 to 2021-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1609484400000, end_timestamp_ms=1612162799000, instrument=f5
# Retrieved 1659 records from hexapod_mini_instrument table
# Processed 1659 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-01-05 18:39:01.731000 to 2021-01-05 20:57:12.216000 (duration: 0 days 02:18:10.485000)
#   ✓ F5: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-01-01 00:00:00 to 2021-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1609484400000, end_timestamp_ms=1612162799000, instrument=mmirs
# Retrieved 274989 records from hexapod_mini_instrument table
# Processed 274989 instrument records
# Identified 3 observing runs:
#   Run 1: 2021-01-01 07:00:03.966000 to 2021-01-05 18:38:56.725000 (duration: 4 days 11:38:52.759000)
#   Run 2: 2021-01-20 19:00:05.048000 to 2021-01-26 15:04:42.623000 (duration: 5 days 20:04:37.575000)
#   Run 3: 2021-01-26 16:37:48.695000 to 2021-02-01 06:59:54.825000 (duration: 5 days 14:22:06.130000)
#   ✓ MMIRS: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-01-01 00:00:00 to 2021-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1609484400000, end_timestamp_ms=1612162799000, instrument=red
# Retrieved 51740 records from hexapod_mini_instrument table
# Processed 51740 instrument records
# Identified 2 observing runs:
#   Run 1: 2021-01-06 22:17:07.826000 to 2021-01-09 22:08:14.926000 (duration: 2 days 23:51:07.100000)
#   Run 2: 2021-01-13 00:50:35.946000 to 2021-01-13 00:51:55.032000 (duration: 0 days 00:01:19.086000)
#   ✓ RED: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:05.088000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BLUE
# ======================================================================
# Analyzing 2 observing run(s) for blue:
#   Run 1: 2021-01-05 20:57:17.217000 to 2021-01-06 22:17:02.831000
#     Duration: 1 days 01:19:45.614000
#     Filtered 196086 points in 10s intervals with variance >= 2.0" arcsec (retained 77.6%)
#     Retrieved 874144 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0631" Std=0.0685" Min=0.0000" Max=0.9139"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0094" Std=1.0378" Min=-2.5532" Max=1.9370"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 315397 points:
#       Mean=0.0392" Std=0.0384" Min=0.0000" Max=0.7081"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 315397 points:
#       Mean=1.0010" Std=0.3248" Min=-1.9225" Max=1.9370"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 290661 points:
#       Mean=0.0985" Std=0.0814" Min=0.0000" Max=0.9031"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 290661 points:
#       Mean=-1.0836" Std=0.3159" Min=-2.5532" Max=1.2465"
#   Run 2: 2021-01-09 22:08:19.925000 to 2021-01-20 19:00:00.997000
#     Duration: 10 days 20:51:41.072000
#     Filtered 139726 points in 10s intervals with variance >= 2.0" arcsec (retained 98.0%)
#     Retrieved 7102911 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0721" Std=0.0861" Min=0.0000" Max=1.3116"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0351" Std=0.9108" Min=-2.5578" Max=2.4169"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 3156057 points:
#       Mean=0.0693" Std=0.0776" Min=0.0000" Max=1.0880"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 3156057 points:
#       Mean=0.8261" Std=0.3702" Min=-1.8879" Max=2.4169"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2952399 points:
#       Mean=0.0824" Std=0.0781" Min=0.0000" Max=1.0518"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2952399 points:
#       Mean=-0.9569" Std=0.3431" Min=-2.5578" Max=1.6883"
#
# Successfully analyzed 2 run(s) for blue
#
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 1 observing run(s) for f5:
#   Run 1: 2021-01-05 18:39:01.731000 to 2021-01-05 20:57:12.216000
#     Duration: 0 days 02:18:10.485000
#     No valid RMS records after filtering
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 3 observing run(s) for mmirs:
#   Run 1: 2021-01-01 07:00:03.966000 to 2021-01-05 18:38:56.725000
#     Duration: 4 days 11:38:52.759000
#     Filtered 413247 points in 10s intervals with variance >= 2.0" arcsec (retained 90.2%)
#     Retrieved 4238325 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0457" Std=0.0513" Min=0.0000" Max=1.3138"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0273" Std=0.8302" Min=-2.1527" Max=2.3249"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1524377 points:
#       Mean=0.0494" Std=0.0479" Min=0.0000" Max=0.8014"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1524377 points:
#       Mean=0.8883" Std=0.3203" Min=-1.4472" Max=2.3249"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1920173 points:
#       Mean=0.0450" Std=0.0507" Min=0.0000" Max=1.2946"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1920173 points:
#       Mean=-0.7422" Std=0.3141" Min=-2.1527" Max=1.7332"
#   Run 2: 2021-01-20 19:00:05.048000 to 2021-01-26 15:04:42.623000
#     Duration: 5 days 20:04:37.575000
#     Retrieved 12000 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0208" Std=0.0071" Min=0.0110" Max=0.0651"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0600" Std=0.0324" Min=-0.0520" Max=0.2088"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1993 points:
#       Mean=0.0205" Std=0.0088" Min=0.0053" Max=0.0585"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1993 points:
#       Mean=0.0512" Std=0.0313" Min=-0.0520" Max=0.1801"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 28 points:
#       Mean=0.0153" Std=0.0097" Min=0.0018" Max=0.0346"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 28 points:
#       Mean=0.0561" Std=0.0187" Min=0.0202" Max=0.1031"
#   Run 3: 2021-01-26 16:37:48.695000 to 2021-02-01 06:59:54.825000
#     Duration: 5 days 14:22:06.130000
#     Filtered 71938 points in 10s intervals with variance >= 2.0" arcsec (retained 90.2%)
#     Retrieved 737824 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0334" Std=0.0266" Min=0.0000" Max=1.0072"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0499" Std=0.8440" Min=-2.1171" Max=2.8208"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 317450 points:
#       Mean=0.0355" Std=0.0262" Min=0.0000" Max=0.9176"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 317450 points:
#       Mean=0.7177" Std=0.2630" Min=-1.1020" Max=2.8208"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 273722 points:
#       Mean=0.0355" Std=0.0267" Min=0.0000" Max=0.7051"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 273722 points:
#       Mean=-0.9763" Std=0.3063" Min=-2.1171" Max=1.1661"
#
# Successfully analyzed 3 run(s) for mmirs
#
# ======================================================================
# PROCESSING: RED
# ======================================================================
# Analyzing 2 observing run(s) for red:
#   Run 1: 2021-01-06 22:17:07.826000 to 2021-01-09 22:08:14.926000
#     Duration: 2 days 23:51:07.100000
#     Filtered 23407 points in 10s intervals with variance >= 2.0" arcsec (retained 99.0%)
#     Retrieved 2315359 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0416" Std=0.0452" Min=0.0000" Max=1.2943"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.3890" Std=0.8596" Min=-1.9241" Max=2.8285"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1476032 points:
#       Mean=0.0426" Std=0.0553" Min=0.0000" Max=1.0776"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1476032 points:
#       Mean=0.9764" Std=0.2701" Min=-1.2382" Max=2.8285"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 658195 points:
#       Mean=0.0528" Std=0.0356" Min=0.0000" Max=1.2606"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 658195 points:
#       Mean=-0.8005" Std=0.3434" Min=-1.9241" Max=1.7605"
#   Run 2: Skipped (duration 0 days 00:01:19.086000 is less than 1.0 hours)
#
# Successfully analyzed 1 run(s) for red
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 3
#   BLUE: 2 run(s)
#   MMIRS: 3 run(s)
#   RED: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ blue Run 1: blue_20210105_205717_to_20210106_221702.json
# ✓ blue Run 2: blue_20210109_220819_to_20210120_190000.json
# ✓ mmirs Run 1: mmirs_20210101_070003_to_20210105_183856.json
# ✓ mmirs Run 2: mmirs_20210120_190005_to_20210126_150442.json
# ✓ mmirs Run 3: mmirs_20210126_163748_to_20210201_065954.json
# ✓ red Run 1: red_20210106_221707_to_20210109_220814.json
#
# ✓ Saved statistics for 6 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BLUE (BOTH (Total)):
#   RMS Errors: 30006
#   Timestamps: 30006
#   Rolling StdDev: 30006
#   Altitudes: 30006
#   Alt Velocities: 30006
# Plot data array lengths for BLUE (UP (Elevation Increasing)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# Plot data array lengths for BLUE (DOWN (Elevation Decreasing)):
#   RMS Errors: 30030
#   Timestamps: 30030
#   Rolling StdDev: 30030
#   Altitudes: 30030
#   Alt Velocities: 30030
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30021
#   Timestamps: 30021
#   Rolling StdDev: 30021
#   Altitudes: 30021
#   Alt Velocities: 30021
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30063
#   Timestamps: 30063
#   Rolling StdDev: 30063
#   Altitudes: 30063
#   Alt Velocities: 30063
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30054
#   Timestamps: 30054
#   Rolling StdDev: 30054
#   Altitudes: 30054
#   Alt Velocities: 30054
# Plot data array lengths for RED (BOTH (Total)):
#   RMS Errors: 30027
#   Timestamps: 30027
#   Rolling StdDev: 30027
#   Altitudes: 30027
#   Alt Velocities: 30027
# Plot data array lengths for RED (UP (Elevation Increasing)):
#   RMS Errors: 30126
#   Timestamps: 30126
#   Rolling StdDev: 30126
#   Altitudes: 30126
#   Alt Velocities: 30126
# Plot data array lengths for RED (DOWN (Elevation Decreasing)):
#   RMS Errors: 30381
#   Timestamps: 30381
#   Rolling StdDev: 30381
#   Altitudes: 30381
#   Alt Velocities: 30381
# ================================================================================
# Generated 9 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 18:13:51
# End DateTime:   2026-02-12 18:32:01
# Elapsed Time:   0h 18m 9s
# ================================================================================
