# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2025-04-01 00:00:00'
end_datetime = '2025-04-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 22:13:29
# Analysis period: 2025-04-01 00:00:00 to 2025-04-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2025-04-01 00:00:00 to 2025-04-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1743490800000, end_timestamp_ms=1746082799000
# Retrieved 1025508 total records from hexapod_mini_instrument
# Found 10 unique instrument(s)
#   ARIES: 2 records, 2025-04-11 16:28:15.296000 to 2025-04-11 16:28:15.349000
#   BINOSPEC: 537919 records, 2025-04-01 00:00:00.004000 to 2025-04-30 15:18:54.899000
#   BLUE: 4 records, 2025-04-16 10:15:26.664000 to 2025-04-16 10:15:32.213000
#   F15: 70438 records, 2025-04-16 10:04:17.430000 to 2025-04-18 11:32:03.274000
#   F5: 10030 records, 2025-04-09 11:48:53.497000 to 2025-04-11 16:19:45.060000
#   F9: 8 records, 2025-04-09 11:51:32.527000 to 2025-04-09 11:51:48.420000
#   HECTO: 12377 records, 2025-04-30 15:18:58.839000 to 2025-04-30 23:59:58.878000
#   MIRAC: 67971 records, 2025-04-11 16:19:50.069000 to 2025-04-13 16:01:47.952000
#   MMIRS: 232693 records, 2025-04-04 13:55:07.899000 to 2025-04-11 09:17:10.969000
#   PISCES-LGS: 94066 records, 2025-04-13 16:01:52.462000 to 2025-04-16 10:04:13.633000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   ARIES:
#     First observed: 2025-04-11 16:28:15.296000
#     Last observed:  2025-04-11 16:28:15.349000
#     Duration:       0:00:00.053000
#
#   BINOSPEC:
#     First observed: 2025-04-01 00:00:00.004000
#     Last observed:  2025-04-30 15:18:54.899000
#     Duration:       29 days, 15:18:54.895000
#
#   BLUE:
#     First observed: 2025-04-16 10:15:26.664000
#     Last observed:  2025-04-16 10:15:32.213000
#     Duration:       0:00:05.549000
#
#   F15:
#     First observed: 2025-04-16 10:04:17.430000
#     Last observed:  2025-04-18 11:32:03.274000
#     Duration:       2 days, 1:27:45.844000
#
#   F5:
#     First observed: 2025-04-09 11:48:53.497000
#     Last observed:  2025-04-11 16:19:45.060000
#     Duration:       2 days, 4:30:51.563000
#
#   F9:
#     First observed: 2025-04-09 11:51:32.527000
#     Last observed:  2025-04-09 11:51:48.420000
#     Duration:       0:00:15.893000
#
#   HECTO:
#     First observed: 2025-04-30 15:18:58.839000
#     Last observed:  2025-04-30 23:59:58.878000
#     Duration:       8:41:00.039000
#
#   MIRAC:
#     First observed: 2025-04-11 16:19:50.069000
#     Last observed:  2025-04-13 16:01:47.952000
#     Duration:       1 day, 23:41:57.883000
#
#   MMIRS:
#     First observed: 2025-04-04 13:55:07.899000
#     Last observed:  2025-04-11 09:17:10.969000
#     Duration:       6 days, 19:22:03.070000
#
#   PISCES-LGS:
#     First observed: 2025-04-13 16:01:52.462000
#     Last observed:  2025-04-16 10:04:13.633000
#     Duration:       2 days, 18:02:21.171000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-04-01 00:00:00 to 2025-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1743490800000, end_timestamp_ms=1746082799000, instrument=aries
# Retrieved 2 records from hexapod_mini_instrument table
# Processed 2 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2025-04-11 23:28:15.296000 to 2025-04-11 23:28:15.349000 (duration: 0 days 00:00:00.053000)
#   ✓ ARIES: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-04-01 00:00:00 to 2025-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1743490800000, end_timestamp_ms=1746082799000, instrument=binospec
# Retrieved 537919 records from hexapod_mini_instrument table
# Processed 537919 instrument records
# Identified 2 observing runs:
#   Run 1: 2025-04-01 07:00:00.004000 to 2025-04-04 20:55:06.479000 (duration: 3 days 13:55:06.475000)
#   Run 2: 2025-04-18 18:32:05.337000 to 2025-04-30 22:18:54.899000 (duration: 12 days 03:46:49.562000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-04-01 00:00:00 to 2025-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1743490800000, end_timestamp_ms=1746082799000, instrument=blue
# Retrieved 4 records from hexapod_mini_instrument table
# Processed 4 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2025-04-16 17:15:26.664000 to 2025-04-16 17:15:32.213000 (duration: 0 days 00:00:05.549000)
#   ✓ BLUE: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-04-01 00:00:00 to 2025-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1743490800000, end_timestamp_ms=1746082799000, instrument=f15
# Retrieved 70438 records from hexapod_mini_instrument table
# Processed 70438 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2025-04-16 17:04:17.430000 to 2025-04-18 18:32:03.274000 (duration: 2 days 01:27:45.844000)
#   ✓ F15: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-04-01 00:00:00 to 2025-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1743490800000, end_timestamp_ms=1746082799000, instrument=f5
# Retrieved 10030 records from hexapod_mini_instrument table
# Processed 10030 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2025-04-09 18:48:53.497000 to 2025-04-09 19:17:58.222000 (duration: 0 days 00:29:04.725000)
#   Run 2: 2025-04-11 16:17:13.188000 to 2025-04-11 23:19:45.060000 (duration: 0 days 07:02:31.872000)
#   ✓ F5: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-04-01 00:00:00 to 2025-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1743490800000, end_timestamp_ms=1746082799000, instrument=f9
# Retrieved 8 records from hexapod_mini_instrument table
# Processed 8 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2025-04-09 18:51:32.527000 to 2025-04-09 18:51:48.420000 (duration: 0 days 00:00:15.893000)
#   ✓ F9: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-04-01 00:00:00 to 2025-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1743490800000, end_timestamp_ms=1746082799000, instrument=hecto
# Retrieved 12377 records from hexapod_mini_instrument table
# Processed 12377 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2025-04-30 22:18:58.839000 to 2025-05-01 06:59:58.878000 (duration: 0 days 08:41:00.039000)
#   ✓ HECTO: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-04-01 00:00:00 to 2025-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1743490800000, end_timestamp_ms=1746082799000, instrument=mirac
# Retrieved 67971 records from hexapod_mini_instrument table
# Processed 67971 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2025-04-11 23:19:50.069000 to 2025-04-13 23:01:47.952000 (duration: 1 days 23:41:57.883000)
#   ✓ MIRAC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-04-01 00:00:00 to 2025-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1743490800000, end_timestamp_ms=1746082799000, instrument=mmirs
# Retrieved 232693 records from hexapod_mini_instrument table
# Processed 232693 instrument records
# Identified 1 observing runs:
#   Run 1: 2025-04-04 20:55:07.899000 to 2025-04-11 16:17:10.969000 (duration: 6 days 19:22:03.070000)
#   ✓ MMIRS: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-04-01 00:00:00 to 2025-04-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1743490800000, end_timestamp_ms=1746082799000, instrument=pisces-lgs
# Retrieved 94066 records from hexapod_mini_instrument table
# Processed 94066 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2025-04-13 23:01:52.462000 to 2025-04-16 17:04:13.633000 (duration: 2 days 18:02:21.171000)
#   ✓ PISCES-LGS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: ARIES
# ======================================================================
# Analyzing 1 observing run(s) for aries:
#   Run 1: Skipped (duration 0 days 00:00:00.053000 is less than 1.0 hours)
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2025-04-01 07:00:00.004000 to 2025-04-04 20:55:06.479000
#     Duration: 3 days 13:55:06.475000
#     Filtered 16989 points in 10s intervals with variance >= 2.0" arcsec (retained 98.1%)
#     Retrieved 885411 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.1024" Std=0.0589" Min=0.0000" Max=1.4044"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.1680" Std=0.8181" Min=-2.2143" Max=2.0665"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 476822 points:
#       Mean=0.0970" Std=0.0565" Min=0.0000" Max=0.8740"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 476822 points:
#       Mean=0.7994" Std=0.3215" Min=-1.2508" Max=2.0665"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 293870 points:
#       Mean=0.1230" Std=0.0650" Min=0.0000" Max=1.1487"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 293870 points:
#       Mean=-0.7885" Std=0.4341" Min=-2.2143" Max=1.3825"
#   Run 2: 2025-04-18 18:32:05.337000 to 2025-04-30 22:18:54.899000
#     Duration: 12 days 03:46:49.562000
#     Filtered 133619 points in 10s intervals with variance >= 2.0" arcsec (retained 98.2%)
#     Retrieved 7254190 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0666" Std=0.0803" Min=0.0000" Max=1.2600"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2770" Std=0.7552" Min=-2.4843" Max=2.3560"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2196982 points:
#       Mean=0.0583" Std=0.0524" Min=0.0000" Max=1.3144"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2196982 points:
#       Mean=0.5978" Std=0.4237" Min=-1.9536" Max=2.3560"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 3762180 points:
#       Mean=0.0809" Std=0.0881" Min=0.0000" Max=0.9761"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 3762180 points:
#       Mean=-0.8515" Std=0.3789" Min=-2.4843" Max=2.1487"
#
# Successfully analyzed 2 run(s) for binospec
#
# ======================================================================
# PROCESSING: BLUE
# ======================================================================
# Analyzing 1 observing run(s) for blue:
#   Run 1: Skipped (duration 0 days 00:00:05.549000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: F15
# ======================================================================
# Analyzing 1 observing run(s) for f15:
#   Run 1: 2025-04-16 17:04:17.430000 to 2025-04-18 18:32:03.274000
#     Duration: 2 days 01:27:45.844000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 2 observing run(s) for f5:
#   Run 1: Skipped (duration 0 days 00:29:04.725000 is less than 1.0 hours)
#   Run 2: 2025-04-11 16:17:13.188000 to 2025-04-11 23:19:45.060000
#     Duration: 0 days 07:02:31.872000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: F9
# ======================================================================
# Analyzing 1 observing run(s) for f9:
#   Run 1: Skipped (duration 0 days 00:00:15.893000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2025-04-30 22:18:58.839000 to 2025-05-01 06:59:58.878000
#     Duration: 0 days 08:41:00.039000
#     Filtered 8538 points in 10s intervals with variance >= 2.0" arcsec (retained 96.1%)
#     Retrieved 220538 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0317" Std=0.0321" Min=0.0000" Max=1.2172"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1171" Std=1.2291" Min=-2.4745" Max=1.6051"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 96047 points:
#       Mean=0.0360" Std=0.0235" Min=0.0129" Max=0.9533"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 96047 points:
#       Mean=1.2205" Std=0.0795" Min=-1.1928" Max=1.6051"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 113000 points:
#       Mean=0.0288" Std=0.0307" Min=0.0000" Max=0.5325"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 113000 points:
#       Mean=-1.2431" Std=0.1886" Min=-2.4745" Max=1.2645"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# PROCESSING: MIRAC
# ======================================================================
# Analyzing 1 observing run(s) for mirac:
#   Run 1: 2025-04-11 23:19:50.069000 to 2025-04-13 23:01:47.952000
#     Duration: 1 days 23:41:57.883000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2025-04-04 20:55:07.899000 to 2025-04-11 16:17:10.969000
#     Duration: 6 days 19:22:03.070000
#     Filtered 496889 points in 10s intervals with variance >= 2.0" arcsec (retained 90.5%)
#     Retrieved 5207920 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0774" Std=0.0841" Min=0.0000" Max=1.1759"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.6118" Std=0.7578" Min=-2.7124" Max=3.9101"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 783514 points:
#       Mean=0.0764" Std=0.0688" Min=0.0000" Max=1.2954"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 783514 points:
#       Mean=0.7097" Std=0.5632" Min=-1.9924" Max=3.8136"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 3462161 points:
#       Mean=0.0904" Std=0.0923" Min=0.0000" Max=1.3437"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 3462161 points:
#       Mean=-0.9805" Std=0.3513" Min=-2.7124" Max=3.9101"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# PROCESSING: PISCES-LGS
# ======================================================================
# Analyzing 1 observing run(s) for pisces-lgs:
#   Run 1: 2025-04-13 23:01:52.462000 to 2025-04-16 17:04:13.633000
#     Duration: 2 days 18:02:21.171000
#     No valid RMS records after filtering
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 3
#   BINOSPEC: 2 run(s)
#   HECTO: 1 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20250401_070000_to_20250404_205506.json
# ✓ binospec Run 2: binospec_20250418_183205_to_20250430_221854.json
# ✓ hecto Run 1: hecto_20250430_221858_to_20250501_065958.json
# ✓ mmirs Run 1: mmirs_20250404_205507_to_20250411_161710.json
#
# ✓ Saved statistics for 4 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30036
#   Timestamps: 30036
#   Rolling StdDev: 30036
#   Altitudes: 30036
#   Alt Velocities: 30036
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30045
#   Timestamps: 30045
#   Rolling StdDev: 30045
#   Altitudes: 30045
#   Alt Velocities: 30045
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30045
#   Timestamps: 30045
#   Rolling StdDev: 30045
#   Altitudes: 30045
#   Alt Velocities: 30045
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30288
#   Timestamps: 30288
#   Rolling StdDev: 30288
#   Altitudes: 30288
#   Alt Velocities: 30288
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 32016
#   Timestamps: 32016
#   Rolling StdDev: 32016
#   Altitudes: 32016
#   Alt Velocities: 32016
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30819
#   Timestamps: 30819
#   Rolling StdDev: 30819
#   Altitudes: 30819
#   Alt Velocities: 30819
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30009
#   Timestamps: 30009
#   Rolling StdDev: 30009
#   Altitudes: 30009
#   Alt Velocities: 30009
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30138
#   Timestamps: 30138
#   Rolling StdDev: 30138
#   Altitudes: 30138
#   Alt Velocities: 30138
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30021
#   Timestamps: 30021
#   Rolling StdDev: 30021
#   Altitudes: 30021
#   Alt Velocities: 30021
# ================================================================================
# Generated 9 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 22:13:29
# End DateTime:   2026-02-12 22:33:52
# Elapsed Time:   0h 20m 22s
# ================================================================================
