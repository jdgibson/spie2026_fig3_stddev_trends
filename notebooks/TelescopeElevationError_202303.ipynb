# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2023-03-01 00:00:00'
end_datetime = '2023-03-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 20:28:00
# Analysis period: 2023-03-01 00:00:00 to 2023-03-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2023-03-01 00:00:00 to 2023-03-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1677654000000, end_timestamp_ms=1680332399000
# Retrieved 533589 total records from hexapod_mini_instrument
# Found 7 unique instrument(s)
#   NA: 36 records, 2023-03-04 06:06:03.659000 to 2023-03-28 19:26:30.537000
#   ARIES: 19706 records, 2023-03-02 17:02:43.931000 to 2023-03-03 20:25:37.680000
#   BINOSPEC: 408083 records, 2023-03-01 00:00:01.128000 to 2023-03-30 18:37:00.951000
#   F15: 39168 records, 2023-03-06 06:11:17.494000 to 2023-03-08 12:36:48.247000
#   F5: 3919 records, 2023-03-02 11:36:01.498000 to 2023-03-02 17:02:38.866000
#   MMIRS: 21150 records, 2023-03-30 18:37:05.011000 to 2023-03-31 23:59:56.903000
#   PISCES-LGS: 41527 records, 2023-03-03 20:25:42.725000 to 2023-03-06 06:11:12.376000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   ARIES:
#     First observed: 2023-03-02 17:02:43.931000
#     Last observed:  2023-03-03 20:25:37.680000
#     Duration:       1 day, 3:22:53.749000
#
#   BINOSPEC:
#     First observed: 2023-03-01 00:00:01.128000
#     Last observed:  2023-03-30 18:37:00.951000
#     Duration:       29 days, 18:36:59.823000
#
#   F15:
#     First observed: 2023-03-06 06:11:17.494000
#     Last observed:  2023-03-08 12:36:48.247000
#     Duration:       2 days, 6:25:30.753000
#
#   F5:
#     First observed: 2023-03-02 11:36:01.498000
#     Last observed:  2023-03-02 17:02:38.866000
#     Duration:       5:26:37.368000
#
#   MMIRS:
#     First observed: 2023-03-30 18:37:05.011000
#     Last observed:  2023-03-31 23:59:56.903000
#     Duration:       1 day, 5:22:51.892000
#
#   PISCES-LGS:
#     First observed: 2023-03-03 20:25:42.725000
#     Last observed:  2023-03-06 06:11:12.376000
#     Duration:       2 days, 9:45:29.651000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-03-01 00:00:00 to 2023-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1677654000000, end_timestamp_ms=1680332399000, instrument=NA
# Retrieved 36 records from hexapod_mini_instrument table
# Processed 36 instrument records
#
# Identified 3 observing runs:
#   Run 1: 2023-03-04 13:06:03.659000 to 2023-03-04 13:08:49.755000 (duration: 0 days 00:02:46.096000)
#   Run 2: 2023-03-20 18:03:22.091000 to 2023-03-20 18:03:22.135000 (duration: 0 days 00:00:00.044000)
#   Run 3: 2023-03-29 02:26:30.537000 to 2023-03-29 02:26:30.537000 (duration: 0 days 00:00:00)
#   ✓ NA: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-03-01 00:00:00 to 2023-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1677654000000, end_timestamp_ms=1680332399000, instrument=aries
# Retrieved 19706 records from hexapod_mini_instrument table
# Processed 19706 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-03-03 00:02:43.931000 to 2023-03-04 03:25:37.680000 (duration: 1 days 03:22:53.749000)
#   ✓ ARIES: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-03-01 00:00:00 to 2023-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1677654000000, end_timestamp_ms=1680332399000, instrument=binospec
# Retrieved 408083 records from hexapod_mini_instrument table
# Processed 408083 instrument records
# Identified 3 observing runs:
#   Run 1: 2023-03-01 07:00:01.128000 to 2023-03-02 18:35:56.439000 (duration: 1 days 11:35:55.311000)
#   Run 2: 2023-03-08 19:36:53.294000 to 2023-03-20 15:25:52.084000 (duration: 11 days 19:48:58.790000)
#   Run 3: 2023-03-20 18:03:27.015000 to 2023-03-31 01:37:00.951000 (duration: 10 days 07:33:33.936000)
#   ✓ BINOSPEC: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-03-01 00:00:00 to 2023-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1677654000000, end_timestamp_ms=1680332399000, instrument=f15
# Retrieved 39168 records from hexapod_mini_instrument table
# Processed 39168 instrument records
# Identified 1 observing runs:
#   Run 1: 2023-03-06 13:11:17.494000 to 2023-03-08 19:36:48.247000 (duration: 2 days 06:25:30.753000)
#   ✓ F15: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-03-01 00:00:00 to 2023-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1677654000000, end_timestamp_ms=1680332399000, instrument=f5
# Retrieved 3919 records from hexapod_mini_instrument table
# Processed 3919 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-03-02 18:36:01.498000 to 2023-03-03 00:02:38.866000 (duration: 0 days 05:26:37.368000)
#   ✓ F5: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-03-01 00:00:00 to 2023-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1677654000000, end_timestamp_ms=1680332399000, instrument=mmirs
# Retrieved 21150 records from hexapod_mini_instrument table
# Processed 21150 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-03-31 01:37:05.011000 to 2023-04-01 06:59:56.903000 (duration: 1 days 05:22:51.892000)
#   ✓ MMIRS: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-03-01 00:00:00 to 2023-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1677654000000, end_timestamp_ms=1680332399000, instrument=pisces-lgs
# Retrieved 41527 records from hexapod_mini_instrument table
# Processed 41527 instrument records
# Identified 1 observing runs:
#   Run 1: 2023-03-04 03:25:42.725000 to 2023-03-06 13:11:12.376000 (duration: 2 days 09:45:29.651000)
#   ✓ PISCES-LGS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 3 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:02:46.096000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:00.044000 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: ARIES
# ======================================================================
# Analyzing 1 observing run(s) for aries:
#   Run 1: 2023-03-03 00:02:43.931000 to 2023-03-04 03:25:37.680000
#     Duration: 1 days 03:22:53.749000
#     No valid RMS records after filtering
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 3 observing run(s) for binospec:
#   Run 1: 2023-03-01 07:00:01.128000 to 2023-03-02 18:35:56.439000
#     Duration: 1 days 11:35:55.311000
#     No valid RMS records after filtering
#   Run 2: 2023-03-08 19:36:53.294000 to 2023-03-20 15:25:52.084000
#     Duration: 11 days 19:48:58.790000
#     Filtered 37468 points in 10s intervals with variance >= 2.0" arcsec (retained 98.9%)
#     Retrieved 3412282 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0723" Std=0.0674" Min=0.0000" Max=1.2252"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0356" Std=0.9348" Min=-2.4628" Max=2.2497"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1627939 points:
#       Mean=0.0613" Std=0.0572" Min=0.0000" Max=0.9393"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1627939 points:
#       Mean=0.8991" Std=0.3334" Min=-1.4067" Max=2.2497"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1436517 points:
#       Mean=0.0820" Std=0.0627" Min=0.0000" Max=0.8494"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1436517 points:
#       Mean=-0.9302" Std=0.3522" Min=-2.4628" Max=1.6224"
#   Run 3: 2023-03-20 18:03:27.015000 to 2023-03-31 01:37:00.951000
#     Duration: 10 days 07:33:33.936000
#     Filtered 64235 points in 10s intervals with variance >= 2.0" arcsec (retained 98.3%)
#     Retrieved 3842987 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0640" Std=0.0661" Min=0.0000" Max=1.3160"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.3626" Std=0.7842" Min=-2.6659" Max=2.2516"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 905065 points:
#       Mean=0.0707" Std=0.0715" Min=0.0000" Max=0.9445"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 905065 points:
#       Mean=0.7968" Std=0.3927" Min=-1.3832" Max=2.2516"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2400267 points:
#       Mean=0.0699" Std=0.0643" Min=0.0000" Max=1.0666"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2400267 points:
#       Mean=-0.8580" Std=0.3534" Min=-2.6659" Max=1.5734"
#
# Successfully analyzed 2 run(s) for binospec
#
# ======================================================================
# PROCESSING: F15
# ======================================================================
# Analyzing 1 observing run(s) for f15:
#   Run 1: 2023-03-06 13:11:17.494000 to 2023-03-08 19:36:48.247000
#     Duration: 2 days 06:25:30.753000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 1 observing run(s) for f5:
#   Run 1: 2023-03-02 18:36:01.498000 to 2023-03-03 00:02:38.866000
#     Duration: 0 days 05:26:37.368000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2023-03-31 01:37:05.011000 to 2023-04-01 06:59:56.903000
#     Duration: 1 days 05:22:51.892000
#     Filtered 30120 points in 10s intervals with variance >= 2.0" arcsec (retained 93.0%)
#     Retrieved 428643 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0729" Std=0.0453" Min=0.0000" Max=0.4314"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.8679" Std=0.5489" Min=-1.2742" Max=2.0172"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 330201 points:
#       Mean=0.0672" Std=0.0426" Min=0.0000" Max=0.5500"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 330201 points:
#       Mean=1.0722" Std=0.3067" Min=-0.9007" Max=2.0172"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 30107 points:
#       Mean=0.1209" Std=0.0479" Min=0.0213" Max=0.3698"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 30107 points:
#       Mean=-0.3015" Std=0.2546" Min=-1.2742" Max=1.4838"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# PROCESSING: PISCES-LGS
# ======================================================================
# Analyzing 1 observing run(s) for pisces-lgs:
#   Run 1: 2023-03-04 03:25:42.725000 to 2023-03-06 13:11:12.376000
#     Duration: 2 days 09:45:29.651000
#     No valid RMS records after filtering
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 2 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 2: binospec_20230308_193653_to_20230320_152552.json
# ✓ binospec Run 3: binospec_20230320_180327_to_20230331_013700.json
# ✓ mmirs Run 1: mmirs_20230331_013705_to_20230401_065956.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30036
#   Timestamps: 30036
#   Rolling StdDev: 30036
#   Altitudes: 30036
#   Alt Velocities: 30036
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30054
#   Timestamps: 30054
#   Rolling StdDev: 30054
#   Altitudes: 30054
#   Alt Velocities: 30054
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30657
#   Timestamps: 30657
#   Rolling StdDev: 30657
#   Altitudes: 30657
#   Alt Velocities: 30657
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30021
#   Timestamps: 30021
#   Rolling StdDev: 30021
#   Altitudes: 30021
#   Alt Velocities: 30021
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30108
#   Timestamps: 30108
#   Rolling StdDev: 30108
#   Altitudes: 30108
#   Alt Velocities: 30108
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 20:28:00
# End DateTime:   2026-02-12 20:36:59
# Elapsed Time:   0h 8m 59s
# ================================================================================
