# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2023-01-01 00:00:00'
end_datetime = '2023-01-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 20:20:39
# Analysis period: 2023-01-01 00:00:00 to 2023-01-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2023-01-01 00:00:00 to 2023-01-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1672556400000, end_timestamp_ms=1675234799000
# Retrieved 628784 total records from hexapod_mini_instrument
# Found 5 unique instrument(s)
#   ARIES: 19020 records, 2023-01-06 15:45:35.570000 to 2023-01-07 18:11:13.651000
#   BINOSPEC: 362342 records, 2023-01-10 11:52:48.684000 to 2023-01-31 11:20:39.116000
#   F15: 6917 records, 2023-01-06 11:41:00.183000 to 2023-01-10 11:52:43.632000
#   HECTO: 197208 records, 2023-01-01 00:00:02.373000 to 2023-01-31 23:59:57.835000
#   PISCES-LGS: 43297 records, 2023-01-07 18:11:18.699000 to 2023-01-10 06:20:42.853000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   ARIES:
#     First observed: 2023-01-06 15:45:35.570000
#     Last observed:  2023-01-07 18:11:13.651000
#     Duration:       1 day, 2:25:38.081000
#
#   BINOSPEC:
#     First observed: 2023-01-10 11:52:48.684000
#     Last observed:  2023-01-31 11:20:39.116000
#     Duration:       20 days, 23:27:50.432000
#
#   F15:
#     First observed: 2023-01-06 11:41:00.183000
#     Last observed:  2023-01-10 11:52:43.632000
#     Duration:       4 days, 0:11:43.449000
#
#   HECTO:
#     First observed: 2023-01-01 00:00:02.373000
#     Last observed:  2023-01-31 23:59:57.835000
#     Duration:       30 days, 23:59:55.462000
#
#   PISCES-LGS:
#     First observed: 2023-01-07 18:11:18.699000
#     Last observed:  2023-01-10 06:20:42.853000
#     Duration:       2 days, 12:09:24.154000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-01-01 00:00:00 to 2023-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1672556400000, end_timestamp_ms=1675234799000, instrument=aries
# Retrieved 19020 records from hexapod_mini_instrument table
# Processed 19020 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-01-06 22:45:35.570000 to 2023-01-08 01:11:13.651000 (duration: 1 days 02:25:38.081000)
#   ✓ ARIES: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-01-01 00:00:00 to 2023-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1672556400000, end_timestamp_ms=1675234799000, instrument=binospec
# Retrieved 362342 records from hexapod_mini_instrument table
# Processed 362342 instrument records
# Identified 1 observing runs:
#   Run 1: 2023-01-10 18:52:48.684000 to 2023-01-31 18:20:39.116000 (duration: 20 days 23:27:50.432000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-01-01 00:00:00 to 2023-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1672556400000, end_timestamp_ms=1675234799000, instrument=f15
# Retrieved 6917 records from hexapod_mini_instrument table
# Processed 6917 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2023-01-06 18:41:00.183000 to 2023-01-06 22:45:30.511000 (duration: 0 days 04:04:30.328000)
#   Run 2: 2023-01-10 13:20:47.941000 to 2023-01-10 18:52:43.632000 (duration: 0 days 05:31:55.691000)
#   ✓ F15: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-01-01 00:00:00 to 2023-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1672556400000, end_timestamp_ms=1675234799000, instrument=hecto
# Retrieved 197208 records from hexapod_mini_instrument table
# Processed 197208 instrument records
# Identified 2 observing runs:
#   Run 1: 2023-01-01 07:00:02.373000 to 2023-01-06 18:40:55.109000 (duration: 5 days 11:40:52.736000)
#   Run 2: 2023-01-31 18:20:44.159000 to 2023-02-01 06:59:57.835000 (duration: 0 days 12:39:13.676000)
#   ✓ HECTO: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-01-01 00:00:00 to 2023-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1672556400000, end_timestamp_ms=1675234799000, instrument=pisces-lgs
# Retrieved 43297 records from hexapod_mini_instrument table
# Processed 43297 instrument records
# Identified 1 observing runs:
#   Run 1: 2023-01-08 01:11:18.699000 to 2023-01-10 13:20:42.853000 (duration: 2 days 12:09:24.154000)
#   ✓ PISCES-LGS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: ARIES
# ======================================================================
# Analyzing 1 observing run(s) for aries:
#   Run 1: 2023-01-06 22:45:35.570000 to 2023-01-08 01:11:13.651000
#     Duration: 1 days 02:25:38.081000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2023-01-10 18:52:48.684000 to 2023-01-31 18:20:39.116000
#     Duration: 20 days 23:27:50.432000
#     Filtered 148878 points in 10s intervals with variance >= 2.0" arcsec (retained 98.0%)
#     Retrieved 7506535 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0768" Std=0.0974" Min=0.0000" Max=1.3304"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1427" Std=0.8932" Min=-2.4568" Max=2.6442"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2834014 points:
#       Mean=0.0690" Std=0.0806" Min=0.0000" Max=1.1982"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2834014 points:
#       Mean=0.8355" Std=0.3882" Min=-2.0068" Max=2.6442"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 3774147 points:
#       Mean=0.0957" Std=0.1035" Min=0.0000" Max=0.8176"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 3774147 points:
#       Mean=-0.9085" Std=0.3335" Min=-2.4568" Max=1.5000"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: F15
# ======================================================================
# Analyzing 2 observing run(s) for f15:
#   Run 1: 2023-01-06 18:41:00.183000 to 2023-01-06 22:45:30.511000
#     Duration: 0 days 04:04:30.328000
#     No valid RMS records after filtering
#   Run 2: 2023-01-10 13:20:47.941000 to 2023-01-10 18:52:43.632000
#     Duration: 0 days 05:31:55.691000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 2 observing run(s) for hecto:
#   Run 1: 2023-01-01 07:00:02.373000 to 2023-01-06 18:40:55.109000
#     Duration: 5 days 11:40:52.736000
#     Filtered 6797 points in 10s intervals with variance >= 2.0" arcsec (retained 99.0%)
#     Retrieved 695938 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0495" Std=0.0408" Min=0.0000" Max=1.2049"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.3569" Std=0.9279" Min=-2.3148" Max=2.3935"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 414650 points:
#       Mean=0.0604" Std=0.0462" Min=0.0000" Max=0.6783"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 414650 points:
#       Mean=1.0943" Std=0.1430" Min=-1.1661" Max=2.3935"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 271616 points:
#       Mean=0.0331" Std=0.0210" Min=0.0000" Max=0.8434"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 271616 points:
#       Mean=-0.7604" Std=0.2560" Min=-2.3148" Max=1.2200"
#   Run 2: 2023-01-31 18:20:44.159000 to 2023-02-01 06:59:57.835000
#     Duration: 0 days 12:39:13.676000
#     No valid RMS records after filtering
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# PROCESSING: PISCES-LGS
# ======================================================================
# Analyzing 1 observing run(s) for pisces-lgs:
#   Run 1: 2023-01-08 01:11:18.699000 to 2023-01-10 13:20:42.853000
#     Duration: 2 days 12:09:24.154000
#     No valid RMS records after filtering
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20230110_185248_to_20230131_182039.json
# ✓ hecto Run 1: hecto_20230101_070002_to_20230106_184055.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30033
#   Timestamps: 30033
#   Rolling StdDev: 30033
#   Altitudes: 30033
#   Alt Velocities: 30033
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30045
#   Timestamps: 30045
#   Rolling StdDev: 30045
#   Altitudes: 30045
#   Alt Velocities: 30045
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30033
#   Timestamps: 30033
#   Rolling StdDev: 30033
#   Altitudes: 30033
#   Alt Velocities: 30033
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30405
#   Timestamps: 30405
#   Rolling StdDev: 30405
#   Altitudes: 30405
#   Alt Velocities: 30405
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30342
#   Timestamps: 30342
#   Rolling StdDev: 30342
#   Altitudes: 30342
#   Alt Velocities: 30342
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30180
#   Timestamps: 30180
#   Rolling StdDev: 30180
#   Altitudes: 30180
#   Alt Velocities: 30180
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 20:20:39
# End DateTime:   2026-02-12 20:46:15
# Elapsed Time:   0h 25m 36s
# ================================================================================
