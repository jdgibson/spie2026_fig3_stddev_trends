# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2022-03-01 00:00:00'
end_datetime = '2022-03-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 19:35:57
# Analysis period: 2022-03-01 00:00:00 to 2022-03-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2022-03-01 00:00:00 to 2022-03-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1646118000000, end_timestamp_ms=1648796399000
# Retrieved 1054761 total records from hexapod_mini_instrument
# Found 4 unique instrument(s)
#   NA: 39 records, 2022-03-01 11:28:37 to 2022-03-02 14:50:29.073000
#   BINOSPEC: 494371 records, 2022-03-02 18:31:44.799000 to 2022-03-31 23:59:58.777000
#   HECTO: 387991 records, 2022-03-01 00:00:03.534000 to 2022-03-18 15:50:32.123000
#   MMIRS: 172360 records, 2022-03-14 19:29:57.174000 to 2022-03-23 15:34:54.491000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2022-03-02 18:31:44.799000
#     Last observed:  2022-03-31 23:59:58.777000
#     Duration:       29 days, 5:28:13.978000
#
#   HECTO:
#     First observed: 2022-03-01 00:00:03.534000
#     Last observed:  2022-03-18 15:50:32.123000
#     Duration:       17 days, 15:50:28.589000
#
#   MMIRS:
#     First observed: 2022-03-14 19:29:57.174000
#     Last observed:  2022-03-23 15:34:54.491000
#     Duration:       8 days, 20:04:57.317000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-03-01 00:00:00 to 2022-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1646118000000, end_timestamp_ms=1648796399000, instrument=NA
# Retrieved 39 records from hexapod_mini_instrument table
# Processed 39 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2022-03-01 18:28:37 to 2022-03-01 18:28:37 (duration: 0 days 00:00:00)
#   Run 2: 2022-03-02 21:47:30.704000 to 2022-03-02 21:50:29.073000 (duration: 0 days 00:02:58.369000)
#   ✓ NA: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-03-01 00:00:00 to 2022-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1646118000000, end_timestamp_ms=1648796399000, instrument=binospec
# Retrieved 494371 records from hexapod_mini_instrument table
# Processed 494371 instrument records
# Identified 3 observing runs:
#   Run 1: 2022-03-03 01:31:44.799000 to 2022-03-09 00:33:56.764000 (duration: 5 days 23:02:11.965000)
#   Run 2: 2022-03-15 02:29:52.113000 to 2022-03-15 02:29:52.113000 (duration: 0 days 00:00:00)
#   Run 3: 2022-03-23 22:34:53.749000 to 2022-04-01 06:59:58.777000 (duration: 8 days 08:25:05.028000)
#   ✓ BINOSPEC: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-03-01 00:00:00 to 2022-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1646118000000, end_timestamp_ms=1648796399000, instrument=hecto
# Retrieved 387991 records from hexapod_mini_instrument table
# Processed 387991 instrument records
# Identified 3 observing runs:
#   Run 1: 2022-03-01 07:00:03.534000 to 2022-03-02 16:17:54.073000 (duration: 1 days 09:17:50.539000)
#   Run 2: 2022-03-02 21:49:40.852000 to 2022-03-03 01:32:09.553000 (duration: 0 days 03:42:28.701000)
#   Run 3: 2022-03-09 00:33:23.089000 to 2022-03-18 22:50:32.123000 (duration: 9 days 22:17:09.034000)
#   ✓ HECTO: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-03-01 00:00:00 to 2022-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1646118000000, end_timestamp_ms=1648796399000, instrument=mmirs
# Retrieved 172360 records from hexapod_mini_instrument table
# Processed 172360 instrument records
# Identified 2 observing runs:
#   Run 1: 2022-03-15 02:29:57.174000 to 2022-03-15 02:30:12.327000 (duration: 0 days 00:00:15.153000)
#   Run 2: 2022-03-18 22:50:31.490000 to 2022-03-23 22:34:54.491000 (duration: 4 days 23:44:23.001000)
#   ✓ MMIRS: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 2 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:02:58.369000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 3 observing run(s) for binospec:
#   Run 1: 2022-03-03 01:31:44.799000 to 2022-03-09 00:33:56.764000
#     Duration: 5 days 23:02:11.965000
#     Filtered 37632 points in 10s intervals with variance >= 2.0" arcsec (retained 97.4%)
#     Retrieved 1465639 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0529" Std=0.0516" Min=0.0000" Max=0.9603"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0157" Std=0.8680" Min=-2.2014" Max=2.1484"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 691836 points:
#       Mean=0.0442" Std=0.0483" Min=0.0000" Max=0.6360"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 691836 points:
#       Mean=0.7680" Std=0.3101" Min=-1.2473" Max=2.1484"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 592981 points:
#       Mean=0.0651" Std=0.0527" Min=0.0000" Max=0.6843"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 592981 points:
#       Mean=-0.9225" Std=0.3705" Min=-2.2014" Max=1.4255"
#   Run 2: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 3: 2022-03-23 22:34:53.749000 to 2022-04-01 06:59:58.777000
#     Duration: 8 days 08:25:05.028000
#     Filtered 104502 points in 10s intervals with variance >= 2.0" arcsec (retained 97.3%)
#     Retrieved 3845690 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0642" Std=0.0711" Min=0.0000" Max=1.1888"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2112" Std=0.8713" Min=-2.6099" Max=2.4887"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1217813 points:
#       Mean=0.0692" Std=0.0726" Min=0.0000" Max=1.0309"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1217813 points:
#       Mean=0.8511" Std=0.3989" Min=-1.9622" Max=2.4887"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2011984 points:
#       Mean=0.0686" Std=0.0657" Min=0.0000" Max=0.8646"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2011984 points:
#       Mean=-0.8959" Std=0.3586" Min=-2.6099" Max=1.7733"
#
# Successfully analyzed 2 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 3 observing run(s) for hecto:
#   Run 1: 2022-03-01 07:00:03.534000 to 2022-03-02 16:17:54.073000
#     Duration: 1 days 09:17:50.539000
#     Filtered 8953 points in 10s intervals with variance >= 2.0" arcsec (retained 99.2%)
#     Retrieved 1092000 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0301" Std=0.0331" Min=0.0000" Max=0.8723"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.4788" Std=0.7966" Min=-1.5377" Max=1.5156"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 794339 points:
#       Mean=0.0293" Std=0.0297" Min=0.0000" Max=0.5854"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 794339 points:
#       Mean=0.8812" Std=0.3544" Min=-1.0272" Max=1.5156"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 203982 points:
#       Mean=0.0276" Std=0.0184" Min=0.0000" Max=0.4141"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 203982 points:
#       Mean=-0.9334" Std=0.4054" Min=-1.5377" Max=1.2816"
#   Run 2: 2022-03-02 21:49:40.852000 to 2022-03-03 01:32:09.553000
#     Duration: 0 days 03:42:28.701000
#     No valid RMS records after filtering
#   Run 3: 2022-03-09 00:33:23.089000 to 2022-03-18 22:50:32.123000
#     Duration: 9 days 22:17:09.034000
#     Filtered 71666 points in 10s intervals with variance >= 2.0" arcsec (retained 98.7%)
#     Retrieved 5551019 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0562" Std=0.0748" Min=0.0000" Max=1.3832"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.1725" Std=0.8432" Min=-2.6732" Max=2.8826"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 3010454 points:
#       Mean=0.0591" Std=0.0805" Min=0.0000" Max=0.9497"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 3010454 points:
#       Mean=0.8397" Std=0.3306" Min=-1.2503" Max=2.8826"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1909127 points:
#       Mean=0.0556" Std=0.0601" Min=0.0000" Max=0.9835"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1909127 points:
#       Mean=-0.8432" Std=0.3332" Min=-2.6732" Max=1.3175"
#
# Successfully analyzed 2 run(s) for hecto
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 2 observing run(s) for mmirs:
#   Run 1: Skipped (duration 0 days 00:00:15.153000 is less than 1.0 hours)
#   Run 2: 2022-03-18 22:50:31.490000 to 2022-03-23 22:34:54.491000
#     Duration: 4 days 23:44:23.001000
#     Filtered 104254 points in 10s intervals with variance >= 2.0" arcsec (retained 92.6%)
#     Retrieved 1407574 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0502" Std=0.0484" Min=0.0000" Max=1.1894"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0889" Std=0.9824" Min=-2.2768" Max=2.0613"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 629555 points:
#       Mean=0.0469" Std=0.0467" Min=0.0000" Max=1.3161"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 629555 points:
#       Mean=0.9470" Std=0.5552" Min=-1.8766" Max=2.0613"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 509169 points:
#       Mean=0.0570" Std=0.0494" Min=0.0000" Max=1.0900"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 509169 points:
#       Mean=-0.8806" Std=0.3963" Min=-2.2768" Max=1.3185"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 3
#   BINOSPEC: 2 run(s)
#   HECTO: 2 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20220303_013144_to_20220309_003356.json
# ✓ binospec Run 3: binospec_20220323_223453_to_20220401_065958.json
# ✓ hecto Run 1: hecto_20220301_070003_to_20220302_161754.json
# ✓ hecto Run 3: hecto_20220309_003323_to_20220318_225032.json
# ✓ mmirs Run 2: mmirs_20220318_225031_to_20220323_223454.json
#
# ✓ Saved statistics for 5 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30054
#   Timestamps: 30054
#   Rolling StdDev: 30054
#   Altitudes: 30054
#   Alt Velocities: 30054
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30153
#   Timestamps: 30153
#   Rolling StdDev: 30153
#   Altitudes: 30153
#   Alt Velocities: 30153
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30060
#   Timestamps: 30060
#   Rolling StdDev: 30060
#   Altitudes: 30060
#   Alt Velocities: 30060
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30012
#   Timestamps: 30012
#   Rolling StdDev: 30012
#   Altitudes: 30012
#   Alt Velocities: 30012
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30039
#   Timestamps: 30039
#   Rolling StdDev: 30039
#   Altitudes: 30039
#   Alt Velocities: 30039
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30045
#   Timestamps: 30045
#   Rolling StdDev: 30045
#   Altitudes: 30045
#   Alt Velocities: 30045
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30078
#   Timestamps: 30078
#   Rolling StdDev: 30078
#   Altitudes: 30078
#   Alt Velocities: 30078
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30465
#   Timestamps: 30465
#   Rolling StdDev: 30465
#   Altitudes: 30465
#   Alt Velocities: 30465
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30552
#   Timestamps: 30552
#   Rolling StdDev: 30552
#   Altitudes: 30552
#   Alt Velocities: 30552
# ================================================================================
# Generated 9 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 19:35:57
# End DateTime:   2026-02-12 19:53:26
# Elapsed Time:   0h 17m 29s
# ================================================================================
