# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2020-10-01 00:00:00'
end_datetime = '2020-10-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 18:01:16
# Analysis period: 2020-10-01 00:00:00 to 2020-10-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2020-10-01 00:00:00 to 2020-10-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1601535600000, end_timestamp_ms=1604213999000
# Retrieved 531223 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 4 records, 2020-10-04 08:58:59.250000 to 2020-10-26 09:51:07.079000
#   BINOSPEC: 171672 records, 2020-10-13 17:24:52.180000 to 2020-10-23 15:54:25.221000
#   HECTO: 359547 records, 2020-10-01 00:00:02.739000 to 2020-10-31 23:59:55.808000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2020-10-13 17:24:52.180000
#     Last observed:  2020-10-23 15:54:25.221000
#     Duration:       9 days, 22:29:33.041000
#
#   HECTO:
#     First observed: 2020-10-01 00:00:02.739000
#     Last observed:  2020-10-31 23:59:55.808000
#     Duration:       30 days, 23:59:53.069000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-10-01 00:00:00 to 2020-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1601535600000, end_timestamp_ms=1604213999000, instrument=NA
# Retrieved 4 records from hexapod_mini_instrument table
# Processed 4 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2020-10-04 15:58:59.250000 to 2020-10-04 15:58:59.250000 (duration: 0 days 00:00:00)
#   Run 2: 2020-10-26 16:51:02.888000 to 2020-10-26 16:51:07.079000 (duration: 0 days 00:00:04.191000)
#   ✓ NA: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-10-01 00:00:00 to 2020-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1601535600000, end_timestamp_ms=1604213999000, instrument=binospec
# Retrieved 171672 records from hexapod_mini_instrument table
# Processed 171672 instrument records
# Identified 1 observing runs:
#   Run 1: 2020-10-14 00:24:52.180000 to 2020-10-23 22:54:25.221000 (duration: 9 days 22:29:33.041000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-10-01 00:00:00 to 2020-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1601535600000, end_timestamp_ms=1604213999000, instrument=hecto
# Retrieved 359547 records from hexapod_mini_instrument table
# Processed 359547 instrument records
# Identified 4 observing runs:
#   Run 1: 2020-10-01 07:00:02.739000 to 2020-10-04 12:28:50.808000 (duration: 3 days 05:28:48.069000)
#   Run 2: 2020-10-04 15:58:59.337000 to 2020-10-14 00:24:47.182000 (duration: 9 days 08:25:47.845000)
#   Run 3: 2020-10-23 22:54:30.266000 to 2020-10-26 14:23:00.990000 (duration: 2 days 15:28:30.724000)
#   Run 4: 2020-10-26 16:51:12.166000 to 2020-11-01 06:59:55.808000 (duration: 5 days 14:08:43.642000)
#   ✓ HECTO: 4 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 2 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:04.191000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2020-10-14 00:24:52.180000 to 2020-10-23 22:54:25.221000
#     Duration: 9 days 22:29:33.041000
#     Filtered 133748 points in 10s intervals with variance >= 2.0" arcsec (retained 98.2%)
#     Retrieved 7407723 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0590" Std=0.0809" Min=0.0000" Max=1.3387"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0023" Std=0.8348" Min=-2.9463" Max=2.7189"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 3183303 points:
#       Mean=0.0619" Std=0.0764" Min=0.0000" Max=1.2982"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 3183303 points:
#       Mean=0.7928" Std=0.3687" Min=-2.5703" Max=2.7189"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2950108 points:
#       Mean=0.0591" Std=0.0711" Min=0.0000" Max=0.8093"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2950108 points:
#       Mean=-0.8399" Std=0.3941" Min=-2.9463" Max=2.3113"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 4 observing run(s) for hecto:
#   Run 1: 2020-10-01 07:00:02.739000 to 2020-10-04 12:28:50.808000
#     Duration: 3 days 05:28:48.069000
#     Filtered 68730 points in 10s intervals with variance >= 2.0" arcsec (retained 97.0%)
#     Retrieved 2255418 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0415" Std=0.0435" Min=0.0000" Max=1.0285"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0361" Std=0.8158" Min=-2.7939" Max=2.5753"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 981683 points:
#       Mean=0.0458" Std=0.0431" Min=0.0000" Max=0.8636"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 981683 points:
#       Mean=0.7731" Std=0.3995" Min=-1.3383" Max=2.5753"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 843640 points:
#       Mean=0.0449" Std=0.0424" Min=0.0000" Max=0.7845"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 843640 points:
#       Mean=-0.8170" Std=0.3890" Min=-2.7939" Max=1.2249"
#   Run 2: 2020-10-04 15:58:59.337000 to 2020-10-14 00:24:47.182000
#     Duration: 9 days 08:25:47.845000
#     Filtered 191395 points in 10s intervals with variance >= 2.0" arcsec (retained 96.9%)
#     Retrieved 6104123 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0840" Std=0.0906" Min=0.0000" Max=1.2694"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0224" Std=0.9606" Min=-2.5403" Max=2.7826"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2582554 points:
#       Mean=0.0829" Std=0.0891" Min=0.0000" Max=1.1363"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2582554 points:
#       Mean=0.9532" Std=0.3736" Min=-1.8201" Max=2.7826"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2815315 points:
#       Mean=0.0950" Std=0.0891" Min=0.0000" Max=1.0210"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2815315 points:
#       Mean=-0.9090" Std=0.3565" Min=-2.5403" Max=1.2806"
#   Run 3: 2020-10-23 22:54:30.266000 to 2020-10-26 14:23:00.990000
#     Duration: 2 days 15:28:30.724000
#     Filtered 31011 points in 10s intervals with variance >= 2.0" arcsec (retained 97.4%)
#     Retrieved 1187215 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0568" Std=0.0450" Min=0.0000" Max=1.1609"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.3712" Std=0.9468" Min=-2.2945" Max=1.7565"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 723273 points:
#       Mean=0.0545" Std=0.0386" Min=0.0000" Max=0.7490"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 723273 points:
#       Mean=1.0626" Std=0.2321" Min=-0.4888" Max=1.7565"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 376851 points:
#       Mean=0.0642" Std=0.0540" Min=0.0000" Max=0.5829"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 376851 points:
#       Mean=-0.8919" Std=0.3054" Min=-2.2945" Max=1.0900"
#   Run 4: 2020-10-26 16:51:12.166000 to 2020-11-01 06:59:55.808000
#     Duration: 5 days 14:08:43.642000
#     Filtered 12590 points in 10s intervals with variance >= 2.0" arcsec (retained 98.9%)
#     Retrieved 1151840 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0417" Std=0.0408" Min=0.0000" Max=1.2163"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.6313" Std=0.7195" Min=-1.6518" Max=1.2906"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 203143 points:
#       Mean=0.0433" Std=0.0418" Min=0.0000" Max=0.5530"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 203143 points:
#       Mean=0.6592" Std=0.2704" Min=-1.3060" Max=1.2906"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 843402 points:
#       Mean=0.0416" Std=0.0390" Min=0.0000" Max=0.7092"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 843402 points:
#       Mean=-1.0076" Std=0.3036" Min=-1.6518" Max=1.2770"
#
# Successfully analyzed 4 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 4 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20201014_002452_to_20201023_225425.json
# ✓ hecto Run 1: hecto_20201001_070002_to_20201004_122850.json
# ✓ hecto Run 2: hecto_20201004_155859_to_20201014_002447.json
# ✓ hecto Run 3: hecto_20201023_225430_to_20201026_142300.json
# ✓ hecto Run 4: hecto_20201026_165112_to_20201101_065955.json
#
# ✓ Saved statistics for 5 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30018
#   Timestamps: 30018
#   Rolling StdDev: 30018
#   Altitudes: 30018
#   Alt Velocities: 30018
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30033
#   Timestamps: 30033
#   Rolling StdDev: 30033
#   Altitudes: 30033
#   Alt Velocities: 30033
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30003
#   Timestamps: 30003
#   Rolling StdDev: 30003
#   Altitudes: 30003
#   Alt Velocities: 30003
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30006
#   Timestamps: 30006
#   Rolling StdDev: 30006
#   Altitudes: 30006
#   Alt Velocities: 30006
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30057
#   Timestamps: 30057
#   Rolling StdDev: 30057
#   Altitudes: 30057
#   Alt Velocities: 30057
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 18:01:16
# End DateTime:   2026-02-12 18:26:43
# Elapsed Time:   0h 25m 27s
# ================================================================================
