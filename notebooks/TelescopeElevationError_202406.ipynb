# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2024-06-01 00:00:00'
end_datetime = '2024-06-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 21:33:11
# Analysis period: 2024-06-01 00:00:00 to 2024-06-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2024-06-01 00:00:00 to 2024-06-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1717225200000, end_timestamp_ms=1719817199000
# Retrieved 1026994 total records from hexapod_mini_instrument
# Found 4 unique instrument(s)
#   ARIES: 215328 records, 2024-06-14 19:18:53.693000 to 2024-06-21 02:57:01.434000
#   BINOSPEC: 329373 records, 2024-06-01 00:00:03.384000 to 2024-06-10 14:40:34.047000
#   F15: 15173 records, 2024-06-21 02:57:06.374000 to 2024-06-21 13:34:18.563000
#   HECTO: 467120 records, 2024-06-10 14:40:37.944000 to 2024-06-30 23:59:55.260000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   ARIES:
#     First observed: 2024-06-14 19:18:53.693000
#     Last observed:  2024-06-21 02:57:01.434000
#     Duration:       6 days, 7:38:07.741000
#
#   BINOSPEC:
#     First observed: 2024-06-01 00:00:03.384000
#     Last observed:  2024-06-10 14:40:34.047000
#     Duration:       9 days, 14:40:30.663000
#
#   F15:
#     First observed: 2024-06-21 02:57:06.374000
#     Last observed:  2024-06-21 13:34:18.563000
#     Duration:       10:37:12.189000
#
#   HECTO:
#     First observed: 2024-06-10 14:40:37.944000
#     Last observed:  2024-06-30 23:59:55.260000
#     Duration:       20 days, 9:19:17.316000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-06-01 00:00:00 to 2024-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1717225200000, end_timestamp_ms=1719817199000, instrument=aries
# Retrieved 215328 records from hexapod_mini_instrument table
# Processed 215328 instrument records
# Identified 1 observing runs:
#   Run 1: 2024-06-15 02:18:53.693000 to 2024-06-21 09:57:01.434000 (duration: 6 days 07:38:07.741000)
#   ✓ ARIES: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-06-01 00:00:00 to 2024-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1717225200000, end_timestamp_ms=1719817199000, instrument=binospec
# Retrieved 329373 records from hexapod_mini_instrument table
# Processed 329373 instrument records
# Identified 1 observing runs:
#   Run 1: 2024-06-01 07:00:03.384000 to 2024-06-10 21:40:34.047000 (duration: 9 days 14:40:30.663000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-06-01 00:00:00 to 2024-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1717225200000, end_timestamp_ms=1719817199000, instrument=f15
# Retrieved 15173 records from hexapod_mini_instrument table
# Processed 15173 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2024-06-21 09:57:06.374000 to 2024-06-21 20:34:18.563000 (duration: 0 days 10:37:12.189000)
#   ✓ F15: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-06-01 00:00:00 to 2024-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1717225200000, end_timestamp_ms=1719817199000, instrument=hecto
# Retrieved 467120 records from hexapod_mini_instrument table
# Processed 467120 instrument records
# Identified 2 observing runs:
#   Run 1: 2024-06-10 21:40:37.944000 to 2024-06-15 02:18:51.010000 (duration: 4 days 04:38:13.066000)
#   Run 2: 2024-06-21 20:34:21.064000 to 2024-07-01 06:59:55.260000 (duration: 9 days 10:25:34.196000)
#   ✓ HECTO: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: ARIES
# ======================================================================
# Analyzing 1 observing run(s) for aries:
#   Run 1: 2024-06-15 02:18:53.693000 to 2024-06-21 09:57:01.434000
#     Duration: 6 days 07:38:07.741000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2024-06-01 07:00:03.384000 to 2024-06-10 21:40:34.047000
#     Duration: 9 days 14:40:30.663000
#     Filtered 164571 points in 10s intervals with variance >= 2.0" arcsec (retained 96.9%)
#     Retrieved 5380817 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0890" Std=0.0929" Min=0.0000" Max=1.2640"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.5247" Std=0.9003" Min=-2.7020" Max=3.0788"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1290647 points:
#       Mean=0.0696" Std=0.0674" Min=0.0000" Max=1.2208"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1290647 points:
#       Mean=0.8667" Std=0.4043" Min=-2.7020" Max=3.0788"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 3598491 points:
#       Mean=0.1012" Std=0.1005" Min=0.0000" Max=0.9568"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 3598491 points:
#       Mean=-1.0622" Std=0.3107" Min=-2.6685" Max=1.3468"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: F15
# ======================================================================
# Analyzing 1 observing run(s) for f15:
#   Run 1: 2024-06-21 09:57:06.374000 to 2024-06-21 20:34:18.563000
#     Duration: 0 days 10:37:12.189000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 2 observing run(s) for hecto:
#   Run 1: 2024-06-10 21:40:37.944000 to 2024-06-15 02:18:51.010000
#     Duration: 4 days 04:38:13.066000
#     Filtered 46964 points in 10s intervals with variance >= 2.0" arcsec (retained 96.9%)
#     Retrieved 1512000 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0503" Std=0.0570" Min=0.0000" Max=1.4597"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.5033" Std=0.9374" Min=-1.7994" Max=1.7896"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 354334 points:
#       Mean=0.0361" Std=0.0452" Min=0.0000" Max=1.2899"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 354334 points:
#       Mean=1.0171" Std=0.3376" Min=-1.5436" Max=1.7896"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1043682 points:
#       Mean=0.0525" Std=0.0585" Min=0.0000" Max=0.7058"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1043682 points:
#       Mean=-1.0227" Std=0.3563" Min=-1.7994" Max=1.3220"
#   Run 2: 2024-06-21 20:34:21.064000 to 2024-07-01 06:59:55.260000
#     Duration: 9 days 10:25:34.196000
#     Retrieved 156000 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0408" Std=0.0175" Min=0.0000" Max=0.1926"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.6434" Std=0.1233" Min=-1.0848" Max=-0.1945"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1 points:
#       Mean=nan" Std=nan" Min=nan" Max=nan"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1 points:
#       Mean=-0.5246" Std=0.0000" Min=-0.5246" Max=-0.5246"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 151818 points:
#       Mean=0.0409" Std=0.0177" Min=0.0000" Max=0.1926"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 151818 points:
#       Mean=-0.6452" Std=0.1236" Min=-1.0848" Max=-0.1945"
#
# Successfully analyzed 2 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20240601_070003_to_20240610_214034.json
# ✓ hecto Run 1: hecto_20240610_214037_to_20240615_021851.json
# ✓ hecto Run 2: hecto_20240621_203421_to_20240701_065955.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30036
#   Timestamps: 30036
#   Rolling StdDev: 30036
#   Altitudes: 30036
#   Alt Velocities: 30036
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30018
#   Timestamps: 30018
#   Rolling StdDev: 30018
#   Altitudes: 30018
#   Alt Velocities: 30018
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30072
#   Timestamps: 30072
#   Rolling StdDev: 30072
#   Altitudes: 30072
#   Alt Velocities: 30072
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30021
#   Timestamps: 30021
#   Rolling StdDev: 30021
#   Altitudes: 30021
#   Alt Velocities: 30021
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30372
#   Timestamps: 30372
#   Rolling StdDev: 30372
#   Altitudes: 30372
#   Alt Velocities: 30372
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30141
#   Timestamps: 30141
#   Rolling StdDev: 30141
#   Altitudes: 30141
#   Alt Velocities: 30141
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 21:33:11
# End DateTime:   2026-02-12 21:43:20
# Elapsed Time:   0h 10m 9s
# ================================================================================
