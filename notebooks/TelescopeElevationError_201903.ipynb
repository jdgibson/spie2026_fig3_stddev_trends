# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2019-03-01 00:00:00'
end_datetime = '2019-03-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 16:52:39
# Analysis period: 2019-03-01 00:00:00 to 2019-03-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2019-03-01 00:00:00 to 2019-03-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1551423600000, end_timestamp_ms=1554101999000
# Retrieved 44444 total records from hexapod_mini_instrument
# Found 2 unique instrument(s)
#   BINOSPEC: 8101 records, 2019-03-26 09:00:14.739000 to 2019-03-31 23:59:42
#   HECTO: 36343 records, 2019-03-01 00:00:51 to 2019-03-26 08:59:41
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2019-03-26 09:00:14.739000
#     Last observed:  2019-03-31 23:59:42
#     Duration:       5 days, 14:59:27.261000
#
#   HECTO:
#     First observed: 2019-03-01 00:00:51
#     Last observed:  2019-03-26 08:59:41
#     Duration:       25 days, 8:58:50
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-03-01 00:00:00 to 2019-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1551423600000, end_timestamp_ms=1554101999000, instrument=binospec
# Retrieved 8101 records from hexapod_mini_instrument table
# Processed 8101 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2019-03-26 16:00:14.739000 to 2019-04-01 06:59:42 (duration: 5 days 14:59:27.261000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-03-01 00:00:00 to 2019-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1551423600000, end_timestamp_ms=1554101999000, instrument=hecto
# Retrieved 36343 records from hexapod_mini_instrument table
# Processed 36343 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2019-03-01 07:00:51 to 2019-03-19 15:15:07 (duration: 18 days 08:14:16)
#   Run 2: 2019-03-19 18:28:50.743000 to 2019-03-26 15:59:41 (duration: 6 days 21:30:50.257000)
#   ✓ HECTO: 2 observing runs
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2019-03-26 16:00:14.739000 to 2019-04-01 06:59:42
#     Duration: 5 days 14:59:27.261000
#     Filtered 24387 points in 10s intervals with variance >= 2.0" arcsec (retained 99.2%)
#     Retrieved 3053014 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0469" Std=0.0494" Min=0.0000" Max=1.1977"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0072" Std=0.6897" Min=-2.2745" Max=2.6324"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1186792 points:
#       Mean=0.0436" Std=0.0431" Min=0.0000" Max=0.7936"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1186792 points:
#       Mean=0.6892" Std=0.3617" Min=-1.6046" Max=2.6324"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1205389 points:
#       Mean=0.0533" Std=0.0441" Min=0.0000" Max=0.7030"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1205389 points:
#       Mean=-0.6624" Std=0.3569" Min=-2.2745" Max=1.3611"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 2 observing run(s) for hecto:
#   Run 1: 2019-03-01 07:00:51 to 2019-03-19 15:15:07
#     Duration: 18 days 08:14:16
#     Filtered 70588 points in 10s intervals with variance >= 2.0" arcsec (retained 98.4%)
#     Retrieved 4475241 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0577" Std=0.0685" Min=0.0000" Max=1.3348"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.2204" Std=0.8698" Min=-2.3109" Max=1.7307"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2770792 points:
#       Mean=0.0567" Std=0.0665" Min=0.0000" Max=0.8857"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2770792 points:
#       Mean=0.8120" Std=0.2826" Min=-1.6086" Max=1.7307"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1301341 points:
#       Mean=0.0673" Std=0.0634" Min=0.0000" Max=0.7483"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1301341 points:
#       Mean=-0.9938" Std=0.3724" Min=-2.3109" Max=1.2864"
#   Run 2: 2019-03-19 18:28:50.743000 to 2019-03-26 15:59:41
#     Duration: 6 days 21:30:50.257000
#     Filtered 37498 points in 10s intervals with variance >= 2.0" arcsec (retained 99.1%)
#     Retrieved 3959363 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0506" Std=0.0610" Min=0.0000" Max=1.1357"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.3659" Std=0.8160" Min=-2.7276" Max=2.2430"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1019466 points:
#       Mean=0.0343" Std=0.0330" Min=0.0000" Max=0.7920"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1019466 points:
#       Mean=0.8230" Std=0.3460" Min=-1.3849" Max=2.2430"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2563907 points:
#       Mean=0.0598" Std=0.0703" Min=0.0000" Max=0.6887"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2563907 points:
#       Mean=-0.8856" Std=0.3332" Min=-2.7276" Max=1.0927"
#
# Successfully analyzed 2 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20190326_160014_to_20190401_065942.json
# ✓ hecto Run 1: hecto_20190301_070051_to_20190319_151507.json
# ✓ hecto Run 2: hecto_20190319_182850_to_20190326_155941.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30087
#   Timestamps: 30087
#   Rolling StdDev: 30087
#   Altitudes: 30087
#   Alt Velocities: 30087
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30174
#   Timestamps: 30174
#   Rolling StdDev: 30174
#   Altitudes: 30174
#   Alt Velocities: 30174
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30135
#   Timestamps: 30135
#   Rolling StdDev: 30135
#   Altitudes: 30135
#   Alt Velocities: 30135
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30024
#   Timestamps: 30024
#   Rolling StdDev: 30024
#   Altitudes: 30024
#   Alt Velocities: 30024
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30003
#   Timestamps: 30003
#   Rolling StdDev: 30003
#   Altitudes: 30003
#   Alt Velocities: 30003
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30042
#   Timestamps: 30042
#   Rolling StdDev: 30042
#   Altitudes: 30042
#   Alt Velocities: 30042
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 16:52:39
# End DateTime:   2026-02-12 17:13:16
# Elapsed Time:   0h 20m 36s
# ================================================================================
