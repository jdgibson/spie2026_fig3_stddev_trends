# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2021-05-01 00:00:00'
end_datetime = '2021-05-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 18:45:19
# Analysis period: 2021-05-01 00:00:00 to 2021-05-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2021-05-01 00:00:00 to 2021-05-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1619852400000, end_timestamp_ms=1622530799000
# Retrieved 527507 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 4 records, 2021-05-13 21:38:15.984000 to 2021-05-14 15:57:04.011000
#   BINOSPEC: 344938 records, 2021-05-01 00:00:03.010000 to 2021-05-21 10:10:45.656000
#   MMIRS: 182565 records, 2021-05-21 10:10:50.703000 to 2021-05-31 23:59:56.533000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2021-05-01 00:00:03.010000
#     Last observed:  2021-05-21 10:10:45.656000
#     Duration:       20 days, 10:10:42.646000
#
#   MMIRS:
#     First observed: 2021-05-21 10:10:50.703000
#     Last observed:  2021-05-31 23:59:56.533000
#     Duration:       10 days, 13:49:05.830000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-05-01 00:00:00 to 2021-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1619852400000, end_timestamp_ms=1622530799000, instrument=NA
# Retrieved 4 records from hexapod_mini_instrument table
# Processed 4 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2021-05-14 04:38:15.984000 to 2021-05-14 04:38:20.058000 (duration: 0 days 00:00:04.074000)
#   Run 2: 2021-05-14 22:57:04.011000 to 2021-05-14 22:57:04.011000 (duration: 0 days 00:00:00)
#   ✓ NA: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-05-01 00:00:00 to 2021-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1619852400000, end_timestamp_ms=1622530799000, instrument=binospec
# Retrieved 344938 records from hexapod_mini_instrument table
# Processed 344938 instrument records
# Identified 2 observing runs:
#   Run 1: 2021-05-01 07:00:03.010000 to 2021-05-13 17:50:41.249000 (duration: 12 days 10:50:38.239000)
#   Run 2: 2021-05-14 04:38:25.237000 to 2021-05-21 17:10:45.656000 (duration: 7 days 12:32:20.419000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-05-01 00:00:00 to 2021-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1619852400000, end_timestamp_ms=1622530799000, instrument=mmirs
# Retrieved 182565 records from hexapod_mini_instrument table
# Processed 182565 instrument records
# Identified 1 observing runs:
#   Run 1: 2021-05-21 17:10:50.703000 to 2021-06-01 06:59:56.533000 (duration: 10 days 13:49:05.830000)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 2 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:04.074000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2021-05-01 07:00:03.010000 to 2021-05-13 17:50:41.249000
#     Duration: 12 days 10:50:38.239000
#     Filtered 142219 points in 10s intervals with variance >= 2.0" arcsec (retained 98.1%)
#     Retrieved 7301540 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0677" Std=0.0851" Min=0.0000" Max=1.2493"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4112" Std=0.7081" Min=-2.4004" Max=2.1649"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1431515 points:
#       Mean=0.0774" Std=0.0698" Min=0.0000" Max=1.2790"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1431515 points:
#       Mean=0.7760" Std=0.3520" Min=-1.9692" Max=2.1649"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 4923505 points:
#       Mean=0.0838" Std=0.1075" Min=0.0000" Max=0.9749"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 4923505 points:
#       Mean=-0.8083" Std=0.3114" Min=-2.4004" Max=1.5041"
#   Run 2: 2021-05-14 04:38:25.237000 to 2021-05-21 17:10:45.656000
#     Duration: 7 days 12:32:20.419000
#     Filtered 137669 points in 10s intervals with variance >= 2.0" arcsec (retained 96.1%)
#     Retrieved 3575188 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0804" Std=0.0728" Min=0.0000" Max=1.1668"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2497" Std=0.8156" Min=-3.2575" Max=2.4782"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 936249 points:
#       Mean=0.0804" Std=0.0636" Min=0.0000" Max=1.0317"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 936249 points:
#       Mean=0.9220" Std=0.3529" Min=-1.8914" Max=2.3294"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2151393 points:
#       Mean=0.0888" Std=0.0740" Min=0.0000" Max=1.0132"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2151393 points:
#       Mean=-0.7737" Std=0.3408" Min=-3.2575" Max=2.4782"
#
# Successfully analyzed 2 run(s) for binospec
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2021-05-21 17:10:50.703000 to 2021-06-01 06:59:56.533000
#     Duration: 10 days 13:49:05.830000
#     Filtered 513873 points in 10s intervals with variance >= 2.0" arcsec (retained 91.3%)
#     Retrieved 5883408 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0824" Std=0.1000" Min=0.0000" Max=1.2851"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4790" Std=0.9113" Min=-3.0110" Max=2.4584"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1403197 points:
#       Mean=0.0578" Std=0.0581" Min=0.0000" Max=1.1203"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1403197 points:
#       Mean=0.8699" Std=0.4469" Min=-2.5155" Max=2.4584"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 3563186 points:
#       Mean=0.1073" Std=0.1138" Min=0.0000" Max=1.0833"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 3563186 points:
#       Mean=-1.0441" Std=0.3217" Min=-3.0110" Max=1.9478"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 2 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20210501_070003_to_20210513_175041.json
# ✓ binospec Run 2: binospec_20210514_043825_to_20210521_171045.json
# ✓ mmirs Run 1: mmirs_20210521_171050_to_20210601_065956.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30021
#   Timestamps: 30021
#   Rolling StdDev: 30021
#   Altitudes: 30021
#   Alt Velocities: 30021
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30099
#   Timestamps: 30099
#   Rolling StdDev: 30099
#   Altitudes: 30099
#   Alt Velocities: 30099
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30021
#   Timestamps: 30021
#   Rolling StdDev: 30021
#   Altitudes: 30021
#   Alt Velocities: 30021
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30054
#   Timestamps: 30054
#   Rolling StdDev: 30054
#   Altitudes: 30054
#   Alt Velocities: 30054
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30069
#   Timestamps: 30069
#   Rolling StdDev: 30069
#   Altitudes: 30069
#   Alt Velocities: 30069
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30027
#   Timestamps: 30027
#   Rolling StdDev: 30027
#   Altitudes: 30027
#   Alt Velocities: 30027
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 18:45:19
# End DateTime:   2026-02-12 19:14:33
# Elapsed Time:   0h 29m 13s
# ================================================================================
