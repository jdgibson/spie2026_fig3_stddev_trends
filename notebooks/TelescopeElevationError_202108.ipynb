# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2021-08-01 00:00:00'
end_datetime = '2021-08-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 19:04:36
# Analysis period: 2021-08-01 00:00:00 to 2021-08-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2021-08-01 00:00:00 to 2021-08-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1627801200000, end_timestamp_ms=1630479599000
# Retrieved 514069 total records from hexapod_mini_instrument
# Found 2 unique instrument(s)
#   NA: 24 records, 2021-08-04 11:25:44.804000 to 2021-08-20 08:56:08.864000
#   HECTO: 514045 records, 2021-08-01 00:00:02.881000 to 2021-08-31 23:59:58.673000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   HECTO:
#     First observed: 2021-08-01 00:00:02.881000
#     Last observed:  2021-08-31 23:59:58.673000
#     Duration:       30 days, 23:59:55.792000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-08-01 00:00:00 to 2021-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1627801200000, end_timestamp_ms=1630479599000, instrument=NA
# Retrieved 24 records from hexapod_mini_instrument table
# Processed 24 instrument records
#
# Identified 6 observing runs:
#   Run 1: 2021-08-04 18:25:44.804000 to 2021-08-04 18:25:44.891000 (duration: 0 days 00:00:00.087000)
#   Run 2: 2021-08-11 00:44:08.261000 to 2021-08-11 00:45:03.956000 (duration: 0 days 00:00:55.695000)
#   Run 3: 2021-08-17 14:40:26.402000 to 2021-08-17 14:40:31.610000 (duration: 0 days 00:00:05.208000)
#   Run 4: 2021-08-17 18:54:26.319000 to 2021-08-17 18:54:31.426000 (duration: 0 days 00:00:05.107000)
#   Run 5: 2021-08-18 03:38:28.520000 to 2021-08-18 03:38:28.520000 (duration: 0 days 00:00:00)
#   Run 6: 2021-08-20 15:56:03.786000 to 2021-08-20 15:56:08.864000 (duration: 0 days 00:00:05.078000)
#   ✓ NA: 6 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-08-01 00:00:00 to 2021-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1627801200000, end_timestamp_ms=1630479599000, instrument=hecto
# Retrieved 514045 records from hexapod_mini_instrument table
# Processed 514045 instrument records
# Identified 3 observing runs:
#   Run 1: 2021-08-01 07:00:02.881000 to 2021-08-04 11:24:19.477000 (duration: 3 days 04:24:16.596000)
#   Run 2: 2021-08-04 18:25:49.867000 to 2021-08-19 18:40:01.454000 (duration: 15 days 00:14:11.587000)
#   Run 3: 2021-08-20 15:56:13.392000 to 2021-09-01 06:59:58.673000 (duration: 11 days 15:03:45.281000)
#   ✓ HECTO: 3 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 6 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00.087000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:55.695000 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:00:05.208000 is less than 1.0 hours)
#   Run 4: Skipped (duration 0 days 00:00:05.107000 is less than 1.0 hours)
#   Run 5: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 6: Skipped (duration 0 days 00:00:05.078000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 3 observing run(s) for hecto:
#   Run 1: 2021-08-01 07:00:02.881000 to 2021-08-04 11:24:19.477000
#     Duration: 3 days 04:24:16.596000
#     No valid RMS records after filtering
#   Run 2: 2021-08-04 18:25:49.867000 to 2021-08-19 18:40:01.454000
#     Duration: 15 days 00:14:11.587000
#     No valid RMS records after filtering
#   Run 3: 2021-08-20 15:56:13.392000 to 2021-09-01 06:59:58.673000
#     Duration: 11 days 15:03:45.281000
#     Retrieved 72000 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0287" Std=0.0138" Min=0.0114" Max=0.3070"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.1978" Std=0.2147" Min=-0.2598" Max=1.0197"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 35425 points:
#       Mean=0.0303" Std=0.0160" Min=0.0110" Max=0.2568"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 35425 points:
#       Mean=0.3436" Std=0.1124" Min=-0.1863" Max=1.0197"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 5174 points:
#       Mean=0.0280" Std=0.0194" Min=0.0111" Max=0.3166"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 5174 points:
#       Mean=-0.0754" Std=0.0494" Min=-0.2321" Max=1.0058"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 1
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ hecto Run 3: hecto_20210820_155613_to_20210901_065958.json
#
# ✓ Saved statistics for 1 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30858
#   Timestamps: 30858
#   Rolling StdDev: 30858
#   Altitudes: 30858
#   Alt Velocities: 30858
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 35426
#   Timestamps: 35426
#   Rolling StdDev: 35426
#   Altitudes: 35426
#   Alt Velocities: 35426
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 5174
#   Timestamps: 5174
#   Rolling StdDev: 5174
#   Altitudes: 5174
#   Alt Velocities: 5174
# ================================================================================
# Generated 3 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 19:04:36
# End DateTime:   2026-02-12 19:04:49
# Elapsed Time:   0h 0m 12s
# ================================================================================
