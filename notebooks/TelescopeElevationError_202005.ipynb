# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2020-05-01 00:00:00'
end_datetime = '2020-05-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 17:52:47
# Analysis period: 2020-05-01 00:00:00 to 2020-05-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2020-05-01 00:00:00 to 2020-05-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1588316400000, end_timestamp_ms=1590994799000
# Retrieved 2337980 total records from hexapod_mini_instrument
# Found 2 unique instrument(s)
#   NA: 15 records, 2020-05-01 06:02:02.156000 to 2020-05-29 09:47:54.415000
#   BINOSPEC: 2337965 records, 2020-05-01 00:00:00.758000 to 2020-05-31 23:59:56.593000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2020-05-01 00:00:00.758000
#     Last observed:  2020-05-31 23:59:56.593000
#     Duration:       30 days, 23:59:55.835000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-05-01 00:00:00 to 2020-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1588316400000, end_timestamp_ms=1590994799000, instrument=NA
# Retrieved 15 records from hexapod_mini_instrument table
# Processed 15 instrument records
#
# Identified 3 observing runs:
#   Run 1: 2020-05-01 13:02:02.156000 to 2020-05-01 13:02:08.640000 (duration: 0 days 00:00:06.484000)
#   Run 2: 2020-05-28 22:40:50.339000 to 2020-05-28 22:51:36.896000 (duration: 0 days 00:10:46.557000)
#   Run 3: 2020-05-29 16:47:09.128000 to 2020-05-29 16:47:54.415000 (duration: 0 days 00:00:45.287000)
#   ✓ NA: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-05-01 00:00:00 to 2020-05-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1588316400000, end_timestamp_ms=1590994799000, instrument=binospec
# Retrieved 2337965 records from hexapod_mini_instrument table
# Processed 2337965 instrument records
# Identified 1 observing runs:
#   Run 1: 2020-05-01 07:00:00.758000 to 2020-06-01 06:59:56.593000 (duration: 30 days 23:59:55.835000)
#   ✓ BINOSPEC: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 3 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:06.484000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:10:46.557000 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:00:45.287000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2020-05-01 07:00:00.758000 to 2020-06-01 06:59:56.593000
#     Duration: 30 days 23:59:55.835000
#     Retrieved 84000 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0415" Std=0.0350" Min=0.0113" Max=0.6988"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.8723" Std=0.5405" Min=-1.4981" Max=0.8932"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 9354 points:
#       Mean=0.1042" Std=0.0456" Min=0.0236" Max=0.3314"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 9354 points:
#       Mean=0.3638" Std=0.1534" Min=-0.4429" Max=0.8924"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 72006 points:
#       Mean=0.0325" Std=0.0218" Min=0.0113" Max=0.5936"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 72006 points:
#       Mean=-1.0789" Std=0.1948" Min=-1.4981" Max=0.7795"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 1
#   BINOSPEC: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20200501_070000_to_20200601_065956.json
#
# ✓ Saved statistics for 1 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 31500
#   Timestamps: 31500
#   Rolling StdDev: 31500
#   Altitudes: 31500
#   Alt Velocities: 31500
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 9354
#   Timestamps: 9354
#   Rolling StdDev: 9354
#   Altitudes: 9354
#   Alt Velocities: 9354
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30861
#   Timestamps: 30861
#   Rolling StdDev: 30861
#   Altitudes: 30861
#   Alt Velocities: 30861
# ================================================================================
# Generated 3 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 17:52:47
# End DateTime:   2026-02-12 17:53:19
# Elapsed Time:   0h 0m 31s
# ================================================================================
