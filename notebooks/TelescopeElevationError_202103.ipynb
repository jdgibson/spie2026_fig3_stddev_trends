# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2021-03-01 00:00:00'
end_datetime = '2021-03-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 18:32:05
# Analysis period: 2021-03-01 00:00:00 to 2021-03-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2021-03-01 00:00:00 to 2021-03-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1614582000000, end_timestamp_ms=1617260399000
# Retrieved 535321 total records from hexapod_mini_instrument
# Found 6 unique instrument(s)
#   NA: 3 records, 2021-03-16 12:51:05.567000 to 2021-03-16 12:51:10.645000
#   BINOSPEC: 219989 records, 2021-03-12 06:40:22.123000 to 2021-03-31 23:59:58.748000
#   BLUE: 112815 records, 2021-03-05 17:56:17.185000 to 2021-03-12 06:40:17.033000
#   F5: 1604 records, 2021-03-04 10:38:42.579000 to 2021-03-04 12:52:18.573000
#   MMIRS: 179991 records, 2021-03-01 00:00:01.177000 to 2021-03-31 15:56:13.752000
#   RED: 20919 records, 2021-03-04 12:52:23.633000 to 2021-03-05 17:56:12.099000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2021-03-12 06:40:22.123000
#     Last observed:  2021-03-31 23:59:58.748000
#     Duration:       19 days, 17:19:36.625000
#
#   BLUE:
#     First observed: 2021-03-05 17:56:17.185000
#     Last observed:  2021-03-12 06:40:17.033000
#     Duration:       6 days, 12:43:59.848000
#
#   F5:
#     First observed: 2021-03-04 10:38:42.579000
#     Last observed:  2021-03-04 12:52:18.573000
#     Duration:       2:13:35.994000
#
#   MMIRS:
#     First observed: 2021-03-01 00:00:01.177000
#     Last observed:  2021-03-31 15:56:13.752000
#     Duration:       30 days, 15:56:12.575000
#
#   RED:
#     First observed: 2021-03-04 12:52:23.633000
#     Last observed:  2021-03-05 17:56:12.099000
#     Duration:       1 day, 5:03:48.466000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-03-01 00:00:00 to 2021-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1614582000000, end_timestamp_ms=1617260399000, instrument=NA
# Retrieved 3 records from hexapod_mini_instrument table
# Processed 3 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-03-16 19:51:05.567000 to 2021-03-16 19:51:10.645000 (duration: 0 days 00:00:05.078000)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-03-01 00:00:00 to 2021-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1614582000000, end_timestamp_ms=1617260399000, instrument=binospec
# Retrieved 219989 records from hexapod_mini_instrument table
# Processed 219989 instrument records
# Identified 2 observing runs:
#   Run 1: 2021-03-12 13:40:22.123000 to 2021-03-24 23:30:28.617000 (duration: 12 days 09:50:06.494000)
#   Run 2: 2021-03-31 22:56:18.750000 to 2021-04-01 06:59:58.748000 (duration: 0 days 08:03:39.998000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-03-01 00:00:00 to 2021-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1614582000000, end_timestamp_ms=1617260399000, instrument=blue
# Retrieved 112815 records from hexapod_mini_instrument table
# Processed 112815 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-03-06 00:56:17.185000 to 2021-03-12 13:40:17.033000 (duration: 6 days 12:43:59.848000)
#   ✓ BLUE: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-03-01 00:00:00 to 2021-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1614582000000, end_timestamp_ms=1617260399000, instrument=f5
# Retrieved 1604 records from hexapod_mini_instrument table
# Processed 1604 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-03-04 17:38:42.579000 to 2021-03-04 19:52:18.573000 (duration: 0 days 02:13:35.994000)
#   ✓ F5: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-03-01 00:00:00 to 2021-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1614582000000, end_timestamp_ms=1617260399000, instrument=mmirs
# Retrieved 179991 records from hexapod_mini_instrument table
# Processed 179991 instrument records
# Identified 2 observing runs:
#   Run 1: 2021-03-01 07:00:01.177000 to 2021-03-04 17:38:37.522000 (duration: 3 days 10:38:36.345000)
#   Run 2: 2021-03-24 23:30:33.663000 to 2021-03-31 22:56:13.752000 (duration: 6 days 23:25:40.089000)
#   ✓ MMIRS: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-03-01 00:00:00 to 2021-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1614582000000, end_timestamp_ms=1617260399000, instrument=red
# Retrieved 20919 records from hexapod_mini_instrument table
# Processed 20919 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-03-04 19:52:23.633000 to 2021-03-06 00:56:12.099000 (duration: 1 days 05:03:48.466000)
#   ✓ RED: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:05.078000 is less than 1.0 hours)
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2021-03-12 13:40:22.123000 to 2021-03-24 23:30:28.617000
#     Duration: 12 days 09:50:06.494000
#     Filtered 73972 points in 10s intervals with variance >= 2.0" arcsec (retained 98.3%)
#     Retrieved 4249259 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0613" Std=0.0630" Min=0.0000" Max=1.0262"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1731" Std=0.7575" Min=-2.7862" Max=3.1683"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1346750 points:
#       Mean=0.0687" Std=0.0560" Min=0.0000" Max=0.9257"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1346750 points:
#       Mean=0.7495" Std=0.3393" Min=-2.0432" Max=2.6697"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2248766 points:
#       Mean=0.0671" Std=0.0616" Min=0.0000" Max=1.0867"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2248766 points:
#       Mean=-0.7542" Std=0.3477" Min=-2.7862" Max=3.1683"
#   Run 2: 2021-03-31 22:56:18.750000 to 2021-04-01 06:59:58.748000
#     Duration: 0 days 08:03:39.998000
#     Filtered 19023 points in 10s intervals with variance >= 2.0" arcsec (retained 94.1%)
#     Retrieved 323290 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0759" Std=0.0704" Min=0.0000" Max=0.6012"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.2332" Std=0.6313" Min=-1.1533" Max=1.5225"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 194777 points:
#       Mean=0.0791" Std=0.0756" Min=0.0000" Max=0.6057"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 194777 points:
#       Mean=0.5922" Std=0.2606" Min=-0.9447" Max=1.4890"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 67416 points:
#       Mean=0.0562" Std=0.0724" Min=0.0120" Max=0.4956"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 67416 points:
#       Mean=-0.7758" Std=0.3778" Min=-1.1533" Max=1.3828"
#
# Successfully analyzed 2 run(s) for binospec
#
# ======================================================================
# PROCESSING: BLUE
# ======================================================================
# Analyzing 1 observing run(s) for blue:
#   Run 1: 2021-03-06 00:56:17.185000 to 2021-03-12 13:40:17.033000
#     Duration: 6 days 12:43:59.848000
#     Filtered 173936 points in 10s intervals with variance >= 2.0" arcsec (retained 95.3%)
#     Retrieved 3668886 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0951" Std=0.0786" Min=0.0000" Max=1.2939"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2350" Std=0.9420" Min=-2.8100" Max=2.4476"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1198876 points:
#       Mean=0.1165" Std=0.0783" Min=0.0000" Max=1.0881"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1198876 points:
#       Mean=0.8803" Std=0.4252" Min=-1.7238" Max=2.4476"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1910324 points:
#       Mean=0.0938" Std=0.0738" Min=0.0000" Max=1.2957"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1910324 points:
#       Mean=-0.9763" Std=0.3649" Min=-2.8100" Max=2.1557"
#
# Successfully analyzed 1 run(s) for blue
#
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 1 observing run(s) for f5:
#   Run 1: 2021-03-04 17:38:42.579000 to 2021-03-04 19:52:18.573000
#     Duration: 0 days 02:13:35.994000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 2 observing run(s) for mmirs:
#   Run 1: 2021-03-01 07:00:01.177000 to 2021-03-04 17:38:37.522000
#     Duration: 3 days 10:38:36.345000
#     Filtered 119597 points in 10s intervals with variance >= 2.0" arcsec (retained 92.9%)
#     Retrieved 1682087 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0564" Std=0.0581" Min=0.0000" Max=1.0596"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4371" Std=0.8654" Min=-3.1006" Max=2.2357"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 455731 points:
#       Mean=0.0573" Std=0.0467" Min=0.0000" Max=0.6853"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 455731 points:
#       Mean=0.7369" Std=0.3451" Min=-1.6788" Max=2.2357"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 975146 points:
#       Mean=0.0612" Std=0.0602" Min=0.0000" Max=0.9476"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 975146 points:
#       Mean=-1.0494" Std=0.2831" Min=-3.1006" Max=1.2650"
#   Run 2: 2021-03-24 23:30:33.663000 to 2021-03-31 22:56:13.752000
#     Duration: 6 days 23:25:40.089000
#     Filtered 320833 points in 10s intervals with variance >= 2.0" arcsec (retained 88.9%)
#     Retrieved 2903190 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0755" Std=0.0776" Min=0.0000" Max=1.3272"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.6561" Std=0.8288" Min=-2.6080" Max=2.6064"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 416390 points:
#       Mean=0.0760" Std=0.0635" Min=0.0000" Max=1.0263"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 416390 points:
#       Mean=1.0203" Std=0.3601" Min=-1.8442" Max=2.6064"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2027460 points:
#       Mean=0.0807" Std=0.0790" Min=0.0000" Max=0.7397"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2027460 points:
#       Mean=-1.0353" Std=0.3218" Min=-2.6080" Max=1.6267"
#
# Successfully analyzed 2 run(s) for mmirs
#
# ======================================================================
# PROCESSING: RED
# ======================================================================
# Analyzing 1 observing run(s) for red:
#   Run 1: 2021-03-04 19:52:23.633000 to 2021-03-06 00:56:12.099000
#     Duration: 1 days 05:03:48.466000
#     No valid RMS records after filtering
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 3
#   BINOSPEC: 2 run(s)
#   BLUE: 1 run(s)
#   MMIRS: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20210312_134022_to_20210324_233028.json
# ✓ binospec Run 2: binospec_20210331_225618_to_20210401_065958.json
# ✓ blue Run 1: blue_20210306_005617_to_20210312_134017.json
# ✓ mmirs Run 1: mmirs_20210301_070001_to_20210304_173837.json
# ✓ mmirs Run 2: mmirs_20210324_233033_to_20210331_225613.json
#
# ✓ Saved statistics for 5 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30066
#   Timestamps: 30066
#   Rolling StdDev: 30066
#   Altitudes: 30066
#   Alt Velocities: 30066
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30030
#   Timestamps: 30030
#   Rolling StdDev: 30030
#   Altitudes: 30030
#   Alt Velocities: 30030
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30081
#   Timestamps: 30081
#   Rolling StdDev: 30081
#   Altitudes: 30081
#   Alt Velocities: 30081
# Plot data array lengths for BLUE (BOTH (Total)):
#   RMS Errors: 30045
#   Timestamps: 30045
#   Rolling StdDev: 30045
#   Altitudes: 30045
#   Alt Velocities: 30045
# Plot data array lengths for BLUE (UP (Elevation Increasing)):
#   RMS Errors: 30225
#   Timestamps: 30225
#   Rolling StdDev: 30225
#   Altitudes: 30225
#   Alt Velocities: 30225
# Plot data array lengths for BLUE (DOWN (Elevation Decreasing)):
#   RMS Errors: 30006
#   Timestamps: 30006
#   Rolling StdDev: 30006
#   Altitudes: 30006
#   Alt Velocities: 30006
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30036
#   Timestamps: 30036
#   Rolling StdDev: 30036
#   Altitudes: 30036
#   Alt Velocities: 30036
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30075
#   Timestamps: 30075
#   Rolling StdDev: 30075
#   Altitudes: 30075
#   Alt Velocities: 30075
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30027
#   Timestamps: 30027
#   Rolling StdDev: 30027
#   Altitudes: 30027
#   Alt Velocities: 30027
# ================================================================================
# Generated 9 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 18:32:05
# End DateTime:   2026-02-12 18:45:15
# Elapsed Time:   0h 13m 10s
# ================================================================================
