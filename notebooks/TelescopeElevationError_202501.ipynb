# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2025-01-01 00:00:00'
end_datetime = '2025-01-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 22:03:01
# Analysis period: 2025-01-01 00:00:00 to 2025-01-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2025-01-01 00:00:00 to 2025-01-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1735714800000, end_timestamp_ms=1738393199000
# Retrieved 885860 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 2946 records, 2025-01-15 10:08:30.884000 to 2025-01-22 15:52:22.821000
#   BINOSPEC: 399669 records, 2025-01-01 00:00:04.783000 to 2025-01-31 23:59:57.500000
#   MMIRS: 483245 records, 2025-01-07 16:01:38.246000 to 2025-01-22 11:31:39.141000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2025-01-01 00:00:04.783000
#     Last observed:  2025-01-31 23:59:57.500000
#     Duration:       30 days, 23:59:52.717000
#
#   MMIRS:
#     First observed: 2025-01-07 16:01:38.246000
#     Last observed:  2025-01-22 11:31:39.141000
#     Duration:       14 days, 19:30:00.895000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-01-01 00:00:00 to 2025-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1735714800000, end_timestamp_ms=1738393199000, instrument=NA
# Retrieved 2946 records from hexapod_mini_instrument table
# Processed 2946 instrument records
#
# Identified 3 observing runs:
#   Run 1: 2025-01-15 17:08:30.884000 to 2025-01-15 17:08:30.884000 (duration: 0 days 00:00:00)
#   Run 2: 2025-01-22 16:15:16.830000 to 2025-01-22 16:15:16.927000 (duration: 0 days 00:00:00.097000)
#   Run 3: 2025-01-22 18:47:04.247000 to 2025-01-22 22:52:22.821000 (duration: 0 days 04:05:18.574000)
#   ✓ NA: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-01-01 00:00:00 to 2025-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1735714800000, end_timestamp_ms=1738393199000, instrument=binospec
# Retrieved 399669 records from hexapod_mini_instrument table
# Processed 399669 instrument records
# Identified 7 observing runs:
#   Run 1: 2025-01-01 07:00:04.783000 to 2025-01-07 23:01:33.626000 (duration: 6 days 16:01:28.843000)
#   Run 2: 2025-01-21 23:11:53.599000 to 2025-01-22 16:12:19.412000 (duration: 0 days 17:00:25.813000)
#   Run 3: 2025-01-22 18:31:41.444000 to 2025-01-22 18:45:01.968000 (duration: 0 days 00:13:20.524000)
#   Run 4: 2025-01-22 22:52:22.857000 to 2025-01-25 17:36:44.104000 (duration: 2 days 18:44:21.247000)
#   Run 5: 2025-01-29 18:41:20.537000 to 2025-01-30 05:53:42.758000 (duration: 0 days 11:12:22.221000)
#   Run 6: 2025-01-30 15:42:51.337000 to 2025-01-31 13:47:25.391000 (duration: 0 days 22:04:34.054000)
#   Run 7: 2025-02-01 03:45:12.023000 to 2025-02-01 06:59:57.500000 (duration: 0 days 03:14:45.477000)
#   ✓ BINOSPEC: 7 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-01-01 00:00:00 to 2025-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1735714800000, end_timestamp_ms=1738393199000, instrument=mmirs
# Retrieved 483245 records from hexapod_mini_instrument table
# Processed 483245 instrument records
# Identified 2 observing runs:
#   Run 1: 2025-01-07 23:01:38.246000 to 2025-01-21 23:11:50.838000 (duration: 14 days 00:10:12.592000)
#   Run 2: 2025-01-22 16:15:21.161000 to 2025-01-22 18:31:39.141000 (duration: 0 days 02:16:17.980000)
#   ✓ MMIRS: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 3 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:00.097000 is less than 1.0 hours)
#   Run 3: 2025-01-22 18:47:04.247000 to 2025-01-22 22:52:22.821000
#     Duration: 0 days 04:05:18.574000
#     No valid RMS records after filtering
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 7 observing run(s) for binospec:
#   Run 1: 2025-01-01 07:00:04.783000 to 2025-01-07 23:01:33.626000
#     Duration: 6 days 16:01:28.843000
#     Filtered 132644 points in 10s intervals with variance >= 2.0" arcsec (retained 97.0%)
#     Retrieved 4372558 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0797" Std=0.0760" Min=0.0000" Max=1.4106"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.1285" Std=0.8942" Min=-2.2234" Max=2.5304"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2048858 points:
#       Mean=0.0975" Std=0.0799" Min=0.0000" Max=1.1621"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2048858 points:
#       Mean=0.9196" Std=0.3930" Min=-1.4211" Max=2.5304"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1639037 points:
#       Mean=0.0781" Std=0.0671" Min=0.0000" Max=1.3089"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1639037 points:
#       Mean=-0.8107" Std=0.4141" Min=-2.2234" Max=2.1544"
#   Run 2: 2025-01-21 23:11:53.599000 to 2025-01-22 16:12:19.412000
#     Duration: 0 days 17:00:25.813000
#     Filtered 93283 points in 10s intervals with variance >= 2.0" arcsec (retained 89.1%)
#     Retrieved 858939 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.1123" Std=0.0813" Min=0.0000" Max=0.9006"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0762" Std=0.7723" Min=-2.0361" Max=2.7189"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 277504 points:
#       Mean=0.1031" Std=0.0657" Min=0.0000" Max=0.7253"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 277504 points:
#       Mean=0.7884" Std=0.3727" Min=-1.4592" Max=2.7189"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 390099 points:
#       Mean=0.1258" Std=0.0972" Min=0.0000" Max=0.7647"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 390099 points:
#       Mean=-0.6796" Std=0.3659" Min=-2.0361" Max=1.7702"
#   Run 3: Skipped (duration 0 days 00:13:20.524000 is less than 1.0 hours)
#   Run 4: 2025-01-22 22:52:22.857000 to 2025-01-25 17:36:44.104000
#     Duration: 2 days 18:44:21.247000
#     Filtered 103390 points in 10s intervals with variance >= 2.0" arcsec (retained 93.6%)
#     Retrieved 1607239 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0701" Std=0.0705" Min=0.0000" Max=1.2841"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.3444" Std=0.7454" Min=-2.2694" Max=2.3576"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 364087 points:
#       Mean=0.0766" Std=0.0642" Min=0.0000" Max=0.6383"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 364087 points:
#       Mean=0.7999" Std=0.3011" Min=-1.1616" Max=2.3576"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 989616 points:
#       Mean=0.0748" Std=0.0758" Min=0.0000" Max=0.8356"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 989616 points:
#       Mean=-0.7977" Std=0.3253" Min=-2.2694" Max=1.3791"
#   Run 5: 2025-01-29 18:41:20.537000 to 2025-01-30 05:53:42.758000
#     Duration: 0 days 11:12:22.221000
#     No valid RMS records after filtering
#   Run 6: 2025-01-30 15:42:51.337000 to 2025-01-31 13:47:25.391000
#     Duration: 0 days 22:04:34.054000
#     No valid RMS records after filtering
#   Run 7: 2025-02-01 03:45:12.023000 to 2025-02-01 06:59:57.500000
#     Duration: 0 days 03:14:45.477000
#     Filtered 1966 points in 10s intervals with variance >= 2.0" arcsec (retained 99.2%)
#     Retrieved 236117 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0452" Std=0.0342" Min=0.0000" Max=0.6088"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2175" Std=0.3569" Min=-1.4845" Max=0.6690"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 20403 points:
#       Mean=0.0405" Std=0.0301" Min=0.0100" Max=0.2836"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 20403 points:
#       Mean=0.0824" Std=0.0727" Min=-1.2031" Max=0.5996"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 97834 points:
#       Mean=0.0645" Std=0.0426" Min=0.0121" Max=0.6336"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 97834 points:
#       Mean=-0.5182" Std=0.3342" Min=-1.4845" Max=0.6690"
#
# Successfully analyzed 4 run(s) for binospec
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 2 observing run(s) for mmirs:
#   Run 1: 2025-01-07 23:01:38.246000 to 2025-01-21 23:11:50.838000
#     Duration: 14 days 00:10:12.592000
#     Filtered 626035 points in 10s intervals with variance >= 2.0" arcsec (retained 91.9%)
#     Retrieved 7740833 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0652" Std=0.0797" Min=0.0000" Max=1.1714"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0345" Std=0.7922" Min=-2.5221" Max=2.4175"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2862850 points:
#       Mean=0.0696" Std=0.0765" Min=0.0000" Max=0.8725"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2862850 points:
#       Mean=0.7623" Std=0.3649" Min=-1.4667" Max=2.4175"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 3023352 points:
#       Mean=0.0757" Std=0.0810" Min=0.0000" Max=0.9861"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 3023352 points:
#       Mean=-0.8022" Std=0.3718" Min=-2.5221" Max=2.4026"
#   Run 2: 2025-01-22 16:15:21.161000 to 2025-01-22 18:31:39.141000
#     Duration: 0 days 02:16:17.980000
#     No valid RMS records after filtering
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 4 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20250101_070004_to_20250107_230133.json
# ✓ binospec Run 2: binospec_20250121_231153_to_20250122_161219.json
# ✓ binospec Run 4: binospec_20250122_225222_to_20250125_173644.json
# ✓ binospec Run 7: binospec_20250201_034512_to_20250201_065957.json
# ✓ mmirs Run 1: mmirs_20250107_230138_to_20250121_231150.json
#
# ✓ Saved statistics for 5 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30018
#   Timestamps: 30018
#   Rolling StdDev: 30018
#   Altitudes: 30018
#   Alt Velocities: 30018
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30012
#   Timestamps: 30012
#   Rolling StdDev: 30012
#   Altitudes: 30012
#   Alt Velocities: 30012
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30066
#   Timestamps: 30066
#   Rolling StdDev: 30066
#   Altitudes: 30066
#   Alt Velocities: 30066
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30021
#   Timestamps: 30021
#   Rolling StdDev: 30021
#   Altitudes: 30021
#   Alt Velocities: 30021
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30030
#   Timestamps: 30030
#   Rolling StdDev: 30030
#   Altitudes: 30030
#   Alt Velocities: 30030
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30036
#   Timestamps: 30036
#   Rolling StdDev: 30036
#   Altitudes: 30036
#   Alt Velocities: 30036
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 22:03:01
# End DateTime:   2026-02-12 22:23:19
# Elapsed Time:   0h 20m 18s
# ================================================================================
