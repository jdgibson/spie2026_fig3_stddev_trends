# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2022-11-01 00:00:00'
end_datetime = '2022-11-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 20:03:24
# Analysis period: 2022-11-01 00:00:00 to 2022-11-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2022-11-01 00:00:00 to 2022-11-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1667286000000, end_timestamp_ms=1669877999000
# Retrieved 1021909 total records from hexapod_mini_instrument
# Found 6 unique instrument(s)
#   ARIES: 117248 records, 2022-11-01 00:00:02.643000 to 2022-11-04 10:09:05.974000
#   BLUE: 184378 records, 2022-11-16 16:57:00.488000 to 2022-11-22 06:06:32.063000
#   F15: 1636 records, 2022-11-04 10:09:07.749000 to 2022-11-04 11:17:51.923000
#   F5: 26637 records, 2022-11-04 11:17:54.123000 to 2022-11-16 16:37:20.550000
#   F9: 9554 records, 2022-11-08 12:06:44.844000 to 2022-11-29 11:32:20.850000
#   HECTO: 682456 records, 2022-11-04 19:22:28.328000 to 2022-11-30 23:59:58.467000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   ARIES:
#     First observed: 2022-11-01 00:00:02.643000
#     Last observed:  2022-11-04 10:09:05.974000
#     Duration:       3 days, 10:09:03.331000
#
#   BLUE:
#     First observed: 2022-11-16 16:57:00.488000
#     Last observed:  2022-11-22 06:06:32.063000
#     Duration:       5 days, 13:09:31.575000
#
#   F15:
#     First observed: 2022-11-04 10:09:07.749000
#     Last observed:  2022-11-04 11:17:51.923000
#     Duration:       1:08:44.174000
#
#   F5:
#     First observed: 2022-11-04 11:17:54.123000
#     Last observed:  2022-11-16 16:37:20.550000
#     Duration:       12 days, 5:19:26.427000
#
#   F9:
#     First observed: 2022-11-08 12:06:44.844000
#     Last observed:  2022-11-29 11:32:20.850000
#     Duration:       20 days, 23:25:36.006000
#
#   HECTO:
#     First observed: 2022-11-04 19:22:28.328000
#     Last observed:  2022-11-30 23:59:58.467000
#     Duration:       26 days, 4:37:30.139000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-11-01 00:00:00 to 2022-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1667286000000, end_timestamp_ms=1669877999000, instrument=aries
# Retrieved 117248 records from hexapod_mini_instrument table
# Processed 117248 instrument records
# Identified 1 observing runs:
#   Run 1: 2022-11-01 07:00:02.643000 to 2022-11-04 17:09:05.974000 (duration: 3 days 10:09:03.331000)
#   ✓ ARIES: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-11-01 00:00:00 to 2022-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1667286000000, end_timestamp_ms=1669877999000, instrument=blue
# Retrieved 184378 records from hexapod_mini_instrument table
# Processed 184378 instrument records
# Identified 1 observing runs:
#   Run 1: 2022-11-16 23:57:00.488000 to 2022-11-22 13:06:32.063000 (duration: 5 days 13:09:31.575000)
#   ✓ BLUE: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-11-01 00:00:00 to 2022-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1667286000000, end_timestamp_ms=1669877999000, instrument=f15
# Retrieved 1636 records from hexapod_mini_instrument table
# Processed 1636 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2022-11-04 17:09:07.749000 to 2022-11-04 18:17:51.923000 (duration: 0 days 01:08:44.174000)
#   ✓ F15: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-11-01 00:00:00 to 2022-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1667286000000, end_timestamp_ms=1669877999000, instrument=f5
# Retrieved 26637 records from hexapod_mini_instrument table
# Processed 26637 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2022-11-04 18:17:54.123000 to 2022-11-05 02:22:23.678000 (duration: 0 days 08:04:29.555000)
#   Run 2: 2022-11-16 13:02:11.561000 to 2022-11-16 23:37:20.550000 (duration: 0 days 10:35:08.989000)
#   ✓ F5: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-11-01 00:00:00 to 2022-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1667286000000, end_timestamp_ms=1669877999000, instrument=f9
# Retrieved 9554 records from hexapod_mini_instrument table
# Processed 9554 instrument records
#
# Identified 4 observing runs:
#   Run 1: 2022-11-08 19:06:44.844000 to 2022-11-08 19:37:20.639000 (duration: 0 days 00:30:35.795000)
#   Run 2: 2022-11-16 23:37:21.866000 to 2022-11-16 23:56:56.342000 (duration: 0 days 00:19:34.476000)
#   Run 3: 2022-11-22 13:06:36.929000 to 2022-11-22 18:18:56.715000 (duration: 0 days 05:12:19.786000)
#   Run 4: 2022-11-29 17:52:57.481000 to 2022-11-29 18:32:20.850000 (duration: 0 days 00:39:23.369000)
#   ✓ F9: 4 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-11-01 00:00:00 to 2022-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1667286000000, end_timestamp_ms=1669877999000, instrument=hecto
# Retrieved 682456 records from hexapod_mini_instrument table
# Processed 682456 instrument records
# Identified 2 observing runs:
#   Run 1: 2022-11-05 02:22:28.328000 to 2022-11-16 13:02:06.521000 (duration: 11 days 10:39:38.193000)
#   Run 2: 2022-11-22 18:19:00.605000 to 2022-12-01 06:59:58.467000 (duration: 8 days 12:40:57.862000)
#   ✓ HECTO: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: ARIES
# ======================================================================
# Analyzing 1 observing run(s) for aries:
#   Run 1: 2022-11-01 07:00:02.643000 to 2022-11-04 17:09:05.974000
#     Duration: 3 days 10:09:03.331000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: BLUE
# ======================================================================
# Analyzing 1 observing run(s) for blue:
#   Run 1: 2022-11-16 23:57:00.488000 to 2022-11-22 13:06:32.063000
#     Duration: 5 days 13:09:31.575000
#     Filtered 55703 points in 10s intervals with variance >= 2.0" arcsec (retained 98.6%)
#     Retrieved 3997650 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0729" Std=0.0863" Min=0.0000" Max=1.2462"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.5724" Std=0.6987" Min=-2.6648" Max=2.5232"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 694631 points:
#       Mean=0.0812" Std=0.0661" Min=0.0000" Max=1.2239"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 694631 points:
#       Mean=0.5533" Std=0.3479" Min=-1.4233" Max=2.5232"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2757730 points:
#       Mean=0.0854" Std=0.1003" Min=0.0000" Max=1.3228"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2757730 points:
#       Mean=-0.9593" Std=0.3503" Min=-2.6648" Max=2.0743"
#
# Successfully analyzed 1 run(s) for blue
#
# ======================================================================
# PROCESSING: F15
# ======================================================================
# Analyzing 1 observing run(s) for f15:
#   Run 1: 2022-11-04 17:09:07.749000 to 2022-11-04 18:17:51.923000
#     Duration: 0 days 01:08:44.174000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 2 observing run(s) for f5:
#   Run 1: 2022-11-04 18:17:54.123000 to 2022-11-05 02:22:23.678000
#     Duration: 0 days 08:04:29.555000
#     No valid RMS records after filtering
#   Run 2: 2022-11-16 13:02:11.561000 to 2022-11-16 23:37:20.550000
#     Duration: 0 days 10:35:08.989000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: F9
# ======================================================================
# Analyzing 4 observing run(s) for f9:
#   Run 1: Skipped (duration 0 days 00:30:35.795000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:19:34.476000 is less than 1.0 hours)
#   Run 3: 2022-11-22 13:06:36.929000 to 2022-11-22 18:18:56.715000
#     Duration: 0 days 05:12:19.786000
#     No valid RMS records after filtering
#   Run 4: Skipped (duration 0 days 00:39:23.369000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 2 observing run(s) for hecto:
#   Run 1: 2022-11-05 02:22:28.328000 to 2022-11-16 13:02:06.521000
#     Duration: 11 days 10:39:38.193000
#     Filtered 91336 points in 10s intervals with variance >= 2.0" arcsec (retained 98.1%)
#     Retrieved 4859550 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0649" Std=0.0745" Min=0.0000" Max=1.3160"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1596" Std=0.9134" Min=-2.7372" Max=2.0492"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1912325 points:
#       Mean=0.0585" Std=0.0596" Min=0.0000" Max=0.9029"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1912325 points:
#       Mean=0.7885" Std=0.3718" Min=-1.3634" Max=2.0492"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2240803 points:
#       Mean=0.0840" Std=0.0884" Min=0.0000" Max=1.0304"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2240803 points:
#       Mean=-1.0207" Std=0.3458" Min=-2.7372" Max=1.3639"
#   Run 2: 2022-11-22 18:19:00.605000 to 2022-12-01 06:59:58.467000
#     Duration: 8 days 12:40:57.862000
#     Filtered 291321 points in 10s intervals with variance >= 2.0" arcsec (retained 94.0%)
#     Retrieved 4828444 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0703" Std=0.0771" Min=0.0000" Max=1.2785"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.3755" Std=0.8880" Min=-2.5272" Max=2.4480"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2906516 points:
#       Mean=0.0804" Std=0.0978" Min=0.0000" Max=1.1798"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2906516 points:
#       Mean=0.9687" Std=0.3167" Min=-1.8145" Max=2.4480"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1253687 points:
#       Mean=0.0811" Std=0.0685" Min=0.0000" Max=1.3073"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1253687 points:
#       Mean=-0.8941" Std=0.3594" Min=-2.5272" Max=1.8472"
#
# Successfully analyzed 2 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BLUE: 1 run(s)
#   HECTO: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ blue Run 1: blue_20221116_235700_to_20221122_130632.json
# ✓ hecto Run 1: hecto_20221105_022228_to_20221116_130206.json
# ✓ hecto Run 2: hecto_20221122_181900_to_20221201_065958.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BLUE (BOTH (Total)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# Plot data array lengths for BLUE (UP (Elevation Increasing)):
#   RMS Errors: 30204
#   Timestamps: 30204
#   Rolling StdDev: 30204
#   Altitudes: 30204
#   Alt Velocities: 30204
# Plot data array lengths for BLUE (DOWN (Elevation Decreasing)):
#   RMS Errors: 30087
#   Timestamps: 30087
#   Rolling StdDev: 30087
#   Altitudes: 30087
#   Alt Velocities: 30087
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30018
#   Timestamps: 30018
#   Rolling StdDev: 30018
#   Altitudes: 30018
#   Alt Velocities: 30018
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30057
#   Timestamps: 30057
#   Rolling StdDev: 30057
#   Altitudes: 30057
#   Alt Velocities: 30057
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30039
#   Timestamps: 30039
#   Rolling StdDev: 30039
#   Altitudes: 30039
#   Alt Velocities: 30039
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 20:03:24
# End DateTime:   2026-02-12 20:26:41
# Elapsed Time:   0h 23m 17s
# ================================================================================
