# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2022-12-01 00:00:00'
end_datetime = '2022-12-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 20:06:49
# Analysis period: 2022-12-01 00:00:00 to 2022-12-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2022-12-01 00:00:00 to 2022-12-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1669878000000, end_timestamp_ms=1672556399000
# Retrieved 1062110 total records from hexapod_mini_instrument
# Found 8 unique instrument(s)
#   NA: 1 records, 2022-12-31 02:51:30.725000 to 2022-12-31 02:51:30.725000
#   ARIES: 13896 records, 2022-12-05 14:58:27.082000 to 2022-12-06 00:42:24.626000
#   BINOSPEC: 589993 records, 2022-12-13 15:39:34.734000 to 2022-12-30 20:57:19.291000
#   F15: 5635 records, 2022-12-09 04:54:53.855000 to 2022-12-09 08:51:54.336000
#   F9: 4860 records, 2022-12-09 08:51:57.558000 to 2022-12-09 12:16:08.042000
#   HECTO: 237222 records, 2022-12-01 00:00:03.472000 to 2022-12-31 23:59:57.898000
#   MMIRS: 101687 records, 2022-12-02 15:44:37.016000 to 2022-12-05 14:58:25.766000
#   PISCES-LGS: 108816 records, 2022-12-06 00:42:25.183000 to 2022-12-09 04:55:24.929000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   ARIES:
#     First observed: 2022-12-05 14:58:27.082000
#     Last observed:  2022-12-06 00:42:24.626000
#     Duration:       9:43:57.544000
#
#   BINOSPEC:
#     First observed: 2022-12-13 15:39:34.734000
#     Last observed:  2022-12-30 20:57:19.291000
#     Duration:       17 days, 5:17:44.557000
#
#   F15:
#     First observed: 2022-12-09 04:54:53.855000
#     Last observed:  2022-12-09 08:51:54.336000
#     Duration:       3:57:00.481000
#
#   F9:
#     First observed: 2022-12-09 08:51:57.558000
#     Last observed:  2022-12-09 12:16:08.042000
#     Duration:       3:24:10.484000
#
#   HECTO:
#     First observed: 2022-12-01 00:00:03.472000
#     Last observed:  2022-12-31 23:59:57.898000
#     Duration:       30 days, 23:59:54.426000
#
#   MMIRS:
#     First observed: 2022-12-02 15:44:37.016000
#     Last observed:  2022-12-05 14:58:25.766000
#     Duration:       2 days, 23:13:48.750000
#
#   PISCES-LGS:
#     First observed: 2022-12-06 00:42:25.183000
#     Last observed:  2022-12-09 04:55:24.929000
#     Duration:       3 days, 4:12:59.746000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-12-01 00:00:00 to 2022-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1669878000000, end_timestamp_ms=1672556399000, instrument=NA
# Retrieved 1 records from hexapod_mini_instrument table
# Processed 1 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2022-12-31 09:51:30.725000 to 2022-12-31 09:51:30.725000 (duration: 0 days 00:00:00)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-12-01 00:00:00 to 2022-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1669878000000, end_timestamp_ms=1672556399000, instrument=aries
# Retrieved 13896 records from hexapod_mini_instrument table
# Processed 13896 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2022-12-05 21:58:27.082000 to 2022-12-06 07:42:24.626000 (duration: 0 days 09:43:57.544000)
#   ✓ ARIES: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-12-01 00:00:00 to 2022-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1669878000000, end_timestamp_ms=1672556399000, instrument=binospec
# Retrieved 589993 records from hexapod_mini_instrument table
# Processed 589993 instrument records
# Identified 1 observing runs:
#   Run 1: 2022-12-13 22:39:34.734000 to 2022-12-31 03:57:19.291000 (duration: 17 days 05:17:44.557000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-12-01 00:00:00 to 2022-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1669878000000, end_timestamp_ms=1672556399000, instrument=f15
# Retrieved 5635 records from hexapod_mini_instrument table
# Processed 5635 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2022-12-09 11:54:53.855000 to 2022-12-09 15:51:54.336000 (duration: 0 days 03:57:00.481000)
#   ✓ F15: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-12-01 00:00:00 to 2022-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1669878000000, end_timestamp_ms=1672556399000, instrument=f9
# Retrieved 4860 records from hexapod_mini_instrument table
# Processed 4860 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2022-12-09 15:51:57.558000 to 2022-12-09 19:16:08.042000 (duration: 0 days 03:24:10.484000)
#   ✓ F9: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-12-01 00:00:00 to 2022-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1669878000000, end_timestamp_ms=1672556399000, instrument=hecto
# Retrieved 237222 records from hexapod_mini_instrument table
# Processed 237222 instrument records
# Identified 3 observing runs:
#   Run 1: 2022-12-01 07:00:03.472000 to 2022-12-02 22:44:32.806000 (duration: 1 days 15:44:29.334000)
#   Run 2: 2022-12-09 19:16:12.701000 to 2022-12-13 22:39:33.234000 (duration: 4 days 03:23:20.533000)
#   Run 3: 2022-12-31 03:57:20.953000 to 2023-01-01 06:59:57.898000 (duration: 1 days 03:02:36.945000)
#   ✓ HECTO: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-12-01 00:00:00 to 2022-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1669878000000, end_timestamp_ms=1672556399000, instrument=mmirs
# Retrieved 101687 records from hexapod_mini_instrument table
# Processed 101687 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2022-12-02 22:44:37.016000 to 2022-12-05 21:58:25.766000 (duration: 2 days 23:13:48.750000)
#   ✓ MMIRS: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-12-01 00:00:00 to 2022-12-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1669878000000, end_timestamp_ms=1672556399000, instrument=pisces-lgs
# Retrieved 108816 records from hexapod_mini_instrument table
# Processed 108816 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2022-12-06 07:42:25.183000 to 2022-12-09 11:55:24.929000 (duration: 3 days 04:12:59.746000)
#   ✓ PISCES-LGS: 1 observing runs
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: ARIES
# ======================================================================
# Analyzing 1 observing run(s) for aries:
#   Run 1: 2022-12-05 21:58:27.082000 to 2022-12-06 07:42:24.626000
#     Duration: 0 days 09:43:57.544000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2022-12-13 22:39:34.734000 to 2022-12-31 03:57:19.291000
#     Duration: 17 days 05:17:44.557000
#     Filtered 297332 points in 10s intervals with variance >= 2.0" arcsec (retained 96.2%)
#     Retrieved 7898618 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0706" Std=0.0938" Min=0.0000" Max=1.4820"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0881" Std=0.9032" Min=-2.1979" Max=2.5435"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 3209278 points:
#       Mean=0.0755" Std=0.0908" Min=0.0000" Max=1.6526"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 3209278 points:
#       Mean=0.8328" Std=0.3772" Min=-1.6826" Max=2.5435"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 3628679 points:
#       Mean=0.0821" Std=0.1007" Min=0.0000" Max=1.1995"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 3628679 points:
#       Mean=-0.9261" Std=0.3275" Min=-2.1979" Max=2.0610"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: F15
# ======================================================================
# Analyzing 1 observing run(s) for f15:
#   Run 1: 2022-12-09 11:54:53.855000 to 2022-12-09 15:51:54.336000
#     Duration: 0 days 03:57:00.481000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: F9
# ======================================================================
# Analyzing 1 observing run(s) for f9:
#   Run 1: 2022-12-09 15:51:57.558000 to 2022-12-09 19:16:08.042000
#     Duration: 0 days 03:24:10.484000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 3 observing run(s) for hecto:
#   Run 1: 2022-12-01 07:00:03.472000 to 2022-12-02 22:44:32.806000
#     Duration: 1 days 15:44:29.334000
#     Filtered 29263 points in 10s intervals with variance >= 2.0" arcsec (retained 94.6%)
#     Retrieved 539350 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0682" Std=0.0599" Min=0.0000" Max=1.2380"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.4328" Std=1.0182" Min=-2.2051" Max=2.0463"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 331136 points:
#       Mean=0.0780" Std=0.0624" Min=0.0000" Max=0.7491"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 331136 points:
#       Mean=1.1389" Std=0.2316" Min=-1.1458" Max=2.0463"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 157365 points:
#       Mean=0.0487" Std=0.0441" Min=0.0000" Max=0.5213"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 157365 points:
#       Mean=-0.9649" Std=0.4240" Min=-2.2051" Max=1.4358"
#   Run 2: 2022-12-09 19:16:12.701000 to 2022-12-13 22:39:33.234000
#     Duration: 4 days 03:23:20.533000
#     Filtered 41180 points in 10s intervals with variance >= 2.0" arcsec (retained 97.3%)
#     Retrieved 1535904 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0539" Std=0.0511" Min=0.0000" Max=1.2055"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.4089" Std=0.8793" Min=-2.4794" Max=2.3460"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 990297 points:
#       Mean=0.0547" Std=0.0528" Min=0.0000" Max=0.7674"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 990297 points:
#       Mean=0.9701" Std=0.3414" Min=-1.1955" Max=2.3460"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 409250 points:
#       Mean=0.0553" Std=0.0406" Min=0.0000" Max=0.9287"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 409250 points:
#       Mean=-0.8669" Std=0.3125" Min=-2.4794" Max=1.2730"
#   Run 3: 2022-12-31 03:57:20.953000 to 2023-01-01 06:59:57.898000
#     Duration: 1 days 03:02:36.945000
#     Filtered 10310 points in 10s intervals with variance >= 2.0" arcsec (retained 98.0%)
#     Retrieved 527007 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0592" Std=0.0492" Min=0.0000" Max=1.1986"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0232" Std=1.0522" Min=-1.8331" Max=1.5452"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 242225 points:
#       Mean=0.0298" Std=0.0216" Min=0.0000" Max=0.6616"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 242225 points:
#       Mean=1.0705" Std=0.3107" Min=-0.9499" Max=1.5452"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 242759 points:
#       Mean=0.0936" Std=0.0475" Min=0.0000" Max=0.6538"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 242759 points:
#       Mean=-1.0189" Std=0.2673" Min=-1.8331" Max=1.3776"
#
# Successfully analyzed 3 run(s) for hecto
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2022-12-02 22:44:37.016000 to 2022-12-05 21:58:25.766000
#     Duration: 2 days 23:13:48.750000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: PISCES-LGS
# ======================================================================
# Analyzing 1 observing run(s) for pisces-lgs:
#   Run 1: 2022-12-06 07:42:25.183000 to 2022-12-09 11:55:24.929000
#     Duration: 3 days 04:12:59.746000
#     No valid RMS records after filtering
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 3 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20221213_223934_to_20221231_035719.json
# ✓ hecto Run 1: hecto_20221201_070003_to_20221202_224432.json
# ✓ hecto Run 2: hecto_20221209_191612_to_20221213_223933.json
# ✓ hecto Run 3: hecto_20221231_035720_to_20230101_065957.json
#
# ✓ Saved statistics for 4 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30006
#   Timestamps: 30006
#   Rolling StdDev: 30006
#   Altitudes: 30006
#   Alt Velocities: 30006
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30087
#   Timestamps: 30087
#   Rolling StdDev: 30087
#   Altitudes: 30087
#   Alt Velocities: 30087
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30072
#   Timestamps: 30072
#   Rolling StdDev: 30072
#   Altitudes: 30072
#   Alt Velocities: 30072
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30018
#   Timestamps: 30018
#   Rolling StdDev: 30018
#   Altitudes: 30018
#   Alt Velocities: 30018
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30072
#   Timestamps: 30072
#   Rolling StdDev: 30072
#   Altitudes: 30072
#   Alt Velocities: 30072
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30354
#   Timestamps: 30354
#   Rolling StdDev: 30354
#   Altitudes: 30354
#   Alt Velocities: 30354
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 20:06:49
# End DateTime:   2026-02-12 20:27:57
# Elapsed Time:   0h 21m 7s
# ================================================================================
