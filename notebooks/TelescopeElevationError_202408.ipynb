# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2024-08-01 00:00:00'
end_datetime = '2024-08-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 21:42:06
# Analysis period: 2024-08-01 00:00:00 to 2024-08-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2024-08-01 00:00:00 to 2024-08-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1722495600000, end_timestamp_ms=1725173999000
# Retrieved 1060895 total records from hexapod_mini_instrument
# Found 5 unique instrument(s)
#   BINOSPEC: 856931 records, 2024-08-01 00:00:00.483000 to 2024-08-31 23:59:57.838000
#   BLUE: 1568 records, 2024-08-01 15:05:18.607000 to 2024-08-05 14:47:15.717000
#   F15: 239 records, 2024-08-19 09:41:13.049000 to 2024-08-19 10:05:47.410000
#   F5: 380 records, 2024-08-01 15:51:19.828000 to 2024-08-19 10:02:44.457000
#   MIRAC: 201777 records, 2024-08-13 12:18:04.366000 to 2024-08-19 09:41:09.692000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2024-08-01 00:00:00.483000
#     Last observed:  2024-08-31 23:59:57.838000
#     Duration:       30 days, 23:59:57.355000
#
#   BLUE:
#     First observed: 2024-08-01 15:05:18.607000
#     Last observed:  2024-08-05 14:47:15.717000
#     Duration:       3 days, 23:41:57.110000
#
#   F15:
#     First observed: 2024-08-19 09:41:13.049000
#     Last observed:  2024-08-19 10:05:47.410000
#     Duration:       0:24:34.361000
#
#   F5:
#     First observed: 2024-08-01 15:51:19.828000
#     Last observed:  2024-08-19 10:02:44.457000
#     Duration:       17 days, 18:11:24.629000
#
#   MIRAC:
#     First observed: 2024-08-13 12:18:04.366000
#     Last observed:  2024-08-19 09:41:09.692000
#     Duration:       5 days, 21:23:05.326000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-08-01 00:00:00 to 2024-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1722495600000, end_timestamp_ms=1725173999000, instrument=binospec
# Retrieved 856931 records from hexapod_mini_instrument table
# Processed 856931 instrument records
# Identified 2 observing runs:
#   Run 1: 2024-08-01 07:00:00.483000 to 2024-08-13 19:16:39.619000 (duration: 12 days 12:16:39.136000)
#   Run 2: 2024-08-19 17:05:52.360000 to 2024-09-01 06:59:57.838000 (duration: 12 days 13:54:05.478000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-08-01 00:00:00 to 2024-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1722495600000, end_timestamp_ms=1725173999000, instrument=blue
# Retrieved 1568 records from hexapod_mini_instrument table
# Processed 1568 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2024-08-01 22:05:18.607000 to 2024-08-01 22:51:15.486000 (duration: 0 days 00:45:56.879000)
#   Run 2: 2024-08-05 21:27:24.998000 to 2024-08-05 21:47:15.717000 (duration: 0 days 00:19:50.719000)
#   ✓ BLUE: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-08-01 00:00:00 to 2024-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1722495600000, end_timestamp_ms=1725173999000, instrument=f15
# Retrieved 239 records from hexapod_mini_instrument table
# Processed 239 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2024-08-19 16:41:13.049000 to 2024-08-19 17:05:47.410000 (duration: 0 days 00:24:34.361000)
#   ✓ F15: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-08-01 00:00:00 to 2024-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1722495600000, end_timestamp_ms=1725173999000, instrument=f5
# Retrieved 380 records from hexapod_mini_instrument table
# Processed 380 instrument records
#
# Identified 3 observing runs:
#   Run 1: 2024-08-01 22:51:19.828000 to 2024-08-01 22:51:20.572000 (duration: 0 days 00:00:00.744000)
#   Run 2: 2024-08-13 19:16:42.993000 to 2024-08-13 19:17:59.615000 (duration: 0 days 00:01:16.622000)
#   Run 3: 2024-08-19 16:48:14.981000 to 2024-08-19 17:02:44.457000 (duration: 0 days 00:14:29.476000)
#   ✓ F5: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-08-01 00:00:00 to 2024-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1722495600000, end_timestamp_ms=1725173999000, instrument=mirac
# Retrieved 201777 records from hexapod_mini_instrument table
# Processed 201777 instrument records
# Identified 1 observing runs:
#   Run 1: 2024-08-13 19:18:04.366000 to 2024-08-19 16:41:09.692000 (duration: 5 days 21:23:05.326000)
#   ✓ MIRAC: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2024-08-01 07:00:00.483000 to 2024-08-13 19:16:39.619000
#     Duration: 12 days 12:16:39.136000
#     Filtered 16395 points in 10s intervals with variance >= 2.0" arcsec (retained 95.6%)
#     Retrieved 370157 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.1161" Std=0.0667" Min=0.0000" Max=1.0799"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.5191" Std=0.6485" Min=-2.3027" Max=1.7459"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 56122 points:
#       Mean=0.1685" Std=0.0791" Min=0.0226" Max=0.7762"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 56122 points:
#       Mean=0.3689" Std=0.3083" Min=-1.4380" Max=1.7459"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 223411 points:
#       Mean=0.1163" Std=0.0648" Min=0.0000" Max=0.9676"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 223411 points:
#       Mean=-0.9107" Std=0.4122" Min=-2.3027" Max=1.5110"
#   Run 2: 2024-08-19 17:05:52.360000 to 2024-09-01 06:59:57.838000
#     Duration: 12 days 13:54:05.478000
#     Filtered 65444 points in 10s intervals with variance >= 2.0" arcsec (retained 95.8%)
#     Retrieved 1565899 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.1235" Std=0.0792" Min=0.0000" Max=1.1902"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1448" Std=0.8590" Min=-2.4430" Max=2.1979"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 608289 points:
#       Mean=0.1254" Std=0.0676" Min=0.0000" Max=1.2111"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 608289 points:
#       Mean=0.6765" Std=0.5217" Min=-2.0462" Max=2.1979"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 697090 points:
#       Mean=0.1363" Std=0.0755" Min=0.0000" Max=0.9093"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 697090 points:
#       Mean=-0.8863" Std=0.3885" Min=-2.4430" Max=1.5197"
#
# Successfully analyzed 2 run(s) for binospec
#
# ======================================================================
# PROCESSING: BLUE
# ======================================================================
# Analyzing 2 observing run(s) for blue:
#   Run 1: Skipped (duration 0 days 00:45:56.879000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:19:50.719000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: F15
# ======================================================================
# Analyzing 1 observing run(s) for f15:
#   Run 1: Skipped (duration 0 days 00:24:34.361000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 3 observing run(s) for f5:
#   Run 1: Skipped (duration 0 days 00:00:00.744000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:01:16.622000 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:14:29.476000 is less than 1.0 hours)
# ======================================================================
# PROCESSING: MIRAC
# ======================================================================
# Analyzing 1 observing run(s) for mirac:
#   Run 1: 2024-08-13 19:18:04.366000 to 2024-08-19 16:41:09.692000
#     Duration: 5 days 21:23:05.326000
#     No valid RMS records after filtering
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 1
#   BINOSPEC: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20240801_070000_to_20240813_191639.json
# ✓ binospec Run 2: binospec_20240819_170552_to_20240901_065957.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30069
#   Timestamps: 30069
#   Rolling StdDev: 30069
#   Altitudes: 30069
#   Alt Velocities: 30069
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30201
#   Timestamps: 30201
#   Rolling StdDev: 30201
#   Altitudes: 30201
#   Alt Velocities: 30201
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30018
#   Timestamps: 30018
#   Rolling StdDev: 30018
#   Altitudes: 30018
#   Alt Velocities: 30018
# ================================================================================
# Generated 3 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 21:42:06
# End DateTime:   2026-02-12 21:44:31
# Elapsed Time:   0h 2m 25s
# ================================================================================
