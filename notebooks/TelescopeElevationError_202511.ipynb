# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2025-11-01 00:00:00'
end_datetime = '2025-11-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 22:41:18
# Analysis period: 2025-11-01 00:00:00 to 2025-11-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2025-11-01 00:00:00 to 2025-11-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1761980400000, end_timestamp_ms=1764572399000
# Retrieved 1022413 total records from hexapod_mini_instrument
# Found 2 unique instrument(s)
#   BINOSPEC: 801418 records, 2025-11-07 11:40:37.972000 to 2025-11-30 23:59:57.268000
#   MMIRS: 220995 records, 2025-11-01 00:00:01.082000 to 2025-11-07 11:40:33.219000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2025-11-07 11:40:37.972000
#     Last observed:  2025-11-30 23:59:57.268000
#     Duration:       23 days, 12:19:19.296000
#
#   MMIRS:
#     First observed: 2025-11-01 00:00:01.082000
#     Last observed:  2025-11-07 11:40:33.219000
#     Duration:       6 days, 11:40:32.137000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-11-01 00:00:00 to 2025-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1761980400000, end_timestamp_ms=1764572399000, instrument=binospec
# Retrieved 801418 records from hexapod_mini_instrument table
# Processed 801418 instrument records
# Identified 1 observing runs:
#   Run 1: 2025-11-07 18:40:37.972000 to 2025-12-01 06:59:57.268000 (duration: 23 days 12:19:19.296000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2025-11-01 00:00:00 to 2025-11-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1761980400000, end_timestamp_ms=1764572399000, instrument=mmirs
# Retrieved 220995 records from hexapod_mini_instrument table
# Processed 220995 instrument records
# Identified 1 observing runs:
#   Run 1: 2025-11-01 07:00:01.082000 to 2025-11-07 18:40:33.219000 (duration: 6 days 11:40:32.137000)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2025-11-07 18:40:37.972000 to 2025-12-01 06:59:57.268000
#     Duration: 23 days 12:19:19.296000
#     Filtered 219703 points in 10s intervals with variance >= 2.0" arcsec (retained 98.2%)
#     Retrieved 12348093 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0836" Std=0.1413" Min=0.0000" Max=1.3219"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2549" Std=0.9122" Min=-2.5856" Max=2.9170"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 4403309 points:
#       Mean=0.0659" Std=0.0966" Min=0.0000" Max=1.3976"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 4403309 points:
#       Mean=0.7855" Std=0.4302" Min=-2.1638" Max=2.9170"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 6527389 points:
#       Mean=0.1301" Std=0.1774" Min=0.0000" Max=1.2873"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 6527389 points:
#       Mean=-0.9964" Std=0.3262" Min=-2.5856" Max=1.5648"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2025-11-01 07:00:01.082000 to 2025-11-07 18:40:33.219000
#     Duration: 6 days 11:40:32.137000
#     Filtered 213696 points in 10s intervals with variance >= 2.0" arcsec (retained 94.6%)
#     Retrieved 3975489 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0664" Std=0.0553" Min=0.0000" Max=1.2049"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.2675" Std=0.6870" Min=-2.7663" Max=2.1197"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1040964 points:
#       Mean=0.0714" Std=0.0508" Min=0.0000" Max=0.8092"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1040964 points:
#       Mean=0.6062" Std=0.3409" Min=-1.4607" Max=2.1197"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2120668 points:
#       Mean=0.0746" Std=0.0561" Min=0.0000" Max=0.9360"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2120668 points:
#       Mean=-0.7692" Std=0.3310" Min=-2.7663" Max=1.6859"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20251107_184037_to_20251201_065957.json
# ✓ mmirs Run 1: mmirs_20251101_070001_to_20251107_184033.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30021
#   Timestamps: 30021
#   Rolling StdDev: 30021
#   Altitudes: 30021
#   Alt Velocities: 30021
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30024
#   Timestamps: 30024
#   Rolling StdDev: 30024
#   Altitudes: 30024
#   Alt Velocities: 30024
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30036
#   Timestamps: 30036
#   Rolling StdDev: 30036
#   Altitudes: 30036
#   Alt Velocities: 30036
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30030
#   Timestamps: 30030
#   Rolling StdDev: 30030
#   Altitudes: 30030
#   Alt Velocities: 30030
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30012
#   Timestamps: 30012
#   Rolling StdDev: 30012
#   Altitudes: 30012
#   Alt Velocities: 30012
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 22:41:18
# End DateTime:   2026-02-12 23:15:47
# Elapsed Time:   0h 34m 28s
# ================================================================================
