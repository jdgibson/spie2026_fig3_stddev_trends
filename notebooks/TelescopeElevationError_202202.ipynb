# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2022-02-01 00:00:00'
end_datetime = '2022-02-28 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 19:35:36
# Analysis period: 2022-02-01 00:00:00 to 2022-02-28 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2022-02-01 00:00:00 to 2022-02-28 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1643698800000, end_timestamp_ms=1646117999000
# Retrieved 483671 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 20 records, 2022-02-22 13:50:55.670000 to 2022-02-23 09:23:07.872000
#   BINOSPEC: 148860 records, 2022-02-01 00:00:01.501000 to 2022-02-09 14:50:55.910000
#   HECTO: 334791 records, 2022-02-09 14:51:00.966000 to 2022-02-28 23:59:58.511000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2022-02-01 00:00:01.501000
#     Last observed:  2022-02-09 14:50:55.910000
#     Duration:       8 days, 14:50:54.409000
#
#   HECTO:
#     First observed: 2022-02-09 14:51:00.966000
#     Last observed:  2022-02-28 23:59:58.511000
#     Duration:       19 days, 9:08:57.545000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-02-01 00:00:00 to 2022-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1643698800000, end_timestamp_ms=1646117999000, instrument=NA
# Retrieved 20 records from hexapod_mini_instrument table
# Processed 20 instrument records
#
# Identified 3 observing runs:
#   Run 1: 2022-02-22 20:50:55.670000 to 2022-02-22 21:30:31.672000 (duration: 0 days 00:39:36.002000)
#   Run 2: 2022-02-22 22:43:30.906000 to 2022-02-22 22:52:03.413000 (duration: 0 days 00:08:32.507000)
#   Run 3: 2022-02-23 16:23:07.872000 to 2022-02-23 16:23:07.872000 (duration: 0 days 00:00:00)
#   ✓ NA: 3 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-02-01 00:00:00 to 2022-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1643698800000, end_timestamp_ms=1646117999000, instrument=binospec
# Retrieved 148860 records from hexapod_mini_instrument table
# Processed 148860 instrument records
# Identified 1 observing runs:
#   Run 1: 2022-02-01 07:00:01.501000 to 2022-02-09 21:50:55.910000 (duration: 8 days 14:50:54.409000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2022-02-01 00:00:00 to 2022-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1643698800000, end_timestamp_ms=1646117999000, instrument=hecto
# Retrieved 334791 records from hexapod_mini_instrument table
# Processed 334791 instrument records
# Identified 1 observing runs:
#   Run 1: 2022-02-09 21:51:00.966000 to 2022-03-01 06:59:58.511000 (duration: 19 days 09:08:57.545000)
#   ✓ HECTO: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 3 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:39:36.002000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:08:32.507000 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2022-02-01 07:00:01.501000 to 2022-02-09 21:50:55.910000
#     Duration: 8 days 14:50:54.409000
#     Filtered 50431 points in 10s intervals with variance >= 2.0" arcsec (retained 97.1%)
#     Retrieved 1744302 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0475" Std=0.0503" Min=0.0000" Max=1.2899"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4741" Std=1.0209" Min=-2.2259" Max=2.4618"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 425803 points:
#       Mean=0.0527" Std=0.0625" Min=0.0000" Max=0.8089"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 425803 points:
#       Mean=1.2166" Std=0.1434" Min=-1.7253" Max=2.4618"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1227248 points:
#       Mean=0.0478" Std=0.0484" Min=0.0000" Max=1.0164"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1227248 points:
#       Mean=-1.0681" Std=0.2809" Min=-2.2259" Max=1.7487"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2022-02-09 21:51:00.966000 to 2022-03-01 06:59:58.511000
#     Duration: 19 days 09:08:57.545000
#     Filtered 83773 points in 10s intervals with variance >= 2.0" arcsec (retained 98.8%)
#     Retrieved 7040629 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0567" Std=0.0793" Min=0.0000" Max=1.1589"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.1749" Std=0.7758" Min=-2.0724" Max=2.2985"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 3687676 points:
#       Mean=0.0649" Std=0.0851" Min=0.0000" Max=0.9154"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 3687676 points:
#       Mean=0.7853" Std=0.3527" Min=-1.4396" Max=2.2985"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2243293 points:
#       Mean=0.0501" Std=0.0569" Min=0.0000" Max=1.0941"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2243293 points:
#       Mean=-0.7587" Std=0.3576" Min=-2.0724" Max=1.6682"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20220201_070001_to_20220209_215055.json
# ✓ hecto Run 1: hecto_20220209_215100_to_20220301_065958.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30069
#   Timestamps: 30069
#   Rolling StdDev: 30069
#   Altitudes: 30069
#   Alt Velocities: 30069
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30417
#   Timestamps: 30417
#   Rolling StdDev: 30417
#   Altitudes: 30417
#   Alt Velocities: 30417
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30180
#   Timestamps: 30180
#   Rolling StdDev: 30180
#   Altitudes: 30180
#   Alt Velocities: 30180
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30030
#   Timestamps: 30030
#   Rolling StdDev: 30030
#   Altitudes: 30030
#   Alt Velocities: 30030
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30063
#   Timestamps: 30063
#   Rolling StdDev: 30063
#   Altitudes: 30063
#   Alt Velocities: 30063
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30045
#   Timestamps: 30045
#   Rolling StdDev: 30045
#   Altitudes: 30045
#   Alt Velocities: 30045
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 19:35:36
# End DateTime:   2026-02-12 20:01:27
# Elapsed Time:   0h 25m 51s
# ================================================================================
