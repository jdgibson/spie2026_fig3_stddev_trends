# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2020-03-01 00:00:00'
end_datetime = '2020-03-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 17:47:47
# Analysis period: 2020-03-01 00:00:00 to 2020-03-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2020-03-01 00:00:00 to 2020-03-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1583046000000, end_timestamp_ms=1585724399000
# Retrieved 2543057 total records from hexapod_mini_instrument
# Found 4 unique instrument(s)
#   NA: 52 records, 2020-03-26 05:54:57.840000 to 2020-03-26 15:08:30.617000
#   BINOSPEC: 1490082 records, 2020-03-13 15:23:28.623000 to 2020-03-31 23:59:58.148000
#   BLUE: 307480 records, 2020-03-01 00:00:01.039000 to 2020-03-04 15:35:12.378000
#   MMIRS: 745443 records, 2020-03-04 15:35:13.466000 to 2020-03-13 15:23:27.631000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2020-03-13 15:23:28.623000
#     Last observed:  2020-03-31 23:59:58.148000
#     Duration:       18 days, 8:36:29.525000
#
#   BLUE:
#     First observed: 2020-03-01 00:00:01.039000
#     Last observed:  2020-03-04 15:35:12.378000
#     Duration:       3 days, 15:35:11.339000
#
#   MMIRS:
#     First observed: 2020-03-04 15:35:13.466000
#     Last observed:  2020-03-13 15:23:27.631000
#     Duration:       8 days, 23:48:14.165000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-03-01 00:00:00 to 2020-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1583046000000, end_timestamp_ms=1585724399000, instrument=NA
# Retrieved 52 records from hexapod_mini_instrument table
# Processed 52 instrument records
#
# Identified 2 observing runs:
#   Run 1: 2020-03-26 12:54:57.840000 to 2020-03-26 12:55:08.911000 (duration: 0 days 00:00:11.071000)
#   Run 2: 2020-03-26 21:52:47.638000 to 2020-03-26 22:08:30.617000 (duration: 0 days 00:15:42.979000)
#   ✓ NA: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-03-01 00:00:00 to 2020-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1583046000000, end_timestamp_ms=1585724399000, instrument=binospec
# Retrieved 1490082 records from hexapod_mini_instrument table
# Processed 1490082 instrument records
# Identified 2 observing runs:
#   Run 1: 2020-03-13 22:23:28.623000 to 2020-03-26 14:50:03.480000 (duration: 12 days 16:26:34.857000)
#   Run 2: 2020-03-26 21:53:11.709000 to 2020-04-01 06:59:58.148000 (duration: 5 days 09:06:46.439000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-03-01 00:00:00 to 2020-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1583046000000, end_timestamp_ms=1585724399000, instrument=blue
# Retrieved 307480 records from hexapod_mini_instrument table
# Processed 307480 instrument records
# Identified 1 observing runs:
#   Run 1: 2020-03-01 07:00:01.039000 to 2020-03-04 22:35:12.378000 (duration: 3 days 15:35:11.339000)
#   ✓ BLUE: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-03-01 00:00:00 to 2020-03-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1583046000000, end_timestamp_ms=1585724399000, instrument=mmirs
# Retrieved 745443 records from hexapod_mini_instrument table
# Processed 745443 instrument records
# Identified 1 observing runs:
#   Run 1: 2020-03-04 22:35:13.466000 to 2020-03-13 22:23:27.631000 (duration: 8 days 23:48:14.165000)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 2 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:11.071000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:15:42.979000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2020-03-13 22:23:28.623000 to 2020-03-26 14:50:03.480000
#     Duration: 12 days 16:26:34.857000
#     Filtered 13833 points in 10s intervals with variance >= 2.0" arcsec (retained 99.1%)
#     Retrieved 1544932 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0526" Std=0.0488" Min=0.0000" Max=1.2306"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0109" Std=0.7382" Min=-2.0273" Max=1.7459"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 669344 points:
#       Mean=0.0624" Std=0.0529" Min=0.0000" Max=0.7024"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 669344 points:
#       Mean=0.7298" Std=0.3248" Min=-1.6256" Max=1.7459"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 679561 points:
#       Mean=0.0476" Std=0.0423" Min=0.0000" Max=0.8630"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 679561 points:
#       Mean=-0.6984" Std=0.2884" Min=-2.0273" Max=1.1691"
#   Run 2: 2020-03-26 21:53:11.709000 to 2020-04-01 06:59:58.148000
#     Duration: 5 days 09:06:46.439000
#     No valid RMS records after filtering
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: BLUE
# ======================================================================
# Analyzing 1 observing run(s) for blue:
#   Run 1: 2020-03-01 07:00:01.039000 to 2020-03-04 22:35:12.378000
#     Duration: 3 days 15:35:11.339000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2020-03-04 22:35:13.466000 to 2020-03-13 22:23:27.631000
#     Duration: 8 days 23:48:14.165000
#     Filtered 174241 points in 10s intervals with variance >= 2.0" arcsec (retained 94.0%)
#     Retrieved 2928100 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0452" Std=0.0468" Min=0.0000" Max=1.2255"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.2713" Std=0.7210" Min=-2.5325" Max=2.6978"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1623038 points:
#       Mean=0.0519" Std=0.0491" Min=0.0000" Max=0.7867"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1623038 points:
#       Mean=0.7577" Std=0.3519" Min=-1.2661" Max=2.6978"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 680161 points:
#       Mean=0.0466" Std=0.0375" Min=0.0000" Max=0.8539"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 680161 points:
#       Mean=-0.7301" Std=0.3999" Min=-2.5325" Max=1.4325"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20200313_222328_to_20200326_145003.json
# ✓ mmirs Run 1: mmirs_20200304_223513_to_20200313_222327.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30024
#   Timestamps: 30024
#   Rolling StdDev: 30024
#   Altitudes: 30024
#   Alt Velocities: 30024
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30426
#   Timestamps: 30426
#   Rolling StdDev: 30426
#   Altitudes: 30426
#   Alt Velocities: 30426
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30429
#   Timestamps: 30429
#   Rolling StdDev: 30429
#   Altitudes: 30429
#   Alt Velocities: 30429
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30045
#   Timestamps: 30045
#   Rolling StdDev: 30045
#   Altitudes: 30045
#   Alt Velocities: 30045
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30057
#   Timestamps: 30057
#   Rolling StdDev: 30057
#   Altitudes: 30057
#   Alt Velocities: 30057
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30009
#   Timestamps: 30009
#   Rolling StdDev: 30009
#   Altitudes: 30009
#   Alt Velocities: 30009
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 17:47:47
# End DateTime:   2026-02-12 17:52:13
# Elapsed Time:   0h 4m 26s
# ================================================================================
