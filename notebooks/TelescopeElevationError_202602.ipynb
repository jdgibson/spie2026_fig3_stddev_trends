# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2026-02-01 00:00:00'
end_datetime = '2026-02-28 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 22:56:38
# Analysis period: 2026-02-01 00:00:00 to 2026-02-28 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2026-02-01 00:00:00 to 2026-02-28 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1769929200000, end_timestamp_ms=1772348399000
# Retrieved 407295 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   BINOSPEC: 47162 records, 2026-02-11 13:43:20.735000 to 2026-02-12 22:56:16.293000
#   HECTO: 237663 records, 2026-02-04 14:17:59.433000 to 2026-02-11 13:43:15.672000
#   MMIRS: 122470 records, 2026-02-01 00:00:00.955000 to 2026-02-04 14:17:55.327000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2026-02-11 13:43:20.735000
#     Last observed:  2026-02-12 22:56:16.293000
#     Duration:       1 day, 9:12:55.558000
#
#   HECTO:
#     First observed: 2026-02-04 14:17:59.433000
#     Last observed:  2026-02-11 13:43:15.672000
#     Duration:       6 days, 23:25:16.239000
#
#   MMIRS:
#     First observed: 2026-02-01 00:00:00.955000
#     Last observed:  2026-02-04 14:17:55.327000
#     Duration:       3 days, 14:17:54.372000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2026-02-01 00:00:00 to 2026-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1769929200000, end_timestamp_ms=1772348399000, instrument=binospec
# Retrieved 47162 records from hexapod_mini_instrument table
# Processed 47162 instrument records
# Identified 1 observing runs:
#   Run 1: 2026-02-11 20:43:20.735000 to 2026-02-13 05:56:16.293000 (duration: 1 days 09:12:55.558000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2026-02-01 00:00:00 to 2026-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1769929200000, end_timestamp_ms=1772348399000, instrument=hecto
# Retrieved 237663 records from hexapod_mini_instrument table
# Processed 237663 instrument records
# Identified 1 observing runs:
#   Run 1: 2026-02-04 21:17:59.433000 to 2026-02-11 20:43:15.672000 (duration: 6 days 23:25:16.239000)
#   ✓ HECTO: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2026-02-01 00:00:00 to 2026-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1769929200000, end_timestamp_ms=1772348399000, instrument=mmirs
# Retrieved 122470 records from hexapod_mini_instrument table
# Processed 122470 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2026-02-01 07:00:00.955000 to 2026-02-04 21:17:55.327000 (duration: 3 days 14:17:54.372000)
#   ✓ MMIRS: 1 observing runs
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2026-02-11 20:43:20.735000 to 2026-02-13 05:56:16.293000
#     Duration: 1 days 09:12:55.558000
#     Filtered 3970 points in 10s intervals with variance >= 2.0" arcsec (retained 98.3%)
#     Retrieved 239970 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0724" Std=0.0437" Min=0.0000" Max=0.5957"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.8638" Std=0.3562" Min=-1.7238" Max=0.5714"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 72 points:
#       Mean=0.2150" Std=0.0836" Min=0.0770" Max=0.4340"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 72 points:
#       Mean=-0.5267" Std=0.3265" Min=-1.3595" Max=0.1616"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 224939 points:
#       Mean=0.0732" Std=0.0452" Min=0.0000" Max=0.5948"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 224939 points:
#       Mean=-0.8864" Std=0.3467" Min=-1.7238" Max=0.5714"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2026-02-04 21:17:59.433000 to 2026-02-11 20:43:15.672000
#     Duration: 6 days 23:25:16.239000
#     Filtered 20949 points in 10s intervals with variance >= 2.0" arcsec (retained 99.3%)
#     Retrieved 2842822 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0656" Std=0.0630" Min=0.0000" Max=1.1312"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.5738" Std=0.7459" Min=-1.8311" Max=2.1619"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2139689 points:
#       Mean=0.0718" Std=0.0673" Min=0.0000" Max=0.8167"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2139689 points:
#       Mean=0.9559" Std=0.2489" Min=-1.1815" Max=2.1619"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 542094 points:
#       Mean=0.0638" Std=0.0529" Min=0.0000" Max=0.7804"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 542094 points:
#       Mean=-0.7827" Std=0.3484" Min=-1.8311" Max=1.7111"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2026-02-01 07:00:00.955000 to 2026-02-04 21:17:55.327000
#     Duration: 3 days 14:17:54.372000
#     Filtered 103226 points in 10s intervals with variance >= 2.0" arcsec (retained 92.0%)
#     Retrieved 1292327 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0568" Std=0.0448" Min=0.0000" Max=1.2035"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.5396" Std=0.9037" Min=-2.4210" Max=2.1350"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 267860 points:
#       Mean=0.0618" Std=0.0411" Min=0.0000" Max=1.1154"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 267860 points:
#       Mean=1.0118" Std=0.3184" Min=-1.3139" Max=2.1350"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 877975 points:
#       Mean=0.0564" Std=0.0430" Min=0.0000" Max=0.7322"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 877975 points:
#       Mean=-1.0308" Std=0.2979" Min=-2.4210" Max=1.2743"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 3
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20260211_204320_to_20260213_055616.json
# ✓ hecto Run 1: hecto_20260204_211759_to_20260211_204315.json
# ✓ mmirs Run 1: mmirs_20260201_070000_to_20260204_211755.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30783
#   Timestamps: 30783
#   Rolling StdDev: 30783
#   Altitudes: 30783
#   Alt Velocities: 30783
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 72
#   Timestamps: 72
#   Rolling StdDev: 72
#   Altitudes: 72
#   Alt Velocities: 72
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30675
#   Timestamps: 30675
#   Rolling StdDev: 30675
#   Altitudes: 30675
#   Alt Velocities: 30675
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30021
#   Timestamps: 30021
#   Rolling StdDev: 30021
#   Altitudes: 30021
#   Alt Velocities: 30021
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30138
#   Timestamps: 30138
#   Rolling StdDev: 30138
#   Altitudes: 30138
#   Alt Velocities: 30138
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30117
#   Timestamps: 30117
#   Rolling StdDev: 30117
#   Altitudes: 30117
#   Alt Velocities: 30117
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30234
#   Timestamps: 30234
#   Rolling StdDev: 30234
#   Altitudes: 30234
#   Alt Velocities: 30234
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30909
#   Timestamps: 30909
#   Rolling StdDev: 30909
#   Altitudes: 30909
#   Alt Velocities: 30909
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30276
#   Timestamps: 30276
#   Rolling StdDev: 30276
#   Altitudes: 30276
#   Alt Velocities: 30276
# ================================================================================
# Generated 9 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 22:56:38
# End DateTime:   2026-02-12 22:59:53
# Elapsed Time:   0h 3m 14s
# ================================================================================
