# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2021-10-01 00:00:00'
end_datetime = '2021-10-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 19:04:51
# Analysis period: 2021-10-01 00:00:00 to 2021-10-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2021-10-01 00:00:00 to 2021-10-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1633071600000, end_timestamp_ms=1635749999000
# Retrieved 535354 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 1 records, 2021-10-28 21:15:15.967000 to 2021-10-28 21:15:15.967000
#   BINOSPEC: 156276 records, 2021-10-05 16:23:24.822000 to 2021-10-14 17:27:59.329000
#   HECTO: 379077 records, 2021-10-01 00:00:02.775000 to 2021-10-31 23:59:54.183000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2021-10-05 16:23:24.822000
#     Last observed:  2021-10-14 17:27:59.329000
#     Duration:       9 days, 1:04:34.507000
#
#   HECTO:
#     First observed: 2021-10-01 00:00:02.775000
#     Last observed:  2021-10-31 23:59:54.183000
#     Duration:       30 days, 23:59:51.408000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-10-01 00:00:00 to 2021-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1633071600000, end_timestamp_ms=1635749999000, instrument=NA
# Retrieved 1 records from hexapod_mini_instrument table
# Processed 1 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-10-29 04:15:15.967000 to 2021-10-29 04:15:15.967000 (duration: 0 days 00:00:00)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-10-01 00:00:00 to 2021-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1633071600000, end_timestamp_ms=1635749999000, instrument=binospec
# Retrieved 156276 records from hexapod_mini_instrument table
# Processed 156276 instrument records
# Identified 1 observing runs:
#   Run 1: 2021-10-05 23:23:24.822000 to 2021-10-15 00:27:59.329000 (duration: 9 days 01:04:34.507000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-10-01 00:00:00 to 2021-10-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1633071600000, end_timestamp_ms=1635749999000, instrument=hecto
# Retrieved 379077 records from hexapod_mini_instrument table
# Processed 379077 instrument records
# Identified 2 observing runs:
#   Run 1: 2021-10-01 07:00:02.775000 to 2021-10-05 23:23:19.721000 (duration: 4 days 16:23:16.946000)
#   Run 2: 2021-10-15 00:28:04.372000 to 2021-11-01 06:59:54.183000 (duration: 17 days 06:31:49.811000)
#   ✓ HECTO: 2 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2021-10-05 23:23:24.822000 to 2021-10-15 00:27:59.329000
#     Duration: 9 days 01:04:34.507000
#     Filtered 84888 points in 10s intervals with variance >= 2.0" arcsec (retained 98.1%)
#     Retrieved 4532743 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0816" Std=0.0751" Min=0.0000" Max=1.2953"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0025" Std=0.8996" Min=-2.5956" Max=2.6122"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1991863 points:
#       Mean=0.0772" Std=0.0785" Min=0.0000" Max=1.3335"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1991863 points:
#       Mean=0.8410" Std=0.3815" Min=-2.2776" Max=2.6122"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1924690 points:
#       Mean=0.0998" Std=0.0734" Min=0.0000" Max=1.2900"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1924690 points:
#       Mean=-0.8584" Std=0.4080" Min=-2.5956" Max=2.0734"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 2 observing run(s) for hecto:
#   Run 1: 2021-10-01 07:00:02.775000 to 2021-10-05 23:23:19.721000
#     Duration: 4 days 16:23:16.946000
#     Filtered 12861 points in 10s intervals with variance >= 2.0" arcsec (retained 98.6%)
#     Retrieved 945972 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0739" Std=0.0450" Min=0.0000" Max=1.1974"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1782" Std=0.7941" Min=-1.8888" Max=2.3681"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 280728 points:
#       Mean=0.1083" Std=0.0504" Min=0.0000" Max=0.8894"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 280728 points:
#       Mean=0.7815" Std=0.4337" Min=-1.3233" Max=2.3681"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 535064 points:
#       Mean=0.0632" Std=0.0394" Min=0.0000" Max=1.0563"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 535064 points:
#       Mean=-0.7011" Std=0.4115" Min=-1.8888" Max=1.5603"
#   Run 2: 2021-10-15 00:28:04.372000 to 2021-11-01 06:59:54.183000
#     Duration: 17 days 06:31:49.811000
#     Filtered 294118 points in 10s intervals with variance >= 2.0" arcsec (retained 96.5%)
#     Retrieved 8317240 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0800" Std=0.1061" Min=0.0000" Max=1.6328"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.2526" Std=0.9466" Min=-2.4728" Max=2.7310"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 4698077 points:
#       Mean=0.0925" Std=0.1177" Min=0.0000" Max=1.2915"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 4698077 points:
#       Mean=0.9419" Std=0.3738" Min=-2.1340" Max=2.7310"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2553596 points:
#       Mean=0.0905" Std=0.1005" Min=0.0000" Max=1.3764"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2553596 points:
#       Mean=-0.9597" Std=0.4009" Min=-2.4728" Max=2.1394"
#
# Successfully analyzed 2 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 2 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20211005_232324_to_20211015_002759.json
# ✓ hecto Run 1: hecto_20211001_070002_to_20211005_232319.json
# ✓ hecto Run 2: hecto_20211015_002804_to_20211101_065954.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30054
#   Timestamps: 30054
#   Rolling StdDev: 30054
#   Altitudes: 30054
#   Alt Velocities: 30054
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30030
#   Timestamps: 30030
#   Rolling StdDev: 30030
#   Altitudes: 30030
#   Alt Velocities: 30030
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30075
#   Timestamps: 30075
#   Rolling StdDev: 30075
#   Altitudes: 30075
#   Alt Velocities: 30075
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30021
#   Timestamps: 30021
#   Rolling StdDev: 30021
#   Altitudes: 30021
#   Alt Velocities: 30021
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30054
#   Timestamps: 30054
#   Rolling StdDev: 30054
#   Altitudes: 30054
#   Alt Velocities: 30054
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30087
#   Timestamps: 30087
#   Rolling StdDev: 30087
#   Altitudes: 30087
#   Alt Velocities: 30087
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 19:04:51
# End DateTime:   2026-02-12 19:35:54
# Elapsed Time:   0h 31m 2s
# ================================================================================
