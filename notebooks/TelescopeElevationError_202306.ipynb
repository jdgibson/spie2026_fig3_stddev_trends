# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2023-06-01 00:00:00'
end_datetime = '2023-06-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 20:44:11
# Analysis period: 2023-06-01 00:00:00 to 2023-06-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2023-06-01 00:00:00 to 2023-06-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1685602800000, end_timestamp_ms=1688194799000
# Retrieved 518217 total records from hexapod_mini_instrument
# Found 5 unique instrument(s)
#   BINOSPEC: 348878 records, 2023-06-06 11:50:58.967000 to 2023-06-26 16:34:48.907000
#   F15: 5081 records, 2023-06-06 04:42:54.467000 to 2023-06-06 11:46:38.538000
#   F5: 51 records, 2023-06-06 11:46:43.589000 to 2023-06-06 11:50:53.880000
#   HECTO: 74443 records, 2023-06-26 16:34:53.962000 to 2023-06-30 23:59:58.240000
#   PISCES-LGS: 89764 records, 2023-06-01 00:00:00.978000 to 2023-06-06 04:44:09.264000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2023-06-06 11:50:58.967000
#     Last observed:  2023-06-26 16:34:48.907000
#     Duration:       20 days, 4:43:49.940000
#
#   F15:
#     First observed: 2023-06-06 04:42:54.467000
#     Last observed:  2023-06-06 11:46:38.538000
#     Duration:       7:03:44.071000
#
#   F5:
#     First observed: 2023-06-06 11:46:43.589000
#     Last observed:  2023-06-06 11:50:53.880000
#     Duration:       0:04:10.291000
#
#   HECTO:
#     First observed: 2023-06-26 16:34:53.962000
#     Last observed:  2023-06-30 23:59:58.240000
#     Duration:       4 days, 7:25:04.278000
#
#   PISCES-LGS:
#     First observed: 2023-06-01 00:00:00.978000
#     Last observed:  2023-06-06 04:44:09.264000
#     Duration:       5 days, 4:44:08.286000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-06-01 00:00:00 to 2023-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1685602800000, end_timestamp_ms=1688194799000, instrument=binospec
# Retrieved 348878 records from hexapod_mini_instrument table
# Processed 348878 instrument records
# Identified 1 observing runs:
#   Run 1: 2023-06-06 18:50:58.967000 to 2023-06-26 23:34:48.907000 (duration: 20 days 04:43:49.940000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-06-01 00:00:00 to 2023-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1685602800000, end_timestamp_ms=1688194799000, instrument=f15
# Retrieved 5081 records from hexapod_mini_instrument table
# Processed 5081 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-06-06 11:42:54.467000 to 2023-06-06 18:46:38.538000 (duration: 0 days 07:03:44.071000)
#   ✓ F15: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-06-01 00:00:00 to 2023-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1685602800000, end_timestamp_ms=1688194799000, instrument=f5
# Retrieved 51 records from hexapod_mini_instrument table
# Processed 51 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-06-06 18:46:43.589000 to 2023-06-06 18:50:53.880000 (duration: 0 days 00:04:10.291000)
#   ✓ F5: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-06-01 00:00:00 to 2023-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1685602800000, end_timestamp_ms=1688194799000, instrument=hecto
# Retrieved 74443 records from hexapod_mini_instrument table
# Processed 74443 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-06-26 23:34:53.962000 to 2023-07-01 06:59:58.240000 (duration: 4 days 07:25:04.278000)
#   ✓ HECTO: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-06-01 00:00:00 to 2023-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1685602800000, end_timestamp_ms=1688194799000, instrument=pisces-lgs
# Retrieved 89764 records from hexapod_mini_instrument table
# Processed 89764 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2023-06-01 07:00:00.978000 to 2023-06-06 11:44:09.264000 (duration: 5 days 04:44:08.286000)
#   ✓ PISCES-LGS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2023-06-06 18:50:58.967000 to 2023-06-26 23:34:48.907000
#     Duration: 20 days 04:43:49.940000
#     Filtered 341309 points in 10s intervals with variance >= 2.0" arcsec (retained 96.7%)
#     Retrieved 10245135 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0783" Std=0.1093" Min=0.0000" Max=1.3089"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.3071" Std=0.8819" Min=-2.4480" Max=2.5252"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 2835716 points:
#       Mean=0.0711" Std=0.0898" Min=0.0000" Max=1.2911"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 2835716 points:
#       Mean=0.8806" Std=0.3991" Min=-2.0566" Max=2.5252"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 5886975 points:
#       Mean=0.1062" Std=0.1377" Min=0.0000" Max=1.1247"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 5886975 points:
#       Mean=-0.9334" Std=0.3603" Min=-2.4480" Max=1.8907"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: F15
# ======================================================================
# Analyzing 1 observing run(s) for f15:
#   Run 1: 2023-06-06 11:42:54.467000 to 2023-06-06 18:46:38.538000
#     Duration: 0 days 07:03:44.071000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: F5
# ======================================================================
# Analyzing 1 observing run(s) for f5:
#   Run 1: Skipped (duration 0 days 00:04:10.291000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2023-06-26 23:34:53.962000 to 2023-07-01 06:59:58.240000
#     Duration: 4 days 07:25:04.278000
#     Filtered 32759 points in 10s intervals with variance >= 2.0" arcsec (retained 97.3%)
#     Retrieved 1235078 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0409" Std=0.0376" Min=0.0000" Max=1.2082"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0853" Std=0.8873" Min=-2.4001" Max=2.7137"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 627882 points:
#       Mean=0.0366" Std=0.0337" Min=0.0000" Max=0.7347"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 627882 points:
#       Mean=0.8124" Std=0.3816" Min=-1.1815" Max=2.7137"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 451035 points:
#       Mean=0.0526" Std=0.0386" Min=0.0000" Max=0.6729"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 451035 points:
#       Mean=-0.9547" Std=0.2490" Min=-2.4001" Max=1.1997"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# PROCESSING: PISCES-LGS
# ======================================================================
# Analyzing 1 observing run(s) for pisces-lgs:
#   Run 1: 2023-06-01 07:00:00.978000 to 2023-06-06 11:44:09.264000
#     Duration: 5 days 04:44:08.286000
#     No valid RMS records after filtering
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20230606_185058_to_20230626_233448.json
# ✓ hecto Run 1: hecto_20230626_233453_to_20230701_065958.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30012
#   Timestamps: 30012
#   Rolling StdDev: 30012
#   Altitudes: 30012
#   Alt Velocities: 30012
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30063
#   Timestamps: 30063
#   Rolling StdDev: 30063
#   Altitudes: 30063
#   Alt Velocities: 30063
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30036
#   Timestamps: 30036
#   Rolling StdDev: 30036
#   Altitudes: 30036
#   Alt Velocities: 30036
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30060
#   Timestamps: 30060
#   Rolling StdDev: 30060
#   Altitudes: 30060
#   Alt Velocities: 30060
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30384
#   Timestamps: 30384
#   Rolling StdDev: 30384
#   Altitudes: 30384
#   Alt Velocities: 30384
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30069
#   Timestamps: 30069
#   Rolling StdDev: 30069
#   Altitudes: 30069
#   Alt Velocities: 30069
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 20:44:11
# End DateTime:   2026-02-12 21:16:52
# Elapsed Time:   0h 32m 41s
# ================================================================================
