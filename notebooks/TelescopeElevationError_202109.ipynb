# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2021-09-01 00:00:00'
end_datetime = '2021-09-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 19:04:40
# Analysis period: 2021-09-01 00:00:00 to 2021-09-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2021-09-01 00:00:00 to 2021-09-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1630479600000, end_timestamp_ms=1633071599000
# Retrieved 518283 total records from hexapod_mini_instrument
# Found 4 unique instrument(s)
#   NA: 1 records, 2021-09-02 16:17:08.735000 to 2021-09-02 16:17:08.735000
#   BINOSPEC: 223923 records, 2021-09-02 16:21:13.530000 to 2021-09-15 15:26:39.424000
#   HECTO: 207884 records, 2021-09-01 00:00:03.765000 to 2021-09-30 23:59:57.702000
#   MMIRS: 86475 records, 2021-09-15 15:26:44.471000 to 2021-09-20 15:33:32.792000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2021-09-02 16:21:13.530000
#     Last observed:  2021-09-15 15:26:39.424000
#     Duration:       12 days, 23:05:25.894000
#
#   HECTO:
#     First observed: 2021-09-01 00:00:03.765000
#     Last observed:  2021-09-30 23:59:57.702000
#     Duration:       29 days, 23:59:53.937000
#
#   MMIRS:
#     First observed: 2021-09-15 15:26:44.471000
#     Last observed:  2021-09-20 15:33:32.792000
#     Duration:       5 days, 0:06:48.321000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-09-01 00:00:00 to 2021-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1630479600000, end_timestamp_ms=1633071599000, instrument=NA
# Retrieved 1 records from hexapod_mini_instrument table
# Processed 1 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-09-02 23:17:08.735000 to 2021-09-02 23:17:08.735000 (duration: 0 days 00:00:00)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-09-01 00:00:00 to 2021-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1630479600000, end_timestamp_ms=1633071599000, instrument=binospec
# Retrieved 223923 records from hexapod_mini_instrument table
# Processed 223923 instrument records
# Identified 1 observing runs:
#   Run 1: 2021-09-02 23:21:13.530000 to 2021-09-15 22:26:39.424000 (duration: 12 days 23:05:25.894000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-09-01 00:00:00 to 2021-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1630479600000, end_timestamp_ms=1633071599000, instrument=hecto
# Retrieved 207884 records from hexapod_mini_instrument table
# Processed 207884 instrument records
# Identified 2 observing runs:
#   Run 1: 2021-09-01 07:00:03.765000 to 2021-09-02 23:21:08.445000 (duration: 1 days 16:21:04.680000)
#   Run 2: 2021-09-20 22:33:37.792000 to 2021-10-01 06:59:57.702000 (duration: 10 days 08:26:19.910000)
#   ✓ HECTO: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2021-09-01 00:00:00 to 2021-09-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1630479600000, end_timestamp_ms=1633071599000, instrument=mmirs
# Retrieved 86475 records from hexapod_mini_instrument table
# Processed 86475 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2021-09-15 22:26:44.471000 to 2021-09-20 22:33:32.792000 (duration: 5 days 00:06:48.321000)
#   ✓ MMIRS: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2021-09-02 23:21:13.530000 to 2021-09-15 22:26:39.424000
#     Duration: 12 days 23:05:25.894000
#     Filtered 114287 points in 10s intervals with variance >= 2.0" arcsec (retained 97.8%)
#     Retrieved 5230272 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0672" Std=0.0738" Min=0.0000" Max=1.3714"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.1348" Std=0.8247" Min=-2.7624" Max=2.7152"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1823451 points:
#       Mean=0.0696" Std=0.0739" Min=0.0000" Max=1.3366"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1823451 points:
#       Mean=0.7664" Std=0.4851" Min=-1.8832" Max=2.7152"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 2503320 points:
#       Mean=0.0659" Std=0.0612" Min=0.0000" Max=1.0326"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 2503320 points:
#       Mean=-0.7856" Std=0.3715" Min=-2.7624" Max=1.6227"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 2 observing run(s) for hecto:
#   Run 1: 2021-09-01 07:00:03.765000 to 2021-09-02 23:21:08.445000
#     Duration: 1 days 16:21:04.680000
#     No valid RMS records after filtering
#   Run 2: 2021-09-20 22:33:37.792000 to 2021-10-01 06:59:57.702000
#     Duration: 10 days 08:26:19.910000
#     Filtered 59210 points in 10s intervals with variance >= 2.0" arcsec (retained 96.1%)
#     Retrieved 1528269 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0561" Std=0.0539" Min=0.0000" Max=1.0570"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.0178" Std=0.6993" Min=-2.2455" Max=2.6240"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 615869 points:
#       Mean=0.0663" Std=0.0626" Min=0.0000" Max=0.7283"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 615869 points:
#       Mean=0.6790" Std=0.3836" Min=-1.5059" Max=2.6240"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 598034 points:
#       Mean=0.0569" Std=0.0537" Min=0.0000" Max=0.7395"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 598034 points:
#       Mean=-0.6542" Std=0.3251" Min=-2.2455" Max=1.3349"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# PROCESSING: MMIRS
# ======================================================================
# Analyzing 1 observing run(s) for mmirs:
#   Run 1: 2021-09-15 22:26:44.471000 to 2021-09-20 22:33:32.792000
#     Duration: 5 days 00:06:48.321000
#     Filtered 158322 points in 10s intervals with variance >= 2.0" arcsec (retained 89.1%)
#     Retrieved 1454192 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0553" Std=0.0561" Min=0.0000" Max=1.2149"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.0013" Std=0.9147" Min=-2.4162" Max=2.7706"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 579260 points:
#       Mean=0.0456" Std=0.0439" Min=0.0000" Max=0.9550"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 579260 points:
#       Mean=0.8290" Std=0.4913" Min=-2.1544" Max=2.7706"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 527032 points:
#       Mean=0.0722" Std=0.0572" Min=0.0000" Max=0.9851"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 527032 points:
#       Mean=-0.8772" Std=0.4387" Min=-2.4162" Max=1.3728"
#
# Successfully analyzed 1 run(s) for mmirs
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 3
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
#   MMIRS: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20210902_232113_to_20210915_222639.json
# ✓ hecto Run 2: hecto_20210920_223337_to_20211001_065957.json
# ✓ mmirs Run 1: mmirs_20210915_222644_to_20210920_223332.json
#
# ✓ Saved statistics for 3 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30036
#   Timestamps: 30036
#   Rolling StdDev: 30036
#   Altitudes: 30036
#   Alt Velocities: 30036
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30057
#   Timestamps: 30057
#   Rolling StdDev: 30057
#   Altitudes: 30057
#   Alt Velocities: 30057
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30042
#   Timestamps: 30042
#   Rolling StdDev: 30042
#   Altitudes: 30042
#   Alt Velocities: 30042
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30189
#   Timestamps: 30189
#   Rolling StdDev: 30189
#   Altitudes: 30189
#   Alt Velocities: 30189
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30291
#   Timestamps: 30291
#   Rolling StdDev: 30291
#   Altitudes: 30291
#   Alt Velocities: 30291
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30411
#   Timestamps: 30411
#   Rolling StdDev: 30411
#   Altitudes: 30411
#   Alt Velocities: 30411
# Plot data array lengths for MMIRS (BOTH (Total)):
#   RMS Errors: 30138
#   Timestamps: 30138
#   Rolling StdDev: 30138
#   Altitudes: 30138
#   Alt Velocities: 30138
# Plot data array lengths for MMIRS (UP (Elevation Increasing)):
#   RMS Errors: 30489
#   Timestamps: 30489
#   Rolling StdDev: 30489
#   Altitudes: 30489
#   Alt Velocities: 30489
# Plot data array lengths for MMIRS (DOWN (Elevation Decreasing)):
#   RMS Errors: 30408
#   Timestamps: 30408
#   Rolling StdDev: 30408
#   Altitudes: 30408
#   Alt Velocities: 30408
# ================================================================================
# Generated 9 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 19:04:40
# End DateTime:   2026-02-12 19:17:09
# Elapsed Time:   0h 12m 29s
# ================================================================================
