# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2019-01-27 00:00:00'
end_datetime = '2019-01-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 22:57:21
# Analysis period: 2019-01-27 00:00:00 to 2019-01-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2019-01-27 00:00:00 to 2019-01-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1548572400000, end_timestamp_ms=1549004399000
# Retrieved 7200 total records from hexapod_mini_instrument
# Found 2 unique instrument(s)
#   BINOSPEC: 460 records, 2019-01-31 16:21:18 to 2019-01-31 23:59:18
#   HECTO: 6740 records, 2019-01-27 00:00:59 to 2019-01-31 16:20:18
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2019-01-31 16:21:18
#     Last observed:  2019-01-31 23:59:18
#     Duration:       7:38:00
#
#   HECTO:
#     First observed: 2019-01-27 00:00:59
#     Last observed:  2019-01-31 16:20:18
#     Duration:       4 days, 16:19:19
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-01-27 00:00:00 to 2019-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1548572400000, end_timestamp_ms=1549004399000, instrument=binospec
# Retrieved 460 records from hexapod_mini_instrument table
# Processed 460 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2019-01-31 23:21:18 to 2019-02-01 06:59:18 (duration: 0 days 07:38:00)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2019-01-27 00:00:00 to 2019-01-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1548572400000, end_timestamp_ms=1549004399000, instrument=hecto
# Retrieved 6740 records from hexapod_mini_instrument table
# Processed 6740 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2019-01-27 07:00:59 to 2019-01-31 23:20:18 (duration: 4 days 16:19:19)
#   ✓ HECTO: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2019-01-31 23:21:18 to 2019-02-01 06:59:18
#     Duration: 0 days 07:38:00
#     Filtered 4809 points in 10s intervals with variance >= 2.0" arcsec (retained 97.1%)
#     Retrieved 167790 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.1096" Std=0.0549" Min=0.0099" Max=1.0034"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4775" Std=0.5644" Min=-2.0219" Max=1.3170"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 15756 points:
#       Mean=0.1018" Std=0.0731" Min=0.0202" Max=0.8369"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 15756 points:
#       Mean=0.6486" Std=0.4523" Min=-1.5382" Max=1.3170"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 110374 points:
#       Mean=0.1261" Std=0.0600" Min=0.0189" Max=0.5934"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 110374 points:
#       Mean=-0.7437" Std=0.3611" Min=-2.0219" Max=0.8563"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2019-01-27 07:00:59 to 2019-01-31 23:20:18
#     Duration: 4 days 16:19:19
#     Filtered 15575 points in 10s intervals with variance >= 2.0" arcsec (retained 99.4%)
#     Retrieved 2423772 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0410" Std=0.0548" Min=0.0000" Max=1.2339"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.2234" Std=0.8790" Min=-1.8810" Max=2.0652"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1339705 points:
#       Mean=0.0413" Std=0.0479" Min=0.0000" Max=1.2599"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1339705 points:
#       Mean=0.8936" Std=0.4301" Min=-1.8810" Max=2.0652"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 792758 points:
#       Mean=0.0423" Std=0.0483" Min=0.0000" Max=0.7353"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 792758 points:
#       Mean=-0.8330" Std=0.3497" Min=-1.6926" Max=1.4228"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20190131_232118_to_20190201_065918.json
# ✓ hecto Run 1: hecto_20190127_070059_to_20190131_232018.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30561
#   Timestamps: 30561
#   Rolling StdDev: 30561
#   Altitudes: 30561
#   Alt Velocities: 30561
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 31512
#   Timestamps: 31512
#   Rolling StdDev: 31512
#   Altitudes: 31512
#   Alt Velocities: 31512
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30102
#   Timestamps: 30102
#   Rolling StdDev: 30102
#   Altitudes: 30102
#   Alt Velocities: 30102
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30105
#   Timestamps: 30105
#   Rolling StdDev: 30105
#   Altitudes: 30105
#   Alt Velocities: 30105
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30219
#   Timestamps: 30219
#   Rolling StdDev: 30219
#   Altitudes: 30219
#   Alt Velocities: 30219
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30105
#   Timestamps: 30105
#   Rolling StdDev: 30105
#   Altitudes: 30105
#   Alt Velocities: 30105
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 22:57:21
# End DateTime:   2026-02-12 22:59:23
# Elapsed Time:   0h 2m 1s
# ================================================================================
