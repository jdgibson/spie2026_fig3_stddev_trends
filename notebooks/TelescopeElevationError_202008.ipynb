# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2020-08-01 00:00:00'
end_datetime = '2020-08-31 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 17:56:49
# Analysis period: 2020-08-01 00:00:00 to 2020-08-31 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2020-08-01 00:00:00 to 2020-08-31 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1596265200000, end_timestamp_ms=1598943599000
# Retrieved 534757 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 1 records, 2020-08-18 18:11:47.050000 to 2020-08-18 18:11:47.050000
#   BINOSPEC: 426314 records, 2020-08-01 00:00:00.001000 to 2020-08-25 17:19:50.116000
#   HECTO: 108442 records, 2020-08-25 17:19:55.164000 to 2020-08-31 23:59:54.992000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2020-08-01 00:00:00.001000
#     Last observed:  2020-08-25 17:19:50.116000
#     Duration:       24 days, 17:19:50.115000
#
#   HECTO:
#     First observed: 2020-08-25 17:19:55.164000
#     Last observed:  2020-08-31 23:59:54.992000
#     Duration:       6 days, 6:39:59.828000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-08-01 00:00:00 to 2020-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1596265200000, end_timestamp_ms=1598943599000, instrument=NA
# Retrieved 1 records from hexapod_mini_instrument table
# Processed 1 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2020-08-19 01:11:47.050000 to 2020-08-19 01:11:47.050000 (duration: 0 days 00:00:00)
#   ✓ NA: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-08-01 00:00:00 to 2020-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1596265200000, end_timestamp_ms=1598943599000, instrument=binospec
# Retrieved 426314 records from hexapod_mini_instrument table
# Processed 426314 instrument records
# Identified 1 observing runs:
#   Run 1: 2020-08-01 07:00:00.001000 to 2020-08-26 00:19:50.116000 (duration: 24 days 17:19:50.115000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-08-01 00:00:00 to 2020-08-31 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1596265200000, end_timestamp_ms=1598943599000, instrument=hecto
# Retrieved 108442 records from hexapod_mini_instrument table
# Processed 108442 instrument records
#
# Identified 1 observing runs:
#   Run 1: 2020-08-26 00:19:55.164000 to 2020-09-01 06:59:54.992000 (duration: 6 days 06:39:59.828000)
#   ✓ HECTO: 1 observing runs
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 1 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2020-08-01 07:00:00.001000 to 2020-08-26 00:19:50.116000
#     Duration: 24 days 17:19:50.115000
#     Filtered 36586 points in 10s intervals with variance >= 2.0" arcsec (retained 98.5%)
#     Retrieved 2420484 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0478" Std=0.0488" Min=0.0000" Max=1.3699"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.3817" Std=0.7778" Min=-2.1853" Max=1.8783"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 539034 points:
#       Mean=0.0579" Std=0.0464" Min=0.0000" Max=1.0337"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 539034 points:
#       Mean=0.8197" Std=0.3750" Min=-1.3416" Max=1.8783"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1525113 points:
#       Mean=0.0508" Std=0.0484" Min=0.0000" Max=0.6901"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1525113 points:
#       Mean=-0.8728" Std=0.3343" Min=-2.1853" Max=1.2556"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2020-08-26 00:19:55.164000 to 2020-09-01 06:59:54.992000
#     Duration: 6 days 06:39:59.828000
#     No valid RMS records after filtering
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 1
#   BINOSPEC: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20200801_070000_to_20200826_001950.json
#
# ✓ Saved statistics for 1 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30051
#   Timestamps: 30051
#   Rolling StdDev: 30051
#   Altitudes: 30051
#   Alt Velocities: 30051
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30513
#   Timestamps: 30513
#   Rolling StdDev: 30513
#   Altitudes: 30513
#   Alt Velocities: 30513
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30102
#   Timestamps: 30102
#   Rolling StdDev: 30102
#   Altitudes: 30102
#   Alt Velocities: 30102
# ================================================================================
# Generated 3 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 17:56:49
# End DateTime:   2026-02-12 17:59:59
# Elapsed Time:   0h 3m 9s
# ================================================================================
