# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2023-02-01 00:00:00'
end_datetime = '2023-02-28 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 20:26:45
# Analysis period: 2023-02-01 00:00:00 to 2023-02-28 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2023-02-01 00:00:00 to 2023-02-28 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1675234800000, end_timestamp_ms=1677653999000
# Retrieved 483574 total records from hexapod_mini_instrument
# Found 2 unique instrument(s)
#   BINOSPEC: 213524 records, 2023-02-16 15:15:44.666000 to 2023-02-28 23:59:56.020000
#   HECTO: 270050 records, 2023-02-01 00:00:02.914000 to 2023-02-16 15:15:39.614000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2023-02-16 15:15:44.666000
#     Last observed:  2023-02-28 23:59:56.020000
#     Duration:       12 days, 8:44:11.354000
#
#   HECTO:
#     First observed: 2023-02-01 00:00:02.914000
#     Last observed:  2023-02-16 15:15:39.614000
#     Duration:       15 days, 15:15:36.700000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-02-01 00:00:00 to 2023-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1675234800000, end_timestamp_ms=1677653999000, instrument=binospec
# Retrieved 213524 records from hexapod_mini_instrument table
# Processed 213524 instrument records
# Identified 1 observing runs:
#   Run 1: 2023-02-16 22:15:44.666000 to 2023-03-01 06:59:56.020000 (duration: 12 days 08:44:11.354000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2023-02-01 00:00:00 to 2023-02-28 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1675234800000, end_timestamp_ms=1677653999000, instrument=hecto
# Retrieved 270050 records from hexapod_mini_instrument table
# Processed 270050 instrument records
# Identified 1 observing runs:
#   Run 1: 2023-02-01 07:00:02.914000 to 2023-02-16 22:15:39.614000 (duration: 15 days 15:15:36.700000)
#   ✓ HECTO: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2023-02-16 22:15:44.666000 to 2023-03-01 06:59:56.020000
#     Duration: 12 days 08:44:11.354000
#     Filtered 8582 points in 10s intervals with variance >= 2.0" arcsec (retained 96.9%)
#     Retrieved 275786 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0519" Std=0.0449" Min=0.0000" Max=0.7264"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.4830" Std=1.1083" Min=-1.5340" Max=2.3037"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 183149 points:
#       Mean=0.0602" Std=0.0490" Min=0.0000" Max=0.7363"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 183149 points:
#       Mean=1.2176" Std=0.1973" Min=-0.4216" Max=2.3037"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 82619 points:
#       Mean=0.0370" Std=0.0158" Min=0.0127" Max=0.2250"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 82619 points:
#       Mean=-1.1288" Std=0.2727" Min=-1.5340" Max=-0.2390"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2023-02-01 07:00:02.914000 to 2023-02-16 22:15:39.614000
#     Duration: 15 days 15:15:36.700000
#     Filtered 112795 points in 10s intervals with variance >= 2.0" arcsec (retained 97.2%)
#     Retrieved 3994601 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0573" Std=0.0681" Min=0.0000" Max=1.3295"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.1392" Std=0.8775" Min=-2.2840" Max=2.4651"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1905701 points:
#       Mean=0.0715" Std=0.0772" Min=0.0000" Max=0.8923"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1905701 points:
#       Mean=0.8705" Std=0.3880" Min=-1.4391" Max=2.4651"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 1219839 points:
#       Mean=0.0593" Std=0.0559" Min=0.0000" Max=1.1102"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 1219839 points:
#       Mean=-0.9347" Std=0.4250" Min=-2.2840" Max=1.6507"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 1: binospec_20230216_221544_to_20230301_065956.json
# ✓ hecto Run 1: hecto_20230201_070002_to_20230216_221539.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30834
#   Timestamps: 30834
#   Rolling StdDev: 30834
#   Altitudes: 30834
#   Alt Velocities: 30834
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 30525
#   Timestamps: 30525
#   Rolling StdDev: 30525
#   Altitudes: 30525
#   Alt Velocities: 30525
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 30984
#   Timestamps: 30984
#   Rolling StdDev: 30984
#   Altitudes: 30984
#   Alt Velocities: 30984
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30015
#   Timestamps: 30015
#   Rolling StdDev: 30015
#   Altitudes: 30015
#   Alt Velocities: 30015
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30092
#   Timestamps: 30092
#   Rolling StdDev: 30092
#   Altitudes: 30092
#   Alt Velocities: 30092
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30246
#   Timestamps: 30246
#   Rolling StdDev: 30246
#   Altitudes: 30246
#   Alt Velocities: 30246
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 20:26:45
# End DateTime:   2026-02-12 20:33:46
# Elapsed Time:   0h 7m 1s
# ================================================================================
