# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2020-06-01 00:00:00'
end_datetime = '2020-06-30 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 17:53:22
# Analysis period: 2020-06-01 00:00:00 to 2020-06-30 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2020-06-01 00:00:00 to 2020-06-30 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1590994800000, end_timestamp_ms=1593586799000
# Retrieved 1941659 total records from hexapod_mini_instrument
# Found 3 unique instrument(s)
#   NA: 85 records, 2020-06-02 05:37:26.247000 to 2020-06-30 15:24:24.533000
#   BINOSPEC: 45327 records, 2020-06-01 00:00:01.642000 to 2020-06-03 15:28:16.117000
#   HECTO: 1896247 records, 2020-06-03 15:28:16.191000 to 2020-06-30 23:59:58.132000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2020-06-01 00:00:01.642000
#     Last observed:  2020-06-03 15:28:16.117000
#     Duration:       2 days, 15:28:14.475000
#
#   HECTO:
#     First observed: 2020-06-03 15:28:16.191000
#     Last observed:  2020-06-30 23:59:58.132000
#     Duration:       27 days, 8:31:41.941000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-06-01 00:00:00 to 2020-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1590994800000, end_timestamp_ms=1593586799000, instrument=NA
# Retrieved 85 records from hexapod_mini_instrument table
# Processed 85 instrument records
#
# Identified 6 observing runs:
#   Run 1: 2020-06-02 12:37:26.247000 to 2020-06-02 12:38:21.715000 (duration: 0 days 00:00:55.468000)
#   Run 2: 2020-06-13 23:39:23.118000 to 2020-06-13 23:39:23.118000 (duration: 0 days 00:00:00)
#   Run 3: 2020-06-14 04:18:43.299000 to 2020-06-14 04:20:55.708000 (duration: 0 days 00:02:12.409000)
#   Run 4: 2020-06-19 15:29:01.055000 to 2020-06-19 15:29:01.055000 (duration: 0 days 00:00:00)
#   Run 5: 2020-06-30 11:50:53.848000 to 2020-06-30 11:51:15.162000 (duration: 0 days 00:00:21.314000)
#   Run 6: 2020-06-30 22:04:46.208000 to 2020-06-30 22:24:24.533000 (duration: 0 days 00:19:38.325000)
#   ✓ NA: 6 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-06-01 00:00:00 to 2020-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1590994800000, end_timestamp_ms=1593586799000, instrument=binospec
# Retrieved 45327 records from hexapod_mini_instrument table
# Processed 45327 instrument records
# Identified 1 observing runs:
#   Run 1: 2020-06-01 07:00:01.642000 to 2020-06-03 22:28:16.117000 (duration: 2 days 15:28:14.475000)
#   ✓ BINOSPEC: 1 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2020-06-01 00:00:00 to 2020-06-30 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1590994800000, end_timestamp_ms=1593586799000, instrument=hecto
# Retrieved 1896247 records from hexapod_mini_instrument table
# Processed 1896247 instrument records
# Identified 1 observing runs:
#   Run 1: 2020-06-03 22:28:16.191000 to 2020-07-01 06:59:58.132000 (duration: 27 days 08:31:41.941000)
#   ✓ HECTO: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: NA
# ======================================================================
# Analyzing 6 observing run(s) for NA:
#   Run 1: Skipped (duration 0 days 00:00:55.468000 is less than 1.0 hours)
#   Run 2: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 3: Skipped (duration 0 days 00:02:12.409000 is less than 1.0 hours)
#   Run 4: Skipped (duration 0 days 00:00:00 is less than 1.0 hours)
#   Run 5: Skipped (duration 0 days 00:00:21.314000 is less than 1.0 hours)
#   Run 6: Skipped (duration 0 days 00:19:38.325000 is less than 1.0 hours)
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 1 observing run(s) for binospec:
#   Run 1: 2020-06-01 07:00:01.642000 to 2020-06-03 22:28:16.117000
#     Duration: 2 days 15:28:14.475000
#     No valid RMS records after filtering
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2020-06-03 22:28:16.191000 to 2020-07-01 06:59:58.132000
#     Duration: 27 days 08:31:41.941000
#     Filtered 164391 points in 10s intervals with variance >= 2.0" arcsec (retained 97.7%)
#     Retrieved 7306023 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0862" Std=0.1028" Min=0.0000" Max=1.3108"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4607" Std=0.8706" Min=-2.7131" Max=2.2854"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1634993 points:
#       Mean=0.0746" Std=0.0671" Min=0.0000" Max=1.2856"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1634993 points:
#       Mean=0.9089" Std=0.4233" Min=-1.8870" Max=2.2854"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 4795109 points:
#       Mean=0.1048" Std=0.1150" Min=0.0000" Max=0.8186"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 4795109 points:
#       Mean=-0.9844" Std=0.3436" Min=-2.7131" Max=1.3459"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 1
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ hecto Run 1: hecto_20200603_222816_to_20200701_065958.json
#
# ✓ Saved statistics for 1 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30009
#   Timestamps: 30009
#   Rolling StdDev: 30009
#   Altitudes: 30009
#   Alt Velocities: 30009
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30093
#   Timestamps: 30093
#   Rolling StdDev: 30093
#   Altitudes: 30093
#   Alt Velocities: 30093
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30033
#   Timestamps: 30033
#   Rolling StdDev: 30033
#   Altitudes: 30033
#   Alt Velocities: 30033
# ================================================================================
# Generated 3 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 17:53:22
# End DateTime:   2026-02-12 18:13:48
# Elapsed Time:   0h 20m 26s
# ================================================================================
