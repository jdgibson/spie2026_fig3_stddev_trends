# %%
# Cell 1: Setup
import sys, os
sys.path.insert(0, os.getcwd())
from telescope_notebook_runner import run_analysis

# Cell 2: Markdown
# Telescope Elevation Error Analysis

# Cell 3: Configuration
start_datetime = '2024-02-01 00:00:00'
end_datetime = '2024-02-29 23:59:59'

# Configuration: Enable JSON output for individual run statistics
config = {
    'save_run_statistics_json': True,  # Save individual run statistics to JSON files
    'json_output_dir': os.path.join(os.getcwd(), 'json'),  # Output directory for JSON files
}

# Cell 4: Run
results = run_analysis(start_datetime, end_datetime, **config)
# Out:
# ================================================================================
#   TELESCOPE ELEVATION ERROR ANALYSIS
# ================================================================================
# Start DateTime: 2026-02-12 21:16:56
# Analysis period: 2024-02-01 00:00:00 to 2024-02-29 23:59:59
#
# Querying all instruments on telescope during analysis period...
#
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying all instruments and timestamps from 2024-02-01 00:00:00 to 2024-02-29 23:59:59
# SQL Query: Fetching all instruments and timestamps in single query...
# Parameters: start_timestamp_ms=1706770800000, end_timestamp_ms=1709276399000
# Retrieved 361632 total records from hexapod_mini_instrument
# Found 2 unique instrument(s)
#   BINOSPEC: 49288 records, 2024-02-19 10:36:48.862000 to 2024-02-29 23:59:56.286000
#   HECTO: 312344 records, 2024-02-20 13:04:10.321000 to 2024-02-29 15:53:44.197000
#
# ======================================================================
# INSTRUMENTS ON TELESCOPE
# ======================================================================
#
#   BINOSPEC:
#     First observed: 2024-02-19 10:36:48.862000
#     Last observed:  2024-02-29 23:59:56.286000
#     Duration:       10 days, 13:23:07.424000
#
#   HECTO:
#     First observed: 2024-02-20 13:04:10.321000
#     Last observed:  2024-02-29 15:53:44.197000
#     Duration:       9 days, 2:49:33.876000
#
# ======================================================================
#
# Preparing observing runs data...
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-02-01 00:00:00 to 2024-02-29 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1706770800000, end_timestamp_ms=1709276399000, instrument=binospec
# Retrieved 49288 records from hexapod_mini_instrument table
# Processed 49288 instrument records
# Identified 2 observing runs:
#   Run 1: 2024-02-19 17:36:48.862000 to 2024-02-20 20:04:07.383000 (duration: 1 days 02:27:18.521000)
#   Run 2: 2024-02-29 22:53:45.904000 to 2024-03-01 06:59:56.286000 (duration: 0 days 08:06:10.382000)
#   ✓ BINOSPEC: 2 observing runs
# Connecting to measurements database at mariadb.mmto.arizona.edu...
# Successfully connected to MariaDB database
# Querying hexapod_mini_instrument data from 2024-02-01 00:00:00 to 2024-02-29 23:59:59
# SQL Query: SELECT timestamp, value
#         FROM hexapod_mini_instrument
#         WHERE timestamp >= %s AND timestamp <= %s AND value = %s
#         ORDER BY timestamp ASC
# Parameters: start_timestamp_ms=1706770800000, end_timestamp_ms=1709276399000, instrument=hecto
# Retrieved 312344 records from hexapod_mini_instrument table
# Processed 312344 instrument records
# Identified 1 observing runs:
#   Run 1: 2024-02-20 20:04:10.321000 to 2024-02-29 22:53:44.197000 (duration: 9 days 02:49:33.876000)
#   ✓ HECTO: 1 observing runs
#
# Running comprehensive analysis pipeline...
#
# ================================================================================
# QUERYING HEXAPOD MINI INSTRUMENT DATA
# ================================================================================
#
# ======================================================================
# PROCESSING: BINOSPEC
# ======================================================================
# Analyzing 2 observing run(s) for binospec:
#   Run 1: 2024-02-19 17:36:48.862000 to 2024-02-20 20:04:07.383000
#     Duration: 1 days 02:27:18.521000
#     No valid RMS records after filtering
#   Run 2: 2024-02-29 22:53:45.904000 to 2024-03-01 06:59:56.286000
#     Duration: 0 days 08:06:10.382000
#     Filtered 1550 points in 10s intervals with variance >= 2.0" arcsec (retained 99.5%)
#     Retrieved 323550 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0473" Std=0.0254" Min=0.0000" Max=0.8579"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=-0.4152" Std=0.5057" Min=-1.4676" Max=0.9425"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 43864 points:
#       Mean=0.0472" Std=0.0195" Min=0.0120" Max=0.2565"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 43864 points:
#       Mean=0.4904" Std=0.2594" Min=-0.7958" Max=0.9425"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 218365 points:
#       Mean=0.0498" Std=0.0251" Min=0.0000" Max=0.6264"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 218365 points:
#       Mean=-0.6908" Std=0.2761" Min=-1.4676" Max=0.7929"
#
# Successfully analyzed 1 run(s) for binospec
#
# ======================================================================
# PROCESSING: HECTO
# ======================================================================
# Analyzing 1 observing run(s) for hecto:
#   Run 1: 2024-02-20 20:04:10.321000 to 2024-02-29 22:53:44.197000
#     Duration: 9 days 02:49:33.876000
#     Filtered 15396 points in 10s intervals with variance >= 2.0" arcsec (retained 99.1%)
#     Retrieved 1655548 valid RMS records (before filtering)
#     *** PRIMARY METRIC - ROLLING STDDEV (total):
#       Mean=0.0368" Std=0.0321" Min=0.0000" Max=1.0601"
#     SECONDARY METRIC - ELEVATION RMS ERROR (total):
#       Mean=0.3170" Std=0.6931" Min=-1.4597" Max=1.6807"
#     *** PRIMARY METRIC - ROLLING STDDEV (up) - 1044522 points:
#       Mean=0.0384" Std=0.0357" Min=0.0000" Max=0.5690"
#     SECONDARY METRIC - ELEVATION RMS ERROR (up) - 1044522 points:
#       Mean=0.7525" Std=0.3248" Min=-1.1275" Max=1.6807"
#     *** PRIMARY METRIC - ROLLING STDDEV (down) - 410238 points:
#       Mean=0.0429" Std=0.0253" Min=0.0000" Max=0.6893"
#     SECONDARY METRIC - ELEVATION RMS ERROR (down) - 410238 points:
#       Mean=-0.6939" Std=0.2961" Min=-1.4597" Max=1.0008"
#
# Successfully analyzed 1 run(s) for hecto
#
# ======================================================================
# DATA COLLECTION COMPLETE
# ======================================================================
# Total instruments with data: 2
#   BINOSPEC: 1 run(s)
#   HECTO: 1 run(s)
# ======================================================================
#
# ================================================================================
#   SAVING INDIVIDUAL RUN STATISTICS TO JSON
# ================================================================================
# ✓ binospec Run 2: binospec_20240229_225345_to_20240301_065956.json
# ✓ hecto Run 1: hecto_20240220_200410_to_20240229_225344.json
#
# ✓ Saved statistics for 2 run(s) to /Users/jdgibson/git/spie2026_alterr/telescope-elevation-notebooks/notebooks/json
#
#
# ================================================================================
#   GENERATING INDIVIDUAL INSTRUMENT TIME-SERIES PLOTS
# ================================================================================
# Generating time-series plots with RMS and StdDev by direction (TOTAL, UP, DOWN)...
# ================================================================================
# Plot data array lengths for BINOSPEC (BOTH (Total)):
#   RMS Errors: 30189
#   Timestamps: 30189
#   Rolling StdDev: 30189
#   Altitudes: 30189
#   Alt Velocities: 30189
# Plot data array lengths for BINOSPEC (UP (Elevation Increasing)):
#   RMS Errors: 32898
#   Timestamps: 32898
#   Rolling StdDev: 32898
#   Altitudes: 32898
#   Alt Velocities: 32898
# Plot data array lengths for BINOSPEC (DOWN (Elevation Decreasing)):
#   RMS Errors: 31197
#   Timestamps: 31197
#   Rolling StdDev: 31197
#   Altitudes: 31197
#   Alt Velocities: 31197
# Plot data array lengths for HECTO (BOTH (Total)):
#   RMS Errors: 30003
#   Timestamps: 30003
#   Rolling StdDev: 30003
#   Altitudes: 30003
#   Alt Velocities: 30003
# Plot data array lengths for HECTO (UP (Elevation Increasing)):
#   RMS Errors: 30132
#   Timestamps: 30132
#   Rolling StdDev: 30132
#   Altitudes: 30132
#   Alt Velocities: 30132
# Plot data array lengths for HECTO (DOWN (Elevation Decreasing)):
#   RMS Errors: 30018
#   Timestamps: 30018
#   Rolling StdDev: 30018
#   Altitudes: 30018
#   Alt Velocities: 30018
# ================================================================================
# Generated 6 time-series plot figure(s)
# Each instrument now has 3 figures (TOTAL, UP, DOWN)
#
# Plot Structure (3 rows × 2 columns):
#   Row 1 (Top):       RMS Error (left) | Rolling StdDev (right)
#   Row 2 (Middle):    Telescope Altitude (left) | Telescope Altitude (right)
#   Row 3 (Bottom):    Altitude Velocity from mount_mini_velalt (left & right)
#
# Detailed Information:
#   - Altitude velocity data queried from measurements.mount_mini_velalt table
#   - Velocity data resampled to match RMS error measurement timestamps
#   - X-axis labels formatted as dates (YYYY-MM-DD) with 45-degree rotation
#   - All subplots share aligned time axes for easy cross-reference
#   - Rolling StdDev uses adaptive window size (~1% of dataset)
# ================================================================================
# ✓ Individual instrument plots complete
#
# ================================================================================
#   GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
#
# ================================================================================
# GENERATING SUMMARY RESULTS VISUALIZATIONS
# ================================================================================
# ✓ Summary statistics overview plots generated
# ✓ Summary plots complete
#
# ================================================================================
#   ANALYSIS COMPLETED
# ================================================================================
# Start DateTime: 2026-02-12 21:16:56
# End DateTime:   2026-02-12 21:18:17
# Elapsed Time:   0h 1m 21s
# ================================================================================
